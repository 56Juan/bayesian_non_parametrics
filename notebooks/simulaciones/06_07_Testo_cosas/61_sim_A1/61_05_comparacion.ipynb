# %% [markdown]
# # 61_05 — Modelos de referencia · Escenario A-1 · **barrido en $M$**
#
# Paso **3c**, posterior a `61_04_evaluacion`. El PSBPM-FD contra sus referencias,
# sobre el mismo conjunto de información y con **las mismas métricas que el
# `61_04`**: si los dos notebooks midieran cosas distintas, la comparación entre
# modelos no sería la misma comparación que la del barrido en $M$.
#
# | Sección | Qué responde |
# |---|---|
# | 1 | imports, rutas y constantes |
# | 2 | validaciones: mismo corte, mismas covariables, mismo objetivo para todos |
# | 3.1 | **FAR(1) sobre los coeficientes B-spline**, en la métrica $L^2$ (vía Gram) |
# | 3.2 | RF y GBT sobre los coeficientes FPCA, los mismos que usa el PSBPM-FD |
# | 3.3 | las dos líneas base |
# | 3.4 | predicción puntual del PSBPM-FD, recalculada desde las trazas |
# | 4 | **Bloque A** (MAE, RMSE, error máximo) — todos los modelos |
# | 5 | **Bloque B** (Winkler, cobertura simultánea, PICP, MPIW) — sólo FAR y PSBPM-FD |
# | 6 | Bloque A: % de ventanas ganadas y cuánto mejor es cada modelo |
# | 7 | Bloque B: lo mismo, sobre las bandas |
# | 8 | resumen: mínimo, máximo y promedio de cada métrica sobre la ventana |
# | 9 | los 5 orígenes mejor y peor predichos, con las dos bandas superpuestas |

# %% [markdown]
# ## 1. Imports, rutas y artefactos

# %%
import sys
import json as _json
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor

from model_psbp_fd.pipelines import (
    cargar_curvas, cargar_curvas_true, cargar_fpca, cargar_estandarizador,
    cargar_datasets_ar, cargar_hiperparametros, cargar_config_evaluacion,
)
from model_psbp_fd.functions_models import DataStandardizer
from model_psbp_fd.models.pspb_fd_v3 import (
    ruta_traza, ModeloTraza, curva_media_desde_scores,
)
from model_psbp_fd.fit import (
    mise, ventana_movil_funcional,
    # Bloque A: las tres normas del mismo error, para TODOS los modelos
    normas_error_por_origen,
    # Bloque B: intervalo implicado por el modelo, y sus métricas
    residuos_para_banda, banda_predictiva_modelo, sigma_residual,
    resumen_intervalo, indicador_cobertura, indicador_cobertura_simultanea,
)
from model_psbp_fd.graphics import plot_ventana_movil
from model_psbp_fd.utils import get_project_root

plt.style.use("seaborn-v0_8-darkgrid")
# %matplotlib inline

# %%
PROJECT_ROOT = get_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# [CONFIG]
BASENAME, ESCENARIO_ID, REPLICA_ID = "escenario_61", 1, 1
M_FPCA_LIST = (1, 2, 3,4)
# Las 10 metricas del marco teorico 02_02_03, en su orden. No se agregan otras.
METRICAS_A = [
    (u"1. MAE  (L^1)",                     "mae_f"),
    (u"2. RMSE (L^2)",                     "rmse_f"),
    (u"3. E_max promedio por curva",       "linf_medio"),
    (u"4. E_max peor de la ventana",       "linf_max"),
]
METRICAS_B = [
    (u"5. MPIW",                           "mpiw"),
    (u"6. PICP puntual",                   "picp"),
    (u"7. PICPB curva completa",           "picp_simultaneo"),
    (u"8. Winkler",                        "winkler"),
    (u"9. Winkler max promedio",           "winkler_max_medio"),
    (u"10. Winkler max peor ventana",      "winkler_max_glob"),
]
METRICAS_A_COLS = [c for _, c in METRICAS_A]
METRICAS_B_COLS = [c for _, c in METRICAS_B]

# [CONFIG] §9: por que metrica se eligen los origenes extremos, cuantos, y
# que dos bandas se contrastan curva a curva.
METRICA_SEL_IC = "rmse_f"     # una de METRICAS_A_COLS
N_EXTREMOS     = 5
BANDA_A_CONTRASTAR = ("FAR", "PSBPM-FD (predictiva")   # prefijos, en orden

PESOS_TAU = None    

NIVEL_IC   = 0.95    # debe coincidir con el `nivel_credibilidad` del _04
IC_POR_TAU = True    # sigma_eps(tau) punto a punto: la banda hereda la forma
                     # de la innovacion funcional. False = ancho constante.
IC_CORRECCION_ESTIMACION = True   # infla sigma por sqrt(1 + kn/n_train), la
                     # correccion de primer orden por rho estimado y no conocido

# Al PSBPM-FD se le construye la MISMA banda ademas de la suya bayesiana, de
# modo que la tabla tenga tres filas y se pueda separar "gana por el modelo" de
# "gana por el mecanismo de intervalo". Sin esa fila, la comparacion mezcla las
# dos cosas y no hay forma de saber cual manda.
IC_PSBP_TAMBIEN_GAUSSIANA = True

M_FPCA_LIST = tuple(int(m) for m in M_FPCA_LIST)
EXPERIMENT_BASE = f"{BASENAME}_{ESCENARIO_ID}_r{REPLICA_ID:02d}"


def experiment_id(M: int) -> str:
    return f"{EXPERIMENT_BASE}_m{M:02d}"


def rutas(M: int) -> dict:
    eid = experiment_id(M)
    p = {
        "raw":          PROJECT_ROOT / "data" / "simulaciones" / "raw" / eid,
        "functional":   PROJECT_ROOT / "data" / "simulaciones" / "processed" / "functional" / eid,
        "predict":      PROJECT_ROOT / "data" / "simulaciones" / "processed" / "predict" / eid,
        "out_report":   PROJECT_ROOT / "reports" / "simulaciones" / eid,
        "out_artefact": PROJECT_ROOT / "artefact" / "simulaciones" / eid,
    }
    for r in p.values():
        r.mkdir(parents=True, exist_ok=True)
    return p


PATHS_M      = {M: rutas(M) for M in M_FPCA_LIST}
PATH_BARRIDO = PROJECT_ROOT / "reports" / "simulaciones" / f"{EXPERIMENT_BASE}_barrido_M"
PATH_BARRIDO.mkdir(parents=True, exist_ok=True)

# Este notebook NO pisa nada de 61_04: los _04 ocupan 50-65 según el escenario,
# éste escribe 70-75 en cada directorio de M, y 90-93 en el del barrido.
PREFIJO = 70

print(f"barrido en M : {list(M_FPCA_LIST)}")
for M in M_FPCA_LIST:
    print(f"  M={M}  ->  {experiment_id(M)}   (archivos {PREFIJO}-{PREFIJO+5})")
print(f"salidas cruzadas (§8) : {PATH_BARRIDO}   (archivos 90-93)")
# Out:
# barrido en M : [1, 2, 3, 4]
#   M=1  ->  escenario_61_1_r01_m01   (archivos 70-75)
#   M=2  ->  escenario_61_1_r01_m02   (archivos 70-75)
#   M=3  ->  escenario_61_1_r01_m03   (archivos 70-75)
#   M=4  ->  escenario_61_1_r01_m04   (archivos 70-75)
# salidas cruzadas (§8) : C:\Users\56jua\Desktop\git_tesis\bayesian_non_parametrics-1\reports\simulaciones\escenario_61_1_r01_barrido_M   (archivos 90-93)

# %%
EST, saltados = {}, []

for M in M_FPCA_LIST:
    P = PATHS_M[M]
    if not (P["functional"] / "datasets_manifest.json").exists():
        saltados.append((M, "sin datasets_manifest.json - falta correr 61_01"))
        continue

    dfs_train, manifest = cargar_datasets_ar(P, bloque="train")
    dfs_test,  _        = cargar_datasets_ar(P, bloque="test")
    hp_json     = cargar_hiperparametros(P)
    eval_config = cargar_config_evaluacion(P)

    component_idx = manifest["component_idx"]
    n_components  = len(component_idx)
    assert n_components == M, (
        f"{experiment_id(M)} declara M={M} pero su manifest tiene "
        f"{n_components} componentes.")
    assert manifest["scores_scale"] == "raw_fpca_scores"

    objetivo = eval_config.get("objetivo_evaluacion", "curva_verdadera")
    assert objetivo == "curva_verdadera", (
        f"[M={M}] objetivo_evaluacion={objetivo!r}. Este notebook compara "
        "contra la curva verdadera; con otro objetivo las cifras no serían "
        "las del _04.")

    EST[M] = {
        "paths": P, "eid": experiment_id(M),
        "dfs_train": dfs_train, "dfs_test": dfs_test, "manifest": manifest,
        "hp_json": hp_json, "eval_config": eval_config,
        "component_idx": component_idx, "n_components": n_components,
        "cov_names": list(manifest["cov_names"]),
        "n_lags": int(manifest["n_lags"]),
        "T": int(manifest["T"]), "T0": int(manifest["T0"]),
        "n_iter": int(hp_json["n_iter"]),
        "mcmc_cfg": hp_json["mcmc_config"],
        "objetivo": objetivo,
        "modo_residuo": eval_config.get("modo_residuo", "ninguno"),
        "ventanas_w": list(eval_config.get("ventana_movil", {}).get("w", [20, 30, 40])),
    }

assert EST, "Ningún punto del barrido tiene datos. Ejecuta 61_01 primero."
for M, motivo in saltados:
    print(f"! M={M} saltado: {motivo}")

_comun = {M: (e["T"], e["T0"], e["n_lags"], e["objetivo"], e["modo_residuo"],
              tuple(e["ventanas_w"])) for M, e in EST.items()}
if len(set(_comun.values())) > 1:
    for M, v in _comun.items():
        print(f"  M={M}: {v}")
    raise AssertionError(
        "El barrido exige T, T0, n_lags, objetivo, modo_residuo y ventanas "
        "idénticos entre puntos.")

_M0        = next(iter(EST))
T          = EST[_M0]["T"]
T0         = EST[_M0]["T0"]
N_LAGS     = EST[_M0]["n_lags"]
OBJETIVO   = EST[_M0]["objetivo"]
MODO_RESIDUO = EST[_M0]["modo_residuo"]
VENTANAS_W = EST[_M0]["ventanas_w"]
W_COMP     = VENTANAS_W[len(VENTANAS_W) // 2]

print(f"\nT={T}  T0={T0}  n_lags={N_LAGS}  objetivo={OBJETIVO!r}  "
      f"modo_residuo={MODO_RESIDUO!r}")
print(f"anchos de ventana: {VENTANAS_W}   ·   referencia para las tablas: w={W_COMP}")
for M, e in EST.items():
    print(f"  M={M}: {e['n_components']} componentes · "
          f"{len(e['cov_names'])} covariables {e['cov_names']}")
# Out:
# T=1000  T0=700  n_lags=1  objetivo='curva_verdadera'  modo_residuo='ninguno'
# anchos de ventana: [20, 30, 40]   ·   referencia para las tablas: w=30
#   M=1: 1 componentes · 1 covariables ['fpc_1_lag1']
#   M=2: 2 componentes · 2 covariables ['fpc_1_lag1', 'fpc_2_lag1']
#   M=3: 3 componentes · 3 covariables ['fpc_1_lag1', 'fpc_2_lag1', 'fpc_3_lag1']
#   M=4: 4 componentes · 4 covariables ['fpc_1_lag1', 'fpc_2_lag1', 'fpc_3_lag1', 'fpc_4_lag1']

# %%
for M in EST:
    e, P = EST[M], EST[M]["paths"]

    fpca = cargar_fpca(P)
    _ver = fpca.verificar()
    assert _ver["todo_ok"], f"[M={M}] las identidades FPCA no se cumplen: {_ver}"

    std = cargar_estandarizador(P, DataStandardizer)
    X_obs, grilla = cargar_curvas(P)         # (T, G) con ruido de medición
    X_true        = cargar_curvas_true(P)    # (T, G) verdadera - el objetivo

    assert e["component_idx"] == list(range(fpca.M)), (
        "La reconstrucción funcional necesita el vector completo de scores en "
        f"orden; [M={M}] COMPONENT_IDX={e['component_idx']} y M={fpca.M}.")
    assert std.n_ajuste == T0, (
        f"[M={M}] el estandarizador se ajustó con n={std.n_ajuste} y T0={T0}: "
        "habría fuga del bloque de prueba.")

    e.update({"fpca": fpca, "std": std, "X_obs": X_obs, "X_true": X_true,
              "grilla": grilla, "M_fpca": fpca.M, "K": fpca.K,
              "SCORES": fpca.SCORES,
              "SCORES_STD": std.transform(fpca.SCORES),
              "var_explicada": float(fpca.meta["var_explained"])})
    print(f"M={M}  FPCA M={fpca.M} K={fpca.K}  ·  varianza explicada por las M "
          f"retenidas: {e['var_explicada']:.4%}")

for M in EST:
    assert np.allclose(EST[M]["X_true"], EST[_M0]["X_true"]), (
        f"[M={M}] las curvas verdaderas difieren de las de M={_M0}.")
grilla = EST[_M0]["grilla"]
X_true = EST[_M0]["X_true"]
print(f"\nOK los {len(EST)} puntos salen de la MISMA simulación: curvas "
      f"{X_true.shape}, grilla {grilla.shape}")
# Out:
# M=1  FPCA M=1 K=8  ·  varianza explicada por las M retenidas: 50.5650%
# M=2  FPCA M=2 K=8  ·  varianza explicada por las M retenidas: 64.5620%
# M=3  FPCA M=3 K=8  ·  varianza explicada por las M retenidas: 74.0083%
# M=4  FPCA M=4 K=8  ·  varianza explicada por las M retenidas: 81.2539%
#
# OK los 4 puntos salen de la MISMA simulación: curvas (1000, 75), grilla (75,)

# %% [markdown]
# ## 2. Validaciones para aplicar los modelos

# %%
# La serie de orígenes es común: T, T0 y n_lags no dependen de M.
t_orig   = np.arange(N_LAGS + 1, T + 1)      # tiempo del experimento, base-1
n_orig   = len(t_orig)
T0_orig  = T0 - N_LAGS                        # corte en el indexado de orígenes
es_train = t_orig <= T0
X_true_ev = X_true[N_LAGS:]                   # (n_orig, G) VERDADERA

print(f"orígenes evaluados : {n_orig}  (train {es_train.sum()} · "
      f"test {(~es_train).sum()})")
print(f"corte T0={T0}  ->  índice de origen T0_orig={T0_orig}")

for M in EST:
    e = EST[M]
    dfs_full = {k: pd.concat([e["dfs_train"][k], e["dfs_test"][k]],
                             ignore_index=True) for k in range(e["n_components"])}
    assert len(dfs_full[0]) == n_orig, f"[M={M}] {len(dfs_full[0])} != {n_orig}"

    # Objetivo (n_orig, M) en escala estandarizada, y matriz de diseño común.
    Y_obs = np.column_stack([dfs_full[k].iloc[:, 0].to_numpy(dtype=float)
                             for k in range(e["n_components"])])

    cols0 = list(dfs_full[0].columns[1:])
    for k in range(1, e["n_components"]):
        assert list(dfs_full[k].columns[1:]) == cols0, (
            f"[M={M}] la componente k={k} usa covariables distintas de la k=0; "
            "la matriz de diseño común deja de ser válida.")
    assert cols0 == e["cov_names"], (
        f"[M={M}] las columnas del dataset {cols0} no son cov_names "
        f"{e['cov_names']}.")

    Z = np.asarray(dfs_full[0].iloc[:, 1:], dtype=float)      # (n_orig, p)
    e.update({"dfs_full": dfs_full, "Y_obs": Y_obs, "Z": Z, "p_dis": Z.shape[1]})
    print(f"  M={M}: diseño Z {Z.shape}   objetivo Y {Y_obs.shape}")
# Out:
# orígenes evaluados : 999  (train 699 · test 300)
# corte T0=700  ->  índice de origen T0_orig=699
#   M=1: diseño Z (999, 1)   objetivo Y (999, 1)
#   M=2: diseño Z (999, 2)   objetivo Y (999, 2)
#   M=3: diseño Z (999, 3)   objetivo Y (999, 3)
#   M=4: diseño Z (999, 4)   objetivo Y (999, 4)

# %%
# Curvas de referencia y el piso de la representación, por M. El mapa
# scores->curva DETERMINISTA vive en el paquete (`curva_media_desde_scores`):
# es el caso "modo_residuo=ninguno" de PropagadorFuncional, sin muestreo.
for M in EST:
    e = EST[M]
    e["curvas_desde_scores_std"] = (
        lambda Y, e=e: curva_media_desde_scores(Y, e["fpca"], e["std"]))
    e["X_proj"] = e["fpca"].reconstruct(e["SCORES"])[N_LAGS:]

    # Control: reconstruir el objetivo observado debe dar exactamente X_proj.
    f = e["curvas_desde_scores_std"]
    assert np.allclose(f(e["Y_obs"]), e["X_proj"], atol=1e-8), (
        f"[M={M}] el mapa scores->curva no reproduce la proyección FPCA; "
        "revisar el estandarizador cargado.")

    e["MISE_TRUNC"] = {b: mise(X_true_ev[m], e["X_proj"][m], grilla)
                       for b, m in (("train", es_train), ("test", ~es_train))}

print("MISE del TRUNCAMIENTO FPCA (piso común a todos los modelos de cada M):")
print(f"{'M':>3}  {'train':>11}  {'test':>11}")
for M in EST:
    v = EST[M]["MISE_TRUNC"]
    print(f"{M:>3}  {v['train']:>11.6f}  {v['test']:>11.6f}")
print("  <- ningún modelo sobre esa representación puede bajar de ahí")
# Out:
# MISE del TRUNCAMIENTO FPCA (piso común a todos los modelos de cada M):
#   M        train         test
#   1     0.152289     0.151081
#   2     0.137044     0.136413
#   3     0.127530     0.127706
#   4     0.120339     0.120897
#   <- ningún modelo sobre esa representación puede bajar de ahí

# %% [markdown]
# ## 3. Los competidores

# %% [markdown]
# ### 3.1 FAR(1) sobre los COEFICIENTES B-spline, en la métrica $L^2$
#
# Se ajusta sobre los coeficientes de la representación B-spline, no sobre la
# curva en la grilla — un eje de comparación adicional respecto de RF, GBT y el
# PSBPM-FD, que trabajan sobre los $M$ scores FPCA.
#
# Como las B-spline no son ortonormales, el producto interno de dos curvas NO es
# el producto escalar de sus coeficientes: hay que pasar por la Gram de la base
# ($W$) para que la geometría sea la de $L^2$. La celda de abajo hace ese
# blanqueo y lo verifica con un `assert`; el porqué de cada paso —por qué $k_n$
# no es el orden del AR, por qué la cuadratura pasa a ser `"conteo"` una vez
# blanqueado— queda en los comentarios del código, para no repetirlo aquí en
# prosa.

# %%
from model_psbp_fd.fit.far_operador import (
    FAR1, seleccionar_kn)
from model_psbp_fd.pipelines import cargar_representacion
from model_psbp_fd.utils.linalg import safe_chol

# [CONFIG] Tope del barrido de kn. Ahora acota en K -el numero de funciones
# base-, no en L: el operador vive en el espacio de coeficientes.
KN_MAX = 12

# [CONFIG] estructura declarada del generador de este escenario, contra la
# que se contrasta la norma estimada. Es lo unico de esta seccion que cambia
# entre escenarios.

_p_sim0 = EST[_M0]["paths"]["raw"] / "simulation_config.json"
_diag0 = (_json.loads(_p_sim0.read_text(encoding="utf-8")).get("diagnostico", {})
          if _p_sim0.exists() else {})
HS_REFERENCIA = f"{float(_diag0['hs_oraculo_L2']):.4f}"
print(f"||A_oraculo||_HS (L^2) del generador = {HS_REFERENCIA}")
print(f"R^2 del oraculo de 1 rezago          = "
      f"{float(_diag0['r2_oraculo_1rezago']):.4f}")
print(f"R^2 del oraculo de pasado infinito   = "
      f"{float(_diag0['r2_oraculo_pasado_infinito_escalar']):.4f}   "
      "<- la brecha es lo que cuesta mirar UNA sola curva atras")

# [CONFIG] Criterio de far.cv con que se elige kn
CRITERIO_KN = "L2"

# La representacion B-spline es la MISMA en todos los puntos del barrido -la
# elige el GCV del _01 sobre las curvas
for M in EST:
    e = EST[M]
    e["fr"], e["THETA"], _ = cargar_representacion(e["paths"])

fr0     = EST[_M0]["fr"]
THETA0  = np.asarray(EST[_M0]["THETA"], dtype=float)     # (T, K)
W_GRAM  = np.asarray(fr0.gram_, dtype=float)             # (K, K)
L_GRAM  = safe_chol(W_GRAM)                              # W = L L^T

# Coordenadas blanqueadas: el producto escalar euclideo de estas filas ES el
# producto interno L^2 de las curvas que representan.
THETA_W = THETA0 @ L_GRAM                                # (T, K)

# Verificacion de que el cambio de coordenadas hace lo que dice: la norma L^2
# de cada curva calculada con la Gram debe coincidir con la norma euclidea de
# su fila blanqueada.
_n_gram = np.einsum("tk,kl,tl->t", THETA0, W_GRAM, THETA0)
_n_eucl = (THETA_W ** 2).sum(axis=1)
_err = float(np.max(np.abs(_n_gram - _n_eucl)) / max(np.max(_n_gram), 1e-300))
assert _err < 1e-8, (
    f"El blanqueo por la Gram no preserva la norma L^2 (error relativo "
    f"{_err:.2e}): revisar safe_chol o la orientacion de la factorizacion.")

print(f"base B-spline: K = {THETA0.shape[1]} funciones   ·   "
      f"cond(W) = {np.linalg.cond(W_GRAM):.2f}")
print(f"blanqueo por la Gram verificado: ||x||_L2 == ||theta_w||_2 "
      f"(error relativo max {_err:.2e})")
print("El FAR se estima en ESTAS coordenadas, donde euclideo = L^2.")
# Out:
# ||A_oraculo||_HS (L^2) del generador = 1.4345
# R^2 del oraculo de 1 rezago          = 0.2394
# R^2 del oraculo de pasado infinito   = 0.5169   <- la brecha es lo que cuesta mirar UNA sola curva atras
# base B-spline: K = 8 funciones   ·   cond(W) = 3.89
# blanqueo por la Gram verificado: ||x||_L2 == ||theta_w||_2 (error relativo max 7.45e-11)
# El FAR se estima en ESTAS coordenadas, donde euclideo = L^2.

# %%
_KN_TOPE = int(min(KN_MAX, THETA_W.shape[1]))
CV_KN = seleccionar_kn(THETA_W[:T0], kn_max=_KN_TOPE, pesos="conteo")
KN_ELEGIDO = {"L1": CV_KN.kn_L1, "L2": CV_KN.kn_L2,
              "Linf": CV_KN.kn_Linf}[CRITERIO_KN]

print(f"far.cv sobre coeficientes: hold-out de las ultimas "
      f"{CV_KN.n_validacion} curvas de train   ·   kn_max = {_KN_TOPE} (= K)")
print(f"{'kn':>4}  " + "  ".join(f"{c:>9}" for c in CV_KN.columnas[1:]))
for fila in CV_KN.tabla:
    marca = "  <-" if int(fila[0]) == KN_ELEGIDO else ""
    print(f"{int(fila[0]):>4}  " + "  ".join(f"{v:>9.4f}" for v in fila[1:]) + marca)
print(f"\nkn elegido por {CRITERIO_KN}: {KN_ELEGIDO}"
      f"   (L1 -> {CV_KN.kn_L1}, Linf -> {CV_KN.kn_Linf})")

_l2 = CV_KN.tabla[:, 2]
_planitud = float((_l2.max() - _l2.min()) / _l2.min())
print(f"amplitud relativa del criterio {CRITERIO_KN}: {_planitud:.2%}"
      + ("   <- PLANO: la eleccion de kn no es informativa, reportar la tabla"
         if _planitud < 0.05 else ""))
# Out:
# far.cv sobre coeficientes: hold-out de las ultimas 140 curvas de train   ·   kn_max = 8 (= K)
#   kn         L1         L2       Linf      L1max      L2max    Linfmax
#    1     0.0870     0.1044     0.1871     0.1211     0.1421     0.3564
#    2     0.0863     0.1037     0.1867     0.1161     0.1378     0.3621
#    3     0.0858     0.1032     0.1861     0.1153     0.1375     0.3619
#    4     0.0856     0.1032     0.1869     0.1146     0.1369     0.3578
#    5     0.0855     0.1031     0.1866     0.1135     0.1360     0.3548
#    6     0.0855     0.1031     0.1873     0.1125     0.1347     0.3497
#    7     0.0852     0.1030     0.1878     0.1099     0.1317     0.3399  <-
#    8     0.0853     0.1032     0.1878     0.1104     0.1323     0.3402
#
# kn elegido por L2: 7   (L1 -> 7, Linf -> 3)
# amplitud relativa del criterio L2: 1.36%   <- PLANO: la eleccion de kn no es informativa, reportar la tabla

# %%
# Ajuste del operador y prediccion a un paso, todo en coordenadas blanqueadas.
FAR_MOD = FAR1(kn=KN_ELEGIDO, pesos="conteo").fit(THETA_W[:T0])

_diag = FAR_MOD.diagnostico_kn()
print("operador estimado sobre los coeficientes (metrica L^2):")
for k, v in _diag.items():
    print(f"  {k:22s}: {v}")
print()
print("`condicion` = lambda_1 / lambda_kn es por lo que se esta dividiendo en la")
print("direccion mas debil retenida: anticipa la sensibilidad a kn antes de que")
print("se vea en el error.")

# Coeficientes rezagados: el origen t (base-1, t = N_LAGS+1..T) tiene como
# predictor la curva t-1, es decir el indice base-0 t-2.
_THETA_W_lag = THETA_W[N_LAGS - 1:T - 1]
assert _THETA_W_lag.shape[0] == n_orig, (_THETA_W_lag.shape, n_orig)

_THETA_W_pred = FAR_MOD.predict(_THETA_W_lag)          # (n_orig, K) blanqueado

# Vuelta a coeficientes: theta = theta_w L^{-1}, resuelto por triangular en vez
# de invertir la Gram.
THETA_PRED_FAR = np.linalg.solve(L_GRAM.T, _THETA_W_pred.T).T   # (n_orig, K)

# El FAR se EVALUA con la representacion completa -los K coeficientes B-spline-
# y NO truncado a M. 
X_PRED_FAR_GRILLA = fr0.reconstruct(THETA_PRED_FAR)     # (n_orig, G), K completo

# Curvas que NO pasan por la proyeccion a M de cada punto. Las consultan la
# Seccion 4 (Bloque A) y la 5 (Bloque B).
CURVA_DIRECTA = {"FAR": X_PRED_FAR_GRILLA}

# La proyeccion a M se conserva en el mismo formato que los demas modelos.
# NO es lo que se evalua.
for M in EST:
    e = EST[M]
    e["PRED"] = {}      # {nombre: (n_orig, M) en escala estandarizada}
    e["INFO"] = {}      # notas por modelo, para el resumen
    e["PRED"]["FAR"] = e["std"].transform(e["fpca"].transform(THETA_PRED_FAR))
    e["INFO"]["FAR"] = (f"coeficientes B-spline en L^2, K={THETA0.shape[1]} "
                        f"COMPLETO (no truncado a M), kn={KN_ELEGIDO} "
                        f"(far.cv/{CRITERIO_KN}), ||rho||_HS={_diag['norma_hs']:.4f}")
    e["far_hs"]   = float(_diag["norma_hs"])
    e["far_cond"] = float(_diag["condicion"])
    e["far_kn"]   = int(KN_ELEGIDO)

print(f"curva del FAR en la grilla: {X_PRED_FAR_GRILLA.shape}   "
      f"(K={THETA0.shape[1]} completo, INVARIANTE en M)")
# Out:
# operador estimado sobre los coeficientes (metrica L^2):
#   kn                    : 7
#   lambda_1              : 0.060507074064143525
#   lambda_min_retenido   : 0.0049824068283172256
#   condicion             : 12.144145620597461
#   varianza_retenida     : 0.959673225906336
#   norma_hs              : 0.862344336059118
#   n_curvas              : 700
#   n_pares               : 699
#
# `condicion` = lambda_1 / lambda_kn es por lo que se esta dividiendo en la
# direccion mas debil retenida: anticipa la sensibilidad a kn antes de que
# se vea en el error.
# curva del FAR en la grilla: (999, 75)   (K=8 completo, INVARIANTE en M)

# %% [markdown]
# ### 3.2 Modelos de aprendizaje automático
#
# Sin validación cruzada sobre el bloque de prueba, y con hiperparámetros fijos
# entre escenarios **y entre puntos del barrido**. Acotan cuánto de la ventaja
# del modelo propuesto es **no linealidad** y cuánto es la **mezcla**.

# %%
SEED_ML = 20260830

# [CONFIG] Hiperparametros fijos, sin ajuste por validacion cruzada, e

PARAMS_RF  = dict(n_estimators=500, min_samples_leaf=5, max_features="sqrt",
                  random_state=SEED_ML, n_jobs=-1)
PARAMS_GBT = dict(max_iter=300, learning_rate=0.05, max_leaf_nodes=15,
                  min_samples_leaf=10, early_stopping=False,
                  random_state=SEED_ML)

for M in EST:
    e = EST[M]
    y_fit = e["Y_obs"][es_train]
    if e["n_components"] == 1:
        y_fit = y_fit.ravel()
    rf = RandomForestRegressor(**PARAMS_RF).fit(e["Z"][es_train], y_fit)
    e["PRED"]["RF"] = np.asarray(rf.predict(e["Z"]), dtype=float).reshape(
        e["Y_obs"].shape)
    e["INFO"]["RF"] = (f"n_estimators={PARAMS_RF['n_estimators']}, "
                       f"leaf>={PARAMS_RF['min_samples_leaf']}")

    # HistGradientBoosting es univariante: un modelo por score, misma Z.
    pred_gbt = np.empty_like(e["Y_obs"])
    for k in range(e["n_components"]):
        g = HistGradientBoostingRegressor(**PARAMS_GBT)
        g.fit(e["Z"][es_train], e["Y_obs"][es_train, k])
        pred_gbt[:, k] = g.predict(e["Z"])
    e["PRED"]["GBT"] = pred_gbt
    e["INFO"]["GBT"] = (f"max_iter={PARAMS_GBT['max_iter']}, "
                        f"lr={PARAMS_GBT['learning_rate']}")

    print(f"M={M}: RF sobre {int(es_train.sum())} origenes x {e['p_dis']} "
          f"covariables (multisalida) · GBT {e['n_components']} modelos "
          "univariantes")
# Out:
# M=1: RF sobre 699 origenes x 1 covariables (multisalida) · GBT 1 modelos univariantes
# M=2: RF sobre 699 origenes x 2 covariables (multisalida) · GBT 2 modelos univariantes
# M=3: RF sobre 699 origenes x 3 covariables (multisalida) · GBT 3 modelos univariantes
# M=4: RF sobre 699 origenes x 4 covariables (multisalida) · GBT 4 modelos univariantes

# %% [markdown]
# ### 3.3 Las dos líneas base
#
# Sobre la serie completa de orígenes, para que entren en la misma tabla. La
# media incondicional es cero en escala estandarizada, y su RMSE cercano a 1 es
# la unidad de lectura.

# %%
for M in EST:
    e = EST[M]
    e["PRED"]["media"] = np.zeros_like(e["Y_obs"])
    e["INFO"]["media"] = "cero por construccion en escala estandarizada"

    # Persistencia: el score observado en t-1. Para el primer origen
    # (t = N_LAGS+1) el valor en t-1 = N_LAGS existe en SCORES_STD.
    e["PRED"]["persistencia"] = e["SCORES_STD"][N_LAGS - 1:T - 1]
    e["INFO"]["persistencia"] = "y_hat(t) = y(t-1)"

    assert all(v.shape == e["Y_obs"].shape for v in e["PRED"].values()), {
        k: v.shape for k, v in e["PRED"].items()}
    print(f"M={M}: modelos listos -> {', '.join(e['PRED'])}")

MODELOS = list(EST[_M0]["PRED"])       # mismo conjunto y orden en todos los M
# Out:
# M=1: modelos listos -> FAR, RF, GBT, media, persistencia
# M=2: modelos listos -> FAR, RF, GBT, media, persistencia
# M=3: modelos listos -> FAR, RF, GBT, media, persistencia
# M=4: modelos listos -> FAR, RF, GBT, media, persistencia

# %% [markdown]
# ### 3.4 Predicción puntual del PSBPM-FD
#
# Se leen las trazas y se toma **sólo la media predictiva** por score. Es lo
# único que necesita el MISE de un punto, y evita depender de que el `_04` haya
# persistido su tabla de ventana móvil para cada ancho: sólo guarda la de su $w$
# de referencia.

# %%
# La convencion de nombres de las trazas y su lectura viven en el paquete
# (`models.pspb_fd_v3`): aqui solo se recorre. `ModeloTraza` conserva las
# trazas crudas y construye la matriz de diseno con intercepto, de modo que
# la media predictiva sale sin repetir el armado a mano.
for M in EST:
    e, P = EST[M], EST[M]["paths"]
    ci, n_comp, n_iter = e["component_idx"], e["n_components"], e["n_iter"]

    faltan = [ruta_traza(P, ci[k] + 1, c + 1).name
              for k in range(n_comp) for c in range(n_iter)
              if not ruta_traza(P, ci[k] + 1, c + 1).exists()]

    e["X_pred_psbp"] = None
    if faltan:
        print(f"AVISO [M={M}] faltan {len(faltan)} trazas .mat: {faltan[:3]}...")
        print("      Sin PSBPM-FD en la comparacion de este punto del barrido.")
        continue

    # El dataset AR tiene el objetivo en la primera columna y las covariables
    # en el resto, que es exactamente lo que `ModeloTraza._diseno` espera; se
    # arma esa tabla una vez por M.
    df_dis = pd.concat(
        [pd.DataFrame({"_y": np.zeros(e["Z"].shape[0])}),
         pd.DataFrame(e["Z"], columns=list(e["cov_names"]))], axis=1)

    Y_hat_psbp = np.empty_like(e["Y_obs"])
    for k in range(n_comp):
        medias = []
        for c in range(n_iter):
            modelo = ModeloTraza.desde_ruta(ruta_traza(P, ci[k] + 1, c + 1))
            assert modelo.feature_names_ == e["cov_names"], (
                f"[M={M} k={k} c={c+1}] feature_names={modelo.feature_names_} "
                f"!= cov_names={e['cov_names']}")
            medias.append(modelo.momentos(df_dis)["media"])
        # Media entre cadenas con peso igual: es la media de la mezcla, que es
        # lo que `agrupar_momentos` hace para el primer momento.
        Y_hat_psbp[:, k] = np.column_stack(medias).mean(axis=1)

    e["Y_hat_psbp"]  = Y_hat_psbp
    e["X_pred_psbp"] = e["curvas_desde_scores_std"](Y_hat_psbp)
    print(f"OK M={M}: PSBPM-FD recalculado ({n_comp} componentes x {n_iter} cadenas)")
# Out:
# OK M=1: PSBPM-FD recalculado (1 componentes x 2 cadenas)
# OK M=2: PSBPM-FD recalculado (2 componentes x 2 cadenas)
# OK M=3: PSBPM-FD recalculado (3 componentes x 2 cadenas)
# OK M=4: PSBPM-FD recalculado (4 componentes x 2 cadenas)

# %%
TOL_AVISO = 0.01     # por encima: vale la pena mirarlo
TOL_DURO  = 0.05     # por encima: no es error Monte Carlo

for M in EST:
    e = EST[M]
    if e["X_pred_psbp"] is None:
        continue
    npz_path = e["paths"]["predict"] / "banda_funcional_psbp.npz"
    if not npz_path.exists():
        print(f"[M={M}] sin banda_funcional_psbp.npz: no se puede cotejar "
              "con el _04. Ejecuta 61_04 para este M.")
        continue
    z = np.load(npz_path, allow_pickle=False)
    m04 = mise(X_true_ev[~es_train], z["X_pred"][~es_train], grilla)
    m05 = mise(X_true_ev[~es_train], e["X_pred_psbp"][~es_train], grilla)
    dif = abs(m05 - m04) / m04
    print(f"[M={M}] MISE test - _04: {m04:.6f}   recalculado: {m05:.6f}   "
          f"dif rel: {dif:.2e}")
    if dif < TOL_AVISO:
        print("        compatible con el error Monte Carlo del _04; la cifra")
        print("        recalculada es la mas precisa de las dos.")
    else:
        print(f"        POR ENCIMA de {TOL_AVISO:.0%}. Sigue siendo plausible si")
        print("        la predictiva es muy dispersa, pero conviene subir")
        print("        S_FUNC en el _04 antes de citar su MISE como definitivo.")
    assert dif < TOL_DURO, (
        f"[M={M}] el MISE recalculado difiere del _04 en {dif:.1%}, demasiado "
        "para ser error Monte Carlo. Revisar si el _04 corrio con otra "
        "configuracion (modo_residuo, objetivo de evaluacion o particion).")
# Out:
# [M=1] MISE test - _04: 0.189193   recalculado: 0.189183   dif rel: 5.35e-05
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.
# [M=2] MISE test - _04: 0.188290   recalculado: 0.188077   dif rel: 1.13e-03
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.
# [M=3] MISE test - _04: 0.188350   recalculado: 0.187964   dif rel: 2.05e-03
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.
# [M=4] MISE test - _04: 0.188106   recalculado: 0.187821   dif rel: 1.52e-03
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.

# %% [markdown]
# ## 4. Bloque A: error puntual, todos los modelos
#
# Las **mismas tres normas** que `61_04`, sobre la misma ventana móvil y contra
# la misma curva verdadera:
#
# | | qué estima |
# |---|---|
# | **MAE** ($L^1$) | mediana condicional, robusta |
# | **RMSE** ($L^2$) | media condicional |
# | **Error máximo** ($L^\infty$, promedio por curva) | peor caso: por curva $\max_\tau\lvert e_t(\tau)\rvert$, promediado sobre la ventana |
#
# Aplican a **todos** los competidores: FAR, PSBPM-FD, RF, GBT y las dos líneas
# base. No requieren predictiva, sólo una predicción puntual.

# %%
# [CONFIG] Que series entran en las FIGURAS. Las tablas y los CSV llevan todo.

EXCLUIR_DE_FIGURA = {"media", "persistencia", "(truncamiento FPCA)"}

# [CONFIG] Estilo propio de las dos series que se TAPAN entre si.
ESTILOS_VENTANA = {
    "FAR":      dict(color="#1f6f8b", lw=3.0, ls="--"),
    "PSBPM-FD": dict(color="#c0392b", lw=1.6, ls="-", zorder=5),
}


def tabla_ventana(M, w):
    """Todas las series de este punto del barrido sobre ventanas de ancho w."""
    e = EST[M]
    partes = []
    for nom, Yp in e["PRED"].items():
        # El FAR entra por CURVA_DIRECTA: se evalua con los K coeficientes, sin
        # truncar a M. El resto pasa por la proyeccion FPCA de este punto.
        X_mod = CURVA_DIRECTA.get(nom)
        if X_mod is None:
            X_mod = e["curvas_desde_scores_std"](Yp)
        t_ = ventana_movil_funcional(
            X_true_ev, X_mod, grilla, T0_orig, w=w,
            t_offset=N_LAGS, pesos_tau=PESOS_TAU,
            bloque_A=True, verbose=False)
        t_["modelo"] = nom
        partes.append(t_)

    t_tr = ventana_movil_funcional(X_true_ev, e["X_proj"], grilla, T0_orig, w=w,
                                   t_offset=N_LAGS, pesos_tau=PESOS_TAU,
                                   bloque_A=True,
                                   verbose=False)
    t_tr["modelo"] = "(truncamiento FPCA)"
    partes.append(t_tr)

    # PSBPM-FD: de la prediccion recalculada en §5, que existe para CUALQUIER
    # w. Si las trazas no estaban, se recurre al CSV del _04 -buscado por
    # PATRON, porque su prefijo cambia entre escenarios- que solo cubre el w de
    # referencia de aquel notebook.
    if e["X_pred_psbp"] is not None:
        t_ps = ventana_movil_funcional(X_true_ev, e["X_pred_psbp"], grilla,
                                       T0_orig, w=w, t_offset=N_LAGS,
                                       pesos_tau=PESOS_TAU,
                                       bloque_A=True,
                                       verbose=False)
        t_ps["modelo"] = "PSBPM-FD"
        partes.append(t_ps)
        origen = "trazas .mat (recalculado)"
    else:
        cand = sorted(e["paths"]["out_report"].glob(f"*_ventana_funcional_w{w}.csv"))
        if cand:
            t_ps = pd.read_csv(cand[0])
            t_ps["modelo"] = "PSBPM-FD"
            _cols = [c for c in ["t_centro", "bloque", "cruza_T0", "mise",
                                 "mae_f", "rmse_f", "linf_medio", "modelo"]
                     if c in t_ps.columns]
            partes.append(t_ps[_cols])
            origen = cand[0].name
        else:
            origen = None

    out = pd.concat(partes, ignore_index=True)
    out.attrs["w"] = w
    return out, origen


for M in EST:
    e = EST[M]
    e["tablas_w"] = {}
    for w in VENTANAS_W:
        e["tablas_w"][w], org = tabla_ventana(M, w)
        e["tablas_w"][w].to_csv(
            e["paths"]["out_report"] / f"{PREFIJO + 2}_ventana_modelos_w{w}.csv",
            index=False)
        n_series = e["tablas_w"][w]["modelo"].nunique()
        print(f"  M={M} w={w:>3}: {n_series} series · {len(e['tablas_w'][w])} filas"
              + (f" · PSBPM-FD desde {org}" if org else " · SIN PSBPM-FD"))
    e["ventana_df"] = e["tablas_w"][W_COMP]   # la que consumen las tablas numericas
# Out:
#   M=1 w= 20: 7 series · 6860 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=1 w= 30: 7 series · 6790 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=1 w= 40: 7 series · 6720 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=2 w= 20: 7 series · 6860 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=2 w= 30: 7 series · 6790 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=2 w= 40: 7 series · 6720 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=3 w= 20: 7 series · 6860 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=3 w= 30: 7 series · 6790 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=3 w= 40: 7 series · 6720 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=4 w= 20: 7 series · 6860 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=4 w= 30: 7 series · 6790 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=4 w= 40: 7 series · 6720 filas · PSBPM-FD desde trazas .mat (recalculado)

# %%
# Bloque A por modelo, en una sola vista. `tablas_w` ya trae las columnas
# -tabla_ventana llama a ventana_movil_funcional con bloque_A=True-.
fuera = set(EXCLUIR_DE_FIGURA)

for M in EST:
    e = EST[M]
    tw = e["tablas_w"][W_COMP]
    tf = tw[~tw["modelo"].isin(fuera)].copy()
    tf.attrs["w"] = W_COMP

    faltan = [c for c in METRICAS_A_COLS if c not in tf.columns]
    assert not faltan, f"[M={M}] faltan columnas del Bloque A: {faltan}"

    plot_ventana_movil(
        tf, T0, METRICAS_A_COLS, columna_grupo="modelo", estilos=ESTILOS_VENTANA,
        title=f"M={M} · Bloque A por modelo (w={W_COMP}) · "
              "MAE, RMSE, error máximo · contra la curva verdadera",
        save_path=str(e["paths"]["out_report"]
                      / f"{PREFIJO + 8}_ventana_bloqueA_modelos_w{W_COMP}.png"),
        verbose=False)
    plt.show()

    sub = tf.dropna(subset=METRICAS_A_COLS)
    faltan_ag = [c for c in ("l2_medio", "razon_agregacion") if c not in sub.columns]
    assert not faltan_ag, (
        f"[M={M}] faltan {faltan_ag}: la tabla no se genero con bloque_A=True.")

    assert (sub["mae_f"] <= sub["l2_medio"] + 1e-9).all(), (
        f"[M={M}] mae_f > l2_medio en alguna ventana: se rompio la cadena por "
        f"origen y el problema esta en como se construyo esa prediccion.")
    assert (sub["l2_medio"] <= sub["linf_medio"] + 1e-9).all(), (
        f"[M={M}] l2_medio > linf_medio en alguna ventana: idem.")


    assert (sub["l2_medio"] <= sub["rmse_f"] + 1e-9).all(), (
        f"[M={M}] l2_medio > rmse_f: imposible por Jensen; revise la agregacion.")

    _jen = sub[sub["rmse_f"] > sub["linf_medio"] + 1e-9]
    if len(_jen):
        print(f"[M={M}] Jensen: {len(_jen)}/{len(sub)} ventanas con "
              f"rmse_f > linf_medio (media cuadratica vs aritmetica). "
              f"exceso relativo maximo {((_jen['rmse_f'] / _jen['linf_medio']) - 1).max():.2%}"
              f" · razon_agregacion minima {_jen['razon_agregacion'].min():.3f}"
              f" · modelos {sorted(_jen['modelo'].unique())}")
    print(f"[M={M}] Bloque A dibujado para {sorted(sub['modelo'].unique())}")
# Out:
# [M=1] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']
# [M=2] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']
# [M=3] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']
# [M=4] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']

# %% [markdown]
# ## 5. Bloque B: intervalos, sólo FAR y PSBPM-FD
#
# Las **mismas cuatro cifras** que `61_04` —Winkler, cobertura simultánea,
# cobertura puntual y MPIW— sobre la misma ventana móvil.
#
# La diferencia con el Bloque A es a qué modelos aplica. El FAR **no** es un
# algoritmo de predicción puntual: es un modelo, $X_{t+1}=\rho(X_t)+\varepsilon$,
# de modo que su intervalo a un paso sale de su propia especificación y no de un
# procedimiento adosado. El PSBPM-FD tiene su predictiva muestreada. RF, GBT y
# las líneas base no son modelos de probabilidad: rellenarles una banda
# gaussiana de residuos dentro de muestra las haría parecer artificialmente
# angostas y decidiría la comparación por el supuesto, no por el método.

# %%
# Construcción de las bandas. Los residuos son los del bloque de
# entrenamiento contra la curva VERDADERA, que es el objetivo de evaluación.
BANDAS = {}          # {M: {nombre_fila: (li, ls)}}

for M in EST:
    e = EST[M]
    n_train = int(es_train.sum())
    corr = (np.sqrt(1.0 + e["far_kn"] / n_train)
            if IC_CORRECCION_ESTIMACION else None)

    bandas = {}

    # -- FAR: el intervalo que implica su propio modelo --------------------
    # K completo, igual que en el Bloque A: las dos filas del FAR -banda y
    # error puntual- tienen que salir de la MISMA curva predicha.
    X_far = CURVA_DIRECTA["FAR"]
    r_far = residuos_para_banda(X_true_ev, X_far, es_train)
    bandas["FAR (IC del modelo AR)"] = (
        banda_predictiva_modelo(X_far, r_far, nivel=NIVEL_IC,
                                por_tau=IC_POR_TAU,
                                correccion_estimacion=corr),
        X_far)

    # -- PSBPM-FD: la MISMA banda, para aislar el mecanismo ----------------
    if IC_PSBP_TAMBIEN_GAUSSIANA and e["X_pred_psbp"] is not None:
        r_ps = residuos_para_banda(X_true_ev, e["X_pred_psbp"], es_train)
        bandas["PSBPM-FD (IC gaussiano, mismo mecanismo)"] = (
            banda_predictiva_modelo(e["X_pred_psbp"], r_ps, nivel=NIVEL_IC,
                                    por_tau=IC_POR_TAU,
                                    correccion_estimacion=corr),
            e["X_pred_psbp"])

    # -- PSBPM-FD: su banda nativa, leída del artefacto del _04 ------------
    npz = e["paths"]["predict"] / "banda_funcional_psbp.npz"
    if npz.exists():
        z = np.load(npz, allow_pickle=False)
        assert z["li"].shape == X_true_ev.shape, (
            f"[M={M}] la banda del _04 es {z['li'].shape} y aquí hay "
            f"{X_true_ev.shape}: ¿corrieron con distinta partición?")
        assert abs(float(z["nivel"][0]) - NIVEL_IC) < 1e-9, (
            f"[M={M}] el _04 usó nivel {float(z['nivel'][0])} y aquí NIVEL_IC="
            f"{NIVEL_IC}: el Winkler de las dos filas no sería comparable.")
        bandas["PSBPM-FD (predictiva bayesiana)"] = (
            (z["li"].astype(float), z["ls"].astype(float)),
            z["X_pred"].astype(float))
    else:
        print(f"! [M={M}] falta {npz.name}: ejecuta 61_04 para persistir la "
              "banda nativa. Van solo las filas gaussianas.")

    BANDAS[M] = bandas
    sd = sigma_residual(r_far, por_tau=IC_POR_TAU)
    print(f"M={M}  kn={e['far_kn']}  corrección={corr if corr else 1.0:.4f}  "
          f"sigma_eps(tau) del FAR: min={sd.min():.4f} máx={sd.max():.4f} "
          f"(razón {sd.max()/sd.min():.2f})  ·  filas: {len(bandas)}")
# Out:
# M=1  kn=7  corrección=1.0050  sigma_eps(tau) del FAR: min=0.3638 máx=0.4664 (razón 1.28)  ·  filas: 3
# M=2  kn=7  corrección=1.0050  sigma_eps(tau) del FAR: min=0.3638 máx=0.4664 (razón 1.28)  ·  filas: 3
# M=3  kn=7  corrección=1.0050  sigma_eps(tau) del FAR: min=0.3638 máx=0.4664 (razón 1.28)  ·  filas: 3
# M=4  kn=7  corrección=1.0050  sigma_eps(tau) del FAR: min=0.3638 máx=0.4664 (razón 1.28)  ·  filas: 3

# %%
# Las cuatro cifras del Bloque B, por fila y por bloque. El Winkler es la
# PRIMARIA; picp y mpiw son su descomposición y no ordenan nada por su cuenta.
for M in EST:
    e = EST[M]
    filas = []
    for nombre, ((li, ls), _Xp) in BANDAS[M].items():
        for etq, mask in (("train", es_train), ("test", ~es_train)):
            r = resumen_intervalo(X_true_ev[mask], li[mask], ls[mask],
                                  nivel=NIVEL_IC, tau=grilla)
            picp_si = float(indicador_cobertura_simultanea(
                X_true_ev[mask], li[mask], ls[mask]).mean())
            filas.append({"banda": nombre, "bloque": etq,
                          **{k: r[k] for k in
                             ("winkler", "picp", "ee_picp", "ace", "mpiw")},
                          "picp_simultaneo": picp_si})
    B_df = pd.DataFrame(filas).set_index(["bloque", "banda"]).sort_index()
    B_df.to_csv(e["paths"]["out_report"] / "80_bloqueB_modelos.csv")
    e["B_modelos"] = B_df

    display(B_df.loc["test"].style
            .format({"winkler": "{:.4f}", "picp": "{:.4f}", "ee_picp": "{:.4f}",
                     "ace": "{:+.4f}", "mpiw": "{:.4f}",
                     "picp_simultaneo": "{:.4f}"})
            .background_gradient(subset=["winkler"], cmap="RdYlGn_r")
            .set_caption(f"M={M} · Bloque B, bloque de PRUEBA · PRIMARIA: "
                         f"winkler · nivel nominal {NIVEL_IC:.0%}"))

    # La lectura de tres filas, que es la razón de haberlas construido.
    te_ = B_df.loc["test"]
    g_far = "FAR (IC del modelo AR)"
    g_psg = "PSBPM-FD (IC gaussiano, mismo mecanismo)"
    g_psb = "PSBPM-FD (predictiva bayesiana)"
    if {g_far, g_psg} <= set(te_.index):
        d_modelo = te_.loc[g_psg, "winkler"] - te_.loc[g_far, "winkler"]
        print(f"[M={M}] mismo MECANISMO de banda, distinto MODELO: "
              f"PSBPM-FD - FAR = {d_modelo:+.4f} de Winkler")
    if {g_psg, g_psb} <= set(te_.index):
        d_mec = te_.loc[g_psb, "winkler"] - te_.loc[g_psg, "winkler"]
        print(f"        mismo MODELO, distinto MECANISMO: bayesiana - gaussiana "
              f"= {d_mec:+.4f}")
        print("        Si el segundo domina al primero, lo que separa a las")
        print("        filas es la forma de la predictiva y no la calidad de la")
        print("        media condicional; si domina el primero, al revés.")
# Out:
# <style type="text/css">
# #T_fc29b_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_fc29b_row1_col0 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_fc29b_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fc29b">
#   <caption>M=1 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc29b_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_fc29b_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_fc29b_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_fc29b_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_fc29b_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_fc29b_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc29b_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_fc29b_row0_col0" class="data row0 col0" >2.0324</td>
#       <td id="T_fc29b_row0_col1" class="data row0 col1" >0.9529</td>
#       <td id="T_fc29b_row0_col2" class="data row0 col2" >0.0014</td>
#       <td id="T_fc29b_row0_col3" class="data row0 col3" >+0.0029</td>
#       <td id="T_fc29b_row0_col4" class="data row0 col4" >1.7131</td>
#       <td id="T_fc29b_row0_col5" class="data row0 col5" >0.1133</td>
#     </tr>
#     <tr>
#       <th id="T_fc29b_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_fc29b_row1_col0" class="data row1 col0" >2.0518</td>
#       <td id="T_fc29b_row1_col1" class="data row1 col1" >0.9521</td>
#       <td id="T_fc29b_row1_col2" class="data row1 col2" >0.0014</td>
#       <td id="T_fc29b_row1_col3" class="data row1 col3" >+0.0021</td>
#       <td id="T_fc29b_row1_col4" class="data row1 col4" >1.7354</td>
#       <td id="T_fc29b_row1_col5" class="data row1 col5" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_fc29b_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_fc29b_row2_col0" class="data row2 col0" >4.0647</td>
#       <td id="T_fc29b_row2_col1" class="data row2 col1" >0.6555</td>
#       <td id="T_fc29b_row2_col2" class="data row2 col2" >0.0032</td>
#       <td id="T_fc29b_row2_col3" class="data row2 col3" >-0.2945</td>
#       <td id="T_fc29b_row2_col4" class="data row2 col4" >0.8210</td>
#       <td id="T_fc29b_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
# [M=1] mismo MECANISMO de banda, distinto MODELO: PSBPM-FD - FAR = +0.0194 de Winkler
#         mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +2.0129
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# <style type="text/css">
# #T_6f6d1_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_6f6d1_row1_col0 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_6f6d1_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6f6d1">
#   <caption>M=2 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f6d1_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_6f6d1_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_6f6d1_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_6f6d1_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_6f6d1_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_6f6d1_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f6d1_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_6f6d1_row0_col0" class="data row0 col0" >2.0324</td>
#       <td id="T_6f6d1_row0_col1" class="data row0 col1" >0.9529</td>
#       <td id="T_6f6d1_row0_col2" class="data row0 col2" >0.0014</td>
#       <td id="T_6f6d1_row0_col3" class="data row0 col3" >+0.0029</td>
#       <td id="T_6f6d1_row0_col4" class="data row0 col4" >1.7131</td>
#       <td id="T_6f6d1_row0_col5" class="data row0 col5" >0.1133</td>
#     </tr>
#     <tr>
#       <th id="T_6f6d1_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_6f6d1_row1_col0" class="data row1 col0" >2.0469</td>
#       <td id="T_6f6d1_row1_col1" class="data row1 col1" >0.9524</td>
#       <td id="T_6f6d1_row1_col2" class="data row1 col2" >0.0014</td>
#       <td id="T_6f6d1_row1_col3" class="data row1 col3" >+0.0024</td>
#       <td id="T_6f6d1_row1_col4" class="data row1 col4" >1.7304</td>
#       <td id="T_6f6d1_row1_col5" class="data row1 col5" >0.1067</td>
#     </tr>
#     <tr>
#       <th id="T_6f6d1_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_6f6d1_row2_col0" class="data row2 col0" >3.3552</td>
#       <td id="T_6f6d1_row2_col1" class="data row2 col1" >0.7316</td>
#       <td id="T_6f6d1_row2_col2" class="data row2 col2" >0.0030</td>
#       <td id="T_6f6d1_row2_col3" class="data row2 col3" >-0.2184</td>
#       <td id="T_6f6d1_row2_col4" class="data row2 col4" >0.9612</td>
#       <td id="T_6f6d1_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
# [M=2] mismo MECANISMO de banda, distinto MODELO: PSBPM-FD - FAR = +0.0144 de Winkler
#         mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +1.3084
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# <style type="text/css">
# #T_efcb5_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_efcb5_row1_col0 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_efcb5_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_efcb5">
#   <caption>M=3 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efcb5_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_efcb5_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_efcb5_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_efcb5_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_efcb5_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_efcb5_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efcb5_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_efcb5_row0_col0" class="data row0 col0" >2.0324</td>
#       <td id="T_efcb5_row0_col1" class="data row0 col1" >0.9529</td>
#       <td id="T_efcb5_row0_col2" class="data row0 col2" >0.0014</td>
#       <td id="T_efcb5_row0_col3" class="data row0 col3" >+0.0029</td>
#       <td id="T_efcb5_row0_col4" class="data row0 col4" >1.7131</td>
#       <td id="T_efcb5_row0_col5" class="data row0 col5" >0.1133</td>
#     </tr>
#     <tr>
#       <th id="T_efcb5_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_efcb5_row1_col0" class="data row1 col0" >2.0466</td>
#       <td id="T_efcb5_row1_col1" class="data row1 col1" >0.9526</td>
#       <td id="T_efcb5_row1_col2" class="data row1 col2" >0.0014</td>
#       <td id="T_efcb5_row1_col3" class="data row1 col3" >+0.0026</td>
#       <td id="T_efcb5_row1_col4" class="data row1 col4" >1.7300</td>
#       <td id="T_efcb5_row1_col5" class="data row1 col5" >0.1167</td>
#     </tr>
#     <tr>
#       <th id="T_efcb5_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_efcb5_row2_col0" class="data row2 col0" >3.0001</td>
#       <td id="T_efcb5_row2_col1" class="data row2 col1" >0.7744</td>
#       <td id="T_efcb5_row2_col2" class="data row2 col2" >0.0028</td>
#       <td id="T_efcb5_row2_col3" class="data row2 col3" >-0.1756</td>
#       <td id="T_efcb5_row2_col4" class="data row2 col4" >1.0499</td>
#       <td id="T_efcb5_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
# [M=3] mismo MECANISMO de banda, distinto MODELO: PSBPM-FD - FAR = +0.0142 de Winkler
#         mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +0.9535
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# <style type="text/css">
# #T_2014e_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2014e_row1_col0 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_2014e_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2014e">
#   <caption>M=4 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2014e_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_2014e_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_2014e_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_2014e_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_2014e_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_2014e_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2014e_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_2014e_row0_col0" class="data row0 col0" >2.0324</td>
#       <td id="T_2014e_row0_col1" class="data row0 col1" >0.9529</td>
#       <td id="T_2014e_row0_col2" class="data row0 col2" >0.0014</td>
#       <td id="T_2014e_row0_col3" class="data row0 col3" >+0.0029</td>
#       <td id="T_2014e_row0_col4" class="data row0 col4" >1.7131</td>
#       <td id="T_2014e_row0_col5" class="data row0 col5" >0.1133</td>
#     </tr>
#     <tr>
#       <th id="T_2014e_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_2014e_row1_col0" class="data row1 col0" >2.0455</td>
#       <td id="T_2014e_row1_col1" class="data row1 col1" >0.9523</td>
#       <td id="T_2014e_row1_col2" class="data row1 col2" >0.0014</td>
#       <td id="T_2014e_row1_col3" class="data row1 col3" >+0.0023</td>
#       <td id="T_2014e_row1_col4" class="data row1 col4" >1.7292</td>
#       <td id="T_2014e_row1_col5" class="data row1 col5" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_2014e_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_2014e_row2_col0" class="data row2 col0" >2.7753</td>
#       <td id="T_2014e_row2_col1" class="data row2 col1" >0.8013</td>
#       <td id="T_2014e_row2_col2" class="data row2 col2" >0.0027</td>
#       <td id="T_2014e_row2_col3" class="data row2 col3" >-0.1487</td>
#       <td id="T_2014e_row2_col4" class="data row2 col4" >1.1169</td>
#       <td id="T_2014e_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
# [M=4] mismo MECANISMO de banda, distinto MODELO: PSBPM-FD - FAR = +0.0131 de Winkler
#         mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +0.7298
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.

# %%
# Winkler sobre la ventana móvil, y su descomposición. Es la vista que dice
# CUÁNDO la banda falla, no solo cuánto: una cobertura marginal correcta puede
# esconder rachas enteras de violaciones.

for M in EST:
    e = EST[M]
    partes = []
    for nombre, ((li, ls), Xp) in BANDAS[M].items():
        t_ = ventana_movil_funcional(X_true_ev, Xp, grilla, T0_orig, w=W_COMP,
                                     li=li, ls=ls, t_offset=N_LAGS,
                                     pesos_tau=PESOS_TAU,
                                     nivel=NIVEL_IC, bloque_A=True,
                                     verbose=False)
        t_["banda"] = nombre
        partes.append(t_)
    vb = pd.concat(partes, ignore_index=True)
    vb.attrs["w"] = W_COMP
    vb.to_csv(e["paths"]["out_report"] / f"81_ventana_bloqueB_w{W_COMP}.csv",
              index=False)
    e["ventana_B"] = vb

    plot_ventana_movil(
        vb, T0, ["winkler", "picp_simultaneo", "picp", "mpiw"], columna_grupo="banda",
        title=f"M={M} · Bloque B sobre la ventana móvil (w={W_COMP}) — "
              "winkler es la primaria; el resto lo descompone",
        save_path=str(e["paths"]["out_report"]
                      / f"81_ventana_bloqueB_w{W_COMP}.png"),
        verbose=False)
    plt.show()

    # El indicador I_t por origen, puntual y simultaneo, del que picp y
    # picp_simultaneo son el promedio respectivo. Se persiste por banda para
    # poder ver DONDE falla, no solo cuanto en promedio.
    for nombre, ((li, ls), _Xp) in BANDAS[M].items():
        I_t_pt = indicador_cobertura(X_true_ev, li, ls).mean(axis=1)
        I_t_si = indicador_cobertura_simultanea(X_true_ev, li, ls)
        ind = pd.DataFrame({"t": np.arange(len(I_t_pt)) + N_LAGS + 1,
                            "bloque": np.where(es_train, "train", "test"),
                            "banda": nombre, "I_t_puntual": I_t_pt,
                            "I_t_simultaneo": I_t_si.astype(float)})
        ind.to_csv(e["paths"]["out_report"]
                  / f"81b_indicador_cobertura_{nombre.split(' ')[0]}.csv",
                  index=False)

# %% [markdown]
# ## 6. Bloque A: quién gana cada ventana, y por cuánto
#
# Dos lecturas distintas y complementarias sobre la misma tabla de ventana:
#
# 1. **% de ventanas ganadas** — para cada ventana se marca el modelo con el
#    valor más bajo de la métrica. Es una lectura más dura que el promedio: un
#    modelo puede tener mejor promedio y ganar pocas ventanas si pierde por poco
#    muchas veces y gana por mucho unas pocas.
# 2. **Cuánto mejor** — la razón de cada modelo contra el mejor de la ventana y
#    contra el FAR, que es la referencia lineal correctamente especificada en
#    este escenario.
#
# Ambas se calculan sobre las ventanas que **no cruzan $T_0$**.

# %%
# (1) % de ventanas ganadas por modelo, y (2) cuanto mejor/peor es cada uno.
gana_A, rel_A = [], []
for M in EST:
    e = EST[M]
    tw = e["tablas_w"][W_COMP]
    limpio = tw[~tw["cruza_T0"]]
    modelos = [m for m in limpio["modelo"].unique() if m not in fuera]

    for etiqueta, col in METRICAS_A:
        piv = limpio.pivot_table(index=["t_centro", "bloque"], columns="modelo",
                                 values=col)[modelos]
        ganador = piv.idxmin(axis=1)
        for bloque in ("train", "test"):
            sel = ganador.index.get_level_values("bloque") == bloque
            sub = ganador[sel]
            n_tot = len(sub)
            for m in modelos:
                gana_A.append({
                    "M": M, "metrica": etiqueta, "columna": col,
                    "bloque": bloque, "modelo": m,
                    "pct_ventanas_ganadas": float((sub == m).mean()) if n_tot else np.nan,
                    "n_ventanas": n_tot})

            # (2) cuanto mejor: razon contra el mejor de cada ventana y contra
            # el FAR. Se promedia la RAZON por ventana, no se divide el
            # promedio: asi cada ventana pesa igual y no la dominan las de
            # error grande.
            p = piv[sel]
            mejor = p.min(axis=1)
            for m in modelos:
                fila = {"M": M, "metrica": etiqueta, "bloque": bloque, "modelo": m,
                        "razon_vs_mejor": float((p[m] / mejor).mean())}
                if "FAR" in p.columns:
                    fila["razon_vs_FAR"] = float((p[m] / p["FAR"]).mean())
                rel_A.append(fila)

gana_A_df = pd.DataFrame(gana_A)
rel_A_df  = pd.DataFrame(rel_A)
gana_A_df.to_csv(PATH_BARRIDO / "96_ganador_ventana_bloqueA.csv", index=False)
rel_A_df.to_csv(PATH_BARRIDO / "96_razones_bloqueA.csv", index=False)

for etiqueta, _col in METRICAS_A:
    piv_g = (gana_A_df[(gana_A_df.metrica == etiqueta) & (gana_A_df.bloque == "test")]
             .pivot(index="modelo", columns="M", values="pct_ventanas_ganadas"))
    display(piv_g.style.format("{:.1%}", na_rep="-")
            .background_gradient(cmap="RdYlGn", axis=None)
            .set_caption(f"{etiqueta} · % de ventanas de PRUEBA ganadas "
                         f"(w={W_COMP}, sin cruzar T0)"))

for etiqueta, _col in METRICAS_A:
    piv_r = (rel_A_df[(rel_A_df.metrica == etiqueta) & (rel_A_df.bloque == "test")]
             .pivot(index="modelo", columns="M", values="razon_vs_mejor"))
    display(piv_r.style.format("{:.3f}", na_rep="-")
            .background_gradient(cmap="RdYlGn_r", axis=None)
            .set_caption(f"{etiqueta} · razón contra el MEJOR de cada ventana "
                         "(test) · 1.000 = gana siempre"))
# Out:
# <style type="text/css">
# #T_a6378_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a6378_row0_col1 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_a6378_row0_col2 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_a6378_row0_col3 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_a6378_row1_col0 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_a6378_row1_col1, #T_a6378_row3_col1 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_a6378_row1_col2 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_a6378_row1_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a6378_row2_col0 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_a6378_row2_col1, #T_a6378_row3_col3 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_a6378_row2_col2 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_a6378_row2_col3 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_a6378_row3_col0 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_a6378_row3_col2 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a6378">
#   <caption>1. MAE  (L^1) · % de ventanas de PRUEBA ganadas (w=30, sin cruzar T0)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_a6378_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_a6378_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_a6378_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_a6378_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6378_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_a6378_row0_col0" class="data row0 col0" >83.0%</td>
#       <td id="T_a6378_row0_col1" class="data row0 col1" >81.2%</td>
#       <td id="T_a6378_row0_col2" class="data row0 col2" >74.2%</td>
#       <td id="T_a6378_row0_col3" class="data row0 col3" >75.3%</td>
#     </tr>
#     <tr>
#       <th id="T_a6378_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_a6378_row1_col0" class="data row1 col0" >5.9%</td>
#       <td id="T_a6378_row1_col1" class="data row1 col1" >1.8%</td>
#       <td id="T_a6378_row1_col2" class="data row1 col2" >0.7%</td>
#       <td id="T_a6378_row1_col3" class="data row1 col3" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_a6378_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_a6378_row2_col0" class="data row2 col0" >4.8%</td>
#       <td id="T_a6378_row2_col1" class="data row2 col1" >15.1%</td>
#       <td id="T_a6378_row2_col2" class="data row2 col2" >10.3%</td>
#       <td id="T_a6378_row2_col3" class="data row2 col3" >9.2%</td>
#     </tr>
#     <tr>
#       <th id="T_a6378_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_a6378_row3_col0" class="data row3 col0" >6.3%</td>
#       <td id="T_a6378_row3_col1" class="data row3 col1" >1.8%</td>
#       <td id="T_a6378_row3_col2" class="data row3 col2" >14.8%</td>
#       <td id="T_a6378_row3_col3" class="data row3 col3" >15.1%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_eccc2_row0_col0 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_eccc2_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_eccc2_row0_col2 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_eccc2_row0_col3 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_eccc2_row1_col0 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_eccc2_row1_col1 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_eccc2_row1_col2 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_eccc2_row1_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_eccc2_row2_col0 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_eccc2_row2_col1, #T_eccc2_row3_col2 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_eccc2_row2_col2 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_eccc2_row2_col3 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_eccc2_row3_col0 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_eccc2_row3_col1 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_eccc2_row3_col3 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eccc2">
#   <caption>2. RMSE (L^2) · % de ventanas de PRUEBA ganadas (w=30, sin cruzar T0)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_eccc2_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_eccc2_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_eccc2_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_eccc2_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eccc2_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_eccc2_row0_col0" class="data row0 col0" >76.0%</td>
#       <td id="T_eccc2_row0_col1" class="data row0 col1" >81.9%</td>
#       <td id="T_eccc2_row0_col2" class="data row0 col2" >74.9%</td>
#       <td id="T_eccc2_row0_col3" class="data row0 col3" >73.1%</td>
#     </tr>
#     <tr>
#       <th id="T_eccc2_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_eccc2_row1_col0" class="data row1 col0" >5.5%</td>
#       <td id="T_eccc2_row1_col1" class="data row1 col1" >1.8%</td>
#       <td id="T_eccc2_row1_col2" class="data row1 col2" >0.7%</td>
#       <td id="T_eccc2_row1_col3" class="data row1 col3" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_eccc2_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_eccc2_row2_col0" class="data row2 col0" >7.0%</td>
#       <td id="T_eccc2_row2_col1" class="data row2 col1" >14.8%</td>
#       <td id="T_eccc2_row2_col2" class="data row2 col2" >9.6%</td>
#       <td id="T_eccc2_row2_col3" class="data row2 col3" >10.3%</td>
#     </tr>
#     <tr>
#       <th id="T_eccc2_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_eccc2_row3_col0" class="data row3 col0" >11.4%</td>
#       <td id="T_eccc2_row3_col1" class="data row3 col1" >1.5%</td>
#       <td id="T_eccc2_row3_col2" class="data row3 col2" >14.8%</td>
#       <td id="T_eccc2_row3_col3" class="data row3 col3" >16.2%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4dd9f_row0_col0 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_4dd9f_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4dd9f_row0_col2 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_4dd9f_row0_col3 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_4dd9f_row1_col0 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_4dd9f_row1_col1 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_4dd9f_row1_col2 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_4dd9f_row1_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4dd9f_row2_col0 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_4dd9f_row2_col1 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_4dd9f_row2_col2 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_4dd9f_row2_col3 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_4dd9f_row3_col0 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_4dd9f_row3_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_4dd9f_row3_col2 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_4dd9f_row3_col3 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4dd9f">
#   <caption>3. E_max promedio por curva · % de ventanas de PRUEBA ganadas (w=30, sin cruzar T0)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_4dd9f_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_4dd9f_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_4dd9f_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_4dd9f_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4dd9f_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_4dd9f_row0_col0" class="data row0 col0" >62.0%</td>
#       <td id="T_4dd9f_row0_col1" class="data row0 col1" >68.3%</td>
#       <td id="T_4dd9f_row0_col2" class="data row0 col2" >59.4%</td>
#       <td id="T_4dd9f_row0_col3" class="data row0 col3" >61.6%</td>
#     </tr>
#     <tr>
#       <th id="T_4dd9f_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_4dd9f_row1_col0" class="data row1 col0" >5.2%</td>
#       <td id="T_4dd9f_row1_col1" class="data row1 col1" >0.4%</td>
#       <td id="T_4dd9f_row1_col2" class="data row1 col2" >1.5%</td>
#       <td id="T_4dd9f_row1_col3" class="data row1 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_4dd9f_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_4dd9f_row2_col0" class="data row2 col0" >15.5%</td>
#       <td id="T_4dd9f_row2_col1" class="data row2 col1" >21.8%</td>
#       <td id="T_4dd9f_row2_col2" class="data row2 col2" >12.2%</td>
#       <td id="T_4dd9f_row2_col3" class="data row2 col3" >25.5%</td>
#     </tr>
#     <tr>
#       <th id="T_4dd9f_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_4dd9f_row3_col0" class="data row3 col0" >17.3%</td>
#       <td id="T_4dd9f_row3_col1" class="data row3 col1" >9.6%</td>
#       <td id="T_4dd9f_row3_col2" class="data row3 col2" >26.9%</td>
#       <td id="T_4dd9f_row3_col3" class="data row3 col3" >12.9%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_39a72_row0_col0 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_39a72_row0_col1 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_39a72_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_39a72_row0_col3 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_39a72_row1_col0 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_39a72_row1_col1 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_39a72_row1_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_39a72_row1_col3 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_39a72_row2_col0 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_39a72_row2_col1 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_39a72_row2_col2 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_39a72_row2_col3 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_39a72_row3_col0 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_39a72_row3_col1 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_39a72_row3_col2 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_39a72_row3_col3 {
#   background-color: #fed884;
#   color: #000000;
# }
# </style>
# <table id="T_39a72">
#   <caption>4. E_max peor de la ventana · % de ventanas de PRUEBA ganadas (w=30, sin cruzar T0)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_39a72_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_39a72_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_39a72_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_39a72_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39a72_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_39a72_row0_col0" class="data row0 col0" >30.6%</td>
#       <td id="T_39a72_row0_col1" class="data row0 col1" >40.6%</td>
#       <td id="T_39a72_row0_col2" class="data row0 col2" >54.6%</td>
#       <td id="T_39a72_row0_col3" class="data row0 col3" >44.3%</td>
#     </tr>
#     <tr>
#       <th id="T_39a72_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_39a72_row1_col0" class="data row1 col0" >4.1%</td>
#       <td id="T_39a72_row1_col1" class="data row1 col1" >23.2%</td>
#       <td id="T_39a72_row1_col2" class="data row1 col2" >1.1%</td>
#       <td id="T_39a72_row1_col3" class="data row1 col3" >15.5%</td>
#     </tr>
#     <tr>
#       <th id="T_39a72_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_39a72_row2_col0" class="data row2 col0" >29.5%</td>
#       <td id="T_39a72_row2_col1" class="data row2 col1" >31.7%</td>
#       <td id="T_39a72_row2_col2" class="data row2 col2" >25.1%</td>
#       <td id="T_39a72_row2_col3" class="data row2 col3" >18.5%</td>
#     </tr>
#     <tr>
#       <th id="T_39a72_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_39a72_row3_col0" class="data row3 col0" >35.8%</td>
#       <td id="T_39a72_row3_col1" class="data row3 col1" >4.4%</td>
#       <td id="T_39a72_row3_col2" class="data row3 col2" >19.2%</td>
#       <td id="T_39a72_row3_col3" class="data row3 col3" >21.8%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6eaef_row0_col0 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_6eaef_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_6eaef_row0_col2 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_6eaef_row0_col3 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_6eaef_row1_col0 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_6eaef_row1_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_6eaef_row1_col2 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_6eaef_row1_col3 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_6eaef_row2_col0 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_6eaef_row2_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_6eaef_row2_col2, #T_6eaef_row2_col3 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_6eaef_row3_col0 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_6eaef_row3_col1 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_6eaef_row3_col2 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_6eaef_row3_col3 {
#   background-color: #7fc866;
#   color: #000000;
# }
# </style>
# <table id="T_6eaef">
#   <caption>1. MAE  (L^1) · razón contra el MEJOR de cada ventana (test) · 1.000 = gana siempre</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_6eaef_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_6eaef_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_6eaef_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_6eaef_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6eaef_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_6eaef_row0_col0" class="data row0 col0" >1.001</td>
#       <td id="T_6eaef_row0_col1" class="data row0 col1" >1.001</td>
#       <td id="T_6eaef_row0_col2" class="data row0 col2" >1.001</td>
#       <td id="T_6eaef_row0_col3" class="data row0 col3" >1.002</td>
#     </tr>
#     <tr>
#       <th id="T_6eaef_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_6eaef_row1_col0" class="data row1 col0" >1.024</td>
#       <td id="T_6eaef_row1_col1" class="data row1 col1" >1.053</td>
#       <td id="T_6eaef_row1_col2" class="data row1 col2" >1.049</td>
#       <td id="T_6eaef_row1_col3" class="data row1 col3" >1.046</td>
#     </tr>
#     <tr>
#       <th id="T_6eaef_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_6eaef_row2_col0" class="data row2 col0" >1.014</td>
#       <td id="T_6eaef_row2_col1" class="data row2 col1" >1.011</td>
#       <td id="T_6eaef_row2_col2" class="data row2 col2" >1.011</td>
#       <td id="T_6eaef_row2_col3" class="data row2 col3" >1.011</td>
#     </tr>
#     <tr>
#       <th id="T_6eaef_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_6eaef_row3_col0" class="data row3 col0" >1.022</td>
#       <td id="T_6eaef_row3_col1" class="data row3 col1" >1.022</td>
#       <td id="T_6eaef_row3_col2" class="data row3 col2" >1.015</td>
#       <td id="T_6eaef_row3_col3" class="data row3 col3" >1.013</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_15f6c_row0_col0, #T_15f6c_row0_col2 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_15f6c_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_15f6c_row0_col3 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_15f6c_row1_col0 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_15f6c_row1_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_15f6c_row1_col2 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_15f6c_row1_col3 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_15f6c_row2_col0 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_15f6c_row2_col1 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_15f6c_row2_col2, #T_15f6c_row2_col3 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_15f6c_row3_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_15f6c_row3_col1 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_15f6c_row3_col2 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_15f6c_row3_col3 {
#   background-color: #7fc866;
#   color: #000000;
# }
# </style>
# <table id="T_15f6c">
#   <caption>2. RMSE (L^2) · razón contra el MEJOR de cada ventana (test) · 1.000 = gana siempre</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_15f6c_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_15f6c_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_15f6c_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_15f6c_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15f6c_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_15f6c_row0_col0" class="data row0 col0" >1.002</td>
#       <td id="T_15f6c_row0_col1" class="data row0 col1" >1.001</td>
#       <td id="T_15f6c_row0_col2" class="data row0 col2" >1.001</td>
#       <td id="T_15f6c_row0_col3" class="data row0 col3" >1.002</td>
#     </tr>
#     <tr>
#       <th id="T_15f6c_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_15f6c_row1_col0" class="data row1 col0" >1.022</td>
#       <td id="T_15f6c_row1_col1" class="data row1 col1" >1.052</td>
#       <td id="T_15f6c_row1_col2" class="data row1 col2" >1.051</td>
#       <td id="T_15f6c_row1_col3" class="data row1 col3" >1.047</td>
#     </tr>
#     <tr>
#       <th id="T_15f6c_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_15f6c_row2_col0" class="data row2 col0" >1.013</td>
#       <td id="T_15f6c_row2_col1" class="data row2 col1" >1.009</td>
#       <td id="T_15f6c_row2_col2" class="data row2 col2" >1.010</td>
#       <td id="T_15f6c_row2_col3" class="data row2 col3" >1.010</td>
#     </tr>
#     <tr>
#       <th id="T_15f6c_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_15f6c_row3_col0" class="data row3 col0" >1.019</td>
#       <td id="T_15f6c_row3_col1" class="data row3 col1" >1.021</td>
#       <td id="T_15f6c_row3_col2" class="data row3 col2" >1.014</td>
#       <td id="T_15f6c_row3_col3" class="data row3 col3" >1.013</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2f330_row0_col0 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_2f330_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2f330_row0_col2 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_2f330_row0_col3 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_2f330_row1_col0 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_2f330_row1_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_2f330_row1_col2 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_2f330_row1_col3 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_2f330_row2_col0 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_2f330_row2_col1 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_2f330_row2_col2 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_2f330_row2_col3 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_2f330_row3_col0 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_2f330_row3_col1 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_2f330_row3_col2 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_2f330_row3_col3 {
#   background-color: #7ac665;
#   color: #000000;
# }
# </style>
# <table id="T_2f330">
#   <caption>3. E_max promedio por curva · razón contra el MEJOR de cada ventana (test) · 1.000 = gana siempre</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_2f330_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_2f330_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_2f330_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_2f330_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f330_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_2f330_row0_col0" class="data row0 col0" >1.002</td>
#       <td id="T_2f330_row0_col1" class="data row0 col1" >1.002</td>
#       <td id="T_2f330_row0_col2" class="data row0 col2" >1.002</td>
#       <td id="T_2f330_row0_col3" class="data row0 col3" >1.002</td>
#     </tr>
#     <tr>
#       <th id="T_2f330_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_2f330_row1_col0" class="data row1 col0" >1.013</td>
#       <td id="T_2f330_row1_col1" class="data row1 col1" >1.041</td>
#       <td id="T_2f330_row1_col2" class="data row1 col2" >1.041</td>
#       <td id="T_2f330_row1_col3" class="data row1 col3" >1.039</td>
#     </tr>
#     <tr>
#       <th id="T_2f330_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_2f330_row2_col0" class="data row2 col0" >1.009</td>
#       <td id="T_2f330_row2_col1" class="data row2 col1" >1.007</td>
#       <td id="T_2f330_row2_col2" class="data row2 col2" >1.008</td>
#       <td id="T_2f330_row2_col3" class="data row2 col3" >1.006</td>
#     </tr>
#     <tr>
#       <th id="T_2f330_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_2f330_row3_col0" class="data row3 col0" >1.011</td>
#       <td id="T_2f330_row3_col1" class="data row3 col1" >1.015</td>
#       <td id="T_2f330_row3_col2" class="data row3 col2" >1.009</td>
#       <td id="T_2f330_row3_col3" class="data row3 col3" >1.011</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8707c_row0_col0 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_8707c_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8707c_row0_col2, #T_8707c_row0_col3 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_8707c_row1_col0 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_8707c_row1_col1 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_8707c_row1_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8707c_row1_col3 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_8707c_row2_col0 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_8707c_row2_col1, #T_8707c_row2_col3 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_8707c_row2_col2 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_8707c_row3_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_8707c_row3_col1 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_8707c_row3_col2 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_8707c_row3_col3 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# </style>
# <table id="T_8707c">
#   <caption>4. E_max peor de la ventana · razón contra el MEJOR de cada ventana (test) · 1.000 = gana siempre</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_8707c_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_8707c_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_8707c_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_8707c_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8707c_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_8707c_row0_col0" class="data row0 col0" >1.017</td>
#       <td id="T_8707c_row0_col1" class="data row0 col1" >1.014</td>
#       <td id="T_8707c_row0_col2" class="data row0 col2" >1.015</td>
#       <td id="T_8707c_row0_col3" class="data row0 col3" >1.015</td>
#     </tr>
#     <tr>
#       <th id="T_8707c_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_8707c_row1_col0" class="data row1 col0" >1.032</td>
#       <td id="T_8707c_row1_col1" class="data row1 col1" >1.062</td>
#       <td id="T_8707c_row1_col2" class="data row1 col2" >1.112</td>
#       <td id="T_8707c_row1_col3" class="data row1 col3" >1.084</td>
#     </tr>
#     <tr>
#       <th id="T_8707c_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_8707c_row2_col0" class="data row2 col0" >1.022</td>
#       <td id="T_8707c_row2_col1" class="data row2 col1" >1.018</td>
#       <td id="T_8707c_row2_col2" class="data row2 col2" >1.018</td>
#       <td id="T_8707c_row2_col3" class="data row2 col3" >1.018</td>
#     </tr>
#     <tr>
#       <th id="T_8707c_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_8707c_row3_col0" class="data row3 col0" >1.026</td>
#       <td id="T_8707c_row3_col1" class="data row3 col1" >1.036</td>
#       <td id="T_8707c_row3_col2" class="data row3 col2" >1.039</td>
#       <td id="T_8707c_row3_col3" class="data row3 col3" >1.035</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Figura: % de ventanas ganadas, por modelo y metrica, train contra test.
_Ms = sorted(EST)
for M in _Ms:
    sub_M = gana_A_df[gana_A_df.M == M]
    modelos = sorted(sub_M["modelo"].unique())
    fig, axes = plt.subplots(1, len(METRICAS_A),
                             figsize=(5.2 * len(METRICAS_A), 4.2), sharey=True)
    if len(METRICAS_A) == 1:
        axes = [axes]
    ancho = 0.8 / 2
    xs = np.arange(len(modelos))
    for ax, (etiqueta, _c) in zip(axes, METRICAS_A):
        for i_b, bloque in enumerate(("train", "test")):
            vals = [float(sub_M[(sub_M.modelo == m) & (sub_M.bloque == bloque)
                                & (sub_M.metrica == etiqueta)]
                          ["pct_ventanas_ganadas"].iloc[0]) for m in modelos]
            ax.bar(xs + (i_b - 0.5) * ancho, vals, width=ancho, label=bloque,
                   color=("#2c7fb8" if bloque == "train" else "#c0392b"))
        ax.set_xticks(xs); ax.set_xticklabels(modelos, rotation=30, ha="right",
                                              fontsize=8)
        ax.set_title(etiqueta, fontsize=10); ax.set_ylim(0, 1)
        ax.legend(fontsize=8)
    axes[0].set_ylabel("% de ventanas ganadas")
    fig.suptitle(f"M={M} · qué modelo gana cada ventana (w={W_COMP})", fontsize=12)
    fig.tight_layout()
    fig.savefig(EST[M]["paths"]["out_report"]
                / f"{PREFIJO + 8}_ganador_ventana_bloqueA.png",
                dpi=150, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## 7. Bloque B: quién gana cada ventana, y por cuánto
#
# La misma lectura de §6, restringida a las series que **tienen un mecanismo de
# intervalo propio**: el FAR —cuyo IC a un paso sale de su propia especificación
# $X_{t+1}=\rho(X_t)+\varepsilon$— y el PSBPM-FD —cuya predictiva se muestrea y
# cuyos cuantiles empíricos dan la banda—.
#
# El Winkler es la única regla de puntuación propia del bloque, así que es la
# que decide quién gana; PICP y MPIW lo descomponen en cobertura y ancho.

# %%
# % de ventanas ganadas y razones, sobre las bandas (FAR y PSBPM-FD).
# En picp / picp_simultaneo "ganar" NO es tener el valor mas bajo sino estar
# mas cerca del nominal: se compara |picp - NIVEL_IC|.
gana_B, rel_B = [], []
for M in EST:
    e = EST[M]
    vb = e["ventana_B"]
    limpio = vb[~vb["cruza_T0"]]
    bandas = list(limpio["banda"].unique())

    for etiqueta, col in METRICAS_B:
        piv = limpio.pivot_table(index=["t_centro", "bloque"], columns="banda",
                                 values=col)[bandas]
        # Criterio de "mejor" por metrica.
        objetivo = (piv - NIVEL_IC).abs() if col.startswith("picp") else piv
        ganador = objetivo.idxmin(axis=1)
        for bloque in ("train", "test"):
            sel = ganador.index.get_level_values("bloque") == bloque
            sub = ganador[sel]
            n_tot = len(sub)
            for b in bandas:
                gana_B.append({
                    "M": M, "metrica": etiqueta, "columna": col,
                    "bloque": bloque, "banda": b,
                    "pct_ventanas_ganadas": float((sub == b).mean()) if n_tot else np.nan,
                    "n_ventanas": n_tot,
                    "criterio": "|valor - nominal|" if col.startswith("picp")
                                else "menor es mejor"})
            o = objetivo[sel]
            mejor = o.min(axis=1)
            for b in bandas:
                rel_B.append({"M": M, "metrica": etiqueta, "bloque": bloque,
                              "banda": b,
                              "razon_vs_mejor": float(
                                  (o[b] / mejor.replace(0, np.nan)).mean())})

gana_B_df = pd.DataFrame(gana_B)
rel_B_df  = pd.DataFrame(rel_B)
gana_B_df.to_csv(PATH_BARRIDO / "97_ganador_ventana_bloqueB.csv", index=False)
rel_B_df.to_csv(PATH_BARRIDO / "97_razones_bloqueB.csv", index=False)

for etiqueta, col in METRICAS_B:
    piv_g = (gana_B_df[(gana_B_df.metrica == etiqueta) & (gana_B_df.bloque == "test")]
             .pivot(index="banda", columns="M", values="pct_ventanas_ganadas"))
    crit = ("más cerca del nominal" if col.startswith("picp") else "menor es mejor")
    display(piv_g.style.format("{:.1%}", na_rep="-")
            .background_gradient(cmap="RdYlGn", axis=None)
            .set_caption(f"{etiqueta} · % de ventanas de PRUEBA ganadas "
                         f"(criterio: {crit})"))
# Out:
# <style type="text/css">
# #T_60dd3_row0_col0, #T_60dd3_row0_col1, #T_60dd3_row0_col2, #T_60dd3_row0_col3, #T_60dd3_row1_col0, #T_60dd3_row1_col1, #T_60dd3_row1_col2, #T_60dd3_row1_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_60dd3_row2_col0, #T_60dd3_row2_col1, #T_60dd3_row2_col2, #T_60dd3_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_60dd3">
#   <caption>5. MPIW · % de ventanas de PRUEBA ganadas (criterio: menor es mejor)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_60dd3_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_60dd3_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_60dd3_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_60dd3_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60dd3_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_60dd3_row0_col0" class="data row0 col0" >0.0%</td>
#       <td id="T_60dd3_row0_col1" class="data row0 col1" >0.0%</td>
#       <td id="T_60dd3_row0_col2" class="data row0 col2" >0.0%</td>
#       <td id="T_60dd3_row0_col3" class="data row0 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_60dd3_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_60dd3_row1_col0" class="data row1 col0" >0.0%</td>
#       <td id="T_60dd3_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_60dd3_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_60dd3_row1_col3" class="data row1 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_60dd3_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_60dd3_row2_col0" class="data row2 col0" >100.0%</td>
#       <td id="T_60dd3_row2_col1" class="data row2 col1" >100.0%</td>
#       <td id="T_60dd3_row2_col2" class="data row2 col2" >100.0%</td>
#       <td id="T_60dd3_row2_col3" class="data row2 col3" >100.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_fe105_row0_col0 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_fe105_row0_col1 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_fe105_row0_col2 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_fe105_row0_col3 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_fe105_row1_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_fe105_row1_col1 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_fe105_row1_col2 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_fe105_row1_col3 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_fe105_row2_col0, #T_fe105_row2_col1, #T_fe105_row2_col2, #T_fe105_row2_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fe105">
#   <caption>6. PICP puntual · % de ventanas de PRUEBA ganadas (criterio: más cerca del nominal)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_fe105_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_fe105_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_fe105_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_fe105_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe105_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_fe105_row0_col0" class="data row0 col0" >44.3%</td>
#       <td id="T_fe105_row0_col1" class="data row0 col1" >54.6%</td>
#       <td id="T_fe105_row0_col2" class="data row0 col2" >54.2%</td>
#       <td id="T_fe105_row0_col3" class="data row0 col3" >51.3%</td>
#     </tr>
#     <tr>
#       <th id="T_fe105_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_fe105_row1_col0" class="data row1 col0" >55.7%</td>
#       <td id="T_fe105_row1_col1" class="data row1 col1" >45.4%</td>
#       <td id="T_fe105_row1_col2" class="data row1 col2" >45.8%</td>
#       <td id="T_fe105_row1_col3" class="data row1 col3" >48.7%</td>
#     </tr>
#     <tr>
#       <th id="T_fe105_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_fe105_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_fe105_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_fe105_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_fe105_row2_col3" class="data row2 col3" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_72649_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_72649_row0_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_72649_row0_col2 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_72649_row0_col3 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_72649_row1_col0 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_72649_row1_col1 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_72649_row1_col2 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_72649_row1_col3 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_72649_row2_col0, #T_72649_row2_col1, #T_72649_row2_col2, #T_72649_row2_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72649">
#   <caption>7. PICPB curva completa · % de ventanas de PRUEBA ganadas (criterio: más cerca del nominal)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_72649_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_72649_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_72649_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_72649_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72649_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_72649_row0_col0" class="data row0 col0" >81.5%</td>
#       <td id="T_72649_row0_col1" class="data row0 col1" >74.9%</td>
#       <td id="T_72649_row0_col2" class="data row0 col2" >65.3%</td>
#       <td id="T_72649_row0_col3" class="data row0 col3" >66.1%</td>
#     </tr>
#     <tr>
#       <th id="T_72649_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_72649_row1_col0" class="data row1 col0" >18.5%</td>
#       <td id="T_72649_row1_col1" class="data row1 col1" >25.1%</td>
#       <td id="T_72649_row1_col2" class="data row1 col2" >34.7%</td>
#       <td id="T_72649_row1_col3" class="data row1 col3" >33.9%</td>
#     </tr>
#     <tr>
#       <th id="T_72649_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_72649_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_72649_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_72649_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_72649_row2_col3" class="data row2 col3" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ea471_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ea471_row0_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_ea471_row0_col2 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_ea471_row0_col3 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_ea471_row1_col0 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_ea471_row1_col1 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_ea471_row1_col2 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_ea471_row1_col3 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_ea471_row2_col0, #T_ea471_row2_col1, #T_ea471_row2_col2, #T_ea471_row2_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ea471">
#   <caption>8. Winkler · % de ventanas de PRUEBA ganadas (criterio: menor es mejor)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_ea471_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_ea471_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_ea471_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_ea471_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea471_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_ea471_row0_col0" class="data row0 col0" >79.7%</td>
#       <td id="T_ea471_row0_col1" class="data row0 col1" >77.5%</td>
#       <td id="T_ea471_row0_col2" class="data row0 col2" >76.8%</td>
#       <td id="T_ea471_row0_col3" class="data row0 col3" >77.9%</td>
#     </tr>
#     <tr>
#       <th id="T_ea471_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_ea471_row1_col0" class="data row1 col0" >20.3%</td>
#       <td id="T_ea471_row1_col1" class="data row1 col1" >22.5%</td>
#       <td id="T_ea471_row1_col2" class="data row1 col2" >23.2%</td>
#       <td id="T_ea471_row1_col3" class="data row1 col3" >22.1%</td>
#     </tr>
#     <tr>
#       <th id="T_ea471_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_ea471_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_ea471_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_ea471_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_ea471_row2_col3" class="data row2 col3" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8bf5a_row0_col0 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_8bf5a_row0_col1, #T_8bf5a_row0_col3 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_8bf5a_row0_col2 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_8bf5a_row1_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8bf5a_row1_col1, #T_8bf5a_row1_col3 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_8bf5a_row1_col2 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_8bf5a_row2_col0, #T_8bf5a_row2_col1, #T_8bf5a_row2_col2, #T_8bf5a_row2_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8bf5a">
#   <caption>9. Winkler max promedio · % de ventanas de PRUEBA ganadas (criterio: menor es mejor)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_8bf5a_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_8bf5a_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_8bf5a_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_8bf5a_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bf5a_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_8bf5a_row0_col0" class="data row0 col0" >38.7%</td>
#       <td id="T_8bf5a_row0_col1" class="data row0 col1" >44.6%</td>
#       <td id="T_8bf5a_row0_col2" class="data row0 col2" >45.8%</td>
#       <td id="T_8bf5a_row0_col3" class="data row0 col3" >44.6%</td>
#     </tr>
#     <tr>
#       <th id="T_8bf5a_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_8bf5a_row1_col0" class="data row1 col0" >61.3%</td>
#       <td id="T_8bf5a_row1_col1" class="data row1 col1" >55.4%</td>
#       <td id="T_8bf5a_row1_col2" class="data row1 col2" >54.2%</td>
#       <td id="T_8bf5a_row1_col3" class="data row1 col3" >55.4%</td>
#     </tr>
#     <tr>
#       <th id="T_8bf5a_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_8bf5a_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_8bf5a_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_8bf5a_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_8bf5a_row2_col3" class="data row2 col3" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_36c87_row0_col0 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_36c87_row0_col1, #T_36c87_row0_col2, #T_36c87_row0_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_36c87_row1_col0 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_36c87_row1_col1, #T_36c87_row1_col2, #T_36c87_row1_col3 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_36c87_row2_col0, #T_36c87_row2_col1, #T_36c87_row2_col2, #T_36c87_row2_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_36c87">
#   <caption>10. Winkler max peor ventana · % de ventanas de PRUEBA ganadas (criterio: menor es mejor)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_36c87_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_36c87_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_36c87_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_36c87_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36c87_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_36c87_row0_col0" class="data row0 col0" >49.8%</td>
#       <td id="T_36c87_row0_col1" class="data row0 col1" >55.4%</td>
#       <td id="T_36c87_row0_col2" class="data row0 col2" >55.4%</td>
#       <td id="T_36c87_row0_col3" class="data row0 col3" >55.4%</td>
#     </tr>
#     <tr>
#       <th id="T_36c87_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_36c87_row1_col0" class="data row1 col0" >50.2%</td>
#       <td id="T_36c87_row1_col1" class="data row1 col1" >44.6%</td>
#       <td id="T_36c87_row1_col2" class="data row1 col2" >44.6%</td>
#       <td id="T_36c87_row1_col3" class="data row1 col3" >44.6%</td>
#     </tr>
#     <tr>
#       <th id="T_36c87_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_36c87_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_36c87_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_36c87_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_36c87_row2_col3" class="data row2 col3" >0.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 8. Cuadro resumen: mínimo, máximo y promedio
#
# Igual que en `61_04`: la ventana móvil genera una **serie** por métrica y por
# modelo, no una cifra. El resumen muestra los tres números que describen esa
# serie —mínimo, máximo y promedio— por bloque train/test, excluyendo las
# ventanas que cruzan $T_0$.
#
# El **máximo** es el que no aparece en ninguna tabla de promedios y suele ser el
# que decide: un modelo con buen promedio y un máximo muy alto falla feo en
# algún tramo, y eso es información distinta de su error típico.

# %%
# Bloque A: min / max / promedio por modelo y metrica.
resA = []
for M in EST:
    e = EST[M]
    tw = e["tablas_w"][W_COMP]
    limpio = tw[~tw["cruza_T0"]]
    for etiqueta, col in METRICAS_A:
        g = limpio.groupby(["modelo", "bloque"])[col].agg(["min", "max", "mean"])
        for (modelo, bloque), r in g.iterrows():
            resA.append({"M": M, "metrica": etiqueta, "columna": col,
                         "modelo": modelo, "bloque": bloque,
                         "minimo": float(r["min"]), "maximo": float(r["max"]),
                         "promedio": float(r["mean"])})
resumen_A = pd.DataFrame(resA)
resumen_A.to_csv(PATH_BARRIDO / "98_resumen_bloqueA_min_max_prom.csv", index=False)

for M in EST:
    sub = (resumen_A[(resumen_A.M == M) & (resumen_A.bloque == "test")]
           .set_index(["metrica", "modelo"])[["minimo", "maximo", "promedio"]])
    display(sub.style.format("{:.6f}")
            .background_gradient(subset=["maximo"], cmap="RdYlGn_r")
            .set_caption(f"M={M} · Bloque A en el TEST · mínimo / máximo / "
                         f"promedio sobre las ventanas (w={W_COMP})"))
# Out:
# <style type="text/css">
# #T_9244e_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_9244e_row1_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_9244e_row2_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_9244e_row3_col1 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_9244e_row4_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_9244e_row5_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_9244e_row6_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_9244e_row7_col1 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_9244e_row8_col1 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_9244e_row9_col1, #T_9244e_row13_col1 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_9244e_row10_col1 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_9244e_row11_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_9244e_row12_col1 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_9244e_row14_col1 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_9244e_row15_col1 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_9244e_row16_col1, #T_9244e_row18_col1 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_9244e_row17_col1 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_9244e_row19_col1 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_9244e_row20_col1 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_9244e_row21_col1 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_9244e_row22_col1 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_9244e_row23_col1, #T_9244e_row24_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_9244e_row25_col1 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_9244e_row26_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_9244e_row27_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9244e">
#   <caption>M=1 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9244e_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_9244e_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_9244e_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9244e_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_9244e_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_9244e_row0_col0" class="data row0 col0" >0.296843</td>
#       <td id="T_9244e_row0_col1" class="data row0 col1" >0.324336</td>
#       <td id="T_9244e_row0_col2" class="data row0 col2" >0.310031</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_9244e_row1_col0" class="data row1 col0" >0.319077</td>
#       <td id="T_9244e_row1_col1" class="data row1 col1" >0.359050</td>
#       <td id="T_9244e_row1_col2" class="data row1 col2" >0.341189</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_9244e_row2_col0" class="data row2 col0" >0.325910</td>
#       <td id="T_9244e_row2_col1" class="data row2 col1" >0.376738</td>
#       <td id="T_9244e_row2_col2" class="data row2 col2" >0.348966</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_9244e_row3_col0" class="data row3 col0" >0.324171</td>
#       <td id="T_9244e_row3_col1" class="data row3 col1" >0.364369</td>
#       <td id="T_9244e_row3_col2" class="data row3 col2" >0.345671</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_9244e_row4_col0" class="data row4 col0" >0.328387</td>
#       <td id="T_9244e_row4_col1" class="data row4 col1" >0.372779</td>
#       <td id="T_9244e_row4_col2" class="data row4 col2" >0.348127</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_9244e_row5_col0" class="data row5 col0" >0.330174</td>
#       <td id="T_9244e_row5_col1" class="data row5 col1" >0.417514</td>
#       <td id="T_9244e_row5_col2" class="data row5 col2" >0.359883</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_9244e_row6_col0" class="data row6 col0" >0.334007</td>
#       <td id="T_9244e_row6_col1" class="data row6 col1" >0.380448</td>
#       <td id="T_9244e_row6_col2" class="data row6 col2" >0.356245</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_9244e_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_9244e_row7_col0" class="data row7 col0" >0.372821</td>
#       <td id="T_9244e_row7_col1" class="data row7 col1" >0.406573</td>
#       <td id="T_9244e_row7_col2" class="data row7 col2" >0.388346</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_9244e_row8_col0" class="data row8 col0" >0.399529</td>
#       <td id="T_9244e_row8_col1" class="data row8 col1" >0.451953</td>
#       <td id="T_9244e_row8_col2" class="data row8 col2" >0.429101</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_9244e_row9_col0" class="data row9 col0" >0.407911</td>
#       <td id="T_9244e_row9_col1" class="data row9 col1" >0.472441</td>
#       <td id="T_9244e_row9_col2" class="data row9 col2" >0.438115</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_9244e_row10_col0" class="data row10 col0" >0.407189</td>
#       <td id="T_9244e_row10_col1" class="data row10 col1" >0.458610</td>
#       <td id="T_9244e_row10_col2" class="data row10 col2" >0.434046</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_9244e_row11_col0" class="data row11 col0" >0.410957</td>
#       <td id="T_9244e_row11_col1" class="data row11 col1" >0.467899</td>
#       <td id="T_9244e_row11_col2" class="data row11 col2" >0.436813</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_9244e_row12_col0" class="data row12 col0" >0.408984</td>
#       <td id="T_9244e_row12_col1" class="data row12 col1" >0.520641</td>
#       <td id="T_9244e_row12_col2" class="data row12 col2" >0.451269</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_9244e_row13_col0" class="data row13 col0" >0.418676</td>
#       <td id="T_9244e_row13_col1" class="data row13 col1" >0.476973</td>
#       <td id="T_9244e_row13_col2" class="data row13 col2" >0.447163</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_9244e_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_9244e_row14_col0" class="data row14 col0" >0.952149</td>
#       <td id="T_9244e_row14_col1" class="data row14 col1" >1.083042</td>
#       <td id="T_9244e_row14_col2" class="data row14 col2" >1.009502</td>
#     </tr>
#     <tr>
#       <th id="T_9244e_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_9244e_row15_col0" class="data row15 col0" >0.993144</td>
#       <td id="T_9244e_row15_col1" class="data row15 col1" >1.172969</td>
#       <td id="T_9244e_row15_col2" class="data row15 col2" >1.087345</td>
#     </tr>
#     <tr>
#       <th
# <style type="text/css">
# #T_ccc41_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ccc41_row1_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_ccc41_row2_col1 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_ccc41_row3_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_ccc41_row4_col1 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_ccc41_row5_col1 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_ccc41_row6_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_ccc41_row7_col1 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_ccc41_row8_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_ccc41_row9_col1 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_ccc41_row10_col1 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_ccc41_row11_col1 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_ccc41_row12_col1 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_ccc41_row13_col1 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_ccc41_row14_col1 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_ccc41_row15_col1 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_ccc41_row16_col1 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_ccc41_row17_col1 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_ccc41_row18_col1 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_ccc41_row19_col1 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_ccc41_row20_col1 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_ccc41_row21_col1 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_ccc41_row22_col1 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_ccc41_row23_col1 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_ccc41_row24_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_ccc41_row25_col1 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_ccc41_row26_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ccc41_row27_col1 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ccc41">
#   <caption>M=2 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccc41_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_ccc41_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_ccc41_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccc41_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_ccc41_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_ccc41_row0_col0" class="data row0 col0" >0.282897</td>
#       <td id="T_ccc41_row0_col1" class="data row0 col1" >0.305592</td>
#       <td id="T_ccc41_row0_col2" class="data row0 col2" >0.294756</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_ccc41_row1_col0" class="data row1 col0" >0.319077</td>
#       <td id="T_ccc41_row1_col1" class="data row1 col1" >0.359050</td>
#       <td id="T_ccc41_row1_col2" class="data row1 col2" >0.341189</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_ccc41_row2_col0" class="data row2 col0" >0.324490</td>
#       <td id="T_ccc41_row2_col1" class="data row2 col1" >0.384822</td>
#       <td id="T_ccc41_row2_col2" class="data row2 col2" >0.359013</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_ccc41_row3_col0" class="data row3 col0" >0.323301</td>
#       <td id="T_ccc41_row3_col1" class="data row3 col1" >0.363302</td>
#       <td id="T_ccc41_row3_col2" class="data row3 col2" >0.344630</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_ccc41_row4_col0" class="data row4 col0" >0.322743</td>
#       <td id="T_ccc41_row4_col1" class="data row4 col1" >0.369617</td>
#       <td id="T_ccc41_row4_col2" class="data row4 col2" >0.348478</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_ccc41_row5_col0" class="data row5 col0" >0.330174</td>
#       <td id="T_ccc41_row5_col1" class="data row5 col1" >0.417514</td>
#       <td id="T_ccc41_row5_col2" class="data row5 col2" >0.359883</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_ccc41_row6_col0" class="data row6 col0" >0.349590</td>
#       <td id="T_ccc41_row6_col1" class="data row6 col1" >0.401658</td>
#       <td id="T_ccc41_row6_col2" class="data row6 col2" >0.373168</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_ccc41_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_ccc41_row7_col0" class="data row7 col0" >0.356569</td>
#       <td id="T_ccc41_row7_col1" class="data row7 col1" >0.380501</td>
#       <td id="T_ccc41_row7_col2" class="data row7 col2" >0.369373</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_ccc41_row8_col0" class="data row8 col0" >0.399529</td>
#       <td id="T_ccc41_row8_col1" class="data row8 col1" >0.451953</td>
#       <td id="T_ccc41_row8_col2" class="data row8 col2" >0.429101</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_ccc41_row9_col0" class="data row9 col0" >0.404856</td>
#       <td id="T_ccc41_row9_col1" class="data row9 col1" >0.484026</td>
#       <td id="T_ccc41_row9_col2" class="data row9 col2" >0.451324</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_ccc41_row10_col0" class="data row10 col0" >0.405605</td>
#       <td id="T_ccc41_row10_col1" class="data row10 col1" >0.457172</td>
#       <td id="T_ccc41_row10_col2" class="data row10 col2" >0.432786</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_ccc41_row11_col0" class="data row11 col0" >0.403494</td>
#       <td id="T_ccc41_row11_col1" class="data row11 col1" >0.464605</td>
#       <td id="T_ccc41_row11_col2" class="data row11 col2" >0.437861</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_ccc41_row12_col0" class="data row12 col0" >0.408984</td>
#       <td id="T_ccc41_row12_col1" class="data row12 col1" >0.520641</td>
#       <td id="T_ccc41_row12_col2" class="data row12 col2" >0.451269</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_ccc41_row13_col0" class="data row13 col0" >0.437631</td>
#       <td id="T_ccc41_row13_col1" class="data row13 col1" >0.499518</td>
#       <td id="T_ccc41_row13_col2" class="data row13 col2" >0.467875</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_ccc41_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_ccc41_row14_col0" class="data row14 col0" >0.917147</td>
#       <td id="T_ccc41_row14_col1" class="data row14 col1" >1.029790</td>
#       <td id="T_ccc41_row14_col2" class="data row14 col2" >0.969742</td>
#     </tr>
#     <tr>
#       <th id="T_ccc41_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_ccc41_row15_col0" class="data row15 col0" >0.993144</td>
#       <td id="T_ccc41_row
# <style type="text/css">
# #T_8400e_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8400e_row1_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_8400e_row2_col1 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_8400e_row3_col1, #T_8400e_row4_col1, #T_8400e_row7_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_8400e_row5_col1 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_8400e_row6_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_8400e_row8_col1, #T_8400e_row10_col1 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_8400e_row9_col1 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_8400e_row11_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_8400e_row12_col1 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_8400e_row13_col1 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_8400e_row14_col1 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_8400e_row15_col1 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_8400e_row16_col1 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_8400e_row17_col1 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_8400e_row18_col1 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_8400e_row19_col1 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_8400e_row20_col1 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_8400e_row21_col1 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_8400e_row22_col1 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_8400e_row23_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8400e_row24_col1 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_8400e_row25_col1 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_8400e_row26_col1 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_8400e_row27_col1 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8400e">
#   <caption>M=3 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8400e_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_8400e_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_8400e_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8400e_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_8400e_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_8400e_row0_col0" class="data row0 col0" >0.272363</td>
#       <td id="T_8400e_row0_col1" class="data row0 col1" >0.296711</td>
#       <td id="T_8400e_row0_col2" class="data row0 col2" >0.285956</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_8400e_row1_col0" class="data row1 col0" >0.319077</td>
#       <td id="T_8400e_row1_col1" class="data row1 col1" >0.359050</td>
#       <td id="T_8400e_row1_col2" class="data row1 col2" >0.341189</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_8400e_row2_col0" class="data row2 col0" >0.331638</td>
#       <td id="T_8400e_row2_col1" class="data row2 col1" >0.393587</td>
#       <td id="T_8400e_row2_col2" class="data row2 col2" >0.357358</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_8400e_row3_col0" class="data row3 col0" >0.323134</td>
#       <td id="T_8400e_row3_col1" class="data row3 col1" >0.363403</td>
#       <td id="T_8400e_row3_col2" class="data row3 col2" >0.344515</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_8400e_row4_col0" class="data row4 col0" >0.321388</td>
#       <td id="T_8400e_row4_col1" class="data row4 col1" >0.368366</td>
#       <td id="T_8400e_row4_col2" class="data row4 col2" >0.345777</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_8400e_row5_col0" class="data row5 col0" >0.330174</td>
#       <td id="T_8400e_row5_col1" class="data row5 col1" >0.417514</td>
#       <td id="T_8400e_row5_col2" class="data row5 col2" >0.359883</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_8400e_row6_col0" class="data row6 col0" >0.351911</td>
#       <td id="T_8400e_row6_col1" class="data row6 col1" >0.405985</td>
#       <td id="T_8400e_row6_col2" class="data row6 col2" >0.381218</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_8400e_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_8400e_row7_col0" class="data row7 col0" >0.344925</td>
#       <td id="T_8400e_row7_col1" class="data row7 col1" >0.367751</td>
#       <td id="T_8400e_row7_col2" class="data row7 col2" >0.358151</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_8400e_row8_col0" class="data row8 col0" >0.399529</td>
#       <td id="T_8400e_row8_col1" class="data row8 col1" >0.451953</td>
#       <td id="T_8400e_row8_col2" class="data row8 col2" >0.429101</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_8400e_row9_col0" class="data row9 col0" >0.413927</td>
#       <td id="T_8400e_row9_col1" class="data row9 col1" >0.494925</td>
#       <td id="T_8400e_row9_col2" class="data row9 col2" >0.450497</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_8400e_row10_col0" class="data row10 col0" >0.405400</td>
#       <td id="T_8400e_row10_col1" class="data row10 col1" >0.457372</td>
#       <td id="T_8400e_row10_col2" class="data row10 col2" >0.432664</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_8400e_row11_col0" class="data row11 col0" >0.401992</td>
#       <td id="T_8400e_row11_col1" class="data row11 col1" >0.463951</td>
#       <td id="T_8400e_row11_col2" class="data row11 col2" >0.434584</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_8400e_row12_col0" class="data row12 col0" >0.408984</td>
#       <td id="T_8400e_row12_col1" class="data row12 col1" >0.520641</td>
#       <td id="T_8400e_row12_col2" class="data row12 col2" >0.451269</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_8400e_row13_col0" class="data row13 col0" >0.442985</td>
#       <td id="T_8400e_row13_col1" class="data row13 col1" >0.506474</td>
#       <td id="T_8400e_row13_col2" class="data row13 col2" >0.477296</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_8400e_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_8400e_row14_col0" class="data row14 col0" >0.883114</td>
#       <td id="T_8400e_row14_col1" class="data row14 col1" >1.000756</td>
#       <td id="T_8400e_row14_col2" class="data row14 col2" >0.938455</td>
#     </tr>
#     <tr>
#       <th id="T_8400e_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_8400e_row15_col0" class="data row15 col0" >0.993144</td>
#       <td id="T_8400e_row15_col1" class="data row15 col1" >1.172969</td>
#       <td id="T_8400e_row15_col2" class="data row15 col2" >1.087345</td>
#     </tr>
#     <tr>
#       <th
# <style type="text/css">
# #T_8d2ee_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8d2ee_row1_col1, #T_8d2ee_row3_col1, #T_8d2ee_row7_col1 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_8d2ee_row2_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_8d2ee_row4_col1 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_8d2ee_row5_col1, #T_8d2ee_row6_col1 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_8d2ee_row8_col1, #T_8d2ee_row10_col1 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_8d2ee_row9_col1 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_8d2ee_row11_col1 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_8d2ee_row12_col1, #T_8d2ee_row13_col1 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_8d2ee_row14_col1 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_8d2ee_row15_col1 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_8d2ee_row16_col1 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_8d2ee_row17_col1 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_8d2ee_row18_col1 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_8d2ee_row19_col1 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_8d2ee_row20_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_8d2ee_row21_col1 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_8d2ee_row22_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_8d2ee_row23_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8d2ee_row24_col1 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_8d2ee_row25_col1 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_8d2ee_row26_col1 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_8d2ee_row27_col1 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8d2ee">
#   <caption>M=4 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d2ee_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_8d2ee_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_8d2ee_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d2ee_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_8d2ee_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_8d2ee_row0_col0" class="data row0 col0" >0.266464</td>
#       <td id="T_8d2ee_row0_col1" class="data row0 col1" >0.288870</td>
#       <td id="T_8d2ee_row0_col2" class="data row0 col2" >0.278450</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_8d2ee_row1_col0" class="data row1 col0" >0.319077</td>
#       <td id="T_8d2ee_row1_col1" class="data row1 col1" >0.359050</td>
#       <td id="T_8d2ee_row1_col2" class="data row1 col2" >0.341189</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_8d2ee_row2_col0" class="data row2 col0" >0.326711</td>
#       <td id="T_8d2ee_row2_col1" class="data row2 col1" >0.399803</td>
#       <td id="T_8d2ee_row2_col2" class="data row2 col2" >0.356420</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_8d2ee_row3_col0" class="data row3 col0" >0.322892</td>
#       <td id="T_8d2ee_row3_col1" class="data row3 col1" >0.362872</td>
#       <td id="T_8d2ee_row3_col2" class="data row3 col2" >0.344380</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_8d2ee_row4_col0" class="data row4 col0" >0.319613</td>
#       <td id="T_8d2ee_row4_col1" class="data row4 col1" >0.369597</td>
#       <td id="T_8d2ee_row4_col2" class="data row4 col2" >0.345098</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_8d2ee_row5_col0" class="data row5 col0" >0.330174</td>
#       <td id="T_8d2ee_row5_col1" class="data row5 col1" >0.417514</td>
#       <td id="T_8d2ee_row5_col2" class="data row5 col2" >0.359883</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_8d2ee_row6_col0" class="data row6 col0" >0.360116</td>
#       <td id="T_8d2ee_row6_col1" class="data row6 col1" >0.414906</td>
#       <td id="T_8d2ee_row6_col2" class="data row6 col2" >0.389863</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_8d2ee_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_8d2ee_row7_col0" class="data row7 col0" >0.336953</td>
#       <td id="T_8d2ee_row7_col1" class="data row7 col1" >0.359154</td>
#       <td id="T_8d2ee_row7_col2" class="data row7 col2" >0.348410</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_8d2ee_row8_col0" class="data row8 col0" >0.399529</td>
#       <td id="T_8d2ee_row8_col1" class="data row8 col1" >0.451953</td>
#       <td id="T_8d2ee_row8_col2" class="data row8 col2" >0.429101</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_8d2ee_row9_col0" class="data row9 col0" >0.408946</td>
#       <td id="T_8d2ee_row9_col1" class="data row9 col1" >0.501013</td>
#       <td id="T_8d2ee_row9_col2" class="data row9 col2" >0.448489</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_8d2ee_row10_col0" class="data row10 col0" >0.405026</td>
#       <td id="T_8d2ee_row10_col1" class="data row10 col1" >0.456626</td>
#       <td id="T_8d2ee_row10_col2" class="data row10 col2" >0.432489</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_8d2ee_row11_col0" class="data row11 col0" >0.399626</td>
#       <td id="T_8d2ee_row11_col1" class="data row11 col1" >0.464594</td>
#       <td id="T_8d2ee_row11_col2" class="data row11 col2" >0.433931</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_8d2ee_row12_col0" class="data row12 col0" >0.408984</td>
#       <td id="T_8d2ee_row12_col1" class="data row12 col1" >0.520641</td>
#       <td id="T_8d2ee_row12_col2" class="data row12 col2" >0.451269</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_8d2ee_row13_col0" class="data row13 col0" >0.453747</td>
#       <td id="T_8d2ee_row13_col1" class="data row13 col1" >0.519283</td>
#       <td id="T_8d2ee_row13_col2" class="data row13 col2" >0.488863</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_8d2ee_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_8d2ee_row14_col0" class="data row14 col0" >0.852258</td>
#       <td id="T_8d2ee_row14_col1" class="data row14 col1" >0.983748</td>
#       <td id="T_8d2ee_row14_col2" class="data row14 col2" >0.918838</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_8d2ee_row15_col0" class="data row15 col0" >0.993144</td>
#       <td id="T_8d2ee_row15_col1" class="data row15 col1" >1.172969</td>
#       <td id="T_8d2ee_row15_col2" class="data row15 col2" >1.087345</td>
#     </tr>
#     <tr>
#       <th id="T_8d2ee_level1_row16" class="row_heading level1 row16" >GBT</th>
#       <td id="T_8d2ee_row16_col

# %%
# Bloque B: min / max / promedio por banda y metrica.
resB = []
for M in EST:
    e = EST[M]
    vb = e["ventana_B"]
    limpio = vb[~vb["cruza_T0"]]
    for etiqueta, col in METRICAS_B:
        g = limpio.groupby(["banda", "bloque"])[col].agg(["min", "max", "mean"])
        for (banda, bloque), r in g.iterrows():
            resB.append({"M": M, "metrica": etiqueta, "columna": col,
                         "banda": banda, "bloque": bloque,
                         "minimo": float(r["min"]), "maximo": float(r["max"]),
                         "promedio": float(r["mean"])})
resumen_B = pd.DataFrame(resB)
resumen_B.to_csv(PATH_BARRIDO / "99_resumen_bloqueB_min_max_prom.csv", index=False)

for M in EST:
    sub = (resumen_B[(resumen_B.M == M) & (resumen_B.bloque == "test")]
           .set_index(["metrica", "banda"])[["minimo", "maximo", "promedio"]])
    display(sub.style.format("{:.4f}")
            .set_caption(f"M={M} · Bloque B en el TEST · mínimo / máximo / "
                         f"promedio sobre las ventanas (w={W_COMP}) · "
                         f"nivel nominal {NIVEL_IC:.0%}"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_6716f">
#   <caption>M=1 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6716f_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_6716f_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_6716f_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6716f_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_6716f_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_6716f_row0_col0" class="data row0 col0" >1.7122</td>
#       <td id="T_6716f_row0_col1" class="data row0 col1" >1.7122</td>
#       <td id="T_6716f_row0_col2" class="data row0 col2" >1.7122</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_6716f_row1_col0" class="data row1 col0" >1.7353</td>
#       <td id="T_6716f_row1_col1" class="data row1 col1" >1.7353</td>
#       <td id="T_6716f_row1_col2" class="data row1 col2" >1.7353</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_6716f_row2_col0" class="data row2 col0" >0.8103</td>
#       <td id="T_6716f_row2_col1" class="data row2 col1" >0.8291</td>
#       <td id="T_6716f_row2_col2" class="data row2 col2" >0.8197</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_6716f_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_6716f_row3_col0" class="data row3 col0" >0.9396</td>
#       <td id="T_6716f_row3_col1" class="data row3 col1" >0.9720</td>
#       <td id="T_6716f_row3_col2" class="data row3 col2" >0.9535</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_6716f_row4_col0" class="data row4 col0" >0.9347</td>
#       <td id="T_6716f_row4_col1" class="data row4 col1" >0.9671</td>
#       <td id="T_6716f_row4_col2" class="data row4 col2" >0.9527</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_6716f_row5_col0" class="data row5 col0" >0.6311</td>
#       <td id="T_6716f_row5_col1" class="data row5 col1" >0.6867</td>
#       <td id="T_6716f_row5_col2" class="data row5 col2" >0.6559</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_6716f_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_6716f_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_6716f_row6_col1" class="data row6 col1" >0.2333</td>
#       <td id="T_6716f_row6_col2" class="data row6 col2" >0.1178</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_6716f_row7_col0" class="data row7 col0" >0.0000</td>
#       <td id="T_6716f_row7_col1" class="data row7 col1" >0.2667</td>
#       <td id="T_6716f_row7_col2" class="data row7 col2" >0.1053</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_6716f_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_6716f_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_6716f_row8_col2" class="data row8 col2" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_6716f_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_6716f_row9_col0" class="data row9 col0" >1.8555</td>
#       <td id="T_6716f_row9_col1" class="data row9 col1" >2.1595</td>
#       <td id="T_6716f_row9_col2" class="data row9 col2" >2.0266</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_6716f_row10_col0" class="data row10 col0" >1.8965</td>
#       <td id="T_6716f_row10_col1" class="data row10 col1" >2.1950</td>
#       <td id="T_6716f_row10_col2" class="data row10 col2" >2.0436</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_6716f_row11_col0" class="data row11 col0" >3.5558</td>
#       <td id="T_6716f_row11_col1" class="data row11 col1" >4.6389</td>
#       <td id="T_6716f_row11_col2" class="data row11 col2" >4.0502</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_6716f_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_6716f_row12_col0" class="data row12 col0" >7.8801</td>
#       <td id="T_6716f_row12_col1" class="data row12 col1" >14.4377</td>
#       <td id="T_6716f_row12_col2" class="data row12 col2" >11.2079</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_6716f_row13_col0" class="data row13 col0" >7.2025</td>
#       <td id="T_6716f_row13_col1" class="data row13 col1" >14.5703</td>
#       <td id="T_6716f_row13_col2" class="data row13 col2" >11.0679</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_6716f_row14_col0" class="data row14 col0" >24.2681</td>
#       <td id="T_6716f_row14_col1" class="data row14 col1" >32.1758</td>
#       <td id="T_6716f_row14_col2" class="data row14 col2" >28.3660</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_6716f_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_6716f_row15_col0" class="data row15 col0" >22.7157</td>
#       <td id="T_6716f_row15_col1" class="data row15 col1" >45.5660</td>
#       <td id="T_6716f_row15_col2" class="data row15 col2" >31.8702</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_6716f_row16_col0" class="data row16 col0" >21.9285</td>
#       <td id="T_6716f_row16_col1" class="data row16 col1" >47.0646</td>
#       <td id="T_6716f_row16_col2" class="data row16 col2" >31.9492</td>
#     </tr>
#     <tr>
#       <th id="T_6716f_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_6716f_row17_col0" class="data row17 col0" >40.2116</td>
#       <td id="T_6716f_row17_col1" class="data row17 col1" >64.5410</td>
#       <td id="T_6716f_row17_col2" class="data row17 col2" >49.1334</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_b64b2">
#   <caption>M=2 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b64b2_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_b64b2_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_b64b2_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b64b2_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_b64b2_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_b64b2_row0_col0" class="data row0 col0" >1.7122</td>
#       <td id="T_b64b2_row0_col1" class="data row0 col1" >1.7122</td>
#       <td id="T_b64b2_row0_col2" class="data row0 col2" >1.7122</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_b64b2_row1_col0" class="data row1 col0" >1.7303</td>
#       <td id="T_b64b2_row1_col1" class="data row1 col1" >1.7303</td>
#       <td id="T_b64b2_row1_col2" class="data row1 col2" >1.7303</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_b64b2_row2_col0" class="data row2 col0" >0.9504</td>
#       <td id="T_b64b2_row2_col1" class="data row2 col1" >0.9691</td>
#       <td id="T_b64b2_row2_col2" class="data row2 col2" >0.9599</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_b64b2_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_b64b2_row3_col0" class="data row3 col0" >0.9396</td>
#       <td id="T_b64b2_row3_col1" class="data row3 col1" >0.9720</td>
#       <td id="T_b64b2_row3_col2" class="data row3 col2" >0.9535</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_b64b2_row4_col0" class="data row4 col0" >0.9369</td>
#       <td id="T_b64b2_row4_col1" class="data row4 col1" >0.9689</td>
#       <td id="T_b64b2_row4_col2" class="data row4 col2" >0.9530</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_b64b2_row5_col0" class="data row5 col0" >0.6991</td>
#       <td id="T_b64b2_row5_col1" class="data row5 col1" >0.7582</td>
#       <td id="T_b64b2_row5_col2" class="data row5 col2" >0.7316</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_b64b2_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_b64b2_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_b64b2_row6_col1" class="data row6 col1" >0.2333</td>
#       <td id="T_b64b2_row6_col2" class="data row6 col2" >0.1178</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_b64b2_row7_col0" class="data row7 col0" >0.0000</td>
#       <td id="T_b64b2_row7_col1" class="data row7 col1" >0.2333</td>
#       <td id="T_b64b2_row7_col2" class="data row7 col2" >0.1060</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_b64b2_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_b64b2_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_b64b2_row8_col2" class="data row8 col2" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_b64b2_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_b64b2_row9_col0" class="data row9 col0" >1.8555</td>
#       <td id="T_b64b2_row9_col1" class="data row9 col1" >2.1595</td>
#       <td id="T_b64b2_row9_col2" class="data row9 col2" >2.0266</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_b64b2_row10_col0" class="data row10 col0" >1.8850</td>
#       <td id="T_b64b2_row10_col1" class="data row10 col1" >2.1800</td>
#       <td id="T_b64b2_row10_col2" class="data row10 col2" >2.0393</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_b64b2_row11_col0" class="data row11 col0" >2.8939</td>
#       <td id="T_b64b2_row11_col1" class="data row11 col1" >3.7477</td>
#       <td id="T_b64b2_row11_col2" class="data row11 col2" >3.3360</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_b64b2_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_b64b2_row12_col0" class="data row12 col0" >7.8801</td>
#       <td id="T_b64b2_row12_col1" class="data row12 col1" >14.4377</td>
#       <td id="T_b64b2_row12_col2" class="data row12 col2" >11.2079</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_b64b2_row13_col0" class="data row13 col0" >7.3108</td>
#       <td id="T_b64b2_row13_col1" class="data row13 col1" >14.5850</td>
#       <td id="T_b64b2_row13_col2" class="data row13 col2" >11.0815</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_b64b2_row14_col0" class="data row14 col0" >20.7991</td>
#       <td id="T_b64b2_row14_col1" class="data row14 col1" >29.4961</td>
#       <td id="T_b64b2_row14_col2" class="data row14 col2" >25.7168</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_b64b2_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_b64b2_row15_col0" class="data row15 col0" >22.7157</td>
#       <td id="T_b64b2_row15_col1" class="data row15 col1" >45.5660</td>
#       <td id="T_b64b2_row15_col2" class="data row15 col2" >31.8702</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_b64b2_row16_col0" class="data row16 col0" >21.8594</td>
#       <td id="T_b64b2_row16_col1" class="data row16 col1" >47.1624</td>
#       <td id="T_b64b2_row16_col2" class="data row16 col2" >31.8873</td>
#     </tr>
#     <tr>
#       <th id="T_b64b2_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_b64b2_row17_col0" class="data row17 col0" >38.6252</td>
#       <td id="T_b64b2_row17_col1" class="data row17 col1" >64.5629</td>
#       <td id="T_b64b2_row17_col2" class="data row17 col2" >47.3097</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_bac52">
#   <caption>M=3 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bac52_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_bac52_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_bac52_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bac52_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_bac52_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_bac52_row0_col0" class="data row0 col0" >1.7122</td>
#       <td id="T_bac52_row0_col1" class="data row0 col1" >1.7122</td>
#       <td id="T_bac52_row0_col2" class="data row0 col2" >1.7122</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_bac52_row1_col0" class="data row1 col0" >1.7298</td>
#       <td id="T_bac52_row1_col1" class="data row1 col1" >1.7298</td>
#       <td id="T_bac52_row1_col2" class="data row1 col2" >1.7298</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_bac52_row2_col0" class="data row2 col0" >1.0389</td>
#       <td id="T_bac52_row2_col1" class="data row2 col1" >1.0580</td>
#       <td id="T_bac52_row2_col2" class="data row2 col2" >1.0491</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_bac52_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_bac52_row3_col0" class="data row3 col0" >0.9396</td>
#       <td id="T_bac52_row3_col1" class="data row3 col1" >0.9720</td>
#       <td id="T_bac52_row3_col2" class="data row3 col2" >0.9535</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_bac52_row4_col0" class="data row4 col0" >0.9373</td>
#       <td id="T_bac52_row4_col1" class="data row4 col1" >0.9693</td>
#       <td id="T_bac52_row4_col2" class="data row4 col2" >0.9533</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_bac52_row5_col0" class="data row5 col0" >0.7387</td>
#       <td id="T_bac52_row5_col1" class="data row5 col1" >0.8044</td>
#       <td id="T_bac52_row5_col2" class="data row5 col2" >0.7743</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_bac52_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_bac52_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_bac52_row6_col1" class="data row6 col1" >0.2333</td>
#       <td id="T_bac52_row6_col2" class="data row6 col2" >0.1178</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_bac52_row7_col0" class="data row7 col0" >0.0333</td>
#       <td id="T_bac52_row7_col1" class="data row7 col1" >0.2333</td>
#       <td id="T_bac52_row7_col2" class="data row7 col2" >0.1171</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_bac52_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_bac52_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_bac52_row8_col2" class="data row8 col2" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_bac52_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_bac52_row9_col0" class="data row9 col0" >1.8555</td>
#       <td id="T_bac52_row9_col1" class="data row9 col1" >2.1595</td>
#       <td id="T_bac52_row9_col2" class="data row9 col2" >2.0266</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_bac52_row10_col0" class="data row10 col0" >1.8837</td>
#       <td id="T_bac52_row10_col1" class="data row10 col1" >2.1778</td>
#       <td id="T_bac52_row10_col2" class="data row10 col2" >2.0391</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_bac52_row11_col0" class="data row11 col0" >2.5730</td>
#       <td id="T_bac52_row11_col1" class="data row11 col1" >3.4064</td>
#       <td id="T_bac52_row11_col2" class="data row11 col2" >2.9836</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_bac52_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_bac52_row12_col0" class="data row12 col0" >7.8801</td>
#       <td id="T_bac52_row12_col1" class="data row12 col1" >14.4377</td>
#       <td id="T_bac52_row12_col2" class="data row12 col2" >11.2079</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_bac52_row13_col0" class="data row13 col0" >7.3249</td>
#       <td id="T_bac52_row13_col1" class="data row13 col1" >14.5814</td>
#       <td id="T_bac52_row13_col2" class="data row13 col2" >11.0918</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_bac52_row14_col0" class="data row14 col0" >19.4032</td>
#       <td id="T_bac52_row14_col1" class="data row14 col1" >27.7686</td>
#       <td id="T_bac52_row14_col2" class="data row14 col2" >23.9064</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_bac52_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_bac52_row15_col0" class="data row15 col0" >22.7157</td>
#       <td id="T_bac52_row15_col1" class="data row15 col1" >45.5660</td>
#       <td id="T_bac52_row15_col2" class="data row15 col2" >31.8702</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_bac52_row16_col0" class="data row16 col0" >21.8497</td>
#       <td id="T_bac52_row16_col1" class="data row16 col1" >47.1974</td>
#       <td id="T_bac52_row16_col2" class="data row16 col2" >31.8685</td>
#     </tr>
#     <tr>
#       <th id="T_bac52_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_bac52_row17_col0" class="data row17 col0" >36.2184</td>
#       <td id="T_bac52_row17_col1" class="data row17 col1" >61.3797</td>
#       <td id="T_bac52_row17_col2" class="data row17 col2" >45.8562</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3945f">
#   <caption>M=4 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3945f_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_3945f_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_3945f_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3945f_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_3945f_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_3945f_row0_col0" class="data row0 col0" >1.7122</td>
#       <td id="T_3945f_row0_col1" class="data row0 col1" >1.7122</td>
#       <td id="T_3945f_row0_col2" class="data row0 col2" >1.7122</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_3945f_row1_col0" class="data row1 col0" >1.7290</td>
#       <td id="T_3945f_row1_col1" class="data row1 col1" >1.7290</td>
#       <td id="T_3945f_row1_col2" class="data row1 col2" >1.7290</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_3945f_row2_col0" class="data row2 col0" >1.1091</td>
#       <td id="T_3945f_row2_col1" class="data row2 col1" >1.1262</td>
#       <td id="T_3945f_row2_col2" class="data row2 col2" >1.1158</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_3945f_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_3945f_row3_col0" class="data row3 col0" >0.9396</td>
#       <td id="T_3945f_row3_col1" class="data row3 col1" >0.9720</td>
#       <td id="T_3945f_row3_col2" class="data row3 col2" >0.9535</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_3945f_row4_col0" class="data row4 col0" >0.9378</td>
#       <td id="T_3945f_row4_col1" class="data row4 col1" >0.9689</td>
#       <td id="T_3945f_row4_col2" class="data row4 col2" >0.9530</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_3945f_row5_col0" class="data row5 col0" >0.7751</td>
#       <td id="T_3945f_row5_col1" class="data row5 col1" >0.8240</td>
#       <td id="T_3945f_row5_col2" class="data row5 col2" >0.8010</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_3945f_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_3945f_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_3945f_row6_col1" class="data row6 col1" >0.2333</td>
#       <td id="T_3945f_row6_col2" class="data row6 col2" >0.1178</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_3945f_row7_col0" class="data row7 col0" >0.0333</td>
#       <td id="T_3945f_row7_col1" class="data row7 col1" >0.2333</td>
#       <td id="T_3945f_row7_col2" class="data row7 col2" >0.1097</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_3945f_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_3945f_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_3945f_row8_col2" class="data row8 col2" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_3945f_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_3945f_row9_col0" class="data row9 col0" >1.8555</td>
#       <td id="T_3945f_row9_col1" class="data row9 col1" >2.1595</td>
#       <td id="T_3945f_row9_col2" class="data row9 col2" >2.0266</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_3945f_row10_col0" class="data row10 col0" >1.8811</td>
#       <td id="T_3945f_row10_col1" class="data row10 col1" >2.1767</td>
#       <td id="T_3945f_row10_col2" class="data row10 col2" >2.0380</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_3945f_row11_col0" class="data row11 col0" >2.3717</td>
#       <td id="T_3945f_row11_col1" class="data row11 col1" >3.0974</td>
#       <td id="T_3945f_row11_col2" class="data row11 col2" >2.7612</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_3945f_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_3945f_row12_col0" class="data row12 col0" >7.8801</td>
#       <td id="T_3945f_row12_col1" class="data row12 col1" >14.4377</td>
#       <td id="T_3945f_row12_col2" class="data row12 col2" >11.2079</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_3945f_row13_col0" class="data row13 col0" >7.3573</td>
#       <td id="T_3945f_row13_col1" class="data row13 col1" >14.5792</td>
#       <td id="T_3945f_row13_col2" class="data row13 col2" >11.0861</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_3945f_row14_col0" class="data row14 col0" >18.6449</td>
#       <td id="T_3945f_row14_col1" class="data row14 col1" >26.3124</td>
#       <td id="T_3945f_row14_col2" class="data row14 col2" >22.7008</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_3945f_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_3945f_row15_col0" class="data row15 col0" >22.7157</td>
#       <td id="T_3945f_row15_col1" class="data row15 col1" >45.5660</td>
#       <td id="T_3945f_row15_col2" class="data row15 col2" >31.8702</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_3945f_row16_col0" class="data row16 col0" >21.7985</td>
#       <td id="T_3945f_row16_col1" class="data row16 col1" >47.1509</td>
#       <td id="T_3945f_row16_col2" class="data row16 col2" >31.8659</td>
#     </tr>
#     <tr>
#       <th id="T_3945f_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_3945f_row17_col0" class="data row17 col0" >35.2503</td>
#       <td id="T_3945f_row17_col1" class="data row17 col1" >59.6295</td>
#       <td id="T_3945f_row17_col2" class="data row17 col2" >44.1541</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 9. Intervalos de credibilidad: FAR contra PSBPM-FD, curva a curva
#
# Los promedios de §7 y §8 dicen *cuánto*, no *dónde*. Aquí se eligen los
# $N$ orígenes de prueba **mejor** y **peor** predichos según
# `METRICA_SEL_IC` ([CONFIG]) y se dibujan las dos bandas superpuestas sobre la
# misma curva verdadera.
#
# Es donde se ve la diferencia cualitativa que las cifras agregadas promedian: el
# IC del FAR tiene **ancho que no depende del origen** —su $\Sigma_\varepsilon$
# es la misma para todo $t$, de modo que sólo hereda la forma de $\tau$— mientras
# que la banda del PSBPM-FD sale de los cuantiles de una predictiva que sí cambia
# con el estado rezagado. En un escenario homogéneo como éste esa flexibilidad no
# tiene nada que explotar y el contraste debería ser pequeño; en los escenarios
# 2–4 es donde tendría que verse.

# %%
# Seleccion de los origenes extremos por METRICA_SEL_IC, sobre el TEST.
from model_psbp_fd.fit import normas_error_por_origen

_CLAVE_NORMA = {"mae_f": "l1", "rmse_f": "l2", "linf_medio": "linf"}
assert METRICA_SEL_IC in _CLAVE_NORMA, (
    f"METRICA_SEL_IC={METRICA_SEL_IC!r} no es una del Bloque A: "
    f"{list(_CLAVE_NORMA)}")

EXTREMOS = {}
for M in EST:
    e = EST[M]
    if e["X_pred_psbp"] is None:
        print(f"[M={M}] sin PSBPM-FD: se omite §9.")
        continue
    nm = normas_error_por_origen(X_true_ev, e["X_pred_psbp"], grilla,
                                 pesos_tau=PESOS_TAU, verificar=False)
    serie = nm[_CLAVE_NORMA[METRICA_SEL_IC]]          # (n_orig,)
    idx_test = np.where(~es_train)[0]
    orden = idx_test[np.argsort(serie[idx_test])]
    EXTREMOS[M] = {"mejores": orden[:N_EXTREMOS],
                   "peores":  orden[-N_EXTREMOS:][::-1],
                   "serie":   serie}
    print(f"[M={M}] por {METRICA_SEL_IC} (PSBPM-FD, test):")
    print(f"    mejores t = {[int(t_orig[i]) for i in orden[:N_EXTREMOS]]}")
    print(f"    peores  t = {[int(t_orig[i]) for i in orden[-N_EXTREMOS:][::-1]]}")
# Out:
# [M=1] por rmse_f (PSBPM-FD, test):
#     mejores t = [991, 916, 758, 831, 715]
#     peores  t = [720, 896, 826, 872, 760]
# [M=2] por rmse_f (PSBPM-FD, test):
#     mejores t = [916, 991, 758, 903, 715]
#     peores  t = [720, 896, 826, 760, 872]
# [M=3] por rmse_f (PSBPM-FD, test):
#     mejores t = [916, 991, 758, 903, 715]
#     peores  t = [720, 896, 826, 760, 872]
# [M=4] por rmse_f (PSBPM-FD, test):
#     mejores t = [916, 991, 758, 903, 715]
#     peores  t = [720, 896, 826, 760, 872]

# %%
# Las dos bandas superpuestas sobre la misma curva. `plot_extractos_curvas`
# dibuja UNA banda, de modo que este contraste se arma aqui: es una vista
# especifica de esta seccion y no una primitiva reutilizable.
def _banda_por_prefijo(bandas_M, prefijo):
    for nombre in bandas_M:
        if nombre.startswith(prefijo):
            return nombre, bandas_M[nombre]
    return None, None


for M in EXTREMOS:
    e = EST[M]
    n1, b1 = _banda_por_prefijo(BANDAS[M], BANDA_A_CONTRASTAR[0])
    n2, b2 = _banda_por_prefijo(BANDAS[M], BANDA_A_CONTRASTAR[1])
    if b1 is None or b2 is None:
        print(f"[M={M}] no estan las dos bandas de BANDA_A_CONTRASTAR; se omite.")
        continue
    (li1, ls1), Xp1 = b1
    (li2, ls2), Xp2 = b2

    for etiqueta_grupo, indices in (("mejores", EXTREMOS[M]["mejores"]),
                                    ("peores",  EXTREMOS[M]["peores"])):
        fig, axes = plt.subplots(1, len(indices),
                                 figsize=(3.1 * len(indices), 3.2),
                                 sharey=True, squeeze=False)
        for ax, i in zip(axes[0], indices):
            ax.fill_between(grilla, li1[i], ls1[i], color="#1f6f8b", alpha=0.20,
                            lw=0, label=n1)
            ax.fill_between(grilla, li2[i], ls2[i], color="#c0392b", alpha=0.20,
                            lw=0, label=n2)
            ax.plot(grilla, Xp1[i], color="#1f6f8b", lw=1.3, ls="--")
            ax.plot(grilla, Xp2[i], color="#c0392b", lw=1.3)
            ax.plot(grilla, X_true_ev[i], color="k", lw=1.6)
            cob1 = float(np.mean((X_true_ev[i] >= li1[i]) & (X_true_ev[i] <= ls1[i])))
            cob2 = float(np.mean((X_true_ev[i] >= li2[i]) & (X_true_ev[i] <= ls2[i])))
            ax.set_title(f"t={int(t_orig[i])}\ncob {cob1:.2f} / {cob2:.2f}",
                         fontsize=9)
            ax.tick_params(labelsize=7)
            ax.set_xlabel(r"$\tau$", fontsize=8)
        axes[0][0].set_ylabel(r"$X_t(\tau)$", fontsize=9)
        manijas = [
            plt.Line2D([], [], color="k", lw=1.6, label="curva verdadera"),
            plt.Line2D([], [], color="#1f6f8b", lw=1.3, ls="--", label=n1),
            plt.Line2D([], [], color="#c0392b", lw=1.3, label=n2),
        ]
        fig.legend(handles=manijas, loc="lower center", ncol=3, fontsize=8,
                   frameon=False, bbox_to_anchor=(0.5, -0.10))
        fig.suptitle(f"M={M} · {N_EXTREMOS} orígenes {etiqueta_grupo} por "
                     f"{METRICA_SEL_IC} (test) · cobertura puntual en el título",
                     fontsize=11)
        fig.tight_layout()
        fig.savefig(e["paths"]["out_report"]
                    / f"{PREFIJO + 9}_ic_contraste_{etiqueta_grupo}.png",
                    dpi=150, bbox_inches="tight")
        plt.show()

# %%
# Ancho y cobertura por origen, de cada banda, en los mismos 2N origenes.
filas_ic = []
for M in EXTREMOS:
    e = EST[M]
    for etiqueta_grupo, indices in (("mejores", EXTREMOS[M]["mejores"]),
                                    ("peores",  EXTREMOS[M]["peores"])):
        for i in indices:
            for nombre, ((li, ls), _Xp) in BANDAS[M].items():
                dentro = (X_true_ev[i] >= li[i]) & (X_true_ev[i] <= ls[i])
                filas_ic.append({
                    "M": M, "grupo": etiqueta_grupo, "t": int(t_orig[i]),
                    "banda": nombre,
                    f"{METRICA_SEL_IC}_PSBPM": float(EXTREMOS[M]["serie"][i]),
                    "mpiw": float(np.mean(ls[i] - li[i])),
                    "picp_puntual": float(dentro.mean()),
                    "I_t_simultaneo": float(bool(dentro.all())),
                })

ic_df = pd.DataFrame(filas_ic)
for M in EXTREMOS:
    sub = ic_df[ic_df.M == M].set_index(["grupo", "t", "banda"])
    sub.drop(columns=["M"]).to_csv(
        EST[M]["paths"]["out_report"] / f"{PREFIJO + 9}_ic_contraste_origenes.csv")
    display(sub.drop(columns=["M"]).style
            .format({f"{METRICA_SEL_IC}_PSBPM": "{:.4f}", "mpiw": "{:.4f}",
                     "picp_puntual": "{:.3f}", "I_t_simultaneo": "{:.0f}"})
            .set_caption(f"M={M} · ancho y cobertura por origen · "
                         f"I_t_simultaneo = 1 si la banda contiene la curva "
                         "ENTERA"))

print("Lectura: si el MPIW del FAR es practicamente el mismo en los origenes")
print("mejores y en los peores, es porque su ancho NO depende del origen -su")
print("Sigma_eps es la misma para todo t-. Que el del PSBPM-FD SI cambie entre")
print("grupos es la flexibilidad que el escenario 1 no le deja aprovechar.")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d4e50">
#   <caption>M=1 · ancho y cobertura por origen · I_t_simultaneo = 1 si la banda contiene la curva ENTERA</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4e50_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_d4e50_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_d4e50_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_d4e50_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4e50_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_d4e50_level1_row0" class="row_heading level1 row0" rowspan="3">991</th>
#       <th id="T_d4e50_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_d4e50_row0_col0" class="data row0 col0" >0.3035</td>
#       <td id="T_d4e50_row0_col1" class="data row0 col1" >1.7122</td>
#       <td id="T_d4e50_row0_col2" class="data row0 col2" >0.987</td>
#       <td id="T_d4e50_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d4e50_row1_col0" class="data row1 col0" >0.3035</td>
#       <td id="T_d4e50_row1_col1" class="data row1 col1" >1.7353</td>
#       <td id="T_d4e50_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_d4e50_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d4e50_row2_col0" class="data row2 col0" >0.3035</td>
#       <td id="T_d4e50_row2_col1" class="data row2 col1" >0.7962</td>
#       <td id="T_d4e50_row2_col2" class="data row2 col2" >0.813</td>
#       <td id="T_d4e50_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level1_row3" class="row_heading level1 row3" rowspan="3">916</th>
#       <th id="T_d4e50_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_d4e50_row3_col0" class="data row3 col0" >0.3041</td>
#       <td id="T_d4e50_row3_col1" class="data row3 col1" >1.7122</td>
#       <td id="T_d4e50_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_d4e50_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d4e50_row4_col0" class="data row4 col0" >0.3041</td>
#       <td id="T_d4e50_row4_col1" class="data row4 col1" >1.7353</td>
#       <td id="T_d4e50_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_d4e50_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d4e50_row5_col0" class="data row5 col0" >0.3041</td>
#       <td id="T_d4e50_row5_col1" class="data row5 col1" >0.7874</td>
#       <td id="T_d4e50_row5_col2" class="data row5 col2" >0.800</td>
#       <td id="T_d4e50_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level1_row6" class="row_heading level1 row6" rowspan="3">758</th>
#       <th id="T_d4e50_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_d4e50_row6_col0" class="data row6 col0" >0.3095</td>
#       <td id="T_d4e50_row6_col1" class="data row6 col1" >1.7122</td>
#       <td id="T_d4e50_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_d4e50_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d4e50_row7_col0" class="data row7 col0" >0.3095</td>
#       <td id="T_d4e50_row7_col1" class="data row7 col1" >1.7353</td>
#       <td id="T_d4e50_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_d4e50_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d4e50_row8_col0" class="data row8 col0" >0.3095</td>
#       <td id="T_d4e50_row8_col1" class="data row8 col1" >0.8686</td>
#       <td id="T_d4e50_row8_col2" class="data row8 col2" >0.853</td>
#       <td id="T_d4e50_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level1_row9" class="row_heading level1 row9" rowspan="3">831</th>
#       <th id="T_d4e50_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_d4e50_row9_col0" class="data row9 col0" >0.3181</td>
#       <td id="T_d4e50_row9_col1" class="data row9 col1" >1.7122</td>
#       <td id="T_d4e50_row9_col2" class="data row9 col2" >0.987</td>
#       <td id="T_d4e50_row9_col3" class="data row9 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d4e50_row10_col0" class="data row10 col0" >0.3181</td>
#       <td id="T_d4e50_row10_col1" class="data row10 col1" >1.7353</td>
#       <td id="T_d4e50_row10_col2" class="data row10 col2" >0.987</td>
#       <td id="T_d4e50_row10_col3" class="data row10 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d4e50_row11_col0" class="data row11 col0" >0.3181</td>
#       <td id="T_d4e50_row11_col1" class="data row11 col1" >0.8582</td>
#       <td id="T_d4e50_row11_col2" class="data row11 col2" >0.813</td>
#       <td id="T_d4e50_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level1_row12" class="row_heading level1 row12" rowspan="3">715</th>
#       <th id="T_d4e50_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_d4e50_row12_col0" class="data row12 col0" >0.3202</td>
#       <td id="T_d4e50_row12_col1" class="data row12 col1" >1.7122</td>
#       <td id="T_d4e50_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_d4e50_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d4e50_row13_col0" class="data row13 col0" >0.3202</td>
#       <td id="T_d4e50_row13_col1" class="data row13 col1" >1.7353</td>
#       <td id="T_d4e50_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_d4e50_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d4e50_row14_col0" class="data row14 col0" >0.3202</td>
#       <td id="T_d4e50_row14_col1" class="data row14 col1" >0.7997</td>
#       <td id="T_d4e50_row14_col2" class="data row14 col2" >0.747</td>
#       <td id="T_d4e50_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4e50_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_d4e50_level1_row15" class="row_heading level1 row15" rowspan="3">720</th>
#       <th id="T_d4e50_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_d4e50_row15_col0" class="data row15 col0" >0.7913</td>
#       <td id="T_d4e50_row15_col1" class="data row15 col1" >1.7122</td>
#       <td id="T_d4e50_row15_col2" class="data row15 col2" >0.707</td>
# <style type="text/css">
# </style>
# <table id="T_a274c">
#   <caption>M=2 · ancho y cobertura por origen · I_t_simultaneo = 1 si la banda contiene la curva ENTERA</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a274c_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_a274c_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_a274c_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_a274c_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a274c_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_a274c_level1_row0" class="row_heading level1 row0" rowspan="3">916</th>
#       <th id="T_a274c_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_a274c_row0_col0" class="data row0 col0" >0.3027</td>
#       <td id="T_a274c_row0_col1" class="data row0 col1" >1.7122</td>
#       <td id="T_a274c_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_a274c_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a274c_row1_col0" class="data row1 col0" >0.3027</td>
#       <td id="T_a274c_row1_col1" class="data row1 col1" >1.7303</td>
#       <td id="T_a274c_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_a274c_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a274c_row2_col0" class="data row2 col0" >0.3027</td>
#       <td id="T_a274c_row2_col1" class="data row2 col1" >0.9335</td>
#       <td id="T_a274c_row2_col2" class="data row2 col2" >0.880</td>
#       <td id="T_a274c_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level1_row3" class="row_heading level1 row3" rowspan="3">991</th>
#       <th id="T_a274c_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_a274c_row3_col0" class="data row3 col0" >0.3054</td>
#       <td id="T_a274c_row3_col1" class="data row3 col1" >1.7122</td>
#       <td id="T_a274c_row3_col2" class="data row3 col2" >0.987</td>
#       <td id="T_a274c_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a274c_row4_col0" class="data row4 col0" >0.3054</td>
#       <td id="T_a274c_row4_col1" class="data row4 col1" >1.7303</td>
#       <td id="T_a274c_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_a274c_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a274c_row5_col0" class="data row5 col0" >0.3054</td>
#       <td id="T_a274c_row5_col1" class="data row5 col1" >0.9457</td>
#       <td id="T_a274c_row5_col2" class="data row5 col2" >0.867</td>
#       <td id="T_a274c_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level1_row6" class="row_heading level1 row6" rowspan="3">758</th>
#       <th id="T_a274c_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_a274c_row6_col0" class="data row6 col0" >0.3108</td>
#       <td id="T_a274c_row6_col1" class="data row6 col1" >1.7122</td>
#       <td id="T_a274c_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_a274c_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a274c_row7_col0" class="data row7 col0" >0.3108</td>
#       <td id="T_a274c_row7_col1" class="data row7 col1" >1.7303</td>
#       <td id="T_a274c_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_a274c_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a274c_row8_col0" class="data row8 col0" >0.3108</td>
#       <td id="T_a274c_row8_col1" class="data row8 col1" >0.9621</td>
#       <td id="T_a274c_row8_col2" class="data row8 col2" >0.880</td>
#       <td id="T_a274c_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level1_row9" class="row_heading level1 row9" rowspan="3">903</th>
#       <th id="T_a274c_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_a274c_row9_col0" class="data row9 col0" >0.3175</td>
#       <td id="T_a274c_row9_col1" class="data row9 col1" >1.7122</td>
#       <td id="T_a274c_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_a274c_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a274c_row10_col0" class="data row10 col0" >0.3175</td>
#       <td id="T_a274c_row10_col1" class="data row10 col1" >1.7303</td>
#       <td id="T_a274c_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_a274c_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a274c_row11_col0" class="data row11 col0" >0.3175</td>
#       <td id="T_a274c_row11_col1" class="data row11 col1" >0.9631</td>
#       <td id="T_a274c_row11_col2" class="data row11 col2" >0.840</td>
#       <td id="T_a274c_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level1_row12" class="row_heading level1 row12" rowspan="3">715</th>
#       <th id="T_a274c_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_a274c_row12_col0" class="data row12 col0" >0.3178</td>
#       <td id="T_a274c_row12_col1" class="data row12 col1" >1.7122</td>
#       <td id="T_a274c_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_a274c_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a274c_row13_col0" class="data row13 col0" >0.3178</td>
#       <td id="T_a274c_row13_col1" class="data row13 col1" >1.7303</td>
#       <td id="T_a274c_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_a274c_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a274c_row14_col0" class="data row14 col0" >0.3178</td>
#       <td id="T_a274c_row14_col1" class="data row14 col1" >0.9428</td>
#       <td id="T_a274c_row14_col2" class="data row14 col2" >0.827</td>
#       <td id="T_a274c_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a274c_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_a274c_level1_row15" class="row_heading level1 row15" rowspan="3">720</th>
#       <th id="T_a274c_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_a274c_row15_col0" class="data row15 col0" >0.7831</td>
#       <td id="T_a274c_row15_col1" class="data row15 col1" >1.7122</td>
#       <td id="T_a274c_row15_col2" class="data row15 col2" >0.707</td>
# <style type="text/css">
# </style>
# <table id="T_5d3d3">
#   <caption>M=3 · ancho y cobertura por origen · I_t_simultaneo = 1 si la banda contiene la curva ENTERA</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d3d3_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_5d3d3_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_5d3d3_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_5d3d3_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d3d3_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_5d3d3_level1_row0" class="row_heading level1 row0" rowspan="3">916</th>
#       <th id="T_5d3d3_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_5d3d3_row0_col0" class="data row0 col0" >0.3022</td>
#       <td id="T_5d3d3_row0_col1" class="data row0 col1" >1.7122</td>
#       <td id="T_5d3d3_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_5d3d3_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_5d3d3_row1_col0" class="data row1 col0" >0.3022</td>
#       <td id="T_5d3d3_row1_col1" class="data row1 col1" >1.7298</td>
#       <td id="T_5d3d3_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_5d3d3_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_5d3d3_row2_col0" class="data row2 col0" >0.3022</td>
#       <td id="T_5d3d3_row2_col1" class="data row2 col1" >1.0651</td>
#       <td id="T_5d3d3_row2_col2" class="data row2 col2" >0.893</td>
#       <td id="T_5d3d3_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level1_row3" class="row_heading level1 row3" rowspan="3">991</th>
#       <th id="T_5d3d3_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_5d3d3_row3_col0" class="data row3 col0" >0.3059</td>
#       <td id="T_5d3d3_row3_col1" class="data row3 col1" >1.7122</td>
#       <td id="T_5d3d3_row3_col2" class="data row3 col2" >0.987</td>
#       <td id="T_5d3d3_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_5d3d3_row4_col0" class="data row4 col0" >0.3059</td>
#       <td id="T_5d3d3_row4_col1" class="data row4 col1" >1.7298</td>
#       <td id="T_5d3d3_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_5d3d3_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_5d3d3_row5_col0" class="data row5 col0" >0.3059</td>
#       <td id="T_5d3d3_row5_col1" class="data row5 col1" >1.0405</td>
#       <td id="T_5d3d3_row5_col2" class="data row5 col2" >0.907</td>
#       <td id="T_5d3d3_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level1_row6" class="row_heading level1 row6" rowspan="3">758</th>
#       <th id="T_5d3d3_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_5d3d3_row6_col0" class="data row6 col0" >0.3112</td>
#       <td id="T_5d3d3_row6_col1" class="data row6 col1" >1.7122</td>
#       <td id="T_5d3d3_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_5d3d3_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_5d3d3_row7_col0" class="data row7 col0" >0.3112</td>
#       <td id="T_5d3d3_row7_col1" class="data row7 col1" >1.7298</td>
#       <td id="T_5d3d3_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_5d3d3_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_5d3d3_row8_col0" class="data row8 col0" >0.3112</td>
#       <td id="T_5d3d3_row8_col1" class="data row8 col1" >1.0501</td>
#       <td id="T_5d3d3_row8_col2" class="data row8 col2" >0.907</td>
#       <td id="T_5d3d3_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level1_row9" class="row_heading level1 row9" rowspan="3">903</th>
#       <th id="T_5d3d3_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_5d3d3_row9_col0" class="data row9 col0" >0.3175</td>
#       <td id="T_5d3d3_row9_col1" class="data row9 col1" >1.7122</td>
#       <td id="T_5d3d3_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_5d3d3_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_5d3d3_row10_col0" class="data row10 col0" >0.3175</td>
#       <td id="T_5d3d3_row10_col1" class="data row10 col1" >1.7298</td>
#       <td id="T_5d3d3_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_5d3d3_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_5d3d3_row11_col0" class="data row11 col0" >0.3175</td>
#       <td id="T_5d3d3_row11_col1" class="data row11 col1" >1.0474</td>
#       <td id="T_5d3d3_row11_col2" class="data row11 col2" >0.853</td>
#       <td id="T_5d3d3_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level1_row12" class="row_heading level1 row12" rowspan="3">715</th>
#       <th id="T_5d3d3_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_5d3d3_row12_col0" class="data row12 col0" >0.3178</td>
#       <td id="T_5d3d3_row12_col1" class="data row12 col1" >1.7122</td>
#       <td id="T_5d3d3_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_5d3d3_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_5d3d3_row13_col0" class="data row13 col0" >0.3178</td>
#       <td id="T_5d3d3_row13_col1" class="data row13 col1" >1.7298</td>
#       <td id="T_5d3d3_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_5d3d3_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_5d3d3_row14_col0" class="data row14 col0" >0.3178</td>
#       <td id="T_5d3d3_row14_col1" class="data row14 col1" >1.0493</td>
#       <td id="T_5d3d3_row14_col2" class="data row14 col2" >0.907</td>
#       <td id="T_5d3d3_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5d3d3_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_5d3d3_level1_row15" class="row_heading level1 row15" rowspan="3">720</th>
#       <th id="T_5d3d3_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_5d3d3_row15_col0" class="data row15 col0" >0.7823</td>
#       <td id="T_5d3d3_row15_col1" class="data row15 col1" >1.7122</td>
#       <td id="T_5d3d3_row15_col2" class="data row15 col2" >0.707</td>
# <style type="text/css">
# </style>
# <table id="T_497ae">
#   <caption>M=4 · ancho y cobertura por origen · I_t_simultaneo = 1 si la banda contiene la curva ENTERA</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_497ae_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_497ae_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_497ae_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_497ae_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_497ae_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_497ae_level1_row0" class="row_heading level1 row0" rowspan="3">916</th>
#       <th id="T_497ae_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_497ae_row0_col0" class="data row0 col0" >0.3028</td>
#       <td id="T_497ae_row0_col1" class="data row0 col1" >1.7122</td>
#       <td id="T_497ae_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_497ae_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_497ae_row1_col0" class="data row1 col0" >0.3028</td>
#       <td id="T_497ae_row1_col1" class="data row1 col1" >1.7290</td>
#       <td id="T_497ae_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_497ae_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_497ae_row2_col0" class="data row2 col0" >0.3028</td>
#       <td id="T_497ae_row2_col1" class="data row2 col1" >1.0991</td>
#       <td id="T_497ae_row2_col2" class="data row2 col2" >0.907</td>
#       <td id="T_497ae_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level1_row3" class="row_heading level1 row3" rowspan="3">991</th>
#       <th id="T_497ae_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_497ae_row3_col0" class="data row3 col0" >0.3057</td>
#       <td id="T_497ae_row3_col1" class="data row3 col1" >1.7122</td>
#       <td id="T_497ae_row3_col2" class="data row3 col2" >0.987</td>
#       <td id="T_497ae_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_497ae_row4_col0" class="data row4 col0" >0.3057</td>
#       <td id="T_497ae_row4_col1" class="data row4 col1" >1.7290</td>
#       <td id="T_497ae_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_497ae_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_497ae_row5_col0" class="data row5 col0" >0.3057</td>
#       <td id="T_497ae_row5_col1" class="data row5 col1" >1.1108</td>
#       <td id="T_497ae_row5_col2" class="data row5 col2" >0.907</td>
#       <td id="T_497ae_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level1_row6" class="row_heading level1 row6" rowspan="3">758</th>
#       <th id="T_497ae_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_497ae_row6_col0" class="data row6 col0" >0.3110</td>
#       <td id="T_497ae_row6_col1" class="data row6 col1" >1.7122</td>
#       <td id="T_497ae_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_497ae_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_497ae_row7_col0" class="data row7 col0" >0.3110</td>
#       <td id="T_497ae_row7_col1" class="data row7 col1" >1.7290</td>
#       <td id="T_497ae_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_497ae_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_497ae_row8_col0" class="data row8 col0" >0.3110</td>
#       <td id="T_497ae_row8_col1" class="data row8 col1" >1.0847</td>
#       <td id="T_497ae_row8_col2" class="data row8 col2" >0.907</td>
#       <td id="T_497ae_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level1_row9" class="row_heading level1 row9" rowspan="3">903</th>
#       <th id="T_497ae_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_497ae_row9_col0" class="data row9 col0" >0.3152</td>
#       <td id="T_497ae_row9_col1" class="data row9 col1" >1.7122</td>
#       <td id="T_497ae_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_497ae_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_497ae_row10_col0" class="data row10 col0" >0.3152</td>
#       <td id="T_497ae_row10_col1" class="data row10 col1" >1.7290</td>
#       <td id="T_497ae_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_497ae_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_497ae_row11_col0" class="data row11 col0" >0.3152</td>
#       <td id="T_497ae_row11_col1" class="data row11 col1" >1.0733</td>
#       <td id="T_497ae_row11_col2" class="data row11 col2" >0.880</td>
#       <td id="T_497ae_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level1_row12" class="row_heading level1 row12" rowspan="3">715</th>
#       <th id="T_497ae_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_497ae_row12_col0" class="data row12 col0" >0.3164</td>
#       <td id="T_497ae_row12_col1" class="data row12 col1" >1.7122</td>
#       <td id="T_497ae_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_497ae_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_497ae_row13_col0" class="data row13 col0" >0.3164</td>
#       <td id="T_497ae_row13_col1" class="data row13 col1" >1.7290</td>
#       <td id="T_497ae_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_497ae_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_497ae_row14_col0" class="data row14 col0" >0.3164</td>
#       <td id="T_497ae_row14_col1" class="data row14 col1" >1.1448</td>
#       <td id="T_497ae_row14_col2" class="data row14 col2" >0.947</td>
#       <td id="T_497ae_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_497ae_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_497ae_level1_row15" class="row_heading level1 row15" rowspan="3">720</th>
#       <th id="T_497ae_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_497ae_row15_col0" class="data row15 col0" >0.7800</td>
#       <td id="T_497ae_row15_col1" class="data row15 col1" >1.7122</td>
#       <td id="T_497ae_row15_col2" class="data row15 col2" >0.707</td>
# Lectura: si el MPIW del FAR es practicamente el mismo en los origenes
# mejores y en los peores, es porque su ancho NO depende del origen -su
# Sigma_eps es la misma para todo t-. Que el del PSBPM-FD SI cambie entre
# grupos es la flexibilidad que el escenario 1 no le deja aprovechar.
