# %% [markdown]
# # 103_05 — Modelos de referencia · Escenario A-3 · **barrido en $M$**
#
# Paso **3c**, posterior a `103_04_evaluacion`. El PSBPM-FD contra sus referencias,
# sobre el mismo conjunto de información y con **las mismas métricas que el
# `103_04`**: si los dos notebooks midieran cosas distintas, la comparación entre
# modelos no sería la misma comparación que la del barrido en $M$.
#
# | Sección | Qué responde |
# |---|---|
# | 1 | imports, rutas y constantes |
# | 2 | validaciones: mismo corte, mismas covariables, mismo objetivo para todos |
# | 3.1 | **FAR(1) sobre los coeficientes B-spline**, en la métrica $L^2$ (vía Gram) |
# | 3.2 | RF y GBT sobre los coeficientes FPCA, los mismos que usa el PSBPM-FD |
# | 3.3 | las dos líneas base |
# | 3.4 | predicción puntual del PSBPM-FD, recalculada desde las trazas |
# | 4 | **Bloque A** (MAE, RMSE, error máximo) — todos los modelos |
# | 5 | **Bloque B** (Winkler, cobertura simultánea, PICP, MPIW) — sólo FAR y PSBPM-FD |
# | 6 | Bloque A: % de ventanas ganadas y cuánto mejor es cada modelo |
# | 7 | Bloque B: lo mismo, sobre las bandas |
# | 8 | resumen: mínimo, máximo y promedio de cada métrica sobre la ventana |
# | 9 | los 5 orígenes mejor y peor predichos, con las dos bandas superpuestas |

# %% [markdown]
# ## 1. Imports, rutas y artefactos

# %%
import sys
import json as _json
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor

from model_psbp_fd.pipelines import (
    cargar_curvas, cargar_curvas_true, cargar_representacion,
    cargar_fpca, cargar_estandarizador,
    cargar_datasets_ar, cargar_hiperparametros, cargar_config_evaluacion,
)
from model_psbp_fd.functions_models import DataStandardizer
from model_psbp_fd.models.pspb_fd_v3 import (
    ruta_traza, ModeloTraza, curva_media_desde_scores,
)
from model_psbp_fd.fit import (
    mise, ventana_movil_funcional,
    # Bloque A: las tres normas del mismo error, para TODOS los modelos
    normas_error_por_origen,
    # Bloque B: intervalo implicado por el modelo, y sus métricas
    residuos_para_banda, banda_predictiva_modelo, sigma_residual,
    resumen_intervalo, indicador_cobertura, indicador_cobertura_simultanea,
)
from model_psbp_fd.graphics import plot_ventana_movil
from model_psbp_fd.utils import get_project_root

plt.style.use("seaborn-v0_8-darkgrid")
# %matplotlib inline

# %%
PROJECT_ROOT = get_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# [CONFIG]
BASENAME, ESCENARIO_ID, REPLICA_ID = "escenario_103", 3, 1
M_FPCA_LIST = (1, 2, 3, 4,5,6,7,8)
# Las 10 metricas del marco teorico 02_02_03, en su orden. No se agregan otras.
METRICAS_A = [
    (u"1. MAE  (L^1)",                     "mae_f"),
    (u"2. RMSE (L^2)",                     "rmse_f"),
    (u"3. E_max promedio por curva",       "linf_medio"),
    (u"4. E_max peor de la ventana",       "linf_max"),
]
METRICAS_B = [
    (u"5. MPIW",                           "mpiw"),
    (u"6. PICP puntual",                   "picp"),
    (u"7. PICPB curva completa",           "picp_simultaneo"),
    (u"8. Winkler",                        "winkler"),
    (u"9. Winkler max promedio",           "winkler_max_medio"),
    (u"10. Winkler max peor ventana",      "winkler_max_glob"),
]
METRICAS_A_COLS = [c for _, c in METRICAS_A]
METRICAS_B_COLS = [c for _, c in METRICAS_B]

# [CONFIG] §9: por que metrica se eligen los origenes extremos, cuantos, y
# que dos bandas se contrastan curva a curva.
METRICA_SEL_IC = "rmse_f"     # una de METRICAS_A_COLS
N_EXTREMOS     = 5
BANDA_A_CONTRASTAR = ("FAR", "PSBPM-FD (predictiva")   # prefijos, en orden

PESOS_TAU = None    

NIVEL_IC   = 0.95    # debe coincidir con el `nivel_credibilidad` del _04
IC_POR_TAU = True    # sigma_eps(tau) punto a punto: la banda hereda la forma
                     # de la innovacion funcional. False = ancho constante.
IC_CORRECCION_ESTIMACION = True   # infla sigma por sqrt(1 + kn/n_train), la
                     # correccion de primer orden por rho estimado y no conocido

# Al PSBPM-FD se le construye la MISMA banda ademas de la suya bayesiana, de
# modo que la tabla tenga tres filas y se pueda separar "gana por el modelo" de
# "gana por el mecanismo de intervalo". Sin esa fila, la comparacion mezcla las
# dos cosas y no hay forma de saber cual manda.
IC_PSBP_TAMBIEN_GAUSSIANA = True

M_FPCA_LIST = tuple(int(m) for m in M_FPCA_LIST)
EXPERIMENT_BASE = f"{BASENAME}_{ESCENARIO_ID}_r{REPLICA_ID:02d}"


def experiment_id(M: int) -> str:
    return f"{EXPERIMENT_BASE}_m{M:02d}"


def rutas(M: int) -> dict:
    eid = experiment_id(M)
    p = {
        "raw":          PROJECT_ROOT / "data" / "simulaciones" / "raw" / eid,
        "functional":   PROJECT_ROOT / "data" / "simulaciones" / "processed" / "functional" / eid,
        "predict":      PROJECT_ROOT / "data" / "simulaciones" / "processed" / "predict" / eid,
        "out_report":   PROJECT_ROOT / "reports" / "simulaciones" / eid,
        "out_artefact": PROJECT_ROOT / "artefact" / "simulaciones" / eid,
    }
    for r in p.values():
        r.mkdir(parents=True, exist_ok=True)
    return p


PATHS_M      = {M: rutas(M) for M in M_FPCA_LIST}
PATH_BARRIDO = PROJECT_ROOT / "reports" / "simulaciones" / f"{EXPERIMENT_BASE}_barrido_M"
PATH_BARRIDO.mkdir(parents=True, exist_ok=True)

# Este notebook NO pisa nada de 103_04: los _04 ocupan 50-65 según el escenario,
# éste escribe 70-75 en cada directorio de M, y 90-93 en el del barrido.
PREFIJO = 70

print(f"barrido en M : {list(M_FPCA_LIST)}")
for M in M_FPCA_LIST:
    print(f"  M={M}  ->  {experiment_id(M)}   (archivos {PREFIJO}-{PREFIJO+5})")
print(f"salidas cruzadas (§8) : {PATH_BARRIDO}   (archivos 90-93)")
# Out:
# barrido en M : [1, 2, 3, 4, 5, 6, 7, 8]
#   M=1  ->  escenario_103_3_r01_m01   (archivos 70-75)
#   M=2  ->  escenario_103_3_r01_m02   (archivos 70-75)
#   M=3  ->  escenario_103_3_r01_m03   (archivos 70-75)
#   M=4  ->  escenario_103_3_r01_m04   (archivos 70-75)
#   M=5  ->  escenario_103_3_r01_m05   (archivos 70-75)
#   M=6  ->  escenario_103_3_r01_m06   (archivos 70-75)
#   M=7  ->  escenario_103_3_r01_m07   (archivos 70-75)
#   M=8  ->  escenario_103_3_r01_m08   (archivos 70-75)
# salidas cruzadas (§8) : C:\Users\56jua\Desktop\git_tesis\bayesian_non_parametrics-1\reports\simulaciones\escenario_103_3_r01_barrido_M   (archivos 90-93)

# %%
EST, saltados = {}, []

for M in M_FPCA_LIST:
    P = PATHS_M[M]
    if not (P["functional"] / "datasets_manifest.json").exists():
        saltados.append((M, "sin datasets_manifest.json - falta correr 103_01"))
        continue

    dfs_train, manifest = cargar_datasets_ar(P, bloque="train")
    dfs_test,  _        = cargar_datasets_ar(P, bloque="test")
    hp_json     = cargar_hiperparametros(P)
    P["trazas"] = P["out_artefact"].parent / hp_json.get("trazas_en", P["out_artefact"].name)
    eval_config = cargar_config_evaluacion(P)

    component_idx = manifest["component_idx"]
    n_components  = len(component_idx)
    assert n_components == M, (
        f"{experiment_id(M)} declara M={M} pero su manifest tiene "
        f"{n_components} componentes.")
    assert manifest["scores_scale"] == "raw_fpca_scores"

    objetivo = eval_config.get("objetivo_evaluacion", "curva_suavizada")
    assert objetivo == "curva_suavizada", (
        f"[M={M}] objetivo_evaluacion={objetivo!r}. Este notebook compara "
        "contra la curva suavizada; con otro objetivo las cifras no serían "
        "las del _04. Regenera el punto con 103_01.")

    EST[M] = {
        "paths": P, "eid": experiment_id(M),
        "dfs_train": dfs_train, "dfs_test": dfs_test, "manifest": manifest,
        "hp_json": hp_json, "eval_config": eval_config,
        "component_idx": component_idx, "n_components": n_components,
        "cov_names": list(manifest["cov_names"]),
        "cov_por_componente": [list(manifest["cov_por_componente"][str(k)]) for k in range(n_components)],
        "n_lags": int(manifest["n_lags"]),
        "T": int(manifest["T"]), "T0": int(manifest["T0"]),
        "n_iter": int(hp_json["n_iter"]),
        "mcmc_cfg": hp_json["mcmc_config"],
        "objetivo": objetivo,
        "modo_residuo": eval_config.get("modo_residuo", "ninguno"),
        "ventanas_w": list(eval_config.get("ventana_movil", {}).get("w", [20, 30, 40])),
    }

assert EST, "Ningún punto del barrido tiene datos. Ejecuta 103_01 primero."
for M, motivo in saltados:
    print(f"! M={M} saltado: {motivo}")

_comun = {M: (e["T"], e["T0"], e["n_lags"], e["objetivo"], e["modo_residuo"],
              tuple(e["ventanas_w"])) for M, e in EST.items()}
if len(set(_comun.values())) > 1:
    for M, v in _comun.items():
        print(f"  M={M}: {v}")
    raise AssertionError(
        "El barrido exige T, T0, n_lags, objetivo, modo_residuo y ventanas "
        "idénticos entre puntos.")

_M0        = next(iter(EST))
T          = EST[_M0]["T"]
T0         = EST[_M0]["T0"]
N_LAGS     = EST[_M0]["n_lags"]
OBJETIVO   = EST[_M0]["objetivo"]
MODO_RESIDUO = EST[_M0]["modo_residuo"]
VENTANAS_W = EST[_M0]["ventanas_w"]
W_COMP     = VENTANAS_W[len(VENTANAS_W) // 2]

print(f"\nT={T}  T0={T0}  n_lags={N_LAGS}  objetivo={OBJETIVO!r}  "
      f"modo_residuo={MODO_RESIDUO!r}")
print(f"anchos de ventana: {VENTANAS_W}   ·   referencia para las tablas: w={W_COMP}")
for M, e in EST.items():
    print(f"  M={M}: {e['n_components']} componentes · "
          f"{len(e['cov_names'])} covariables {e['cov_names']}")
# Out:
# T=1000  T0=700  n_lags=4  objetivo='curva_suavizada'  modo_residuo='ninguno'
# anchos de ventana: [20, 30, 40]   ·   referencia para las tablas: w=30
#   M=1: 1 componentes · 4 covariables ['fpc_1_lag1', 'fpc_1_lag2', 'fpc_1_lag3', 'fpc_1_lag4']
#   M=2: 2 componentes · 8 covariables ['fpc_1_lag1', 'fpc_2_lag1', 'fpc_1_lag2', 'fpc_2_lag2', 'fpc_1_lag3', 'fpc_2_lag3', 'fpc_1_lag4', 'fpc_2_lag4']
#   M=3: 3 componentes · 12 covariables ['fpc_1_lag1', 'fpc_2_lag1', 'fpc_3_lag1', 'fpc_1_lag2', 'fpc_2_lag2', 'fpc_3_lag2', 'fpc_1_lag3', 'fpc_2_lag3', 'fpc_3_lag3', 'fpc_1_lag4', 'fpc_2_lag4', 'fpc_3_lag4']
#   M=4: 4 componentes · 16 covariables ['fpc_1_lag1', 'fpc_2_lag1', 'fpc_3_lag1', 'fpc_4_lag1', 'fpc_1_lag2', 'fpc_2_lag2', 'fpc_3_lag2', 'fpc_4_lag2', 'fpc_1_lag3', 'fpc_2_lag3', 'fpc_3_lag3', 'fpc_4_lag3', 'fpc_1_lag4', 'fpc_2_lag4', 'fpc_3_lag4', 'fpc_4_lag4']
#   M=5: 5 componentes · 20 covariables ['fpc_1_lag1', 'fpc_2_lag1', 'fpc_3_lag1', 'fpc_4_lag1', 'fpc_5_lag1', 'fpc_1_lag2', 'fpc_2_lag2', 'fpc_3_lag2', 'fpc_4_lag2', 'fpc_5_lag2', 'fpc_1_lag3', 'fpc_2_lag3', 'fpc_3_lag3', 'fpc_4_lag3', 'fpc_5_lag3', 'fpc_1_lag4', 'fpc_2_lag4', 'fpc_3_lag4', 'fpc_4_lag4', 'fpc_5_lag4']
#   M=6: 6 componentes · 24 covariables ['fpc_1_lag1', 'fpc_2_lag1', 'fpc_3_lag1', 'fpc_4_lag1', 'fpc_5_lag1', 'fpc_6_lag1', 'fpc_1_lag2', 'fpc_2_lag2', 'fpc_3_lag2', 'fpc_4_lag2', 'fpc_5_lag2', 'fpc_6_lag2', 'fpc_1_lag3', 'fpc_2_lag3', 'fpc_3_lag3', 'fpc_4_lag3', 'fpc_5_lag3', 'fpc_6_lag3', 'fpc_1_lag4', 'fpc_2_lag4', 'fpc_3_lag4', 'fpc_4_lag4', 'fpc_5_lag4', 'fpc_6_lag4']
#   M=7: 7 componentes · 28 covariables ['fpc_1_lag1', 'fpc_2_lag1', 'fpc_3_lag1', 'fpc_4_lag1', 'fpc_5_lag1', 'fpc_6_lag1', 'fpc_7_lag1', 'fpc_1_lag2', 'fpc_2_lag2', 'fpc_3_lag2', 'fpc_4_lag2', 'fpc_5_lag2', 'fpc_6_lag2', 'fpc_7_lag2', 'fpc_1_lag3', 'fpc_2_lag3', 'fpc_3_lag3', 'fpc_4_lag3', 'fpc_5_lag3', 'fpc_6_lag3', 'fpc_7_lag3', 'fpc_1_lag4', 'fpc_2_lag4', 'fpc_3_lag4', 'fpc_4_lag4', 'fpc_5_lag4', 'fpc_6_lag4', 'fpc_7_lag4']
#   M=8: 8 componentes · 32 covariables ['fpc_1_lag1', 'fpc_2_lag1', 'fpc_3_lag1', 'fpc_4_lag1', 'fpc_5_lag1', 'fpc_6_lag1', 'fpc_7_lag1', 'fpc_8_lag1', 'fpc_1_lag2', 'fpc_2_lag2', 'fpc_3_lag2', 'fpc_4_lag2', 'fpc_5_lag2', 'fpc_6_lag2', 'fpc_7_lag2', 'fpc_8_lag2', 'fpc_1_lag3', 'fpc_2_lag3', 'fpc_3_lag3', 'fpc_4_lag3', 'fpc_5_lag3', 'fpc_6_lag3', 'fpc_7_lag3', 'fpc_8_lag3', 'fpc_1_lag4', 'fpc_2_lag4', 'fpc_3_lag4', 'fpc_4_lag4', 'fpc_5_lag4', 'fpc_6_lag4', 'fpc_7_lag4', 'fpc_8_lag4']

# %%
for M in EST:
    e, P = EST[M], EST[M]["paths"]

    fpca = cargar_fpca(P)
    _ver = fpca.verificar()
    assert _ver["todo_ok"], f"[M={M}] las identidades FPCA no se cumplen: {_ver}"

    std = cargar_estandarizador(P, DataStandardizer)
    X_obs, grilla = cargar_curvas(P)         # (T, G) con ruido de medición
    X_true        = cargar_curvas_true(P)    # (T, G) verdadera - solo referencia
    fr_M, THETA_M, _ = cargar_representacion(P)
    X_suav        = fr_M.reconstruct(THETA_M)  # (T, G) OBJETIVO: curva suavizada

    assert e["component_idx"] == list(range(fpca.M)), (
        "La reconstrucción funcional necesita el vector completo de scores en "
        f"orden; [M={M}] COMPONENT_IDX={e['component_idx']} y M={fpca.M}.")
    assert std.n_ajuste == T0, (
        f"[M={M}] el estandarizador se ajustó con n={std.n_ajuste} y T0={T0}: "
        "habría fuga del bloque de prueba.")

    e.update({"fpca": fpca, "std": std, "X_obs": X_obs, "X_true": X_true,
              "X_suav": X_suav,
              "grilla": grilla, "M_fpca": fpca.M, "K": fpca.K,
              "SCORES": fpca.SCORES,
              "SCORES_STD": std.transform(fpca.SCORES),
              "var_explicada": float(fpca.meta["var_explained"])})
    print(f"M={M}  FPCA M={fpca.M} K={fpca.K}  ·  varianza explicada por las M "
          f"retenidas: {e['var_explicada']:.4%}")

for M in EST:
    assert np.allclose(EST[M]["X_true"], EST[_M0]["X_true"]), (
        f"[M={M}] las curvas verdaderas difieren de las de M={_M0}.")
grilla = EST[_M0]["grilla"]
X_true = EST[_M0]["X_true"]
X_suav = EST[_M0]["X_suav"]
print(f"\nOK los {len(EST)} puntos salen de la MISMA simulación: curvas "
      f"{X_true.shape}, grilla {grilla.shape}")
# Out:
# M=1  FPCA M=1 K=22  ·  varianza explicada por las M retenidas: 7.8634%
# M=2  FPCA M=2 K=22  ·  varianza explicada por las M retenidas: 15.3765%
# M=3  FPCA M=3 K=22  ·  varianza explicada por las M retenidas: 22.2176%
# M=4  FPCA M=4 K=22  ·  varianza explicada por las M retenidas: 28.7087%
# M=5  FPCA M=5 K=22  ·  varianza explicada por las M retenidas: 34.7130%
# M=6  FPCA M=6 K=22  ·  varianza explicada por las M retenidas: 40.4771%
# M=7  FPCA M=7 K=22  ·  varianza explicada por las M retenidas: 45.9780%
# M=8  FPCA M=8 K=22  ·  varianza explicada por las M retenidas: 51.3602%
#
# OK los 8 puntos salen de la MISMA simulación: curvas (1000, 75), grilla (75,)

# %% [markdown]
# ## 2. Validaciones para aplicar los modelos

# %%
# La serie de orígenes es común: T, T0 y n_lags no dependen de M.
t_orig   = np.arange(N_LAGS + 1, T + 1)      # tiempo del experimento, base-1
n_orig   = len(t_orig)
T0_orig  = T0 - N_LAGS                        # corte en el indexado de orígenes
es_train = t_orig <= T0
X_obj_ev = X_suav[N_LAGS:]                   # (n_orig, G) OBJETIVO: curva suavizada

print(f"orígenes evaluados : {n_orig}  (train {es_train.sum()} · "
      f"test {(~es_train).sum()})")
print(f"corte T0={T0}  ->  índice de origen T0_orig={T0_orig}")

for M in EST:
    e = EST[M]
    dfs_full = {k: pd.concat([e["dfs_train"][k], e["dfs_test"][k]],
                             ignore_index=True) for k in range(e["n_components"])}
    assert len(dfs_full[0]) == n_orig, f"[M={M}] {len(dfs_full[0])} != {n_orig}"

    # Objetivo (n_orig, M) en escala estandarizada, y matriz de diseño común.
    Y_obs = np.column_stack([dfs_full[k].iloc[:, 0].to_numpy(dtype=float)
                             for k in range(e["n_components"])])

    col2k = {c: k for k in range(e["n_components"]) for c in dfs_full[k].columns[1:]}
    assert set(col2k) == set(e["cov_names"]), (
        f"[M={M}] covariables de los datasets {sorted(col2k)} != cov_names {e['cov_names']}.")

    Z = np.column_stack([dfs_full[col2k[c]][c].to_numpy(dtype=float)
                         for c in e["cov_names"]])                # (n_orig, p) todos los rezagos
    e.update({"dfs_full": dfs_full, "Y_obs": Y_obs, "Z": Z, "p_dis": Z.shape[1]})
    print(f"  M={M}: diseño Z {Z.shape}   objetivo Y {Y_obs.shape}")
# Out:
# orígenes evaluados : 996  (train 696 · test 300)
# corte T0=700  ->  índice de origen T0_orig=696
#   M=1: diseño Z (996, 4)   objetivo Y (996, 1)
#   M=2: diseño Z (996, 8)   objetivo Y (996, 2)
#   M=3: diseño Z (996, 12)   objetivo Y (996, 3)
#   M=4: diseño Z (996, 16)   objetivo Y (996, 4)
#   M=5: diseño Z (996, 20)   objetivo Y (996, 5)
#   M=6: diseño Z (996, 24)   objetivo Y (996, 6)
#   M=7: diseño Z (996, 28)   objetivo Y (996, 7)
#   M=8: diseño Z (996, 32)   objetivo Y (996, 8)

# %%
# Curvas de referencia y el piso de la representación, por M. El mapa
# scores->curva DETERMINISTA vive en el paquete (`curva_media_desde_scores`):
# es el caso "modo_residuo=ninguno" de PropagadorFuncional, sin muestreo.
for M in EST:
    e = EST[M]
    e["curvas_desde_scores_std"] = (
        lambda Y, e=e: curva_media_desde_scores(Y, e["fpca"], e["std"]))
    e["X_proj"] = e["fpca"].reconstruct(e["SCORES"])[N_LAGS:]

    # Control: reconstruir el objetivo observado debe dar exactamente X_proj.
    f = e["curvas_desde_scores_std"]
    assert np.allclose(f(e["Y_obs"]), e["X_proj"], atol=1e-8), (
        f"[M={M}] el mapa scores->curva no reproduce la proyección FPCA; "
        "revisar el estandarizador cargado.")

    e["MISE_TRUNC"] = {b: mise(X_obj_ev[m], e["X_proj"][m], grilla)
                       for b, m in (("train", es_train), ("test", ~es_train))}

print("MISE del TRUNCAMIENTO FPCA (piso común a todos los modelos de cada M):")
print(f"{'M':>3}  {'train':>11}  {'test':>11}")
for M in EST:
    v = EST[M]["MISE_TRUNC"]
    print(f"{M:>3}  {v['train']:>11.6f}  {v['test']:>11.6f}")
print("  <- ningún modelo sobre esa representación puede bajar de ahí")
# Out:
# MISE del TRUNCAMIENTO FPCA (piso común a todos los modelos de cada M):
#   M        train         test
#   1     0.730461     0.811963
#   2     0.670894     0.764374
#   3     0.616777     0.712108
#   4     0.565308     0.656456
#   5     0.517641     0.616472
#   6     0.471844     0.561469
#   7     0.428355     0.510739
#   8     0.385624     0.471453
#   <- ningún modelo sobre esa representación puede bajar de ahí

# %% [markdown]
# ## 3. Los competidores

# %% [markdown]
# ### 3.1 FAR(1) sobre los COEFICIENTES B-spline, en la métrica $L^2$
#
# Se ajusta sobre los coeficientes de la representación B-spline, no sobre la
# curva en la grilla — un eje de comparación adicional respecto de RF, GBT y el
# PSBPM-FD, que trabajan sobre los $M$ scores FPCA.
#
# Como las B-spline no son ortonormales, el producto interno de dos curvas NO es
# el producto escalar de sus coeficientes: hay que pasar por la Gram de la base
# ($W$) para que la geometría sea la de $L^2$. La celda de abajo hace ese
# blanqueo y lo verifica con un `assert`; el porqué de cada paso —por qué $k_n$
# no es el orden del AR, por qué la cuadratura pasa a ser `"conteo"` una vez
# blanqueado— queda en los comentarios del código, para no repetirlo aquí en
# prosa.

# %%
from model_psbp_fd.fit.far_operador import (
    FARp, seleccionar_kn)
from model_psbp_fd.utils.linalg import safe_chol

# [CONFIG] Tope del barrido de kn. Ahora acota en K -el numero de funciones
# base-, no en L: el operador vive en el espacio de coeficientes.
KN_MAX = 12

# [CONFIG] cifras del generador contra las que se lee el desempeño. No hay
# HS de referencia: el operador del A-3 es una evaluacion puntual en tau = 1.

_p_sim0 = EST[_M0]["paths"]["raw"] / "simulation_config.json"
_diag0 = (_json.loads(_p_sim0.read_text(encoding="utf-8")).get("diagnostico", {})
          if _p_sim0.exists() else {})
print(f"R^2 del oraculo de 1 rezago (exacto y lineal) = "
      f"{float(_diag0['r2_oraculo_1rezago']):.4f}   "
      "<- el centro casi no tiene que predecir; lo que se puede ganar es la banda")

# [CONFIG] Criterio de far.cv con que se elige kn
CRITERIO_KN = "L2"

# La representacion B-spline es la MISMA en todos los puntos del barrido -la
# elige el GCV del _01 sobre las curvas
for M in EST:
    e = EST[M]
    e["fr"], e["THETA"], _ = cargar_representacion(e["paths"])

fr0     = EST[_M0]["fr"]
THETA0  = np.asarray(EST[_M0]["THETA"], dtype=float)     # (T, K)
W_GRAM  = np.asarray(fr0.gram_, dtype=float)             # (K, K)
L_GRAM  = safe_chol(W_GRAM)                              # W = L L^T

# Coordenadas blanqueadas: el producto escalar euclideo de estas filas ES el
# producto interno L^2 de las curvas que representan.
THETA_W = THETA0 @ L_GRAM                                # (T, K)

# Verificacion de que el cambio de coordenadas hace lo que dice: la norma L^2
# de cada curva calculada con la Gram debe coincidir con la norma euclidea de
# su fila blanqueada.
_n_gram = np.einsum("tk,kl,tl->t", THETA0, W_GRAM, THETA0)
_n_eucl = (THETA_W ** 2).sum(axis=1)
_err = float(np.max(np.abs(_n_gram - _n_eucl)) / max(np.max(_n_gram), 1e-300))
assert _err < 1e-8, (
    f"El blanqueo por la Gram no preserva la norma L^2 (error relativo "
    f"{_err:.2e}): revisar safe_chol o la orientacion de la factorizacion.")

print(f"base B-spline: K = {THETA0.shape[1]} funciones   ·   "
      f"cond(W) = {np.linalg.cond(W_GRAM):.2f}")
print(f"blanqueo por la Gram verificado: ||x||_L2 == ||theta_w||_2 "
      f"(error relativo max {_err:.2e})")
print("El FAR se estima en ESTAS coordenadas, donde euclideo = L^2.")
# Out:
# R^2 del oraculo de 1 rezago (exacto y lineal) = 0.0044   <- el centro casi no tiene que predecir; lo que se puede ganar es la banda
# base B-spline: K = 22 funciones   ·   cond(W) = 8.96
# blanqueo por la Gram verificado: ||x||_L2 == ||theta_w||_2 (error relativo max 9.08e-11)
# El FAR se estima en ESTAS coordenadas, donde euclideo = L^2.

# %%
_KN_TOPE = int(min(KN_MAX, THETA_W.shape[1]))
# p=N_LAGS: el FAR se especifica con el MISMO numero de rezagos que ve el
# PSBPM-FD (ver docstring de FARp). El orden no se barre ni se elige: barrerlo
# le daria al FAR una ventaja de especificacion de la que los demas modelos no
# disponen.
CV_KN = seleccionar_kn(THETA_W[:T0], kn_max=_KN_TOPE, pesos="conteo", p=N_LAGS)
KN_ELEGIDO = {"L1": CV_KN.kn_L1, "L2": CV_KN.kn_L2,
              "Linf": CV_KN.kn_Linf}[CRITERIO_KN]

print(f"far.cv sobre coeficientes: hold-out de las ultimas "
      f"{CV_KN.n_validacion} curvas de train   ·   kn_max = {_KN_TOPE} (= K)")
print(f"{'kn':>4}  " + "  ".join(f"{c:>9}" for c in CV_KN.columnas[1:]))
for fila in CV_KN.tabla:
    marca = "  <-" if int(fila[0]) == KN_ELEGIDO else ""
    print(f"{int(fila[0]):>4}  " + "  ".join(f"{v:>9.4f}" for v in fila[1:]) + marca)
print(f"\nkn elegido por {CRITERIO_KN}: {KN_ELEGIDO}"
      f"   (L1 -> {CV_KN.kn_L1}, Linf -> {CV_KN.kn_Linf})")

_l2 = CV_KN.tabla[:, 2]
_planitud = float((_l2.max() - _l2.min()) / _l2.min())
print(f"amplitud relativa del criterio {CRITERIO_KN}: {_planitud:.2%}"
      + ("   <- PLANO: la eleccion de kn no es informativa, reportar la tabla"
         if _planitud < 0.05 else ""))
# Out:
# far.cv sobre coeficientes: hold-out de las ultimas 140 curvas de train   ·   kn_max = 12 (= K)
#   kn         L1         L2       Linf      L1max      L2max    Linfmax
#    1     0.1395     0.1759     0.4097     0.3281     0.3482     0.6490  <-
#    2     0.1397     0.1762     0.4098     0.3269     0.3472     0.6504
#    3     0.1398     0.1764     0.4105     0.3232     0.3437     0.6417
#    4     0.1404     0.1769     0.4104     0.3154     0.3369     0.6303
#    5     0.1407     0.1772     0.4112     0.3077     0.3300     0.6410
#    6     0.1413     0.1777     0.4114     0.3018     0.3245     0.6183
#    7     0.1416     0.1781     0.4123     0.2933     0.3175     0.6206
#    8     0.1419     0.1782     0.4125     0.2887     0.3128     0.6109
#    9     0.1419     0.1783     0.4127     0.2822     0.3071     0.6123
#   10     0.1425     0.1793     0.4166     0.2769     0.3037     0.6333
#   11     0.1439     0.1812     0.4208     0.2674     0.2946     0.6072
#   12     0.1446     0.1820     0.4206     0.2602     0.2881     0.6169
#
# kn elegido por L2: 1   (L1 -> 1, Linf -> 1)
# amplitud relativa del criterio L2: 3.47%   <- PLANO: la eleccion de kn no es informativa, reportar la tabla

# %%
# Ajuste del operador FAR(p) con p=N_LAGS, todo en coordenadas blanqueadas.
# FARp generaliza FAR1 a p rezagos (Yule-Walker en el subespacio de kn
# direcciones); con p=1 reproduce FAR1 exactamente. p se fija en N_LAGS y NO
# se barre, por la misma razon que en la seleccion de kn de arriba.
FAR_MOD = FARp(p=N_LAGS, kn=KN_ELEGIDO, pesos="conteo").fit(THETA_W[:T0])

_diag = FAR_MOD.diagnostico_kn()
print("operador estimado sobre los coeficientes (metrica L^2):")
for k, v in _diag.items():
    print(f"  {k:22s}: {v}")
print()
print("`condicion` = lambda_1 / lambda_kn es por lo que se esta dividiendo en la")
print("direccion mas debil retenida: anticipa la sensibilidad a kn antes de que")
print("se vea en el error.")
print(f"radio espectral (companera del VAR({N_LAGS}) en el subespacio) = "
      f"{_diag['radio_espectral']:.4f}"
      + ("   <- >= 1: el operador ajustado no es estacionario" if _diag['radio_espectral'] >= 1 else ""))

# predict_serie alinea la prediccion de la curva t con sus p=N_LAGS rezagos
# anteriores y devuelve (T-p, K) = (n_orig, K): exactamente la serie de
# origenes que evalua el resto del notebook, sin construir los rezagos a mano.
_THETA_W_pred = FAR_MOD.predict_serie(THETA_W)         # (n_orig, K) blanqueado
assert _THETA_W_pred.shape[0] == n_orig, (_THETA_W_pred.shape, n_orig)

# Vuelta a coeficientes: theta = theta_w L^{-1}, resuelto por triangular en vez
# de invertir la Gram.
THETA_PRED_FAR = np.linalg.solve(L_GRAM.T, _THETA_W_pred.T).T   # (n_orig, K)

# El FAR se EVALUA con la representacion completa -los K coeficientes B-spline-
# y NO truncado a M. 
X_PRED_FAR_GRILLA = fr0.reconstruct(THETA_PRED_FAR)     # (n_orig, G), K completo

# Curvas que NO pasan por la proyeccion a M de cada punto. Las consultan la
# Seccion 4 (Bloque A) y la 5 (Bloque B).
CURVA_DIRECTA = {"FAR": X_PRED_FAR_GRILLA}

# La proyeccion a M se conserva en el mismo formato que los demas modelos.
# NO es lo que se evalua.
for M in EST:
    e = EST[M]
    e["PRED"] = {}      # {nombre: (n_orig, M) en escala estandarizada}
    e["INFO"] = {}      # notas por modelo, para el resumen
    e["PRED"]["FAR"] = e["std"].transform(e["fpca"].transform(THETA_PRED_FAR))
    # ||rho||_HS combinada: norma de Frobenius del operador (p, L, L) apilado,
    # que colapsa los p rezagos en una sola cifra comparable con el FAR(1) de
    # otras corridas (ahi coincide exactamente con norma_hs, sin combinar).
    _hs_total = float(np.sqrt(np.sum(np.asarray(_diag["norma_hs_por_rezago"]) ** 2)))
    e["INFO"]["FAR"] = (f"coeficientes B-spline en L^2, K={THETA0.shape[1]} "
                        f"COMPLETO (no truncado a M), p={N_LAGS}, kn={KN_ELEGIDO} "
                        f"(far.cv/{CRITERIO_KN}), ||rho||_HS={_hs_total:.4f}")
    e["far_hs"]   = _hs_total
    e["far_hs_por_rezago"] = list(_diag["norma_hs_por_rezago"])
    e["far_cond"] = float(_diag["condicion"])
    e["far_kn"]   = int(KN_ELEGIDO)
    e["far_p"]    = int(N_LAGS)

print(f"curva del FAR en la grilla: {X_PRED_FAR_GRILLA.shape}   "
      f"(K={THETA0.shape[1]} completo, INVARIANTE en M)")
# Out:
# operador estimado sobre los coeficientes (metrica L^2):
#   p                     : 4
#   kn                    : 1
#   lambda_1              : 0.06217947133966875
#   lambda_min_retenido   : 0.06217947133966875
#   condicion             : 1.0
#   varianza_retenida     : 0.07863438398702026
#   norma_hs_por_rezago   : [0.0002885180948957656, 0.017933099842335862, 0.03330498620467311, 0.002918912848346461]
#   radio_espectral       : 0.3308780480255947
#   n_curvas              : 700
#   n_pares               : {1: 699, 2: 698, 3: 697, 4: 696}
#
# `condicion` = lambda_1 / lambda_kn es por lo que se esta dividiendo en la
# direccion mas debil retenida: anticipa la sensibilidad a kn antes de que
# se vea en el error.
# radio espectral (companera del VAR(4) en el subespacio) = 0.3309
# curva del FAR en la grilla: (996, 75)   (K=22 completo, INVARIANTE en M)

# %% [markdown]
# ### 3.2 Modelos de aprendizaje automático
#
# Sin validación cruzada sobre el bloque de prueba, y con hiperparámetros fijos
# entre escenarios **y entre puntos del barrido**. Acotan cuánto de la ventaja
# del modelo propuesto es **no linealidad** y cuánto es la **mezcla**.

# %%
SEED_ML = 20260830

PARAMS_RF  = dict(n_estimators=500, min_samples_leaf=5, max_features="sqrt",
                  random_state=SEED_ML, n_jobs=-1)
PARAMS_GBT = dict(max_iter=300, learning_rate=0.05, max_leaf_nodes=15,
                  min_samples_leaf=10, early_stopping=False,
                  random_state=SEED_ML)

# RF y GBT compiten contra SUS PROPIAS variantes de orden 1..N_LAGS: para cada
# orden r se usan solo las columnas de Z con rezago <= r (todas las
# componentes), se elige el ganador por % de VENTANAS DE TRAIN ganadas en
# mae_f (mismo criterio de la Seccion 6, pero sobre train para no fugar el
# bloque de prueba en la eleccion), y solo esa variante entra a PRED. Con
# N_LAGS=1 hay un solo orden posible y esto reproduce el ajuste de siempre.
_ORDENES = list(range(1, N_LAGS + 1))

# cov_names esta en orden lag-mayor (todas las componentes del lag 1, luego
# todas las del lag 2, ...): la columna r*n_components es exactamente donde
# empieza el lag r+1. Se verifica en vez de asumirlo.
def _cols_orden(e, r):
    n_c = e["n_components"]
    cols = e["cov_names"][: r * n_c]
    for j, nombre in enumerate(cols):
        lag_esperado = j // n_c + 1
        assert nombre.endswith(f"_lag{lag_esperado}"), (
            f"cov_names no esta en orden lag-mayor: {nombre!r} en la posicion "
            f"{j} deberia ser lag{lag_esperado}.")
    return r * n_c


def _elegir_orden(e, familia, ajustar_predecir):
    """Ajusta `familia` en cada orden, evalua en ventanas de TRAIN y devuelve
    (pred_ganador, info_ganador) del orden mas veces ganador en mae_f."""
    preds = {}
    for r in _ORDENES:
        n_col = _cols_orden(e, r)
        preds[r] = ajustar_predecir(e["Z"][:, :n_col])

    if len(_ORDENES) == 1:
        return preds[_ORDENES[0]], _ORDENES[0], None

    filas = []
    for r in _ORDENES:
        X_r = e["curvas_desde_scores_std"](preds[r])
        t_ = ventana_movil_funcional(X_obj_ev, X_r, grilla, T0_orig, w=W_COMP,
                                     t_offset=N_LAGS, pesos_tau=PESOS_TAU,
                                     bloque_A=True, verbose=False)
        t_ = t_[(~t_["cruza_T0"]) & (t_["bloque"] == "train")]
        t_["orden"] = r
        filas.append(t_[["t_centro", "mae_f", "orden"]])
    tabla = pd.concat(filas, ignore_index=True)
    piv = tabla.pivot(index="t_centro", columns="orden", values="mae_f")
    ganador_por_ventana = piv.idxmin(axis=1)
    pct = ganador_por_ventana.value_counts(normalize=True).reindex(
        _ORDENES, fill_value=0.0)
    ganador = int(pct.idxmax())   # empate -> el primer orden (mas parco)
    info = (f"orden elegido por ventanas de train: {ganador} "
           f"({pct[ganador]:.1%} de {len(piv)} ventanas) de {_ORDENES}")
    return preds[ganador], ganador, info


for M in EST:
    e = EST[M]

    def _ajustar_rf(Z_r, e=e):
        y_fit = e["Y_obs"][es_train]
        if e["n_components"] == 1:
            y_fit = y_fit.ravel()
        rf = RandomForestRegressor(**PARAMS_RF).fit(Z_r[es_train], y_fit)
        return np.asarray(rf.predict(Z_r), dtype=float).reshape(e["Y_obs"].shape)

    pred_rf, orden_rf, info_rf = _elegir_orden(e, "RF", _ajustar_rf)
    e["PRED"]["RF"] = pred_rf
    e["INFO"]["RF"] = (f"n_estimators={PARAMS_RF['n_estimators']}, "
                       f"leaf>={PARAMS_RF['min_samples_leaf']}, orden={orden_rf}")
    e["ml_orden_rf"] = orden_rf
    if info_rf:
        print(f"  M={M} RF:  {info_rf}")

    def _ajustar_gbt(Z_r, e=e):
        pred = np.empty_like(e["Y_obs"])
        for k in range(e["n_components"]):
            g = HistGradientBoostingRegressor(**PARAMS_GBT)
            g.fit(Z_r[es_train], e["Y_obs"][es_train, k])
            pred[:, k] = g.predict(Z_r)
        return pred

    pred_gbt, orden_gbt, info_gbt = _elegir_orden(e, "GBT", _ajustar_gbt)
    e["PRED"]["GBT"] = pred_gbt
    e["INFO"]["GBT"] = (f"max_iter={PARAMS_GBT['max_iter']}, "
                        f"lr={PARAMS_GBT['learning_rate']}, orden={orden_gbt}")
    e["ml_orden_gbt"] = orden_gbt
    if info_gbt:
        print(f"  M={M} GBT: {info_gbt}")

    print(f"M={M}: RF orden={orden_rf} sobre {int(es_train.sum())} origenes "
          f"(multisalida) · GBT orden={orden_gbt}, {e['n_components']} "
          "modelos univariantes")
# Out:
#   M=1 RF:  orden elegido por ventanas de train: 4 (77.7% de 667 ventanas) de [1, 2, 3, 4]
#   M=1 GBT: orden elegido por ventanas de train: 4 (90.1% de 667 ventanas) de [1, 2, 3, 4]
# M=1: RF orden=4 sobre 696 origenes (multisalida) · GBT orden=4, 1 modelos univariantes
#   M=2 RF:  orden elegido por ventanas de train: 4 (68.2% de 667 ventanas) de [1, 2, 3, 4]
#   M=2 GBT: orden elegido por ventanas de train: 4 (97.0% de 667 ventanas) de [1, 2, 3, 4]
# M=2: RF orden=4 sobre 696 origenes (multisalida) · GBT orden=4, 2 modelos univariantes
#   M=3 RF:  orden elegido por ventanas de train: 4 (69.9% de 667 ventanas) de [1, 2, 3, 4]
#   M=3 GBT: orden elegido por ventanas de train: 4 (98.5% de 667 ventanas) de [1, 2, 3, 4]
# M=3: RF orden=4 sobre 696 origenes (multisalida) · GBT orden=4, 3 modelos univariantes
#   M=4 RF:  orden elegido por ventanas de train: 4 (96.9% de 667 ventanas) de [1, 2, 3, 4]
#   M=4 GBT: orden elegido por ventanas de train: 4 (97.2% de 667 ventanas) de [1, 2, 3, 4]
# M=4: RF orden=4 sobre 696 origenes (multisalida) · GBT orden=4, 4 modelos univariantes
#   M=5 RF:  orden elegido por ventanas de train: 4 (98.1% de 667 ventanas) de [1, 2, 3, 4]
#   M=5 GBT: orden elegido por ventanas de train: 4 (97.3% de 667 ventanas) de [1, 2, 3, 4]
# M=5: RF orden=4 sobre 696 origenes (multisalida) · GBT orden=4, 5 modelos univariantes
#   M=6 RF:  orden elegido por ventanas de train: 4 (76.3% de 667 ventanas) de [1, 2, 3, 4]
#   M=6 GBT: orden elegido por ventanas de train: 4 (97.9% de 667 ventanas) de [1, 2, 3, 4]
# M=6: RF orden=4 sobre 696 origenes (multisalida) · GBT orden=4, 6 modelos univariantes
#   M=7 RF:  orden elegido por ventanas de train: 4 (99.3% de 667 ventanas) de [1, 2, 3, 4]
#   M=7 GBT: orden elegido por ventanas de train: 4 (100.0% de 667 ventanas) de [1, 2, 3, 4]
# M=7: RF orden=4 sobre 696 origenes (multisalida) · GBT orden=4, 7 modelos univariantes
#   M=8 RF:  orden elegido por ventanas de train: 4 (97.8% de 667 ventanas) de [1, 2, 3, 4]
#   M=8 GBT: orden elegido por ventanas de train: 4 (99.7% de 667 ventanas) de [1, 2, 3, 4]
# M=8: RF orden=4 sobre 696 origenes (multisalida) · GBT orden=4, 8 modelos univariantes

# %% [markdown]
# ### 3.3 Las dos líneas base
#
# Sobre la serie completa de orígenes, para que entren en la misma tabla. La
# media incondicional es cero en escala estandarizada, y su RMSE cercano a 1 es
# la unidad de lectura.

# %%
for M in EST:
    e = EST[M]
    e["PRED"]["media"] = np.zeros_like(e["Y_obs"])
    e["INFO"]["media"] = "cero por construccion en escala estandarizada"

    # Persistencia: el score observado en t-1. Para el primer origen
    # (t = N_LAGS+1) el valor en t-1 = N_LAGS existe en SCORES_STD.
    e["PRED"]["persistencia"] = e["SCORES_STD"][N_LAGS - 1:T - 1]
    e["INFO"]["persistencia"] = "y_hat(t) = y(t-1)"

    assert all(v.shape == e["Y_obs"].shape for v in e["PRED"].values()), {
        k: v.shape for k, v in e["PRED"].items()}
    print(f"M={M}: modelos listos -> {', '.join(e['PRED'])}")

MODELOS = list(EST[_M0]["PRED"])       # mismo conjunto y orden en todos los M
# Out:
# M=1: modelos listos -> FAR, RF, GBT, media, persistencia
# M=2: modelos listos -> FAR, RF, GBT, media, persistencia
# M=3: modelos listos -> FAR, RF, GBT, media, persistencia
# M=4: modelos listos -> FAR, RF, GBT, media, persistencia
# M=5: modelos listos -> FAR, RF, GBT, media, persistencia
# M=6: modelos listos -> FAR, RF, GBT, media, persistencia
# M=7: modelos listos -> FAR, RF, GBT, media, persistencia
# M=8: modelos listos -> FAR, RF, GBT, media, persistencia

# %% [markdown]
# ### 3.4 Predicción puntual del PSBPM-FD
#
# Se leen las trazas y se toma **sólo la media predictiva** por score. Es lo
# único que necesita el MISE de un punto, y evita depender de que el `_04` haya
# persistido su tabla de ventana móvil para cada ancho: sólo guarda la de su $w$
# de referencia.

# %%
# La convencion de nombres de las trazas y su lectura viven en el paquete
# (`models.pspb_fd_v3`): aqui solo se recorre. `ModeloTraza` conserva las
# trazas crudas y construye la matriz de diseno con intercepto, de modo que
# la media predictiva sale sin repetir el armado a mano.
_CACHE_MEDIA = {}

for M in EST:
    e, P = EST[M], EST[M]["paths"]
    ci, n_comp, n_iter = e["component_idx"], e["n_components"], e["n_iter"]

    faltan = [ruta_traza(P, ci[k] + 1, c + 1).name
              for k in range(n_comp) for c in range(n_iter)
              if not ruta_traza(P, ci[k] + 1, c + 1).exists()]

    e["X_pred_psbp"] = None
    if faltan:
        print(f"AVISO [M={M}] faltan {len(faltan)} trazas .mat: {faltan[:3]}...")
        print("      Sin PSBPM-FD en la comparacion de este punto del barrido.")
        continue

    Y_hat_psbp = np.empty_like(e["Y_obs"])
    for k in range(n_comp):
        cov_k = e["cov_por_componente"][k]
        df_dis = pd.concat([pd.DataFrame({"_y": np.zeros(len(e["dfs_full"][k]))}),
                            e["dfs_full"][k][cov_k].reset_index(drop=True)], axis=1)
        medias = []
        for c in range(n_iter):
            if (ci[k], c) not in _CACHE_MEDIA:
                modelo = ModeloTraza.desde_ruta(ruta_traza(P, ci[k] + 1, c + 1))
                assert modelo.feature_names_ == cov_k, (
                    f"[M={M} k={k} c={c+1}] feature_names={modelo.feature_names_} "
                    f"!= covariables del componente={cov_k}")
                _CACHE_MEDIA[(ci[k], c)] = modelo.momentos(df_dis)["media"]
            medias.append(_CACHE_MEDIA[(ci[k], c)])
        # Media entre cadenas con peso igual: es la media de la mezcla, que es
        # lo que `agrupar_momentos` hace para el primer momento.
        Y_hat_psbp[:, k] = np.column_stack(medias).mean(axis=1)

    e["Y_hat_psbp"]  = Y_hat_psbp
    e["X_pred_psbp"] = e["curvas_desde_scores_std"](Y_hat_psbp)
    print(f"OK M={M}: PSBPM-FD recalculado ({n_comp} componentes x {n_iter} cadenas)")
# Out:
# OK M=1: PSBPM-FD recalculado (1 componentes x 2 cadenas)
# OK M=2: PSBPM-FD recalculado (2 componentes x 2 cadenas)
# OK M=3: PSBPM-FD recalculado (3 componentes x 2 cadenas)
# OK M=4: PSBPM-FD recalculado (4 componentes x 2 cadenas)
# OK M=5: PSBPM-FD recalculado (5 componentes x 2 cadenas)
# OK M=6: PSBPM-FD recalculado (6 componentes x 2 cadenas)
# OK M=7: PSBPM-FD recalculado (7 componentes x 2 cadenas)
# OK M=8: PSBPM-FD recalculado (8 componentes x 2 cadenas)

# %%
TOL_AVISO = 0.01     # por encima: vale la pena mirarlo
TOL_DURO  = 0.05     # por encima: no es error Monte Carlo

for M in EST:
    e = EST[M]
    if e["X_pred_psbp"] is None:
        continue
    npz_path = e["paths"]["predict"] / "banda_funcional_psbp.npz"
    if not npz_path.exists():
        print(f"[M={M}] sin banda_funcional_psbp.npz: no se puede cotejar "
              "con el _04. Ejecuta 103_04 para este M.")
        continue
    z = np.load(npz_path, allow_pickle=False)
    m04 = mise(X_obj_ev[~es_train], z["X_pred"][~es_train], grilla)
    m05 = mise(X_obj_ev[~es_train], e["X_pred_psbp"][~es_train], grilla)
    dif = abs(m05 - m04) / m04
    print(f"[M={M}] MISE test - _04: {m04:.6f}   recalculado: {m05:.6f}   "
          f"dif rel: {dif:.2e}")
    if dif < TOL_AVISO:
        print("        compatible con el error Monte Carlo del _04; la cifra")
        print("        recalculada es la mas precisa de las dos.")
    else:
        print(f"        POR ENCIMA de {TOL_AVISO:.0%}. Sigue siendo plausible si")
        print("        la predictiva es muy dispersa, pero conviene subir")
        print("        S_FUNC en el _04 antes de citar su MISE como definitivo.")
    assert dif < TOL_DURO, (
        f"[M={M}] el MISE recalculado difiere del _04 en {dif:.1%}, demasiado "
        "para ser error Monte Carlo. Revisar si el _04 corrio con otra "
        "configuracion (modo_residuo, objetivo de evaluacion o particion).")
# Out:
# [M=1] MISE test - _04: 0.862665   recalculado: 0.862933   dif rel: 3.10e-04
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.
# [M=2] MISE test - _04: 0.862316   recalculado: 0.862868   dif rel: 6.40e-04
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.
# [M=3] MISE test - _04: 0.862487   recalculado: 0.862799   dif rel: 3.62e-04
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.
# [M=4] MISE test - _04: 0.862847   recalculado: 0.862869   dif rel: 2.48e-05
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.
# [M=5] MISE test - _04: 0.862774   recalculado: 0.862707   dif rel: 7.77e-05
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.
# [M=6] MISE test - _04: 0.862660   recalculado: 0.862713   dif rel: 6.11e-05
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.
# [M=7] MISE test - _04: 0.862960   recalculado: 0.862771   dif rel: 2.20e-04
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.
# [M=8] MISE test - _04: 0.862905   recalculado: 0.862680   dif rel: 2.61e-04
#         compatible con el error Monte Carlo del _04; la cifra
#         recalculada es la mas precisa de las dos.

# %% [markdown]
# ## 4. Bloque A: error puntual, todos los modelos
#
# Las **mismas tres normas** que `103_04`, sobre la misma ventana móvil y contra
# la misma curva verdadera:
#
# | | qué estima |
# |---|---|
# | **MAE** ($L^1$) | mediana condicional, robusta |
# | **RMSE** ($L^2$) | media condicional |
# | **Error máximo** ($L^\infty$, promedio por curva) | peor caso: por curva $\max_\tau\lvert e_t(\tau)\rvert$, promediado sobre la ventana |
#
# Aplican a **todos** los competidores: FAR, PSBPM-FD, RF, GBT y las dos líneas
# base. No requieren predictiva, sólo una predicción puntual.

# %%
# [CONFIG] Que series entran en las FIGURAS. Las tablas y los CSV llevan todo.

EXCLUIR_DE_FIGURA = {"media", "persistencia", "(truncamiento FPCA)"}

# [CONFIG] Estilo propio de las dos series que se TAPAN entre si.
ESTILOS_VENTANA = {
    "FAR":      dict(color="#1f6f8b", lw=3.0, ls="--"),
    "PSBPM-FD": dict(color="#c0392b", lw=1.6, ls="-", zorder=5),
}


def tabla_ventana(M, w):
    """Todas las series de este punto del barrido sobre ventanas de ancho w."""
    e = EST[M]
    partes = []
    for nom, Yp in e["PRED"].items():
        # El FAR entra por CURVA_DIRECTA: se evalua con los K coeficientes, sin
        # truncar a M. El resto pasa por la proyeccion FPCA de este punto.
        X_mod = CURVA_DIRECTA.get(nom)
        if X_mod is None:
            X_mod = e["curvas_desde_scores_std"](Yp)
        t_ = ventana_movil_funcional(
            X_obj_ev, X_mod, grilla, T0_orig, w=w,
            t_offset=N_LAGS, pesos_tau=PESOS_TAU,
            bloque_A=True, verbose=False)
        t_["modelo"] = nom
        partes.append(t_)

    t_tr = ventana_movil_funcional(X_obj_ev, e["X_proj"], grilla, T0_orig, w=w,
                                   t_offset=N_LAGS, pesos_tau=PESOS_TAU,
                                   bloque_A=True,
                                   verbose=False)
    t_tr["modelo"] = "(truncamiento FPCA)"
    partes.append(t_tr)

    # PSBPM-FD: de la prediccion recalculada en §5, que existe para CUALQUIER
    # w. Si las trazas no estaban, se recurre al CSV del _04 -buscado por
    # PATRON, porque su prefijo cambia entre escenarios- que solo cubre el w de
    # referencia de aquel notebook.
    if e["X_pred_psbp"] is not None:
        t_ps = ventana_movil_funcional(X_obj_ev, e["X_pred_psbp"], grilla,
                                       T0_orig, w=w, t_offset=N_LAGS,
                                       pesos_tau=PESOS_TAU,
                                       bloque_A=True,
                                       verbose=False)
        t_ps["modelo"] = "PSBPM-FD"
        partes.append(t_ps)
        origen = "trazas .mat (recalculado)"
    else:
        cand = sorted(e["paths"]["out_report"].glob(f"*_ventana_funcional_w{w}.csv"))
        if cand:
            t_ps = pd.read_csv(cand[0])
            t_ps["modelo"] = "PSBPM-FD"
            _cols = [c for c in ["t_centro", "bloque", "cruza_T0", "mise",
                                 "mae_f", "rmse_f", "linf_medio", "modelo"]
                     if c in t_ps.columns]
            partes.append(t_ps[_cols])
            origen = cand[0].name
        else:
            origen = None

    out = pd.concat(partes, ignore_index=True)
    out.attrs["w"] = w
    return out, origen


for M in EST:
    e = EST[M]
    e["tablas_w"] = {}
    for w in VENTANAS_W:
        e["tablas_w"][w], org = tabla_ventana(M, w)
        e["tablas_w"][w].to_csv(
            e["paths"]["out_report"] / f"{PREFIJO + 2}_ventana_modelos_w{w}.csv",
            index=False)
        n_series = e["tablas_w"][w]["modelo"].nunique()
        print(f"  M={M} w={w:>3}: {n_series} series · {len(e['tablas_w'][w])} filas"
              + (f" · PSBPM-FD desde {org}" if org else " · SIN PSBPM-FD"))
    e["ventana_df"] = e["tablas_w"][W_COMP]   # la que consumen las tablas numericas
# Out:
#   M=1 w= 20: 7 series · 6839 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=1 w= 30: 7 series · 6769 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=1 w= 40: 7 series · 6699 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=2 w= 20: 7 series · 6839 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=2 w= 30: 7 series · 6769 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=2 w= 40: 7 series · 6699 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=3 w= 20: 7 series · 6839 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=3 w= 30: 7 series · 6769 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=3 w= 40: 7 series · 6699 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=4 w= 20: 7 series · 6839 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=4 w= 30: 7 series · 6769 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=4 w= 40: 7 series · 6699 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=5 w= 20: 7 series · 6839 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=5 w= 30: 7 series · 6769 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=5 w= 40: 7 series · 6699 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=6 w= 20: 7 series · 6839 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=6 w= 30: 7 series · 6769 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=6 w= 40: 7 series · 6699 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=7 w= 20: 7 series · 6839 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=7 w= 30: 7 series · 6769 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=7 w= 40: 7 series · 6699 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=8 w= 20: 7 series · 6839 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=8 w= 30: 7 series · 6769 filas · PSBPM-FD desde trazas .mat (recalculado)
#   M=8 w= 40: 7 series · 6699 filas · PSBPM-FD desde trazas .mat (recalculado)

# %%
# Bloque A por modelo, en una sola vista. `tablas_w` ya trae las columnas
# -tabla_ventana llama a ventana_movil_funcional con bloque_A=True-.
fuera = set(EXCLUIR_DE_FIGURA)

for M in EST:
    e = EST[M]
    tw = e["tablas_w"][W_COMP]
    tf = tw[~tw["modelo"].isin(fuera)].copy()
    tf.attrs["w"] = W_COMP

    faltan = [c for c in METRICAS_A_COLS if c not in tf.columns]
    assert not faltan, f"[M={M}] faltan columnas del Bloque A: {faltan}"

    plot_ventana_movil(
        tf, T0, METRICAS_A_COLS, columna_grupo="modelo", estilos=ESTILOS_VENTANA,
        title=f"M={M} · Bloque A por modelo (w={W_COMP}) · "
              "MAE, RMSE, error máximo · contra la curva verdadera",
        save_path=str(e["paths"]["out_report"]
                      / f"{PREFIJO + 8}_ventana_bloqueA_modelos_w{W_COMP}.png"),
        verbose=False)
    plt.show()

    sub = tf.dropna(subset=METRICAS_A_COLS)
    faltan_ag = [c for c in ("l2_medio", "razon_agregacion") if c not in sub.columns]
    assert not faltan_ag, (
        f"[M={M}] faltan {faltan_ag}: la tabla no se genero con bloque_A=True.")

    assert (sub["mae_f"] <= sub["l2_medio"] + 1e-9).all(), (
        f"[M={M}] mae_f > l2_medio en alguna ventana: se rompio la cadena por "
        f"origen y el problema esta en como se construyo esa prediccion.")
    assert (sub["l2_medio"] <= sub["linf_medio"] + 1e-9).all(), (
        f"[M={M}] l2_medio > linf_medio en alguna ventana: idem.")


    assert (sub["l2_medio"] <= sub["rmse_f"] + 1e-9).all(), (
        f"[M={M}] l2_medio > rmse_f: imposible por Jensen; revise la agregacion.")

    _jen = sub[sub["rmse_f"] > sub["linf_medio"] + 1e-9]
    if len(_jen):
        print(f"[M={M}] Jensen: {len(_jen)}/{len(sub)} ventanas con "
              f"rmse_f > linf_medio (media cuadratica vs aritmetica). "
              f"exceso relativo maximo {((_jen['rmse_f'] / _jen['linf_medio']) - 1).max():.2%}"
              f" · razon_agregacion minima {_jen['razon_agregacion'].min():.3f}"
              f" · modelos {sorted(_jen['modelo'].unique())}")
    print(f"[M={M}] Bloque A dibujado para {sorted(sub['modelo'].unique())}")
# Out:
# [M=1] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']
# [M=2] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']
# [M=3] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']
# [M=4] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']
# [M=5] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']
# [M=6] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']
# [M=7] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']
# [M=8] Bloque A dibujado para ['FAR', 'GBT', 'PSBPM-FD', 'RF']

# %% [markdown]
# ## 5. Bloque B: intervalos, sólo FAR y PSBPM-FD
#
# Las **mismas cuatro cifras** que `103_04` —Winkler, cobertura simultánea,
# cobertura puntual y MPIW— sobre la misma ventana móvil.
#
# La diferencia con el Bloque A es a qué modelos aplica. El FAR **no** es un
# algoritmo de predicción puntual: es un modelo, $X_{t+1}=\rho(X_t)+\varepsilon$,
# de modo que su intervalo a un paso sale de su propia especificación y no de un
# procedimiento adosado. El PSBPM-FD tiene su predictiva muestreada. RF, GBT y
# las líneas base no son modelos de probabilidad: rellenarles una banda
# gaussiana de residuos dentro de muestra las haría parecer artificialmente
# angostas y decidiría la comparación por el supuesto, no por el método.

# %%
# Construcción de las bandas. Los residuos son los del bloque de
# entrenamiento contra la curva VERDADERA, que es el objetivo de evaluación.
BANDAS = {}          # {M: {nombre_fila: (li, ls)}}

for M in EST:
    e = EST[M]
    n_train = int(es_train.sum())
    corr = (np.sqrt(1.0 + e["far_kn"] / n_train)
            if IC_CORRECCION_ESTIMACION else None)

    bandas = {}

    # -- FAR: el intervalo que implica su propio modelo --------------------
    # K completo, igual que en el Bloque A: las dos filas del FAR -banda y
    # error puntual- tienen que salir de la MISMA curva predicha.
    X_far = CURVA_DIRECTA["FAR"]
    r_far = residuos_para_banda(X_obj_ev, X_far, es_train)
    bandas["FAR (IC del modelo AR)"] = (
        banda_predictiva_modelo(X_far, r_far, nivel=NIVEL_IC,
                                por_tau=IC_POR_TAU,
                                correccion_estimacion=corr),
        X_far)

    # -- PSBPM-FD: la MISMA banda, para aislar el mecanismo ----------------
    if IC_PSBP_TAMBIEN_GAUSSIANA and e["X_pred_psbp"] is not None:
        r_ps = residuos_para_banda(X_obj_ev, e["X_pred_psbp"], es_train)
        bandas["PSBPM-FD (IC gaussiano, mismo mecanismo)"] = (
            banda_predictiva_modelo(e["X_pred_psbp"], r_ps, nivel=NIVEL_IC,
                                    por_tau=IC_POR_TAU,
                                    correccion_estimacion=corr),
            e["X_pred_psbp"])

    # -- PSBPM-FD: su banda nativa, leída del artefacto del _04 ------------
    npz = e["paths"]["predict"] / "banda_funcional_psbp.npz"
    if npz.exists():
        z = np.load(npz, allow_pickle=False)
        assert z["li"].shape == X_obj_ev.shape, (
            f"[M={M}] la banda del _04 es {z['li'].shape} y aquí hay "
            f"{X_obj_ev.shape}: ¿corrieron con distinta partición?")
        assert abs(float(z["nivel"][0]) - NIVEL_IC) < 1e-9, (
            f"[M={M}] el _04 usó nivel {float(z['nivel'][0])} y aquí NIVEL_IC="
            f"{NIVEL_IC}: el Winkler de las dos filas no sería comparable.")
        bandas["PSBPM-FD (predictiva bayesiana)"] = (
            (z["li"].astype(float), z["ls"].astype(float)),
            z["X_pred"].astype(float))
    else:
        print(f"! [M={M}] falta {npz.name}: ejecuta 103_04 para persistir la "
              "banda nativa. Van solo las filas gaussianas.")

    BANDAS[M] = bandas
    sd = sigma_residual(r_far, por_tau=IC_POR_TAU)
    print(f"M={M}  kn={e['far_kn']}  corrección={corr if corr else 1.0:.4f}  "
          f"sigma_eps(tau) del FAR: min={sd.min():.4f} máx={sd.max():.4f} "
          f"(razón {sd.max()/sd.min():.2f})  ·  filas: {len(bandas)}")
# Out:
# M=1  kn=1  corrección=1.0007  sigma_eps(tau) del FAR: min=0.7611 máx=1.3495 (razón 1.77)  ·  filas: 3
# M=2  kn=1  corrección=1.0007  sigma_eps(tau) del FAR: min=0.7611 máx=1.3495 (razón 1.77)  ·  filas: 3
# M=3  kn=1  corrección=1.0007  sigma_eps(tau) del FAR: min=0.7611 máx=1.3495 (razón 1.77)  ·  filas: 3
# M=4  kn=1  corrección=1.0007  sigma_eps(tau) del FAR: min=0.7611 máx=1.3495 (razón 1.77)  ·  filas: 3
# M=5  kn=1  corrección=1.0007  sigma_eps(tau) del FAR: min=0.7611 máx=1.3495 (razón 1.77)  ·  filas: 3
# M=6  kn=1  corrección=1.0007  sigma_eps(tau) del FAR: min=0.7611 máx=1.3495 (razón 1.77)  ·  filas: 3
# M=7  kn=1  corrección=1.0007  sigma_eps(tau) del FAR: min=0.7611 máx=1.3495 (razón 1.77)  ·  filas: 3
# M=8  kn=1  corrección=1.0007  sigma_eps(tau) del FAR: min=0.7611 máx=1.3495 (razón 1.77)  ·  filas: 3

# %%
# Las cuatro cifras del Bloque B, por fila y por bloque. El Winkler es la
# PRIMARIA; picp y mpiw son su descomposición y no ordenan nada por su cuenta.
for M in EST:
    e = EST[M]
    # Los dos objetivos de docs 03_05_00. La banda del FAR vive en los K
    # coeficientes y la del PSBPM-FD en las M autofunciones: contra un objetivo
    # unico uno de los dos paga un truncamiento que el otro no paga.
    OBJETIVOS_B = (("curva_suavizada", X_obj_ev),
                   ("representacion_fpca", e["X_proj"]))
    filas = []
    for objetivo, Y in OBJETIVOS_B:
        for nombre, ((li, ls), _Xp) in BANDAS[M].items():
            for etq, mask in (("train", es_train), ("test", ~es_train)):
                r = resumen_intervalo(Y[mask], li[mask], ls[mask],
                                      nivel=NIVEL_IC, tau=grilla)
                picp_si = float(indicador_cobertura_simultanea(
                    Y[mask], li[mask], ls[mask]).mean())
                filas.append({"objetivo": objetivo, "banda": nombre,
                              "bloque": etq,
                              **{k: r[k] for k in
                                 ("winkler", "picp", "ee_picp", "ace", "mpiw")},
                              "picp_simultaneo": picp_si})
    B_df = (pd.DataFrame(filas)
            .set_index(["bloque", "objetivo", "banda"]).sort_index())
    B_df.to_csv(e["paths"]["out_report"] / "80_bloqueB_modelos.csv")
    e["B_modelos"] = B_df

    display(B_df.loc["test"].style
            .format({"winkler": "{:.4f}", "picp": "{:.4f}", "ee_picp": "{:.4f}",
                     "ace": "{:+.4f}", "mpiw": "{:.4f}",
                     "picp_simultaneo": "{:.4f}"})
            .background_gradient(subset=["winkler"], cmap="RdYlGn_r")
            .set_caption(f"M={M} · Bloque B, bloque de PRUEBA · PRIMARIA: "
                         f"winkler · nivel nominal {NIVEL_IC:.0%}"))

    # La lectura de tres filas, que es la razón de haberlas construido, leída
    # contra cada objetivo por separado.
    g_far = "FAR (IC del modelo AR)"
    g_psg = "PSBPM-FD (IC gaussiano, mismo mecanismo)"
    g_psb = "PSBPM-FD (predictiva bayesiana)"
    for objetivo, _ in OBJETIVOS_B:
        te_ = B_df.loc[("test", objetivo)]
        if {g_far, g_psg} <= set(te_.index):
            d_modelo = te_.loc[g_psg, "winkler"] - te_.loc[g_far, "winkler"]
            print(f"[M={M}] {objetivo:<20} mismo MECANISMO, distinto MODELO: "
                  f"PSBPM-FD - FAR = {d_modelo:+.4f} de Winkler")
        if {g_psg, g_psb} <= set(te_.index):
            d_mec = te_.loc[g_psb, "winkler"] - te_.loc[g_psg, "winkler"]
            print(f"        {objetivo:<20} mismo MODELO, distinto MECANISMO: "
                  f"bayesiana - gaussiana = {d_mec:+.4f}")
        print("        Si el segundo domina al primero, lo que separa a las")
        print("        filas es la forma de la predictiva y no la calidad de la")
        print("        media condicional; si domina el primero, al revés.")
# Out:
# <style type="text/css">
# #T_401b3_row0_col0, #T_401b3_row1_col0 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_401b3_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_401b3_row3_col0, #T_401b3_row4_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_401b3_row5_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_401b3">
#   <caption>M=1 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_401b3_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_401b3_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_401b3_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_401b3_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_401b3_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_401b3_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >objetivo</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_401b3_level0_row0" class="row_heading level0 row0" rowspan="3">curva_suavizada</th>
#       <th id="T_401b3_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_401b3_row0_col0" class="data row0 col0" >4.8867</td>
#       <td id="T_401b3_row0_col1" class="data row0 col1" >0.9380</td>
#       <td id="T_401b3_row0_col2" class="data row0 col2" >0.0016</td>
#       <td id="T_401b3_row0_col3" class="data row0 col3" >-0.0120</td>
#       <td id="T_401b3_row0_col4" class="data row0 col4" >3.4792</td>
#       <td id="T_401b3_row0_col5" class="data row0 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_401b3_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_401b3_row1_col0" class="data row1 col0" >4.8872</td>
#       <td id="T_401b3_row1_col1" class="data row1 col1" >0.9381</td>
#       <td id="T_401b3_row1_col2" class="data row1 col2" >0.0016</td>
#       <td id="T_401b3_row1_col3" class="data row1 col3" >-0.0119</td>
#       <td id="T_401b3_row1_col4" class="data row1 col4" >3.4793</td>
#       <td id="T_401b3_row1_col5" class="data row1 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_401b3_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_401b3_row2_col0" class="data row2 col0" >15.8637</td>
#       <td id="T_401b3_row2_col1" class="data row2 col1" >0.3996</td>
#       <td id="T_401b3_row2_col2" class="data row2 col2" >0.0033</td>
#       <td id="T_401b3_row2_col3" class="data row2 col3" >-0.5504</td>
#       <td id="T_401b3_row2_col4" class="data row2 col4" >0.8822</td>
#       <td id="T_401b3_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_401b3_level0_row3" class="row_heading level0 row3" rowspan="3">representacion_fpca</th>
#       <th id="T_401b3_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_401b3_row3_col0" class="data row3 col0" >3.4836</td>
#       <td id="T_401b3_row3_col1" class="data row3 col1" >0.9996</td>
#       <td id="T_401b3_row3_col2" class="data row3 col2" >0.0001</td>
#       <td id="T_401b3_row3_col3" class="data row3 col3" >+0.0496</td>
#       <td id="T_401b3_row3_col4" class="data row3 col4" >3.4792</td>
#       <td id="T_401b3_row3_col5" class="data row3 col5" >0.9967</td>
#     </tr>
#     <tr>
#       <th id="T_401b3_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_401b3_row4_col0" class="data row4 col0" >3.4836</td>
#       <td id="T_401b3_row4_col1" class="data row4 col1" >0.9996</td>
#       <td id="T_401b3_row4_col2" class="data row4 col2" >0.0001</td>
#       <td id="T_401b3_row4_col3" class="data row4 col3" >+0.0496</td>
#       <td id="T_401b3_row4_col4" class="data row4 col4" >3.4793</td>
#       <td id="T_401b3_row4_col5" class="data row4 col5" >0.9967</td>
#     </tr>
#     <tr>
#       <th id="T_401b3_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_401b3_row5_col0" class="data row5 col0" >1.0480</td>
#       <td id="T_401b3_row5_col1" class="data row5 col1" >0.9767</td>
#       <td id="T_401b3_row5_col2" class="data row5 col2" >0.0010</td>
#       <td id="T_401b3_row5_col3" class="data row5 col3" >+0.0267</td>
#       <td id="T_401b3_row5_col4" class="data row5 col4" >0.8822</td>
#       <td id="T_401b3_row5_col5" class="data row5 col5" >0.9767</td>
#     </tr>
#   </tbody>
# </table>
# [M=1] curva_suavizada      mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = +0.0005 de Winkler
#         curva_suavizada      mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +10.9765
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# [M=1] representacion_fpca  mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = -0.0000 de Winkler
#         representacion_fpca  mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = -2.4356
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# <style type="text/css">
# #T_2a510_row0_col0, #T_2a510_row1_col0 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_2a510_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_2a510_row3_col0, #T_2a510_row4_col0 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_2a510_row5_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2a510">
#   <caption>M=2 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a510_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_2a510_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_2a510_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_2a510_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_2a510_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_2a510_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >objetivo</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a510_level0_row0" class="row_heading level0 row0" rowspan="3">curva_suavizada</th>
#       <th id="T_2a510_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_2a510_row0_col0" class="data row0 col0" >4.8867</td>
#       <td id="T_2a510_row0_col1" class="data row0 col1" >0.9380</td>
#       <td id="T_2a510_row0_col2" class="data row0 col2" >0.0016</td>
#       <td id="T_2a510_row0_col3" class="data row0 col3" >-0.0120</td>
#       <td id="T_2a510_row0_col4" class="data row0 col4" >3.4792</td>
#       <td id="T_2a510_row0_col5" class="data row0 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_2a510_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_2a510_row1_col0" class="data row1 col0" >4.8871</td>
#       <td id="T_2a510_row1_col1" class="data row1 col1" >0.9382</td>
#       <td id="T_2a510_row1_col2" class="data row1 col2" >0.0016</td>
#       <td id="T_2a510_row1_col3" class="data row1 col3" >-0.0118</td>
#       <td id="T_2a510_row1_col4" class="data row1 col4" >3.4793</td>
#       <td id="T_2a510_row1_col5" class="data row1 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_2a510_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_2a510_row2_col0" class="data row2 col0" >12.9760</td>
#       <td id="T_2a510_row2_col1" class="data row2 col1" >0.5184</td>
#       <td id="T_2a510_row2_col2" class="data row2 col2" >0.0033</td>
#       <td id="T_2a510_row2_col3" class="data row2 col3" >-0.4316</td>
#       <td id="T_2a510_row2_col4" class="data row2 col4" >1.2415</td>
#       <td id="T_2a510_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2a510_level0_row3" class="row_heading level0 row3" rowspan="3">representacion_fpca</th>
#       <th id="T_2a510_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_2a510_row3_col0" class="data row3 col0" >3.4984</td>
#       <td id="T_2a510_row3_col1" class="data row3 col1" >0.9985</td>
#       <td id="T_2a510_row3_col2" class="data row3 col2" >0.0003</td>
#       <td id="T_2a510_row3_col3" class="data row3 col3" >+0.0485</td>
#       <td id="T_2a510_row3_col4" class="data row3 col4" >3.4792</td>
#       <td id="T_2a510_row3_col5" class="data row3 col5" >0.9733</td>
#     </tr>
#     <tr>
#       <th id="T_2a510_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_2a510_row4_col0" class="data row4 col0" >3.4982</td>
#       <td id="T_2a510_row4_col1" class="data row4 col1" >0.9985</td>
#       <td id="T_2a510_row4_col2" class="data row4 col2" >0.0003</td>
#       <td id="T_2a510_row4_col3" class="data row4 col3" >+0.0485</td>
#       <td id="T_2a510_row4_col4" class="data row4 col4" >3.4793</td>
#       <td id="T_2a510_row4_col5" class="data row4 col5" >0.9733</td>
#     </tr>
#     <tr>
#       <th id="T_2a510_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_2a510_row5_col0" class="data row5 col0" >1.4927</td>
#       <td id="T_2a510_row5_col1" class="data row5 col1" >0.9632</td>
#       <td id="T_2a510_row5_col2" class="data row5 col2" >0.0013</td>
#       <td id="T_2a510_row5_col3" class="data row5 col3" >+0.0132</td>
#       <td id="T_2a510_row5_col4" class="data row5 col4" >1.2415</td>
#       <td id="T_2a510_row5_col5" class="data row5 col5" >0.8933</td>
#     </tr>
#   </tbody>
# </table>
# [M=2] curva_suavizada      mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = +0.0004 de Winkler
#         curva_suavizada      mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +8.0889
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# [M=2] representacion_fpca  mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = -0.0002 de Winkler
#         representacion_fpca  mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = -2.0056
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# <style type="text/css">
# #T_90187_row0_col0, #T_90187_row1_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_90187_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_90187_row3_col0, #T_90187_row4_col0 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_90187_row5_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_90187">
#   <caption>M=3 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90187_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_90187_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_90187_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_90187_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_90187_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_90187_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >objetivo</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90187_level0_row0" class="row_heading level0 row0" rowspan="3">curva_suavizada</th>
#       <th id="T_90187_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_90187_row0_col0" class="data row0 col0" >4.8867</td>
#       <td id="T_90187_row0_col1" class="data row0 col1" >0.9380</td>
#       <td id="T_90187_row0_col2" class="data row0 col2" >0.0016</td>
#       <td id="T_90187_row0_col3" class="data row0 col3" >-0.0120</td>
#       <td id="T_90187_row0_col4" class="data row0 col4" >3.4792</td>
#       <td id="T_90187_row0_col5" class="data row0 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_90187_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_90187_row1_col0" class="data row1 col0" >4.8866</td>
#       <td id="T_90187_row1_col1" class="data row1 col1" >0.9382</td>
#       <td id="T_90187_row1_col2" class="data row1 col2" >0.0016</td>
#       <td id="T_90187_row1_col3" class="data row1 col3" >-0.0118</td>
#       <td id="T_90187_row1_col4" class="data row1 col4" >3.4790</td>
#       <td id="T_90187_row1_col5" class="data row1 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_90187_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_90187_row2_col0" class="data row2 col0" >10.0844</td>
#       <td id="T_90187_row2_col1" class="data row2 col1" >0.6367</td>
#       <td id="T_90187_row2_col2" class="data row2 col2" >0.0032</td>
#       <td id="T_90187_row2_col3" class="data row2 col3" >-0.3133</td>
#       <td id="T_90187_row2_col4" class="data row2 col4" >1.5924</td>
#       <td id="T_90187_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_90187_level0_row3" class="row_heading level0 row3" rowspan="3">representacion_fpca</th>
#       <th id="T_90187_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_90187_row3_col0" class="data row3 col0" >3.5028</td>
#       <td id="T_90187_row3_col1" class="data row3 col1" >0.9984</td>
#       <td id="T_90187_row3_col2" class="data row3 col2" >0.0003</td>
#       <td id="T_90187_row3_col3" class="data row3 col3" >+0.0484</td>
#       <td id="T_90187_row3_col4" class="data row3 col4" >3.4792</td>
#       <td id="T_90187_row3_col5" class="data row3 col5" >0.9800</td>
#     </tr>
#     <tr>
#       <th id="T_90187_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_90187_row4_col0" class="data row4 col0" >3.5023</td>
#       <td id="T_90187_row4_col1" class="data row4 col1" >0.9985</td>
#       <td id="T_90187_row4_col2" class="data row4 col2" >0.0003</td>
#       <td id="T_90187_row4_col3" class="data row4 col3" >+0.0485</td>
#       <td id="T_90187_row4_col4" class="data row4 col4" >3.4790</td>
#       <td id="T_90187_row4_col5" class="data row4 col5" >0.9800</td>
#     </tr>
#     <tr>
#       <th id="T_90187_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_90187_row5_col0" class="data row5 col0" >1.9256</td>
#       <td id="T_90187_row5_col1" class="data row5 col1" >0.9606</td>
#       <td id="T_90187_row5_col2" class="data row5 col2" >0.0013</td>
#       <td id="T_90187_row5_col3" class="data row5 col3" >+0.0106</td>
#       <td id="T_90187_row5_col4" class="data row5 col4" >1.5924</td>
#       <td id="T_90187_row5_col5" class="data row5 col5" >0.8067</td>
#     </tr>
#   </tbody>
# </table>
# [M=3] curva_suavizada      mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = -0.0001 de Winkler
#         curva_suavizada      mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +5.1978
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# [M=3] representacion_fpca  mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = -0.0005 de Winkler
#         representacion_fpca  mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = -1.5767
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# <style type="text/css">
# #T_41f9e_row0_col0, #T_41f9e_row1_col0 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_41f9e_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_41f9e_row3_col0, #T_41f9e_row4_col0 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_41f9e_row5_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_41f9e">
#   <caption>M=4 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41f9e_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_41f9e_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_41f9e_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_41f9e_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_41f9e_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_41f9e_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >objetivo</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41f9e_level0_row0" class="row_heading level0 row0" rowspan="3">curva_suavizada</th>
#       <th id="T_41f9e_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_41f9e_row0_col0" class="data row0 col0" >4.8867</td>
#       <td id="T_41f9e_row0_col1" class="data row0 col1" >0.9380</td>
#       <td id="T_41f9e_row0_col2" class="data row0 col2" >0.0016</td>
#       <td id="T_41f9e_row0_col3" class="data row0 col3" >-0.0120</td>
#       <td id="T_41f9e_row0_col4" class="data row0 col4" >3.4792</td>
#       <td id="T_41f9e_row0_col5" class="data row0 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_41f9e_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_41f9e_row1_col0" class="data row1 col0" >4.8868</td>
#       <td id="T_41f9e_row1_col1" class="data row1 col1" >0.9381</td>
#       <td id="T_41f9e_row1_col2" class="data row1 col2" >0.0016</td>
#       <td id="T_41f9e_row1_col3" class="data row1 col3" >-0.0119</td>
#       <td id="T_41f9e_row1_col4" class="data row1 col4" >3.4789</td>
#       <td id="T_41f9e_row1_col5" class="data row1 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_41f9e_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_41f9e_row2_col0" class="data row2 col0" >8.7571</td>
#       <td id="T_41f9e_row2_col1" class="data row2 col1" >0.7002</td>
#       <td id="T_41f9e_row2_col2" class="data row2 col2" >0.0031</td>
#       <td id="T_41f9e_row2_col3" class="data row2 col3" >-0.2498</td>
#       <td id="T_41f9e_row2_col4" class="data row2 col4" >1.8352</td>
#       <td id="T_41f9e_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_41f9e_level0_row3" class="row_heading level0 row3" rowspan="3">representacion_fpca</th>
#       <th id="T_41f9e_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_41f9e_row3_col0" class="data row3 col0" >3.5564</td>
#       <td id="T_41f9e_row3_col1" class="data row3 col1" >0.9965</td>
#       <td id="T_41f9e_row3_col2" class="data row3 col2" >0.0004</td>
#       <td id="T_41f9e_row3_col3" class="data row3 col3" >+0.0465</td>
#       <td id="T_41f9e_row3_col4" class="data row3 col4" >3.4792</td>
#       <td id="T_41f9e_row3_col5" class="data row3 col5" >0.9567</td>
#     </tr>
#     <tr>
#       <th id="T_41f9e_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_41f9e_row4_col0" class="data row4 col0" >3.5559</td>
#       <td id="T_41f9e_row4_col1" class="data row4 col1" >0.9965</td>
#       <td id="T_41f9e_row4_col2" class="data row4 col2" >0.0004</td>
#       <td id="T_41f9e_row4_col3" class="data row4 col3" >+0.0465</td>
#       <td id="T_41f9e_row4_col4" class="data row4 col4" >3.4789</td>
#       <td id="T_41f9e_row4_col5" class="data row4 col5" >0.9600</td>
#     </tr>
#     <tr>
#       <th id="T_41f9e_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_41f9e_row5_col0" class="data row5 col0" >2.2921</td>
#       <td id="T_41f9e_row5_col1" class="data row5 col1" >0.9586</td>
#       <td id="T_41f9e_row5_col2" class="data row5 col2" >0.0013</td>
#       <td id="T_41f9e_row5_col3" class="data row5 col3" >+0.0086</td>
#       <td id="T_41f9e_row5_col4" class="data row5 col4" >1.8352</td>
#       <td id="T_41f9e_row5_col5" class="data row5 col5" >0.7500</td>
#     </tr>
#   </tbody>
# </table>
# [M=4] curva_suavizada      mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = +0.0001 de Winkler
#         curva_suavizada      mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +3.8703
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# [M=4] representacion_fpca  mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = -0.0005 de Winkler
#         representacion_fpca  mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = -1.2638
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# <style type="text/css">
# #T_e7a9c_row0_col0, #T_e7a9c_row1_col0 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_e7a9c_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_e7a9c_row3_col0, #T_e7a9c_row4_col0 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_e7a9c_row5_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e7a9c">
#   <caption>M=5 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7a9c_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_e7a9c_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_e7a9c_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_e7a9c_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_e7a9c_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_e7a9c_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >objetivo</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7a9c_level0_row0" class="row_heading level0 row0" rowspan="3">curva_suavizada</th>
#       <th id="T_e7a9c_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_e7a9c_row0_col0" class="data row0 col0" >4.8867</td>
#       <td id="T_e7a9c_row0_col1" class="data row0 col1" >0.9380</td>
#       <td id="T_e7a9c_row0_col2" class="data row0 col2" >0.0016</td>
#       <td id="T_e7a9c_row0_col3" class="data row0 col3" >-0.0120</td>
#       <td id="T_e7a9c_row0_col4" class="data row0 col4" >3.4792</td>
#       <td id="T_e7a9c_row0_col5" class="data row0 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_e7a9c_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_e7a9c_row1_col0" class="data row1 col0" >4.8865</td>
#       <td id="T_e7a9c_row1_col1" class="data row1 col1" >0.9382</td>
#       <td id="T_e7a9c_row1_col2" class="data row1 col2" >0.0016</td>
#       <td id="T_e7a9c_row1_col3" class="data row1 col3" >-0.0118</td>
#       <td id="T_e7a9c_row1_col4" class="data row1 col4" >3.4788</td>
#       <td id="T_e7a9c_row1_col5" class="data row1 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_e7a9c_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_e7a9c_row2_col0" class="data row2 col0" >7.6696</td>
#       <td id="T_e7a9c_row2_col1" class="data row2 col1" >0.7528</td>
#       <td id="T_e7a9c_row2_col2" class="data row2 col2" >0.0029</td>
#       <td id="T_e7a9c_row2_col3" class="data row2 col3" >-0.1972</td>
#       <td id="T_e7a9c_row2_col4" class="data row2 col4" >2.0425</td>
#       <td id="T_e7a9c_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e7a9c_level0_row3" class="row_heading level0 row3" rowspan="3">representacion_fpca</th>
#       <th id="T_e7a9c_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_e7a9c_row3_col0" class="data row3 col0" >3.5792</td>
#       <td id="T_e7a9c_row3_col1" class="data row3 col1" >0.9949</td>
#       <td id="T_e7a9c_row3_col2" class="data row3 col2" >0.0005</td>
#       <td id="T_e7a9c_row3_col3" class="data row3 col3" >+0.0449</td>
#       <td id="T_e7a9c_row3_col4" class="data row3 col4" >3.4792</td>
#       <td id="T_e7a9c_row3_col5" class="data row3 col5" >0.9300</td>
#     </tr>
#     <tr>
#       <th id="T_e7a9c_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_e7a9c_row4_col0" class="data row4 col0" >3.5784</td>
#       <td id="T_e7a9c_row4_col1" class="data row4 col1" >0.9950</td>
#       <td id="T_e7a9c_row4_col2" class="data row4 col2" >0.0005</td>
#       <td id="T_e7a9c_row4_col3" class="data row4 col3" >+0.0450</td>
#       <td id="T_e7a9c_row4_col4" class="data row4 col4" >3.4788</td>
#       <td id="T_e7a9c_row4_col5" class="data row4 col5" >0.9300</td>
#     </tr>
#     <tr>
#       <th id="T_e7a9c_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_e7a9c_row5_col0" class="data row5 col0" >2.5299</td>
#       <td id="T_e7a9c_row5_col1" class="data row5 col1" >0.9585</td>
#       <td id="T_e7a9c_row5_col2" class="data row5 col2" >0.0013</td>
#       <td id="T_e7a9c_row5_col3" class="data row5 col3" >+0.0085</td>
#       <td id="T_e7a9c_row5_col4" class="data row5 col4" >2.0425</td>
#       <td id="T_e7a9c_row5_col5" class="data row5 col5" >0.6900</td>
#     </tr>
#   </tbody>
# </table>
# [M=5] curva_suavizada      mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = -0.0002 de Winkler
#         curva_suavizada      mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +2.7831
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# [M=5] representacion_fpca  mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = -0.0008 de Winkler
#         representacion_fpca  mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = -1.0485
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# <style type="text/css">
# #T_b5cfe_row0_col0, #T_b5cfe_row1_col0 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_b5cfe_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_b5cfe_row3_col0, #T_b5cfe_row4_col0 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_b5cfe_row5_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b5cfe">
#   <caption>M=6 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5cfe_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_b5cfe_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_b5cfe_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_b5cfe_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_b5cfe_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_b5cfe_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >objetivo</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5cfe_level0_row0" class="row_heading level0 row0" rowspan="3">curva_suavizada</th>
#       <th id="T_b5cfe_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_b5cfe_row0_col0" class="data row0 col0" >4.8867</td>
#       <td id="T_b5cfe_row0_col1" class="data row0 col1" >0.9380</td>
#       <td id="T_b5cfe_row0_col2" class="data row0 col2" >0.0016</td>
#       <td id="T_b5cfe_row0_col3" class="data row0 col3" >-0.0120</td>
#       <td id="T_b5cfe_row0_col4" class="data row0 col4" >3.4792</td>
#       <td id="T_b5cfe_row0_col5" class="data row0 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_b5cfe_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_b5cfe_row1_col0" class="data row1 col0" >4.8869</td>
#       <td id="T_b5cfe_row1_col1" class="data row1 col1" >0.9383</td>
#       <td id="T_b5cfe_row1_col2" class="data row1 col2" >0.0016</td>
#       <td id="T_b5cfe_row1_col3" class="data row1 col3" >-0.0117</td>
#       <td id="T_b5cfe_row1_col4" class="data row1 col4" >3.4785</td>
#       <td id="T_b5cfe_row1_col5" class="data row1 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_b5cfe_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_b5cfe_row2_col0" class="data row2 col0" >7.0587</td>
#       <td id="T_b5cfe_row2_col1" class="data row2 col1" >0.7871</td>
#       <td id="T_b5cfe_row2_col2" class="data row2 col2" >0.0027</td>
#       <td id="T_b5cfe_row2_col3" class="data row2 col3" >-0.1629</td>
#       <td id="T_b5cfe_row2_col4" class="data row2 col4" >2.2153</td>
#       <td id="T_b5cfe_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b5cfe_level0_row3" class="row_heading level0 row3" rowspan="3">representacion_fpca</th>
#       <th id="T_b5cfe_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_b5cfe_row3_col0" class="data row3 col0" >3.6234</td>
#       <td id="T_b5cfe_row3_col1" class="data row3 col1" >0.9920</td>
#       <td id="T_b5cfe_row3_col2" class="data row3 col2" >0.0006</td>
#       <td id="T_b5cfe_row3_col3" class="data row3 col3" >+0.0420</td>
#       <td id="T_b5cfe_row3_col4" class="data row3 col4" >3.4792</td>
#       <td id="T_b5cfe_row3_col5" class="data row3 col5" >0.8867</td>
#     </tr>
#     <tr>
#       <th id="T_b5cfe_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_b5cfe_row4_col0" class="data row4 col0" >3.6226</td>
#       <td id="T_b5cfe_row4_col1" class="data row4 col1" >0.9920</td>
#       <td id="T_b5cfe_row4_col2" class="data row4 col2" >0.0006</td>
#       <td id="T_b5cfe_row4_col3" class="data row4 col3" >+0.0420</td>
#       <td id="T_b5cfe_row4_col4" class="data row4 col4" >3.4785</td>
#       <td id="T_b5cfe_row4_col5" class="data row4 col5" >0.8867</td>
#     </tr>
#     <tr>
#       <th id="T_b5cfe_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_b5cfe_row5_col0" class="data row5 col0" >2.7968</td>
#       <td id="T_b5cfe_row5_col1" class="data row5 col1" >0.9558</td>
#       <td id="T_b5cfe_row5_col2" class="data row5 col2" >0.0014</td>
#       <td id="T_b5cfe_row5_col3" class="data row5 col3" >+0.0058</td>
#       <td id="T_b5cfe_row5_col4" class="data row5 col4" >2.2153</td>
#       <td id="T_b5cfe_row5_col5" class="data row5 col5" >0.6767</td>
#     </tr>
#   </tbody>
# </table>
# [M=6] curva_suavizada      mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = +0.0002 de Winkler
#         curva_suavizada      mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +2.1717
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# [M=6] representacion_fpca  mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = -0.0008 de Winkler
#         representacion_fpca  mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = -0.8257
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# <style type="text/css">
# #T_c5896_row0_col0, #T_c5896_row1_col0 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_c5896_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_c5896_row3_col0, #T_c5896_row4_col0 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_c5896_row5_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c5896">
#   <caption>M=7 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5896_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_c5896_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_c5896_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_c5896_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_c5896_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_c5896_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >objetivo</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5896_level0_row0" class="row_heading level0 row0" rowspan="3">curva_suavizada</th>
#       <th id="T_c5896_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_c5896_row0_col0" class="data row0 col0" >4.8867</td>
#       <td id="T_c5896_row0_col1" class="data row0 col1" >0.9380</td>
#       <td id="T_c5896_row0_col2" class="data row0 col2" >0.0016</td>
#       <td id="T_c5896_row0_col3" class="data row0 col3" >-0.0120</td>
#       <td id="T_c5896_row0_col4" class="data row0 col4" >3.4792</td>
#       <td id="T_c5896_row0_col5" class="data row0 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_c5896_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_c5896_row1_col0" class="data row1 col0" >4.8868</td>
#       <td id="T_c5896_row1_col1" class="data row1 col1" >0.9382</td>
#       <td id="T_c5896_row1_col2" class="data row1 col2" >0.0016</td>
#       <td id="T_c5896_row1_col3" class="data row1 col3" >-0.0118</td>
#       <td id="T_c5896_row1_col4" class="data row1 col4" >3.4783</td>
#       <td id="T_c5896_row1_col5" class="data row1 col5" >0.3000</td>
#     </tr>
#     <tr>
#       <th id="T_c5896_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_c5896_row2_col0" class="data row2 col0" >6.6336</td>
#       <td id="T_c5896_row2_col1" class="data row2 col1" >0.8109</td>
#       <td id="T_c5896_row2_col2" class="data row2 col2" >0.0026</td>
#       <td id="T_c5896_row2_col3" class="data row2 col3" >-0.1391</td>
#       <td id="T_c5896_row2_col4" class="data row2 col4" >2.3650</td>
#       <td id="T_c5896_row2_col5" class="data row2 col5" >0.0033</td>
#     </tr>
#     <tr>
#       <th id="T_c5896_level0_row3" class="row_heading level0 row3" rowspan="3">representacion_fpca</th>
#       <th id="T_c5896_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_c5896_row3_col0" class="data row3 col0" >3.7025</td>
#       <td id="T_c5896_row3_col1" class="data row3 col1" >0.9891</td>
#       <td id="T_c5896_row3_col2" class="data row3 col2" >0.0007</td>
#       <td id="T_c5896_row3_col3" class="data row3 col3" >+0.0391</td>
#       <td id="T_c5896_row3_col4" class="data row3 col4" >3.4792</td>
#       <td id="T_c5896_row3_col5" class="data row3 col5" >0.8700</td>
#     </tr>
#     <tr>
#       <th id="T_c5896_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_c5896_row4_col0" class="data row4 col0" >3.7020</td>
#       <td id="T_c5896_row4_col1" class="data row4 col1" >0.9890</td>
#       <td id="T_c5896_row4_col2" class="data row4 col2" >0.0007</td>
#       <td id="T_c5896_row4_col3" class="data row4 col3" >+0.0390</td>
#       <td id="T_c5896_row4_col4" class="data row4 col4" >3.4783</td>
#       <td id="T_c5896_row4_col5" class="data row4 col5" >0.8700</td>
#     </tr>
#     <tr>
#       <th id="T_c5896_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_c5896_row5_col0" class="data row5 col0" >3.0592</td>
#       <td id="T_c5896_row5_col1" class="data row5 col1" >0.9539</td>
#       <td id="T_c5896_row5_col2" class="data row5 col2" >0.0014</td>
#       <td id="T_c5896_row5_col3" class="data row5 col3" >+0.0039</td>
#       <td id="T_c5896_row5_col4" class="data row5 col4" >2.3650</td>
#       <td id="T_c5896_row5_col5" class="data row5 col5" >0.6300</td>
#     </tr>
#   </tbody>
# </table>
# [M=7] curva_suavizada      mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = +0.0001 de Winkler
#         curva_suavizada      mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +1.7468
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# [M=7] representacion_fpca  mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = -0.0005 de Winkler
#         representacion_fpca  mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = -0.6428
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# <style type="text/css">
# #T_a97fc_row0_col0, #T_a97fc_row1_col0 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_a97fc_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a97fc_row3_col0 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_a97fc_row4_col0 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_a97fc_row5_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a97fc">
#   <caption>M=8 · Bloque B, bloque de PRUEBA · PRIMARIA: winkler · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a97fc_level0_col0" class="col_heading level0 col0" >winkler</th>
#       <th id="T_a97fc_level0_col1" class="col_heading level0 col1" >picp</th>
#       <th id="T_a97fc_level0_col2" class="col_heading level0 col2" >ee_picp</th>
#       <th id="T_a97fc_level0_col3" class="col_heading level0 col3" >ace</th>
#       <th id="T_a97fc_level0_col4" class="col_heading level0 col4" >mpiw</th>
#       <th id="T_a97fc_level0_col5" class="col_heading level0 col5" >picp_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >objetivo</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a97fc_level0_row0" class="row_heading level0 row0" rowspan="3">curva_suavizada</th>
#       <th id="T_a97fc_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_a97fc_row0_col0" class="data row0 col0" >4.8867</td>
#       <td id="T_a97fc_row0_col1" class="data row0 col1" >0.9380</td>
#       <td id="T_a97fc_row0_col2" class="data row0 col2" >0.0016</td>
#       <td id="T_a97fc_row0_col3" class="data row0 col3" >-0.0120</td>
#       <td id="T_a97fc_row0_col4" class="data row0 col4" >3.4792</td>
#       <td id="T_a97fc_row0_col5" class="data row0 col5" >0.3033</td>
#     </tr>
#     <tr>
#       <th id="T_a97fc_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a97fc_row1_col0" class="data row1 col0" >4.8866</td>
#       <td id="T_a97fc_row1_col1" class="data row1 col1" >0.9382</td>
#       <td id="T_a97fc_row1_col2" class="data row1 col2" >0.0016</td>
#       <td id="T_a97fc_row1_col3" class="data row1 col3" >-0.0118</td>
#       <td id="T_a97fc_row1_col4" class="data row1 col4" >3.4781</td>
#       <td id="T_a97fc_row1_col5" class="data row1 col5" >0.3000</td>
#     </tr>
#     <tr>
#       <th id="T_a97fc_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a97fc_row2_col0" class="data row2 col0" >6.3088</td>
#       <td id="T_a97fc_row2_col1" class="data row2 col1" >0.8315</td>
#       <td id="T_a97fc_row2_col2" class="data row2 col2" >0.0025</td>
#       <td id="T_a97fc_row2_col3" class="data row2 col3" >-0.1185</td>
#       <td id="T_a97fc_row2_col4" class="data row2 col4" >2.5031</td>
#       <td id="T_a97fc_row2_col5" class="data row2 col5" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_a97fc_level0_row3" class="row_heading level0 row3" rowspan="3">representacion_fpca</th>
#       <th id="T_a97fc_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_a97fc_row3_col0" class="data row3 col0" >3.7844</td>
#       <td id="T_a97fc_row3_col1" class="data row3 col1" >0.9863</td>
#       <td id="T_a97fc_row3_col2" class="data row3 col2" >0.0008</td>
#       <td id="T_a97fc_row3_col3" class="data row3 col3" >+0.0363</td>
#       <td id="T_a97fc_row3_col4" class="data row3 col4" >3.4792</td>
#       <td id="T_a97fc_row3_col5" class="data row3 col5" >0.8333</td>
#     </tr>
#     <tr>
#       <th id="T_a97fc_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a97fc_row4_col0" class="data row4 col0" >3.7839</td>
#       <td id="T_a97fc_row4_col1" class="data row4 col1" >0.9862</td>
#       <td id="T_a97fc_row4_col2" class="data row4 col2" >0.0008</td>
#       <td id="T_a97fc_row4_col3" class="data row4 col3" >+0.0362</td>
#       <td id="T_a97fc_row4_col4" class="data row4 col4" >3.4781</td>
#       <td id="T_a97fc_row4_col5" class="data row4 col5" >0.8333</td>
#     </tr>
#     <tr>
#       <th id="T_a97fc_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a97fc_row5_col0" class="data row5 col0" >3.2598</td>
#       <td id="T_a97fc_row5_col1" class="data row5 col1" >0.9559</td>
#       <td id="T_a97fc_row5_col2" class="data row5 col2" >0.0014</td>
#       <td id="T_a97fc_row5_col3" class="data row5 col3" >+0.0059</td>
#       <td id="T_a97fc_row5_col4" class="data row5 col4" >2.5031</td>
#       <td id="T_a97fc_row5_col5" class="data row5 col5" >0.6167</td>
#     </tr>
#   </tbody>
# </table>
# [M=8] curva_suavizada      mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = -0.0001 de Winkler
#         curva_suavizada      mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = +1.4222
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.
# [M=8] representacion_fpca  mismo MECANISMO, distinto MODELO: PSBPM-FD - FAR = -0.0005 de Winkler
#         representacion_fpca  mismo MODELO, distinto MECANISMO: bayesiana - gaussiana = -0.5240
#         Si el segundo domina al primero, lo que separa a las
#         filas es la forma de la predictiva y no la calidad de la
#         media condicional; si domina el primero, al revés.

# %%
# Winkler sobre la ventana móvil, y su descomposición. Es la vista que dice
# CUÁNDO la banda falla, no solo cuánto: una cobertura marginal correcta puede
# esconder rachas enteras de violaciones.

for M in EST:
    e = EST[M]
    partes = []
    for nombre, ((li, ls), Xp) in BANDAS[M].items():
        t_ = ventana_movil_funcional(X_obj_ev, Xp, grilla, T0_orig, w=W_COMP,
                                     li=li, ls=ls, t_offset=N_LAGS,
                                     pesos_tau=PESOS_TAU,
                                     nivel=NIVEL_IC, bloque_A=True,
                                     verbose=False)
        t_["banda"] = nombre
        partes.append(t_)
    vb = pd.concat(partes, ignore_index=True)
    vb.attrs["w"] = W_COMP
    vb.to_csv(e["paths"]["out_report"] / f"81_ventana_bloqueB_w{W_COMP}.csv",
              index=False)
    e["ventana_B"] = vb

    plot_ventana_movil(
        vb, T0, ["winkler", "picp_simultaneo", "picp", "mpiw"], columna_grupo="banda",
        title=f"M={M} · Bloque B sobre la ventana móvil (w={W_COMP}) — "
              "winkler es la primaria; el resto lo descompone",
        save_path=str(e["paths"]["out_report"]
                      / f"81_ventana_bloqueB_w{W_COMP}.png"),
        verbose=False)
    plt.show()

    # El indicador I_t por origen, puntual y simultaneo, del que picp y
    # picp_simultaneo son el promedio respectivo. Se persiste por banda para
    # poder ver DONDE falla, no solo cuanto en promedio.
    for nombre, ((li, ls), _Xp) in BANDAS[M].items():
        I_t_pt = indicador_cobertura(X_obj_ev, li, ls).mean(axis=1)
        I_t_si = indicador_cobertura_simultanea(X_obj_ev, li, ls)
        ind = pd.DataFrame({"t": np.arange(len(I_t_pt)) + N_LAGS + 1,
                            "bloque": np.where(es_train, "train", "test"),
                            "banda": nombre, "I_t_puntual": I_t_pt,
                            "I_t_simultaneo": I_t_si.astype(float)})
        ind.to_csv(e["paths"]["out_report"]
                  / f"81b_indicador_cobertura_{nombre.split(' ')[0]}.csv",
                  index=False)

# %% [markdown]
# ## 6. Bloque A: quién gana cada ventana, y por cuánto
#
# Dos lecturas distintas y complementarias sobre la misma tabla de ventana:
#
# 1. **% de ventanas ganadas** — para cada ventana se marca el modelo con el
#    valor más bajo de la métrica. Es una lectura más dura que el promedio: un
#    modelo puede tener mejor promedio y ganar pocas ventanas si pierde por poco
#    muchas veces y gana por mucho unas pocas.
# 2. **Cuánto mejor** — la razón de cada modelo contra el mejor de la ventana y
#    contra el FAR, la referencia lineal.
#
# Ambas se calculan sobre las ventanas que **no cruzan $T_0$**.

# %%
# (1) % de ventanas ganadas por modelo, y (2) cuanto mejor/peor es cada uno.
gana_A, rel_A = [], []
for M in EST:
    e = EST[M]
    tw = e["tablas_w"][W_COMP]
    limpio = tw[~tw["cruza_T0"]]
    modelos = [m for m in limpio["modelo"].unique() if m not in fuera]

    for etiqueta, col in METRICAS_A:
        piv = limpio.pivot_table(index=["t_centro", "bloque"], columns="modelo",
                                 values=col)[modelos]
        ganador = piv.idxmin(axis=1)
        for bloque in ("train", "test"):
            sel = ganador.index.get_level_values("bloque") == bloque
            sub = ganador[sel]
            n_tot = len(sub)
            for m in modelos:
                gana_A.append({
                    "M": M, "metrica": etiqueta, "columna": col,
                    "bloque": bloque, "modelo": m,
                    "pct_ventanas_ganadas": float((sub == m).mean()) if n_tot else np.nan,
                    "n_ventanas": n_tot})

            # (2) cuanto mejor: razon contra el mejor de cada ventana y contra
            # el FAR. Se promedia la RAZON por ventana, no se divide el
            # promedio: asi cada ventana pesa igual y no la dominan las de
            # error grande.
            p = piv[sel]
            mejor = p.min(axis=1)
            for m in modelos:
                fila = {"M": M, "metrica": etiqueta, "bloque": bloque, "modelo": m,
                        "razon_vs_mejor": float((p[m] / mejor).mean())}
                if "FAR" in p.columns:
                    fila["razon_vs_FAR"] = float((p[m] / p["FAR"]).mean())
                rel_A.append(fila)

gana_A_df = pd.DataFrame(gana_A)
rel_A_df  = pd.DataFrame(rel_A)
gana_A_df.to_csv(PATH_BARRIDO / "96_ganador_ventana_bloqueA.csv", index=False)
rel_A_df.to_csv(PATH_BARRIDO / "96_razones_bloqueA.csv", index=False)

for etiqueta, _col in METRICAS_A:
    piv_g = (gana_A_df[(gana_A_df.metrica == etiqueta) & (gana_A_df.bloque == "test")]
             .pivot(index="modelo", columns="M", values="pct_ventanas_ganadas"))
    display(piv_g.style.format("{:.1%}", na_rep="-")
            .background_gradient(cmap="RdYlGn", axis=None)
            .set_caption(f"{etiqueta} · % de ventanas de PRUEBA ganadas "
                         f"(w={W_COMP}, sin cruzar T0)"))

for etiqueta, _col in METRICAS_A:
    piv_r = (rel_A_df[(rel_A_df.metrica == etiqueta) & (rel_A_df.bloque == "test")]
             .pivot(index="modelo", columns="M", values="razon_vs_mejor"))
    display(piv_r.style.format("{:.3f}", na_rep="-")
            .background_gradient(cmap="RdYlGn_r", axis=None)
            .set_caption(f"{etiqueta} · razón contra el MEJOR de cada ventana "
                         "(test) · 1.000 = gana siempre"))
# Out:
# <style type="text/css">
# #T_5e262_row0_col0, #T_5e262_row3_col5 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_5e262_row0_col1 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_5e262_row0_col2, #T_5e262_row0_col4 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_5e262_row0_col3 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_5e262_row0_col5 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_5e262_row0_col6 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_5e262_row0_col7 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_5e262_row1_col0 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_5e262_row1_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_5e262_row1_col2, #T_5e262_row1_col3, #T_5e262_row1_col4, #T_5e262_row1_col5, #T_5e262_row1_col6, #T_5e262_row1_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_5e262_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_5e262_row2_col1 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_5e262_row2_col2, #T_5e262_row2_col3 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_5e262_row2_col4 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_5e262_row2_col5 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_5e262_row2_col6 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_5e262_row2_col7 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_5e262_row3_col0 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_5e262_row3_col1 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_5e262_row3_col2 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_5e262_row3_col3 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_5e262_row3_col4 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_5e262_row3_col6 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_5e262_row3_col7 {
#   background-color: #fedc88;
#   color: #000000;
# }
# </style>
# <table id="T_5e262">
#   <caption>1. MAE  (L^1) · % de ventanas de PRUEBA ganadas (w=30, sin cruzar T0)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_5e262_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_5e262_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_5e262_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_5e262_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_5e262_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_5e262_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_5e262_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_5e262_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e262_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_5e262_row0_col0" class="data row0 col0" >23.6%</td>
#       <td id="T_5e262_row0_col1" class="data row0 col1" >26.2%</td>
#       <td id="T_5e262_row0_col2" class="data row0 col2" >18.5%</td>
#       <td id="T_5e262_row0_col3" class="data row0 col3" >25.1%</td>
#       <td id="T_5e262_row0_col4" class="data row0 col4" >18.5%</td>
#       <td id="T_5e262_row0_col5" class="data row0 col5" >21.0%</td>
#       <td id="T_5e262_row0_col6" class="data row0 col6" >25.5%</td>
#       <td id="T_5e262_row0_col7" class="data row0 col7" >18.1%</td>
#     </tr>
#     <tr>
#       <th id="T_5e262_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_5e262_row1_col0" class="data row1 col0" >0.7%</td>
#       <td id="T_5e262_row1_col1" class="data row1 col1" >7.0%</td>
#       <td id="T_5e262_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_5e262_row1_col3" class="data row1 col3" >0.0%</td>
#       <td id="T_5e262_row1_col4" class="data row1 col4" >0.0%</td>
#       <td id="T_5e262_row1_col5" class="data row1 col5" >0.0%</td>
#       <td id="T_5e262_row1_col6" class="data row1 col6" >0.0%</td>
#       <td id="T_5e262_row1_col7" class="data row1 col7" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_5e262_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_5e262_row2_col0" class="data row2 col0" >66.1%</td>
#       <td id="T_5e262_row2_col1" class="data row2 col1" >52.0%</td>
#       <td id="T_5e262_row2_col2" class="data row2 col2" >59.4%</td>
#       <td id="T_5e262_row2_col3" class="data row2 col3" >59.4%</td>
#       <td id="T_5e262_row2_col4" class="data row2 col4" >50.2%</td>
#       <td id="T_5e262_row2_col5" class="data row2 col5" >55.4%</td>
#       <td id="T_5e262_row2_col6" class="data row2 col6" >60.5%</td>
#       <td id="T_5e262_row2_col7" class="data row2 col7" >56.1%</td>
#     </tr>
#     <tr>
#       <th id="T_5e262_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_5e262_row3_col0" class="data row3 col0" >9.6%</td>
#       <td id="T_5e262_row3_col1" class="data row3 col1" >14.8%</td>
#       <td id="T_5e262_row3_col2" class="data row3 col2" >22.1%</td>
#       <td id="T_5e262_row3_col3" class="data row3 col3" >15.5%</td>
#       <td id="T_5e262_row3_col4" class="data row3 col4" >31.4%</td>
#       <td id="T_5e262_row3_col5" class="data row3 col5" >23.6%</td>
#       <td id="T_5e262_row3_col6" class="data row3 col6" >14.0%</td>
#       <td id="T_5e262_row3_col7" class="data row3 col7" >25.8%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2f576_row0_col0 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_2f576_row0_col1 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_2f576_row0_col2 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_2f576_row0_col3, #T_2f576_row3_col7 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_2f576_row0_col4 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_2f576_row0_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_2f576_row0_col6 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_2f576_row0_col7 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_2f576_row1_col0 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_2f576_row1_col1 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_2f576_row1_col2 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_2f576_row1_col3, #T_2f576_row1_col4, #T_2f576_row1_col5, #T_2f576_row1_col6, #T_2f576_row1_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_2f576_row2_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_2f576_row2_col1 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_2f576_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2f576_row2_col3 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_2f576_row2_col4 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_2f576_row2_col5 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_2f576_row2_col6 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_2f576_row2_col7 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_2f576_row3_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_2f576_row3_col1 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_2f576_row3_col2 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_2f576_row3_col3, #T_2f576_row3_col5 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_2f576_row3_col4 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_2f576_row3_col6 {
#   background-color: #fed884;
#   color: #000000;
# }
# </style>
# <table id="T_2f576">
#   <caption>2. RMSE (L^2) · % de ventanas de PRUEBA ganadas (w=30, sin cruzar T0)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_2f576_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_2f576_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_2f576_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_2f576_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_2f576_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_2f576_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_2f576_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_2f576_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f576_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_2f576_row0_col0" class="data row0 col0" >34.7%</td>
#       <td id="T_2f576_row0_col1" class="data row0 col1" >28.4%</td>
#       <td id="T_2f576_row0_col2" class="data row0 col2" >26.2%</td>
#       <td id="T_2f576_row0_col3" class="data row0 col3" >30.6%</td>
#       <td id="T_2f576_row0_col4" class="data row0 col4" >22.5%</td>
#       <td id="T_2f576_row0_col5" class="data row0 col5" >26.9%</td>
#       <td id="T_2f576_row0_col6" class="data row0 col6" >30.3%</td>
#       <td id="T_2f576_row0_col7" class="data row0 col7" >18.5%</td>
#     </tr>
#     <tr>
#       <th id="T_2f576_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_2f576_row1_col0" class="data row1 col0" >7.7%</td>
#       <td id="T_2f576_row1_col1" class="data row1 col1" >15.5%</td>
#       <td id="T_2f576_row1_col2" class="data row1 col2" >0.4%</td>
#       <td id="T_2f576_row1_col3" class="data row1 col3" >0.0%</td>
#       <td id="T_2f576_row1_col4" class="data row1 col4" >0.0%</td>
#       <td id="T_2f576_row1_col5" class="data row1 col5" >0.0%</td>
#       <td id="T_2f576_row1_col6" class="data row1 col6" >0.0%</td>
#       <td id="T_2f576_row1_col7" class="data row1 col7" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_2f576_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_2f576_row2_col0" class="data row2 col0" >47.6%</td>
#       <td id="T_2f576_row2_col1" class="data row2 col1" >42.1%</td>
#       <td id="T_2f576_row2_col2" class="data row2 col2" >53.5%</td>
#       <td id="T_2f576_row2_col3" class="data row2 col3" >42.8%</td>
#       <td id="T_2f576_row2_col4" class="data row2 col4" >35.1%</td>
#       <td id="T_2f576_row2_col5" class="data row2 col5" >46.5%</td>
#       <td id="T_2f576_row2_col6" class="data row2 col6" >49.1%</td>
#       <td id="T_2f576_row2_col7" class="data row2 col7" >50.9%</td>
#     </tr>
#     <tr>
#       <th id="T_2f576_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_2f576_row3_col0" class="data row3 col0" >10.0%</td>
#       <td id="T_2f576_row3_col1" class="data row3 col1" >14.0%</td>
#       <td id="T_2f576_row3_col2" class="data row3 col2" >19.9%</td>
#       <td id="T_2f576_row3_col3" class="data row3 col3" >26.6%</td>
#       <td id="T_2f576_row3_col4" class="data row3 col4" >42.4%</td>
#       <td id="T_2f576_row3_col5" class="data row3 col5" >26.6%</td>
#       <td id="T_2f576_row3_col6" class="data row3 col6" >20.7%</td>
#       <td id="T_2f576_row3_col7" class="data row3 col7" >30.6%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ae56f_row0_col0 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_ae56f_row0_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_ae56f_row0_col2, #T_ae56f_row1_col1 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_ae56f_row0_col3, #T_ae56f_row2_col5 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_ae56f_row0_col4 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_ae56f_row0_col5 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_ae56f_row0_col6, #T_ae56f_row2_col0 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_ae56f_row0_col7 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_ae56f_row1_col0 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_ae56f_row1_col2 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_ae56f_row1_col3 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_ae56f_row1_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ae56f_row1_col5 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_ae56f_row1_col6 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_ae56f_row1_col7 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_ae56f_row2_col1 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_ae56f_row2_col2 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_ae56f_row2_col3 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_ae56f_row2_col4 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_ae56f_row2_col6 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_ae56f_row2_col7 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_ae56f_row3_col0 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_ae56f_row3_col1 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_ae56f_row3_col2 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_ae56f_row3_col3 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_ae56f_row3_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ae56f_row3_col5 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_ae56f_row3_col6 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_ae56f_row3_col7 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ae56f">
#   <caption>3. E_max promedio por curva · % de ventanas de PRUEBA ganadas (w=30, sin cruzar T0)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_ae56f_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_ae56f_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_ae56f_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_ae56f_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_ae56f_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_ae56f_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_ae56f_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_ae56f_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae56f_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_ae56f_row0_col0" class="data row0 col0" >28.4%</td>
#       <td id="T_ae56f_row0_col1" class="data row0 col1" >21.8%</td>
#       <td id="T_ae56f_row0_col2" class="data row0 col2" >20.7%</td>
#       <td id="T_ae56f_row0_col3" class="data row0 col3" >26.2%</td>
#       <td id="T_ae56f_row0_col4" class="data row0 col4" >16.2%</td>
#       <td id="T_ae56f_row0_col5" class="data row0 col5" >21.0%</td>
#       <td id="T_ae56f_row0_col6" class="data row0 col6" >43.2%</td>
#       <td id="T_ae56f_row0_col7" class="data row0 col7" >22.9%</td>
#     </tr>
#     <tr>
#       <th id="T_ae56f_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_ae56f_row1_col0" class="data row1 col0" >24.7%</td>
#       <td id="T_ae56f_row1_col1" class="data row1 col1" >20.7%</td>
#       <td id="T_ae56f_row1_col2" class="data row1 col2" >15.1%</td>
#       <td id="T_ae56f_row1_col3" class="data row1 col3" >3.0%</td>
#       <td id="T_ae56f_row1_col4" class="data row1 col4" >2.2%</td>
#       <td id="T_ae56f_row1_col5" class="data row1 col5" >9.2%</td>
#       <td id="T_ae56f_row1_col6" class="data row1 col6" >6.3%</td>
#       <td id="T_ae56f_row1_col7" class="data row1 col7" >7.4%</td>
#     </tr>
#     <tr>
#       <th id="T_ae56f_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_ae56f_row2_col0" class="data row2 col0" >43.2%</td>
#       <td id="T_ae56f_row2_col1" class="data row2 col1" >42.8%</td>
#       <td id="T_ae56f_row2_col2" class="data row2 col2" >44.6%</td>
#       <td id="T_ae56f_row2_col3" class="data row2 col3" >45.8%</td>
#       <td id="T_ae56f_row2_col4" class="data row2 col4" >35.4%</td>
#       <td id="T_ae56f_row2_col5" class="data row2 col5" >26.2%</td>
#       <td id="T_ae56f_row2_col6" class="data row2 col6" >28.0%</td>
#       <td id="T_ae56f_row2_col7" class="data row2 col7" >30.6%</td>
#     </tr>
#     <tr>
#       <th id="T_ae56f_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_ae56f_row3_col0" class="data row3 col0" >3.7%</td>
#       <td id="T_ae56f_row3_col1" class="data row3 col1" >14.8%</td>
#       <td id="T_ae56f_row3_col2" class="data row3 col2" >19.6%</td>
#       <td id="T_ae56f_row3_col3" class="data row3 col3" >25.1%</td>
#       <td id="T_ae56f_row3_col4" class="data row3 col4" >46.1%</td>
#       <td id="T_ae56f_row3_col5" class="data row3 col5" >43.5%</td>
#       <td id="T_ae56f_row3_col6" class="data row3 col6" >22.5%</td>
#       <td id="T_ae56f_row3_col7" class="data row3 col7" >39.1%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f9e30_row0_col0 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_f9e30_row0_col1 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_f9e30_row0_col2, #T_f9e30_row0_col6, #T_f9e30_row0_col7 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_f9e30_row0_col3, #T_f9e30_row0_col4 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_f9e30_row0_col5 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_f9e30_row1_col0 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_f9e30_row1_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_f9e30_row1_col2, #T_f9e30_row1_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f9e30_row1_col3 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_f9e30_row1_col4 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_f9e30_row1_col5 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_f9e30_row1_col6 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_f9e30_row2_col0, #T_f9e30_row2_col1 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_f9e30_row2_col2 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_f9e30_row2_col3 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_f9e30_row2_col4 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_f9e30_row2_col5 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_f9e30_row2_col6 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_f9e30_row2_col7 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_f9e30_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f9e30_row3_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_f9e30_row3_col2 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_f9e30_row3_col3 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_f9e30_row3_col4 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_f9e30_row3_col5 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_f9e30_row3_col6 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_f9e30_row3_col7 {
#   background-color: #fba05b;
#   color: #000000;
# }
# </style>
# <table id="T_f9e30">
#   <caption>4. E_max peor de la ventana · % de ventanas de PRUEBA ganadas (w=30, sin cruzar T0)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_f9e30_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_f9e30_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_f9e30_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_f9e30_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_f9e30_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_f9e30_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_f9e30_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_f9e30_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9e30_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_f9e30_row0_col0" class="data row0 col0" >34.7%</td>
#       <td id="T_f9e30_row0_col1" class="data row0 col1" >14.4%</td>
#       <td id="T_f9e30_row0_col2" class="data row0 col2" >25.1%</td>
#       <td id="T_f9e30_row0_col3" class="data row0 col3" >31.0%</td>
#       <td id="T_f9e30_row0_col4" class="data row0 col4" >31.0%</td>
#       <td id="T_f9e30_row0_col5" class="data row0 col5" >32.8%</td>
#       <td id="T_f9e30_row0_col6" class="data row0 col6" >25.1%</td>
#       <td id="T_f9e30_row0_col7" class="data row0 col7" >25.1%</td>
#     </tr>
#     <tr>
#       <th id="T_f9e30_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_f9e30_row1_col0" class="data row1 col0" >27.7%</td>
#       <td id="T_f9e30_row1_col1" class="data row1 col1" >42.4%</td>
#       <td id="T_f9e30_row1_col2" class="data row1 col2" >43.5%</td>
#       <td id="T_f9e30_row1_col3" class="data row1 col3" >37.3%</td>
#       <td id="T_f9e30_row1_col4" class="data row1 col4" >39.9%</td>
#       <td id="T_f9e30_row1_col5" class="data row1 col5" >30.6%</td>
#       <td id="T_f9e30_row1_col6" class="data row1 col6" >38.0%</td>
#       <td id="T_f9e30_row1_col7" class="data row1 col7" >43.5%</td>
#     </tr>
#     <tr>
#       <th id="T_f9e30_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_f9e30_row2_col0" class="data row2 col0" >33.9%</td>
#       <td id="T_f9e30_row2_col1" class="data row2 col1" >33.9%</td>
#       <td id="T_f9e30_row2_col2" class="data row2 col2" >27.3%</td>
#       <td id="T_f9e30_row2_col3" class="data row2 col3" >26.2%</td>
#       <td id="T_f9e30_row2_col4" class="data row2 col4" >17.7%</td>
#       <td id="T_f9e30_row2_col5" class="data row2 col5" >7.7%</td>
#       <td id="T_f9e30_row2_col6" class="data row2 col6" >31.7%</td>
#       <td id="T_f9e30_row2_col7" class="data row2 col7" >16.6%</td>
#     </tr>
#     <tr>
#       <th id="T_f9e30_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_f9e30_row3_col0" class="data row3 col0" >3.7%</td>
#       <td id="T_f9e30_row3_col1" class="data row3 col1" >9.2%</td>
#       <td id="T_f9e30_row3_col2" class="data row3 col2" >4.1%</td>
#       <td id="T_f9e30_row3_col3" class="data row3 col3" >5.5%</td>
#       <td id="T_f9e30_row3_col4" class="data row3 col4" >11.4%</td>
#       <td id="T_f9e30_row3_col5" class="data row3 col5" >28.8%</td>
#       <td id="T_f9e30_row3_col6" class="data row3 col6" >5.2%</td>
#       <td id="T_f9e30_row3_col7" class="data row3 col7" >14.8%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_207b0_row0_col0, #T_207b0_row0_col3, #T_207b0_row0_col6, #T_207b0_row2_col2, #T_207b0_row2_col5, #T_207b0_row2_col7 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_207b0_row0_col1, #T_207b0_row0_col5, #T_207b0_row0_col7, #T_207b0_row2_col4 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_207b0_row0_col2, #T_207b0_row2_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_207b0_row0_col4 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_207b0_row1_col0 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_207b0_row1_col1 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_207b0_row1_col2 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_207b0_row1_col3 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_207b0_row1_col4 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_207b0_row1_col5 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_207b0_row1_col6 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_207b0_row1_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_207b0_row2_col0, #T_207b0_row2_col3, #T_207b0_row2_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_207b0_row3_col0 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_207b0_row3_col1 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_207b0_row3_col2 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_207b0_row3_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_207b0_row3_col4, #T_207b0_row3_col5, #T_207b0_row3_col7 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_207b0_row3_col6 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_207b0">
#   <caption>1. MAE  (L^1) · razón contra el MEJOR de cada ventana (test) · 1.000 = gana siempre</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_207b0_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_207b0_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_207b0_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_207b0_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_207b0_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_207b0_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_207b0_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_207b0_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_207b0_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_207b0_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_207b0_row0_col1" class="data row0 col1" >1.001</td>
#       <td id="T_207b0_row0_col2" class="data row0 col2" >1.001</td>
#       <td id="T_207b0_row0_col3" class="data row0 col3" >1.000</td>
#       <td id="T_207b0_row0_col4" class="data row0 col4" >1.001</td>
#       <td id="T_207b0_row0_col5" class="data row0 col5" >1.001</td>
#       <td id="T_207b0_row0_col6" class="data row0 col6" >1.001</td>
#       <td id="T_207b0_row0_col7" class="data row0 col7" >1.001</td>
#     </tr>
#     <tr>
#       <th id="T_207b0_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_207b0_row1_col0" class="data row1 col0" >1.011</td>
#       <td id="T_207b0_row1_col1" class="data row1 col1" >1.020</td>
#       <td id="T_207b0_row1_col2" class="data row1 col2" >1.027</td>
#       <td id="T_207b0_row1_col3" class="data row1 col3" >1.030</td>
#       <td id="T_207b0_row1_col4" class="data row1 col4" >1.033</td>
#       <td id="T_207b0_row1_col5" class="data row1 col5" >1.037</td>
#       <td id="T_207b0_row1_col6" class="data row1 col6" >1.040</td>
#       <td id="T_207b0_row1_col7" class="data row1 col7" >1.043</td>
#     </tr>
#     <tr>
#       <th id="T_207b0_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_207b0_row2_col0" class="data row2 col0" >1.000</td>
#       <td id="T_207b0_row2_col1" class="data row2 col1" >1.001</td>
#       <td id="T_207b0_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_207b0_row2_col3" class="data row2 col3" >1.000</td>
#       <td id="T_207b0_row2_col4" class="data row2 col4" >1.001</td>
#       <td id="T_207b0_row2_col5" class="data row2 col5" >1.000</td>
#       <td id="T_207b0_row2_col6" class="data row2 col6" >1.000</td>
#       <td id="T_207b0_row2_col7" class="data row2 col7" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_207b0_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_207b0_row3_col0" class="data row3 col0" >1.004</td>
#       <td id="T_207b0_row3_col1" class="data row3 col1" >1.003</td>
#       <td id="T_207b0_row3_col2" class="data row3 col2" >1.003</td>
#       <td id="T_207b0_row3_col3" class="data row3 col3" >1.002</td>
#       <td id="T_207b0_row3_col4" class="data row3 col4" >1.002</td>
#       <td id="T_207b0_row3_col5" class="data row3 col5" >1.002</td>
#       <td id="T_207b0_row3_col6" class="data row3 col6" >1.002</td>
#       <td id="T_207b0_row3_col7" class="data row3 col7" >1.002</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ba0a5_row0_col0, #T_ba0a5_row0_col6, #T_ba0a5_row2_col0, #T_ba0a5_row2_col2, #T_ba0a5_row2_col3, #T_ba0a5_row2_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ba0a5_row0_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_ba0a5_row0_col2, #T_ba0a5_row0_col3, #T_ba0a5_row2_col5, #T_ba0a5_row2_col7 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_ba0a5_row0_col4 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_ba0a5_row0_col5, #T_ba0a5_row0_col7 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_ba0a5_row1_col0 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_ba0a5_row1_col1 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_ba0a5_row1_col2 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_ba0a5_row1_col3 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_ba0a5_row1_col4 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_ba0a5_row1_col5 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_ba0a5_row1_col6 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_ba0a5_row1_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ba0a5_row2_col1 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_ba0a5_row2_col4 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_ba0a5_row3_col0 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_ba0a5_row3_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_ba0a5_row3_col2, #T_ba0a5_row3_col3, #T_ba0a5_row3_col5 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_ba0a5_row3_col4 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_ba0a5_row3_col6, #T_ba0a5_row3_col7 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ba0a5">
#   <caption>2. RMSE (L^2) · razón contra el MEJOR de cada ventana (test) · 1.000 = gana siempre</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_ba0a5_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_ba0a5_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_ba0a5_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_ba0a5_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_ba0a5_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_ba0a5_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_ba0a5_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_ba0a5_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba0a5_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_ba0a5_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_ba0a5_row0_col1" class="data row0 col1" >1.001</td>
#       <td id="T_ba0a5_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_ba0a5_row0_col3" class="data row0 col3" >1.000</td>
#       <td id="T_ba0a5_row0_col4" class="data row0 col4" >1.001</td>
#       <td id="T_ba0a5_row0_col5" class="data row0 col5" >1.001</td>
#       <td id="T_ba0a5_row0_col6" class="data row0 col6" >1.000</td>
#       <td id="T_ba0a5_row0_col7" class="data row0 col7" >1.001</td>
#     </tr>
#     <tr>
#       <th id="T_ba0a5_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_ba0a5_row1_col0" class="data row1 col0" >1.008</td>
#       <td id="T_ba0a5_row1_col1" class="data row1 col1" >1.014</td>
#       <td id="T_ba0a5_row1_col2" class="data row1 col2" >1.021</td>
#       <td id="T_ba0a5_row1_col3" class="data row1 col3" >1.023</td>
#       <td id="T_ba0a5_row1_col4" class="data row1 col4" >1.025</td>
#       <td id="T_ba0a5_row1_col5" class="data row1 col5" >1.030</td>
#       <td id="T_ba0a5_row1_col6" class="data row1 col6" >1.034</td>
#       <td id="T_ba0a5_row1_col7" class="data row1 col7" >1.037</td>
#     </tr>
#     <tr>
#       <th id="T_ba0a5_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_ba0a5_row2_col0" class="data row2 col0" >1.000</td>
#       <td id="T_ba0a5_row2_col1" class="data row2 col1" >1.001</td>
#       <td id="T_ba0a5_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_ba0a5_row2_col3" class="data row2 col3" >1.000</td>
#       <td id="T_ba0a5_row2_col4" class="data row2 col4" >1.001</td>
#       <td id="T_ba0a5_row2_col5" class="data row2 col5" >1.000</td>
#       <td id="T_ba0a5_row2_col6" class="data row2 col6" >1.000</td>
#       <td id="T_ba0a5_row2_col7" class="data row2 col7" >1.001</td>
#     </tr>
#     <tr>
#       <th id="T_ba0a5_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_ba0a5_row3_col0" class="data row3 col0" >1.003</td>
#       <td id="T_ba0a5_row3_col1" class="data row3 col1" >1.002</td>
#       <td id="T_ba0a5_row3_col2" class="data row3 col2" >1.002</td>
#       <td id="T_ba0a5_row3_col3" class="data row3 col3" >1.002</td>
#       <td id="T_ba0a5_row3_col4" class="data row3 col4" >1.001</td>
#       <td id="T_ba0a5_row3_col5" class="data row3 col5" >1.002</td>
#       <td id="T_ba0a5_row3_col6" class="data row3 col6" >1.002</td>
#       <td id="T_ba0a5_row3_col7" class="data row3 col7" >1.002</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8aaa4_row0_col0, #T_8aaa4_row2_col2, #T_8aaa4_row3_col4 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_8aaa4_row0_col1, #T_8aaa4_row2_col1, #T_8aaa4_row3_col6 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_8aaa4_row0_col2, #T_8aaa4_row0_col4, #T_8aaa4_row2_col6 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_8aaa4_row0_col3 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_8aaa4_row0_col5, #T_8aaa4_row2_col5 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_8aaa4_row0_col6, #T_8aaa4_row2_col4, #T_8aaa4_row3_col7 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_8aaa4_row0_col7, #T_8aaa4_row2_col7 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_8aaa4_row1_col0 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_8aaa4_row1_col1 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_8aaa4_row1_col2 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_8aaa4_row1_col3 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_8aaa4_row1_col4 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_8aaa4_row1_col5 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_8aaa4_row1_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8aaa4_row1_col7 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_8aaa4_row2_col0 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_8aaa4_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8aaa4_row3_col0 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_8aaa4_row3_col1 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_8aaa4_row3_col2 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_8aaa4_row3_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_8aaa4_row3_col5 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8aaa4">
#   <caption>3. E_max promedio por curva · razón contra el MEJOR de cada ventana (test) · 1.000 = gana siempre</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_8aaa4_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_8aaa4_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_8aaa4_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_8aaa4_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_8aaa4_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_8aaa4_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_8aaa4_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_8aaa4_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8aaa4_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_8aaa4_row0_col0" class="data row0 col0" >1.001</td>
#       <td id="T_8aaa4_row0_col1" class="data row0 col1" >1.003</td>
#       <td id="T_8aaa4_row0_col2" class="data row0 col2" >1.002</td>
#       <td id="T_8aaa4_row0_col3" class="data row0 col3" >1.001</td>
#       <td id="T_8aaa4_row0_col4" class="data row0 col4" >1.002</td>
#       <td id="T_8aaa4_row0_col5" class="data row0 col5" >1.002</td>
#       <td id="T_8aaa4_row0_col6" class="data row0 col6" >1.002</td>
#       <td id="T_8aaa4_row0_col7" class="data row0 col7" >1.002</td>
#     </tr>
#     <tr>
#       <th id="T_8aaa4_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_8aaa4_row1_col0" class="data row1 col0" >1.007</td>
#       <td id="T_8aaa4_row1_col1" class="data row1 col1" >1.012</td>
#       <td id="T_8aaa4_row1_col2" class="data row1 col2" >1.018</td>
#       <td id="T_8aaa4_row1_col3" class="data row1 col3" >1.016</td>
#       <td id="T_8aaa4_row1_col4" class="data row1 col4" >1.022</td>
#       <td id="T_8aaa4_row1_col5" class="data row1 col5" >1.026</td>
#       <td id="T_8aaa4_row1_col6" class="data row1 col6" >1.029</td>
#       <td id="T_8aaa4_row1_col7" class="data row1 col7" >1.028</td>
#     </tr>
#     <tr>
#       <th id="T_8aaa4_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_8aaa4_row2_col0" class="data row2 col0" >1.001</td>
#       <td id="T_8aaa4_row2_col1" class="data row2 col1" >1.003</td>
#       <td id="T_8aaa4_row2_col2" class="data row2 col2" >1.002</td>
#       <td id="T_8aaa4_row2_col3" class="data row2 col3" >1.000</td>
#       <td id="T_8aaa4_row2_col4" class="data row2 col4" >1.002</td>
#       <td id="T_8aaa4_row2_col5" class="data row2 col5" >1.002</td>
#       <td id="T_8aaa4_row2_col6" class="data row2 col6" >1.002</td>
#       <td id="T_8aaa4_row2_col7" class="data row2 col7" >1.002</td>
#     </tr>
#     <tr>
#       <th id="T_8aaa4_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_8aaa4_row3_col0" class="data row3 col0" >1.005</td>
#       <td id="T_8aaa4_row3_col1" class="data row3 col1" >1.004</td>
#       <td id="T_8aaa4_row3_col2" class="data row3 col2" >1.003</td>
#       <td id="T_8aaa4_row3_col3" class="data row3 col3" >1.002</td>
#       <td id="T_8aaa4_row3_col4" class="data row3 col4" >1.002</td>
#       <td id="T_8aaa4_row3_col5" class="data row3 col5" >1.002</td>
#       <td id="T_8aaa4_row3_col6" class="data row3 col6" >1.003</td>
#       <td id="T_8aaa4_row3_col7" class="data row3 col7" >1.002</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a5ba4_row0_col0 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_a5ba4_row0_col1 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_a5ba4_row0_col2, #T_a5ba4_row1_col1 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_a5ba4_row0_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a5ba4_row0_col4 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_a5ba4_row0_col5 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_a5ba4_row0_col6 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_a5ba4_row0_col7 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_a5ba4_row1_col0 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_a5ba4_row1_col2 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_a5ba4_row1_col3 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_a5ba4_row1_col4 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_a5ba4_row1_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a5ba4_row1_col6 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_a5ba4_row1_col7 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_a5ba4_row2_col0 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_a5ba4_row2_col1 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_a5ba4_row2_col2 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_a5ba4_row2_col3 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_a5ba4_row2_col4 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_a5ba4_row2_col5 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_a5ba4_row2_col6 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_a5ba4_row2_col7, #T_a5ba4_row3_col6 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_a5ba4_row3_col0 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_a5ba4_row3_col1 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_a5ba4_row3_col2 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_a5ba4_row3_col3 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_a5ba4_row3_col4 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_a5ba4_row3_col5 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_a5ba4_row3_col7 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# </style>
# <table id="T_a5ba4">
#   <caption>4. E_max peor de la ventana · razón contra el MEJOR de cada ventana (test) · 1.000 = gana siempre</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_a5ba4_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_a5ba4_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_a5ba4_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_a5ba4_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_a5ba4_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_a5ba4_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_a5ba4_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_a5ba4_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5ba4_level0_row0" class="row_heading level0 row0" >FAR</th>
#       <td id="T_a5ba4_row0_col0" class="data row0 col0" >1.019</td>
#       <td id="T_a5ba4_row0_col1" class="data row0 col1" >1.014</td>
#       <td id="T_a5ba4_row0_col2" class="data row0 col2" >1.015</td>
#       <td id="T_a5ba4_row0_col3" class="data row0 col3" >1.007</td>
#       <td id="T_a5ba4_row0_col4" class="data row0 col4" >1.011</td>
#       <td id="T_a5ba4_row0_col5" class="data row0 col5" >1.008</td>
#       <td id="T_a5ba4_row0_col6" class="data row0 col6" >1.010</td>
#       <td id="T_a5ba4_row0_col7" class="data row0 col7" >1.014</td>
#     </tr>
#     <tr>
#       <th id="T_a5ba4_level0_row1" class="row_heading level0 row1" >GBT</th>
#       <td id="T_a5ba4_row1_col0" class="data row1 col0" >1.013</td>
#       <td id="T_a5ba4_row1_col1" class="data row1 col1" >1.015</td>
#       <td id="T_a5ba4_row1_col2" class="data row1 col2" >1.014</td>
#       <td id="T_a5ba4_row1_col3" class="data row1 col3" >1.023</td>
#       <td id="T_a5ba4_row1_col4" class="data row1 col4" >1.026</td>
#       <td id="T_a5ba4_row1_col5" class="data row1 col5" >1.028</td>
#       <td id="T_a5ba4_row1_col6" class="data row1 col6" >1.026</td>
#       <td id="T_a5ba4_row1_col7" class="data row1 col7" >1.025</td>
#     </tr>
#     <tr>
#       <th id="T_a5ba4_level0_row2" class="row_heading level0 row2" >PSBPM-FD</th>
#       <td id="T_a5ba4_row2_col0" class="data row2 col0" >1.020</td>
#       <td id="T_a5ba4_row2_col1" class="data row2 col1" >1.014</td>
#       <td id="T_a5ba4_row2_col2" class="data row2 col2" >1.015</td>
#       <td id="T_a5ba4_row2_col3" class="data row2 col3" >1.007</td>
#       <td id="T_a5ba4_row2_col4" class="data row2 col4" >1.011</td>
#       <td id="T_a5ba4_row2_col5" class="data row2 col5" >1.008</td>
#       <td id="T_a5ba4_row2_col6" class="data row2 col6" >1.010</td>
#       <td id="T_a5ba4_row2_col7" class="data row2 col7" >1.015</td>
#     </tr>
#     <tr>
#       <th id="T_a5ba4_level0_row3" class="row_heading level0 row3" >RF</th>
#       <td id="T_a5ba4_row3_col0" class="data row3 col0" >1.016</td>
#       <td id="T_a5ba4_row3_col1" class="data row3 col1" >1.014</td>
#       <td id="T_a5ba4_row3_col2" class="data row3 col2" >1.018</td>
#       <td id="T_a5ba4_row3_col3" class="data row3 col3" >1.010</td>
#       <td id="T_a5ba4_row3_col4" class="data row3 col4" >1.012</td>
#       <td id="T_a5ba4_row3_col5" class="data row3 col5" >1.009</td>
#       <td id="T_a5ba4_row3_col6" class="data row3 col6" >1.015</td>
#       <td id="T_a5ba4_row3_col7" class="data row3 col7" >1.015</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Figura: % de ventanas ganadas, por modelo y metrica, train contra test.
_Ms = sorted(EST)
for M in _Ms:
    sub_M = gana_A_df[gana_A_df.M == M]
    modelos = sorted(sub_M["modelo"].unique())
    fig, axes = plt.subplots(1, len(METRICAS_A),
                             figsize=(5.2 * len(METRICAS_A), 4.2), sharey=True)
    if len(METRICAS_A) == 1:
        axes = [axes]
    ancho = 0.8 / 2
    xs = np.arange(len(modelos))
    for ax, (etiqueta, _c) in zip(axes, METRICAS_A):
        for i_b, bloque in enumerate(("train", "test")):
            vals = [float(sub_M[(sub_M.modelo == m) & (sub_M.bloque == bloque)
                                & (sub_M.metrica == etiqueta)]
                          ["pct_ventanas_ganadas"].iloc[0]) for m in modelos]
            ax.bar(xs + (i_b - 0.5) * ancho, vals, width=ancho, label=bloque,
                   color=("#2c7fb8" if bloque == "train" else "#c0392b"))
        ax.set_xticks(xs); ax.set_xticklabels(modelos, rotation=30, ha="right",
                                              fontsize=8)
        ax.set_title(etiqueta, fontsize=10); ax.set_ylim(0, 1)
        ax.legend(fontsize=8)
    axes[0].set_ylabel("% de ventanas ganadas")
    fig.suptitle(f"M={M} · qué modelo gana cada ventana (w={W_COMP})", fontsize=12)
    fig.tight_layout()
    fig.savefig(EST[M]["paths"]["out_report"]
                / f"{PREFIJO + 8}_ganador_ventana_bloqueA.png",
                dpi=150, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## 7. Bloque B: quién gana cada ventana, y por cuánto
#
# La misma lectura de §6, restringida a las series que **tienen un mecanismo de
# intervalo propio**: el FAR —cuyo IC a un paso sale de su propia especificación
# $X_{t+1}=\rho(X_t)+\varepsilon$— y el PSBPM-FD —cuya predictiva se muestrea y
# cuyos cuantiles empíricos dan la banda—.
#
# El Winkler es la única regla de puntuación propia del bloque, así que es la
# que decide quién gana; PICP y MPIW lo descomponen en cobertura y ancho.

# %%
# % de ventanas ganadas y razones, sobre las bandas (FAR y PSBPM-FD).
# En picp / picp_simultaneo "ganar" NO es tener el valor mas bajo sino estar
# mas cerca del nominal: se compara |picp - NIVEL_IC|.
gana_B, rel_B = [], []
for M in EST:
    e = EST[M]
    vb = e["ventana_B"]
    limpio = vb[~vb["cruza_T0"]]
    bandas = list(limpio["banda"].unique())

    for etiqueta, col in METRICAS_B:
        piv = limpio.pivot_table(index=["t_centro", "bloque"], columns="banda",
                                 values=col)[bandas]
        # Criterio de "mejor" por metrica.
        objetivo = (piv - NIVEL_IC).abs() if col.startswith("picp") else piv
        ganador = objetivo.idxmin(axis=1)
        for bloque in ("train", "test"):
            sel = ganador.index.get_level_values("bloque") == bloque
            sub = ganador[sel]
            n_tot = len(sub)
            for b in bandas:
                gana_B.append({
                    "M": M, "metrica": etiqueta, "columna": col,
                    "bloque": bloque, "banda": b,
                    "pct_ventanas_ganadas": float((sub == b).mean()) if n_tot else np.nan,
                    "n_ventanas": n_tot,
                    "criterio": "|valor - nominal|" if col.startswith("picp")
                                else "menor es mejor"})
            o = objetivo[sel]
            mejor = o.min(axis=1)
            for b in bandas:
                rel_B.append({"M": M, "metrica": etiqueta, "bloque": bloque,
                              "banda": b,
                              "razon_vs_mejor": float(
                                  (o[b] / mejor.replace(0, np.nan)).mean())})

gana_B_df = pd.DataFrame(gana_B)
rel_B_df  = pd.DataFrame(rel_B)
gana_B_df.to_csv(PATH_BARRIDO / "97_ganador_ventana_bloqueB.csv", index=False)
rel_B_df.to_csv(PATH_BARRIDO / "97_razones_bloqueB.csv", index=False)

for etiqueta, col in METRICAS_B:
    piv_g = (gana_B_df[(gana_B_df.metrica == etiqueta) & (gana_B_df.bloque == "test")]
             .pivot(index="banda", columns="M", values="pct_ventanas_ganadas"))
    crit = ("más cerca del nominal" if col.startswith("picp") else "menor es mejor")
    display(piv_g.style.format("{:.1%}", na_rep="-")
            .background_gradient(cmap="RdYlGn", axis=None)
            .set_caption(f"{etiqueta} · % de ventanas de PRUEBA ganadas "
                         f"(criterio: {crit})"))
# Out:
# <style type="text/css">
# #T_91bd6_row0_col0, #T_91bd6_row0_col1, #T_91bd6_row0_col2, #T_91bd6_row0_col3, #T_91bd6_row0_col4, #T_91bd6_row0_col5, #T_91bd6_row0_col6, #T_91bd6_row0_col7, #T_91bd6_row1_col0, #T_91bd6_row1_col1, #T_91bd6_row1_col2, #T_91bd6_row1_col3, #T_91bd6_row1_col4, #T_91bd6_row1_col5, #T_91bd6_row1_col6, #T_91bd6_row1_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_91bd6_row2_col0, #T_91bd6_row2_col1, #T_91bd6_row2_col2, #T_91bd6_row2_col3, #T_91bd6_row2_col4, #T_91bd6_row2_col5, #T_91bd6_row2_col6, #T_91bd6_row2_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_91bd6">
#   <caption>5. MPIW · % de ventanas de PRUEBA ganadas (criterio: menor es mejor)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_91bd6_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_91bd6_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_91bd6_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_91bd6_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_91bd6_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_91bd6_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_91bd6_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_91bd6_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91bd6_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_91bd6_row0_col0" class="data row0 col0" >0.0%</td>
#       <td id="T_91bd6_row0_col1" class="data row0 col1" >0.0%</td>
#       <td id="T_91bd6_row0_col2" class="data row0 col2" >0.0%</td>
#       <td id="T_91bd6_row0_col3" class="data row0 col3" >0.0%</td>
#       <td id="T_91bd6_row0_col4" class="data row0 col4" >0.0%</td>
#       <td id="T_91bd6_row0_col5" class="data row0 col5" >0.0%</td>
#       <td id="T_91bd6_row0_col6" class="data row0 col6" >0.0%</td>
#       <td id="T_91bd6_row0_col7" class="data row0 col7" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_91bd6_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_91bd6_row1_col0" class="data row1 col0" >0.0%</td>
#       <td id="T_91bd6_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_91bd6_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_91bd6_row1_col3" class="data row1 col3" >0.0%</td>
#       <td id="T_91bd6_row1_col4" class="data row1 col4" >0.0%</td>
#       <td id="T_91bd6_row1_col5" class="data row1 col5" >0.0%</td>
#       <td id="T_91bd6_row1_col6" class="data row1 col6" >0.0%</td>
#       <td id="T_91bd6_row1_col7" class="data row1 col7" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_91bd6_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_91bd6_row2_col0" class="data row2 col0" >100.0%</td>
#       <td id="T_91bd6_row2_col1" class="data row2 col1" >100.0%</td>
#       <td id="T_91bd6_row2_col2" class="data row2 col2" >100.0%</td>
#       <td id="T_91bd6_row2_col3" class="data row2 col3" >100.0%</td>
#       <td id="T_91bd6_row2_col4" class="data row2 col4" >100.0%</td>
#       <td id="T_91bd6_row2_col5" class="data row2 col5" >100.0%</td>
#       <td id="T_91bd6_row2_col6" class="data row2 col6" >100.0%</td>
#       <td id="T_91bd6_row2_col7" class="data row2 col7" >100.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_03d0f_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_03d0f_row0_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_03d0f_row0_col2 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_03d0f_row0_col3 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_03d0f_row0_col4, #T_03d0f_row0_col7 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_03d0f_row0_col5 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_03d0f_row0_col6 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_03d0f_row1_col0 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_03d0f_row1_col1 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_03d0f_row1_col2 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_03d0f_row1_col3 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_03d0f_row1_col4, #T_03d0f_row1_col7 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_03d0f_row1_col5 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_03d0f_row1_col6 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_03d0f_row2_col0, #T_03d0f_row2_col1, #T_03d0f_row2_col2, #T_03d0f_row2_col3, #T_03d0f_row2_col4, #T_03d0f_row2_col5, #T_03d0f_row2_col6, #T_03d0f_row2_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_03d0f">
#   <caption>6. PICP puntual · % de ventanas de PRUEBA ganadas (criterio: más cerca del nominal)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_03d0f_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_03d0f_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_03d0f_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_03d0f_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_03d0f_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_03d0f_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_03d0f_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_03d0f_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03d0f_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_03d0f_row0_col0" class="data row0 col0" >80.4%</td>
#       <td id="T_03d0f_row0_col1" class="data row0 col1" >79.7%</td>
#       <td id="T_03d0f_row0_col2" class="data row0 col2" >72.7%</td>
#       <td id="T_03d0f_row0_col3" class="data row0 col3" >75.6%</td>
#       <td id="T_03d0f_row0_col4" class="data row0 col4" >66.1%</td>
#       <td id="T_03d0f_row0_col5" class="data row0 col5" >62.7%</td>
#       <td id="T_03d0f_row0_col6" class="data row0 col6" >66.4%</td>
#       <td id="T_03d0f_row0_col7" class="data row0 col7" >66.1%</td>
#     </tr>
#     <tr>
#       <th id="T_03d0f_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_03d0f_row1_col0" class="data row1 col0" >19.6%</td>
#       <td id="T_03d0f_row1_col1" class="data row1 col1" >20.3%</td>
#       <td id="T_03d0f_row1_col2" class="data row1 col2" >27.3%</td>
#       <td id="T_03d0f_row1_col3" class="data row1 col3" >24.4%</td>
#       <td id="T_03d0f_row1_col4" class="data row1 col4" >33.9%</td>
#       <td id="T_03d0f_row1_col5" class="data row1 col5" >37.3%</td>
#       <td id="T_03d0f_row1_col6" class="data row1 col6" >33.6%</td>
#       <td id="T_03d0f_row1_col7" class="data row1 col7" >33.9%</td>
#     </tr>
#     <tr>
#       <th id="T_03d0f_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_03d0f_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_03d0f_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_03d0f_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_03d0f_row2_col3" class="data row2 col3" >0.0%</td>
#       <td id="T_03d0f_row2_col4" class="data row2 col4" >0.0%</td>
#       <td id="T_03d0f_row2_col5" class="data row2 col5" >0.0%</td>
#       <td id="T_03d0f_row2_col6" class="data row2 col6" >0.0%</td>
#       <td id="T_03d0f_row2_col7" class="data row2 col7" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d9549_row0_col0, #T_d9549_row0_col1, #T_d9549_row0_col2, #T_d9549_row0_col3, #T_d9549_row0_col4, #T_d9549_row0_col5, #T_d9549_row0_col6, #T_d9549_row0_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d9549_row1_col0, #T_d9549_row1_col1, #T_d9549_row1_col2, #T_d9549_row1_col3, #T_d9549_row1_col4, #T_d9549_row1_col5, #T_d9549_row1_col6, #T_d9549_row1_col7, #T_d9549_row2_col0, #T_d9549_row2_col1, #T_d9549_row2_col2, #T_d9549_row2_col3, #T_d9549_row2_col4, #T_d9549_row2_col5, #T_d9549_row2_col6, #T_d9549_row2_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d9549">
#   <caption>7. PICPB curva completa · % de ventanas de PRUEBA ganadas (criterio: más cerca del nominal)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_d9549_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_d9549_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_d9549_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_d9549_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_d9549_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_d9549_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_d9549_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_d9549_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9549_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_d9549_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_d9549_row0_col1" class="data row0 col1" >100.0%</td>
#       <td id="T_d9549_row0_col2" class="data row0 col2" >100.0%</td>
#       <td id="T_d9549_row0_col3" class="data row0 col3" >100.0%</td>
#       <td id="T_d9549_row0_col4" class="data row0 col4" >100.0%</td>
#       <td id="T_d9549_row0_col5" class="data row0 col5" >100.0%</td>
#       <td id="T_d9549_row0_col6" class="data row0 col6" >100.0%</td>
#       <td id="T_d9549_row0_col7" class="data row0 col7" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d9549_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d9549_row1_col0" class="data row1 col0" >0.0%</td>
#       <td id="T_d9549_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_d9549_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_d9549_row1_col3" class="data row1 col3" >0.0%</td>
#       <td id="T_d9549_row1_col4" class="data row1 col4" >0.0%</td>
#       <td id="T_d9549_row1_col5" class="data row1 col5" >0.0%</td>
#       <td id="T_d9549_row1_col6" class="data row1 col6" >0.0%</td>
#       <td id="T_d9549_row1_col7" class="data row1 col7" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d9549_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d9549_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_d9549_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_d9549_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_d9549_row2_col3" class="data row2 col3" >0.0%</td>
#       <td id="T_d9549_row2_col4" class="data row2 col4" >0.0%</td>
#       <td id="T_d9549_row2_col5" class="data row2 col5" >0.0%</td>
#       <td id="T_d9549_row2_col6" class="data row2 col6" >0.0%</td>
#       <td id="T_d9549_row2_col7" class="data row2 col7" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_392d3_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_392d3_row0_col1 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_392d3_row0_col2 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_392d3_row0_col3 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_392d3_row0_col4 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_392d3_row0_col5, #T_392d3_row1_col7 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_392d3_row0_col6 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_392d3_row0_col7, #T_392d3_row1_col5 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_392d3_row1_col0 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_392d3_row1_col1 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_392d3_row1_col2 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_392d3_row1_col3 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_392d3_row1_col4 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_392d3_row1_col6 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_392d3_row2_col0, #T_392d3_row2_col1, #T_392d3_row2_col2, #T_392d3_row2_col3, #T_392d3_row2_col4, #T_392d3_row2_col5, #T_392d3_row2_col6, #T_392d3_row2_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_392d3">
#   <caption>8. Winkler · % de ventanas de PRUEBA ganadas (criterio: menor es mejor)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_392d3_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_392d3_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_392d3_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_392d3_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_392d3_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_392d3_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_392d3_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_392d3_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_392d3_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_392d3_row0_col0" class="data row0 col0" >55.0%</td>
#       <td id="T_392d3_row0_col1" class="data row0 col1" >48.3%</td>
#       <td id="T_392d3_row0_col2" class="data row0 col2" >46.5%</td>
#       <td id="T_392d3_row0_col3" class="data row0 col3" >49.8%</td>
#       <td id="T_392d3_row0_col4" class="data row0 col4" >48.0%</td>
#       <td id="T_392d3_row0_col5" class="data row0 col5" >47.2%</td>
#       <td id="T_392d3_row0_col6" class="data row0 col6" >53.1%</td>
#       <td id="T_392d3_row0_col7" class="data row0 col7" >52.8%</td>
#     </tr>
#     <tr>
#       <th id="T_392d3_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_392d3_row1_col0" class="data row1 col0" >45.0%</td>
#       <td id="T_392d3_row1_col1" class="data row1 col1" >51.7%</td>
#       <td id="T_392d3_row1_col2" class="data row1 col2" >53.5%</td>
#       <td id="T_392d3_row1_col3" class="data row1 col3" >50.2%</td>
#       <td id="T_392d3_row1_col4" class="data row1 col4" >52.0%</td>
#       <td id="T_392d3_row1_col5" class="data row1 col5" >52.8%</td>
#       <td id="T_392d3_row1_col6" class="data row1 col6" >46.9%</td>
#       <td id="T_392d3_row1_col7" class="data row1 col7" >47.2%</td>
#     </tr>
#     <tr>
#       <th id="T_392d3_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_392d3_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_392d3_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_392d3_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_392d3_row2_col3" class="data row2 col3" >0.0%</td>
#       <td id="T_392d3_row2_col4" class="data row2 col4" >0.0%</td>
#       <td id="T_392d3_row2_col5" class="data row2 col5" >0.0%</td>
#       <td id="T_392d3_row2_col6" class="data row2 col6" >0.0%</td>
#       <td id="T_392d3_row2_col7" class="data row2 col7" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0edab_row0_col0 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_0edab_row0_col1 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_0edab_row0_col2, #T_0edab_row1_col7 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_0edab_row0_col3 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_0edab_row0_col4 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_0edab_row0_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_0edab_row0_col6 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_0edab_row0_col7, #T_0edab_row1_col2 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_0edab_row1_col0 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_0edab_row1_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_0edab_row1_col3 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_0edab_row1_col4 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_0edab_row1_col5 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_0edab_row1_col6 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_0edab_row2_col0, #T_0edab_row2_col1, #T_0edab_row2_col2, #T_0edab_row2_col3, #T_0edab_row2_col4, #T_0edab_row2_col5, #T_0edab_row2_col6, #T_0edab_row2_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0edab">
#   <caption>9. Winkler max promedio · % de ventanas de PRUEBA ganadas (criterio: menor es mejor)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_0edab_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_0edab_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_0edab_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_0edab_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_0edab_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_0edab_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_0edab_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_0edab_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0edab_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_0edab_row0_col0" class="data row0 col0" >57.6%</td>
#       <td id="T_0edab_row0_col1" class="data row0 col1" >55.0%</td>
#       <td id="T_0edab_row0_col2" class="data row0 col2" >43.5%</td>
#       <td id="T_0edab_row0_col3" class="data row0 col3" >47.6%</td>
#       <td id="T_0edab_row0_col4" class="data row0 col4" >49.8%</td>
#       <td id="T_0edab_row0_col5" class="data row0 col5" >59.0%</td>
#       <td id="T_0edab_row0_col6" class="data row0 col6" >57.9%</td>
#       <td id="T_0edab_row0_col7" class="data row0 col7" >56.5%</td>
#     </tr>
#     <tr>
#       <th id="T_0edab_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_0edab_row1_col0" class="data row1 col0" >42.4%</td>
#       <td id="T_0edab_row1_col1" class="data row1 col1" >45.0%</td>
#       <td id="T_0edab_row1_col2" class="data row1 col2" >56.5%</td>
#       <td id="T_0edab_row1_col3" class="data row1 col3" >52.4%</td>
#       <td id="T_0edab_row1_col4" class="data row1 col4" >50.2%</td>
#       <td id="T_0edab_row1_col5" class="data row1 col5" >41.0%</td>
#       <td id="T_0edab_row1_col6" class="data row1 col6" >42.1%</td>
#       <td id="T_0edab_row1_col7" class="data row1 col7" >43.5%</td>
#     </tr>
#     <tr>
#       <th id="T_0edab_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_0edab_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_0edab_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_0edab_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_0edab_row2_col3" class="data row2 col3" >0.0%</td>
#       <td id="T_0edab_row2_col4" class="data row2 col4" >0.0%</td>
#       <td id="T_0edab_row2_col5" class="data row2 col5" >0.0%</td>
#       <td id="T_0edab_row2_col6" class="data row2 col6" >0.0%</td>
#       <td id="T_0edab_row2_col7" class="data row2 col7" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_679fc_row0_col0 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_679fc_row0_col1, #T_679fc_row0_col2 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_679fc_row0_col3 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_679fc_row0_col4, #T_679fc_row0_col5 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_679fc_row0_col6, #T_679fc_row0_col7 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_679fc_row1_col0 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_679fc_row1_col1, #T_679fc_row1_col2 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_679fc_row1_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_679fc_row1_col4, #T_679fc_row1_col5 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_679fc_row1_col6, #T_679fc_row1_col7 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_679fc_row2_col0, #T_679fc_row2_col1, #T_679fc_row2_col2, #T_679fc_row2_col3, #T_679fc_row2_col4, #T_679fc_row2_col5, #T_679fc_row2_col6, #T_679fc_row2_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_679fc">
#   <caption>10. Winkler max peor ventana · % de ventanas de PRUEBA ganadas (criterio: menor es mejor)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >M</th>
#       <th id="T_679fc_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_679fc_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_679fc_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_679fc_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_679fc_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_679fc_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_679fc_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_679fc_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_679fc_level0_row0" class="row_heading level0 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_679fc_row0_col0" class="data row0 col0" >50.2%</td>
#       <td id="T_679fc_row0_col1" class="data row0 col1" >53.9%</td>
#       <td id="T_679fc_row0_col2" class="data row0 col2" >53.9%</td>
#       <td id="T_679fc_row0_col3" class="data row0 col3" >35.8%</td>
#       <td id="T_679fc_row0_col4" class="data row0 col4" >43.2%</td>
#       <td id="T_679fc_row0_col5" class="data row0 col5" >43.2%</td>
#       <td id="T_679fc_row0_col6" class="data row0 col6" >57.2%</td>
#       <td id="T_679fc_row0_col7" class="data row0 col7" >57.2%</td>
#     </tr>
#     <tr>
#       <th id="T_679fc_level0_row1" class="row_heading level0 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_679fc_row1_col0" class="data row1 col0" >49.8%</td>
#       <td id="T_679fc_row1_col1" class="data row1 col1" >46.1%</td>
#       <td id="T_679fc_row1_col2" class="data row1 col2" >46.1%</td>
#       <td id="T_679fc_row1_col3" class="data row1 col3" >64.2%</td>
#       <td id="T_679fc_row1_col4" class="data row1 col4" >56.8%</td>
#       <td id="T_679fc_row1_col5" class="data row1 col5" >56.8%</td>
#       <td id="T_679fc_row1_col6" class="data row1 col6" >42.8%</td>
#       <td id="T_679fc_row1_col7" class="data row1 col7" >42.8%</td>
#     </tr>
#     <tr>
#       <th id="T_679fc_level0_row2" class="row_heading level0 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_679fc_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_679fc_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_679fc_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_679fc_row2_col3" class="data row2 col3" >0.0%</td>
#       <td id="T_679fc_row2_col4" class="data row2 col4" >0.0%</td>
#       <td id="T_679fc_row2_col5" class="data row2 col5" >0.0%</td>
#       <td id="T_679fc_row2_col6" class="data row2 col6" >0.0%</td>
#       <td id="T_679fc_row2_col7" class="data row2 col7" >0.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 8. Cuadro resumen: mínimo, máximo y promedio
#
# Igual que en `103_04`: la ventana móvil genera una **serie** por métrica y por
# modelo, no una cifra. El resumen muestra los tres números que describen esa
# serie —mínimo, máximo y promedio— por bloque train/test, excluyendo las
# ventanas que cruzan $T_0$.
#
# El **máximo** es el que no aparece en ninguna tabla de promedios y suele ser el
# que decide: un modelo con buen promedio y un máximo muy alto falla feo en
# algún tramo, y eso es información distinta de su error típico.

# %%
# Bloque A: min / max / promedio por modelo y metrica.
resA = []
for M in EST:
    e = EST[M]
    tw = e["tablas_w"][W_COMP]
    limpio = tw[~tw["cruza_T0"]]
    for etiqueta, col in METRICAS_A:
        g = limpio.groupby(["modelo", "bloque"])[col].agg(["min", "max", "mean"])
        for (modelo, bloque), r in g.iterrows():
            resA.append({"M": M, "metrica": etiqueta, "columna": col,
                         "modelo": modelo, "bloque": bloque,
                         "minimo": float(r["min"]), "maximo": float(r["max"]),
                         "promedio": float(r["mean"])})
resumen_A = pd.DataFrame(resA)
resumen_A.to_csv(PATH_BARRIDO / "98_resumen_bloqueA_min_max_prom.csv", index=False)

for M in EST:
    sub = (resumen_A[(resumen_A.M == M) & (resumen_A.bloque == "test")]
           .set_index(["metrica", "modelo"])[["minimo", "maximo", "promedio"]])
    display(sub.style.format("{:.6f}")
            .background_gradient(subset=["maximo"], cmap="RdYlGn_r")
            .set_caption(f"M={M} · Bloque A en el TEST · mínimo / máximo / "
                         f"promedio sobre las ventanas (w={W_COMP})"))
# Out:
# <style type="text/css">
# #T_4ff9f_row0_col1, #T_4ff9f_row1_col1, #T_4ff9f_row2_col1, #T_4ff9f_row3_col1, #T_4ff9f_row4_col1, #T_4ff9f_row5_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4ff9f_row6_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_4ff9f_row7_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_4ff9f_row8_col1, #T_4ff9f_row10_col1, #T_4ff9f_row11_col1, #T_4ff9f_row12_col1 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_4ff9f_row9_col1 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_4ff9f_row13_col1 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_4ff9f_row14_col1 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_4ff9f_row15_col1, #T_4ff9f_row16_col1, #T_4ff9f_row17_col1, #T_4ff9f_row18_col1, #T_4ff9f_row19_col1 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_4ff9f_row20_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_4ff9f_row21_col1 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_4ff9f_row22_col1, #T_4ff9f_row24_col1, #T_4ff9f_row26_col1 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_4ff9f_row23_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4ff9f_row25_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_4ff9f_row27_col1 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4ff9f">
#   <caption>M=1 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ff9f_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_4ff9f_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_4ff9f_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ff9f_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_4ff9f_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_4ff9f_row0_col0" class="data row0 col0" >0.571407</td>
#       <td id="T_4ff9f_row0_col1" class="data row0 col1" >0.802074</td>
#       <td id="T_4ff9f_row0_col2" class="data row0 col2" >0.678696</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_4ff9f_row1_col0" class="data row1 col0" >0.593291</td>
#       <td id="T_4ff9f_row1_col1" class="data row1 col1" >0.829748</td>
#       <td id="T_4ff9f_row1_col2" class="data row1 col2" >0.700603</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_4ff9f_row2_col0" class="data row2 col0" >0.606507</td>
#       <td id="T_4ff9f_row2_col1" class="data row2 col1" >0.832301</td>
#       <td id="T_4ff9f_row2_col2" class="data row2 col2" >0.708068</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_4ff9f_row3_col0" class="data row3 col0" >0.593409</td>
#       <td id="T_4ff9f_row3_col1" class="data row3 col1" >0.829410</td>
#       <td id="T_4ff9f_row3_col2" class="data row3 col2" >0.700487</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_4ff9f_row4_col0" class="data row4 col0" >0.597005</td>
#       <td id="T_4ff9f_row4_col1" class="data row4 col1" >0.831654</td>
#       <td id="T_4ff9f_row4_col2" class="data row4 col2" >0.702983</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_4ff9f_row5_col0" class="data row5 col0" >0.593450</td>
#       <td id="T_4ff9f_row5_col1" class="data row5 col1" >0.829369</td>
#       <td id="T_4ff9f_row5_col2" class="data row5 col2" >0.700457</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_4ff9f_row6_col0" class="data row6 col0" >0.611794</td>
#       <td id="T_4ff9f_row6_col1" class="data row6 col1" >0.874447</td>
#       <td id="T_4ff9f_row6_col2" class="data row6 col2" >0.727737</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_4ff9f_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_4ff9f_row7_col0" class="data row7 col0" >0.748894</td>
#       <td id="T_4ff9f_row7_col1" class="data row7 col1" >1.083998</td>
#       <td id="T_4ff9f_row7_col2" class="data row7 col2" >0.901700</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_4ff9f_row8_col0" class="data row8 col0" >0.770722</td>
#       <td id="T_4ff9f_row8_col1" class="data row8 col1" >1.131760</td>
#       <td id="T_4ff9f_row8_col2" class="data row8 col2" >0.929681</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_4ff9f_row9_col0" class="data row9 col0" >0.786200</td>
#       <td id="T_4ff9f_row9_col1" class="data row9 col1" >1.147253</td>
#       <td id="T_4ff9f_row9_col2" class="data row9 col2" >0.936902</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_4ff9f_row10_col0" class="data row10 col0" >0.770804</td>
#       <td id="T_4ff9f_row10_col1" class="data row10 col1" >1.131412</td>
#       <td id="T_4ff9f_row10_col2" class="data row10 col2" >0.929610</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_4ff9f_row11_col0" class="data row11 col0" >0.775430</td>
#       <td id="T_4ff9f_row11_col1" class="data row11 col1" >1.136780</td>
#       <td id="T_4ff9f_row11_col2" class="data row11 col2" >0.932262</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_4ff9f_row12_col0" class="data row12 col0" >0.770794</td>
#       <td id="T_4ff9f_row12_col1" class="data row12 col1" >1.131298</td>
#       <td id="T_4ff9f_row12_col2" class="data row12 col2" >0.929579</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_4ff9f_row13_col0" class="data row13 col0" >0.794163</td>
#       <td id="T_4ff9f_row13_col1" class="data row13 col1" >1.212379</td>
#       <td id="T_4ff9f_row13_col2" class="data row13 col2" >0.961395</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_4ff9f_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_4ff9f_row14_col0" class="data row14 col0" >1.925863</td>
#       <td id="T_4ff9f_row14_col1" class="data row14 col1" >2.776522</td>
#       <td id="T_4ff9f_row14_col2" class="data row14 col2" >2.272701</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_4ff9f_row15_col0" class="data row15 col0" >1.954514</td>
#       <td id="T_4ff9f_row15_col1" class="data row15 col1" >2.815737</td>
#       <td id="T_4ff9f_row15_col2" class="data row15 col2" >2.321682</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row16" class="row_heading level1 row16" >GBT</th>
#       <td id="T_4ff9f_row16_col0" class="data row16 col0" >1.981033</td>
#       <td id="T_4ff9f_row16_col1" class="data row16 col1" >2.820049</td>
#       <td id="T_4ff9f_row16_col2" class="data row16 col2" >2.334732</td>
#     </tr>
#     <tr>
#       <th id="T_4ff9f_level1_row17" class="row_heading level1 row17" >PSBPM-FD</th>
#       <td id="T_4ff9f_row17_col0" class="data row17 col0" >1.954046</td>
#       <td id="T_4ff9f_row17_col1" class="data row17 col1" >2.816300</td>
#       <td id=
# <style type="text/css">
# #T_2e547_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2e547_row1_col1, #T_2e547_row2_col1, #T_2e547_row3_col1, #T_2e547_row4_col1, #T_2e547_row5_col1 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_2e547_row6_col1 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_2e547_row7_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_2e547_row8_col1, #T_2e547_row9_col1, #T_2e547_row10_col1, #T_2e547_row11_col1, #T_2e547_row12_col1 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_2e547_row13_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_2e547_row14_col1 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_2e547_row15_col1, #T_2e547_row16_col1, #T_2e547_row17_col1, #T_2e547_row18_col1, #T_2e547_row19_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_2e547_row20_col1 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_2e547_row21_col1 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_2e547_row22_col1, #T_2e547_row24_col1, #T_2e547_row26_col1 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_2e547_row23_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_2e547_row25_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_2e547_row27_col1 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2e547">
#   <caption>M=2 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e547_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_2e547_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_2e547_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e547_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_2e547_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_2e547_row0_col0" class="data row0 col0" >0.554374</td>
#       <td id="T_2e547_row0_col1" class="data row0 col1" >0.772623</td>
#       <td id="T_2e547_row0_col2" class="data row0 col2" >0.658629</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_2e547_row1_col0" class="data row1 col0" >0.593291</td>
#       <td id="T_2e547_row1_col1" class="data row1 col1" >0.829748</td>
#       <td id="T_2e547_row1_col2" class="data row1 col2" >0.700603</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_2e547_row2_col0" class="data row2 col0" >0.605025</td>
#       <td id="T_2e547_row2_col1" class="data row2 col1" >0.827304</td>
#       <td id="T_2e547_row2_col2" class="data row2 col2" >0.713912</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_2e547_row3_col0" class="data row3 col0" >0.593472</td>
#       <td id="T_2e547_row3_col1" class="data row3 col1" >0.828903</td>
#       <td id="T_2e547_row3_col2" class="data row3 col2" >0.700426</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_2e547_row4_col0" class="data row4 col0" >0.595423</td>
#       <td id="T_2e547_row4_col1" class="data row4 col1" >0.827394</td>
#       <td id="T_2e547_row4_col2" class="data row4 col2" >0.701976</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_2e547_row5_col0" class="data row5 col0" >0.593450</td>
#       <td id="T_2e547_row5_col1" class="data row5 col1" >0.829369</td>
#       <td id="T_2e547_row5_col2" class="data row5 col2" >0.700457</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_2e547_row6_col0" class="data row6 col0" >0.630964</td>
#       <td id="T_2e547_row6_col1" class="data row6 col1" >0.899356</td>
#       <td id="T_2e547_row6_col2" class="data row6 col2" >0.747303</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_2e547_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_2e547_row7_col0" class="data row7 col0" >0.722137</td>
#       <td id="T_2e547_row7_col1" class="data row7 col1" >1.057105</td>
#       <td id="T_2e547_row7_col2" class="data row7 col2" >0.874165</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_2e547_row8_col0" class="data row8 col0" >0.770722</td>
#       <td id="T_2e547_row8_col1" class="data row8 col1" >1.131760</td>
#       <td id="T_2e547_row8_col2" class="data row8 col2" >0.929681</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_2e547_row9_col0" class="data row9 col0" >0.781235</td>
#       <td id="T_2e547_row9_col1" class="data row9 col1" >1.146035</td>
#       <td id="T_2e547_row9_col2" class="data row9 col2" >0.940888</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_2e547_row10_col0" class="data row10 col0" >0.770814</td>
#       <td id="T_2e547_row10_col1" class="data row10 col1" >1.131378</td>
#       <td id="T_2e547_row10_col2" class="data row10 col2" >0.929577</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_2e547_row11_col0" class="data row11 col0" >0.770704</td>
#       <td id="T_2e547_row11_col1" class="data row11 col1" >1.133496</td>
#       <td id="T_2e547_row11_col2" class="data row11 col2" >0.930584</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_2e547_row12_col0" class="data row12 col0" >0.770794</td>
#       <td id="T_2e547_row12_col1" class="data row12 col1" >1.131298</td>
#       <td id="T_2e547_row12_col2" class="data row12 col2" >0.929579</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_2e547_row13_col0" class="data row13 col0" >0.815874</td>
#       <td id="T_2e547_row13_col1" class="data row13 col1" >1.240598</td>
#       <td id="T_2e547_row13_col2" class="data row13 col2" >0.983927</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_2e547_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_2e547_row14_col0" class="data row14 col0" >1.877943</td>
#       <td id="T_2e547_row14_col1" class="data row14 col1" >2.672065</td>
#       <td id="T_2e547_row14_col2" class="data row14 col2" >2.216278</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_2e547_row15_col0" class="data row15 col0" >1.954514</td>
#       <td id="T_2e547_row15_col1" class="data row15 col1" >2.815737</td>
#       <td id="T_2e547_row15_col2" class="data row15 col2" >2.321682</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row16" class="row_heading level1 row16" >GBT</th>
#       <td id="T_2e547_row16_col0" class="data row16 col0" >1.962565</td>
#       <td id="T_2e547_row16_col1" class="data row16 col1" >2.816197</td>
#       <td id="T_2e547_row16_col2" class="data row16 col2" >2.340229</td>
#     </tr>
#     <tr>
#       <th id="T_2e547_level1_row17" class="row_heading level1 row17" >PSBPM-FD</th>
#       <td id="T_2e547_row17_col0" class="data row17 col0" >1.954110</td>
#       <td id="T_2e547_row17_col1" class="data row17 col1" >2.816088</td>
#       <td id=
# <style type="text/css">
# #T_38677_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_38677_row1_col1, #T_38677_row2_col1, #T_38677_row3_col1, #T_38677_row4_col1, #T_38677_row5_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_38677_row6_col1 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_38677_row7_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_38677_row8_col1, #T_38677_row9_col1, #T_38677_row10_col1, #T_38677_row11_col1, #T_38677_row12_col1 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_38677_row13_col1 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_38677_row14_col1 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_38677_row15_col1, #T_38677_row16_col1, #T_38677_row17_col1, #T_38677_row18_col1, #T_38677_row19_col1 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_38677_row20_col1 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_38677_row21_col1, #T_38677_row27_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_38677_row22_col1, #T_38677_row23_col1, #T_38677_row24_col1, #T_38677_row25_col1, #T_38677_row26_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_38677">
#   <caption>M=3 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38677_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_38677_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_38677_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38677_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_38677_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_38677_row0_col0" class="data row0 col0" >0.535200</td>
#       <td id="T_38677_row0_col1" class="data row0 col1" >0.745486</td>
#       <td id="T_38677_row0_col2" class="data row0 col2" >0.635916</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_38677_row1_col0" class="data row1 col0" >0.593291</td>
#       <td id="T_38677_row1_col1" class="data row1 col1" >0.829748</td>
#       <td id="T_38677_row1_col2" class="data row1 col2" >0.700603</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_38677_row2_col0" class="data row2 col0" >0.606491</td>
#       <td id="T_38677_row2_col1" class="data row2 col1" >0.837446</td>
#       <td id="T_38677_row2_col2" class="data row2 col2" >0.718846</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_38677_row3_col0" class="data row3 col0" >0.593481</td>
#       <td id="T_38677_row3_col1" class="data row3 col1" >0.829020</td>
#       <td id="T_38677_row3_col2" class="data row3 col2" >0.700404</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_38677_row4_col0" class="data row4 col0" >0.596298</td>
#       <td id="T_38677_row4_col1" class="data row4 col1" >0.831740</td>
#       <td id="T_38677_row4_col2" class="data row4 col2" >0.701861</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_38677_row5_col0" class="data row5 col0" >0.593450</td>
#       <td id="T_38677_row5_col1" class="data row5 col1" >0.829369</td>
#       <td id="T_38677_row5_col2" class="data row5 col2" >0.700457</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_38677_row6_col0" class="data row6 col0" >0.652270</td>
#       <td id="T_38677_row6_col1" class="data row6 col1" >0.923881</td>
#       <td id="T_38677_row6_col2" class="data row6 col2" >0.771943</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_38677_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_38677_row7_col0" class="data row7 col0" >0.698431</td>
#       <td id="T_38677_row7_col1" class="data row7 col1" >1.037399</td>
#       <td id="T_38677_row7_col2" class="data row7 col2" >0.843677</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_38677_row8_col0" class="data row8 col0" >0.770722</td>
#       <td id="T_38677_row8_col1" class="data row8 col1" >1.131760</td>
#       <td id="T_38677_row8_col2" class="data row8 col2" >0.929681</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_38677_row9_col0" class="data row9 col0" >0.784735</td>
#       <td id="T_38677_row9_col1" class="data row9 col1" >1.146958</td>
#       <td id="T_38677_row9_col2" class="data row9 col2" >0.948637</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_38677_row10_col0" class="data row10 col0" >0.770834</td>
#       <td id="T_38677_row10_col1" class="data row10 col1" >1.131245</td>
#       <td id="T_38677_row10_col2" class="data row10 col2" >0.929541</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_38677_row11_col0" class="data row11 col0" >0.772424</td>
#       <td id="T_38677_row11_col1" class="data row11 col1" >1.133493</td>
#       <td id="T_38677_row11_col2" class="data row11 col2" >0.930762</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_38677_row12_col0" class="data row12 col0" >0.770794</td>
#       <td id="T_38677_row12_col1" class="data row12 col1" >1.131298</td>
#       <td id="T_38677_row12_col2" class="data row12 col2" >0.929579</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_38677_row13_col0" class="data row13 col0" >0.837687</td>
#       <td id="T_38677_row13_col1" class="data row13 col1" >1.255015</td>
#       <td id="T_38677_row13_col2" class="data row13 col2" >1.010406</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_38677_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_38677_row14_col0" class="data row14 col0" >1.779106</td>
#       <td id="T_38677_row14_col1" class="data row14 col1" >2.617822</td>
#       <td id="T_38677_row14_col2" class="data row14 col2" >2.160815</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_38677_row15_col0" class="data row15 col0" >1.954514</td>
#       <td id="T_38677_row15_col1" class="data row15 col1" >2.815737</td>
#       <td id="T_38677_row15_col2" class="data row15 col2" >2.321682</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row16" class="row_heading level1 row16" >GBT</th>
#       <td id="T_38677_row16_col0" class="data row16 col0" >2.002790</td>
#       <td id="T_38677_row16_col1" class="data row16 col1" >2.818502</td>
#       <td id="T_38677_row16_col2" class="data row16 col2" >2.357300</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row17" class="row_heading level1 row17" >PSBPM-FD</th>
#       <td id="T_38677_row17_col0" class="data row17 col0" >1.953946</td>
#       <td id="T_38677_row17_col1" class="data row17 col1" >2.816219</td>
#       <td id="T_38677_row17_col2" class="data row17 col2" >2.321361</td>
#     </tr>
#     <tr>
#       <th id="T_38677_level1_row18" class="row_heading level1 row18" >R
# <style type="text/css">
# #T_03109_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_03109_row1_col1, #T_03109_row2_col1, #T_03109_row3_col1, #T_03109_row4_col1, #T_03109_row5_col1 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_03109_row6_col1, #T_03109_row7_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_03109_row8_col1, #T_03109_row9_col1, #T_03109_row10_col1, #T_03109_row11_col1, #T_03109_row12_col1 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_03109_row13_col1 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_03109_row14_col1 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_03109_row15_col1, #T_03109_row16_col1, #T_03109_row17_col1, #T_03109_row18_col1, #T_03109_row19_col1 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_03109_row20_col1 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_03109_row21_col1, #T_03109_row27_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_03109_row22_col1, #T_03109_row24_col1, #T_03109_row26_col1 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_03109_row23_col1, #T_03109_row25_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_03109">
#   <caption>M=4 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03109_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_03109_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_03109_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03109_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_03109_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_03109_row0_col0" class="data row0 col0" >0.504291</td>
#       <td id="T_03109_row0_col1" class="data row0 col1" >0.716198</td>
#       <td id="T_03109_row0_col2" class="data row0 col2" >0.609848</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_03109_row1_col0" class="data row1 col0" >0.593291</td>
#       <td id="T_03109_row1_col1" class="data row1 col1" >0.829748</td>
#       <td id="T_03109_row1_col2" class="data row1 col2" >0.700603</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_03109_row2_col0" class="data row2 col0" >0.611639</td>
#       <td id="T_03109_row2_col1" class="data row2 col1" >0.846828</td>
#       <td id="T_03109_row2_col2" class="data row2 col2" >0.720916</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_03109_row3_col0" class="data row3 col0" >0.593530</td>
#       <td id="T_03109_row3_col1" class="data row3 col1" >0.829099</td>
#       <td id="T_03109_row3_col2" class="data row3 col2" >0.700438</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_03109_row4_col0" class="data row4 col0" >0.596520</td>
#       <td id="T_03109_row4_col1" class="data row4 col1" >0.830258</td>
#       <td id="T_03109_row4_col2" class="data row4 col2" >0.701860</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_03109_row5_col0" class="data row5 col0" >0.593450</td>
#       <td id="T_03109_row5_col1" class="data row5 col1" >0.829369</td>
#       <td id="T_03109_row5_col2" class="data row5 col2" >0.700457</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_03109_row6_col0" class="data row6 col0" >0.673799</td>
#       <td id="T_03109_row6_col1" class="data row6 col1" >0.954893</td>
#       <td id="T_03109_row6_col2" class="data row6 col2" >0.790947</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_03109_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_03109_row7_col0" class="data row7 col0" >0.666852</td>
#       <td id="T_03109_row7_col1" class="data row7 col1" >0.965581</td>
#       <td id="T_03109_row7_col2" class="data row7 col2" >0.808438</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_03109_row8_col0" class="data row8 col0" >0.770722</td>
#       <td id="T_03109_row8_col1" class="data row8 col1" >1.131760</td>
#       <td id="T_03109_row8_col2" class="data row8 col2" >0.929681</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_03109_row9_col0" class="data row9 col0" >0.787691</td>
#       <td id="T_03109_row9_col1" class="data row9 col1" >1.149808</td>
#       <td id="T_03109_row9_col2" class="data row9 col2" >0.950368</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_03109_row10_col0" class="data row10 col0" >0.770897</td>
#       <td id="T_03109_row10_col1" class="data row10 col1" >1.131374</td>
#       <td id="T_03109_row10_col2" class="data row10 col2" >0.929582</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_03109_row11_col0" class="data row11 col0" >0.772193</td>
#       <td id="T_03109_row11_col1" class="data row11 col1" >1.133345</td>
#       <td id="T_03109_row11_col2" class="data row11 col2" >0.930730</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_03109_row12_col0" class="data row12 col0" >0.770794</td>
#       <td id="T_03109_row12_col1" class="data row12 col1" >1.131298</td>
#       <td id="T_03109_row12_col2" class="data row12 col2" >0.929579</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_03109_row13_col0" class="data row13 col0" >0.860911</td>
#       <td id="T_03109_row13_col1" class="data row13 col1" >1.290904</td>
#       <td id="T_03109_row13_col2" class="data row13 col2" >1.029535</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_03109_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_03109_row14_col0" class="data row14 col0" >1.721116</td>
#       <td id="T_03109_row14_col1" class="data row14 col1" >2.553175</td>
#       <td id="T_03109_row14_col2" class="data row14 col2" >2.095388</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_03109_row15_col0" class="data row15 col0" >1.954514</td>
#       <td id="T_03109_row15_col1" class="data row15 col1" >2.815737</td>
#       <td id="T_03109_row15_col2" class="data row15 col2" >2.321682</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row16" class="row_heading level1 row16" >GBT</th>
#       <td id="T_03109_row16_col0" class="data row16 col0" >2.003829</td>
#       <td id="T_03109_row16_col1" class="data row16 col1" >2.826135</td>
#       <td id="T_03109_row16_col2" class="data row16 col2" >2.357739</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row17" class="row_heading level1 row17" >PSBPM-FD</th>
#       <td id="T_03109_row17_col0" class="data row17 col0" >1.954625</td>
#       <td id="T_03109_row17_col1" class="data row17 col1" >2.816197</td>
#       <td id="T_03109_row17_col2" class="data row17 col2" >2.321427</td>
#     </tr>
#     <tr>
#       <th id="T_03109_level1_row18" class="row_heading level1 row18" >R
# <style type="text/css">
# #T_bf546_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_bf546_row1_col1, #T_bf546_row3_col1, #T_bf546_row4_col1, #T_bf546_row5_col1 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_bf546_row2_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_bf546_row6_col1, #T_bf546_row7_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_bf546_row8_col1, #T_bf546_row10_col1, #T_bf546_row11_col1, #T_bf546_row12_col1 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_bf546_row9_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_bf546_row13_col1 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_bf546_row14_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_bf546_row15_col1, #T_bf546_row16_col1, #T_bf546_row17_col1, #T_bf546_row18_col1, #T_bf546_row19_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_bf546_row20_col1 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_bf546_row21_col1 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_bf546_row22_col1, #T_bf546_row24_col1, #T_bf546_row25_col1, #T_bf546_row26_col1 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_bf546_row23_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_bf546_row27_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bf546">
#   <caption>M=5 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf546_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_bf546_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_bf546_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf546_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_bf546_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_bf546_row0_col0" class="data row0 col0" >0.486563</td>
#       <td id="T_bf546_row0_col1" class="data row0 col1" >0.689332</td>
#       <td id="T_bf546_row0_col2" class="data row0 col2" >0.591111</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_bf546_row1_col0" class="data row1 col0" >0.593291</td>
#       <td id="T_bf546_row1_col1" class="data row1 col1" >0.829748</td>
#       <td id="T_bf546_row1_col2" class="data row1 col2" >0.700603</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_bf546_row2_col0" class="data row2 col0" >0.617811</td>
#       <td id="T_bf546_row2_col1" class="data row2 col1" >0.845496</td>
#       <td id="T_bf546_row2_col2" class="data row2 col2" >0.722872</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_bf546_row3_col0" class="data row3 col0" >0.593440</td>
#       <td id="T_bf546_row3_col1" class="data row3 col1" >0.828874</td>
#       <td id="T_bf546_row3_col2" class="data row3 col2" >0.700381</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_bf546_row4_col0" class="data row4 col0" >0.598077</td>
#       <td id="T_bf546_row4_col1" class="data row4 col1" >0.826432</td>
#       <td id="T_bf546_row4_col2" class="data row4 col2" >0.701064</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_bf546_row5_col0" class="data row5 col0" >0.593450</td>
#       <td id="T_bf546_row5_col1" class="data row5 col1" >0.829369</td>
#       <td id="T_bf546_row5_col2" class="data row5 col2" >0.700457</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_bf546_row6_col0" class="data row6 col0" >0.683769</td>
#       <td id="T_bf546_row6_col1" class="data row6 col1" >0.958907</td>
#       <td id="T_bf546_row6_col2" class="data row6 col2" >0.806634</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_bf546_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_bf546_row7_col0" class="data row7 col0" >0.639048</td>
#       <td id="T_bf546_row7_col1" class="data row7 col1" >0.939081</td>
#       <td id="T_bf546_row7_col2" class="data row7 col2" >0.783013</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_bf546_row8_col0" class="data row8 col0" >0.770722</td>
#       <td id="T_bf546_row8_col1" class="data row8 col1" >1.131760</td>
#       <td id="T_bf546_row8_col2" class="data row8 col2" >0.929681</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_bf546_row9_col0" class="data row9 col0" >0.792829</td>
#       <td id="T_bf546_row9_col1" class="data row9 col1" >1.155863</td>
#       <td id="T_bf546_row9_col2" class="data row9 col2" >0.951816</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_bf546_row10_col0" class="data row10 col0" >0.770821</td>
#       <td id="T_bf546_row10_col1" class="data row10 col1" >1.131334</td>
#       <td id="T_bf546_row10_col2" class="data row10 col2" >0.929498</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_bf546_row11_col0" class="data row11 col0" >0.774204</td>
#       <td id="T_bf546_row11_col1" class="data row11 col1" >1.132895</td>
#       <td id="T_bf546_row11_col2" class="data row11 col2" >0.930067</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_bf546_row12_col0" class="data row12 col0" >0.770794</td>
#       <td id="T_bf546_row12_col1" class="data row12 col1" >1.131298</td>
#       <td id="T_bf546_row12_col2" class="data row12 col2" >0.929579</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_bf546_row13_col0" class="data row13 col0" >0.868885</td>
#       <td id="T_bf546_row13_col1" class="data row13 col1" >1.302381</td>
#       <td id="T_bf546_row13_col2" class="data row13 col2" >1.048497</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_bf546_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_bf546_row14_col0" class="data row14 col0" >1.655242</td>
#       <td id="T_bf546_row14_col1" class="data row14 col1" >2.500163</td>
#       <td id="T_bf546_row14_col2" class="data row14 col2" >2.040341</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_bf546_row15_col0" class="data row15 col0" >1.954514</td>
#       <td id="T_bf546_row15_col1" class="data row15 col1" >2.815737</td>
#       <td id="T_bf546_row15_col2" class="data row15 col2" >2.321682</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row16" class="row_heading level1 row16" >GBT</th>
#       <td id="T_bf546_row16_col0" class="data row16 col0" >1.973407</td>
#       <td id="T_bf546_row16_col1" class="data row16 col1" >2.817805</td>
#       <td id="T_bf546_row16_col2" class="data row16 col2" >2.367558</td>
#     </tr>
#     <tr>
#       <th id="T_bf546_level1_row17" class="row_heading level1 row17" >PSBPM-FD</th>
#       <td id="T_bf546_row17_col0" class="data row17 col0" >1.955110</td>
#       <td id="T_bf546_row17_col1" class="data row17 col1" >2.816997</td>
#       <td id=
# <style type="text/css">
# #T_2c4c7_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2c4c7_row1_col1, #T_2c4c7_row3_col1, #T_2c4c7_row4_col1, #T_2c4c7_row5_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_2c4c7_row2_col1 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_2c4c7_row6_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_2c4c7_row7_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_2c4c7_row8_col1, #T_2c4c7_row9_col1, #T_2c4c7_row10_col1, #T_2c4c7_row11_col1, #T_2c4c7_row12_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_2c4c7_row13_col1 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_2c4c7_row14_col1 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_2c4c7_row15_col1, #T_2c4c7_row18_col1, #T_2c4c7_row19_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_2c4c7_row16_col1 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_2c4c7_row17_col1 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_2c4c7_row20_col1 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_2c4c7_row21_col1 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_2c4c7_row22_col1, #T_2c4c7_row24_col1, #T_2c4c7_row26_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_2c4c7_row23_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_2c4c7_row25_col1 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_2c4c7_row27_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2c4c7">
#   <caption>M=6 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c4c7_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_2c4c7_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_2c4c7_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c4c7_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_2c4c7_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_2c4c7_row0_col0" class="data row0 col0" >0.455294</td>
#       <td id="T_2c4c7_row0_col1" class="data row0 col1" >0.668692</td>
#       <td id="T_2c4c7_row0_col2" class="data row0 col2" >0.565211</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_2c4c7_row1_col0" class="data row1 col0" >0.593291</td>
#       <td id="T_2c4c7_row1_col1" class="data row1 col1" >0.829748</td>
#       <td id="T_2c4c7_row1_col2" class="data row1 col2" >0.700603</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_2c4c7_row2_col0" class="data row2 col0" >0.624738</td>
#       <td id="T_2c4c7_row2_col1" class="data row2 col1" >0.844781</td>
#       <td id="T_2c4c7_row2_col2" class="data row2 col2" >0.725777</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_2c4c7_row3_col0" class="data row3 col0" >0.593637</td>
#       <td id="T_2c4c7_row3_col1" class="data row3 col1" >0.829184</td>
#       <td id="T_2c4c7_row3_col2" class="data row3 col2" >0.700403</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_2c4c7_row4_col0" class="data row4 col0" >0.596961</td>
#       <td id="T_2c4c7_row4_col1" class="data row4 col1" >0.826450</td>
#       <td id="T_2c4c7_row4_col2" class="data row4 col2" >0.701308</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_2c4c7_row5_col0" class="data row5 col0" >0.593450</td>
#       <td id="T_2c4c7_row5_col1" class="data row5 col1" >0.829369</td>
#       <td id="T_2c4c7_row5_col2" class="data row5 col2" >0.700457</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_2c4c7_row6_col0" class="data row6 col0" >0.696287</td>
#       <td id="T_2c4c7_row6_col1" class="data row6 col1" >0.983434</td>
#       <td id="T_2c4c7_row6_col2" class="data row6 col2" >0.825436</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_2c4c7_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_2c4c7_row7_col0" class="data row7 col0" >0.591116</td>
#       <td id="T_2c4c7_row7_col1" class="data row7 col1" >0.908058</td>
#       <td id="T_2c4c7_row7_col2" class="data row7 col2" >0.747986</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_2c4c7_row8_col0" class="data row8 col0" >0.770722</td>
#       <td id="T_2c4c7_row8_col1" class="data row8 col1" >1.131760</td>
#       <td id="T_2c4c7_row8_col2" class="data row8 col2" >0.929681</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_2c4c7_row9_col0" class="data row9 col0" >0.806826</td>
#       <td id="T_2c4c7_row9_col1" class="data row9 col1" >1.153734</td>
#       <td id="T_2c4c7_row9_col2" class="data row9 col2" >0.956607</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_2c4c7_row10_col0" class="data row10 col0" >0.771078</td>
#       <td id="T_2c4c7_row10_col1" class="data row10 col1" >1.131266</td>
#       <td id="T_2c4c7_row10_col2" class="data row10 col2" >0.929525</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_2c4c7_row11_col0" class="data row11 col0" >0.773281</td>
#       <td id="T_2c4c7_row11_col1" class="data row11 col1" >1.132544</td>
#       <td id="T_2c4c7_row11_col2" class="data row11 col2" >0.930565</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_2c4c7_row12_col0" class="data row12 col0" >0.770794</td>
#       <td id="T_2c4c7_row12_col1" class="data row12 col1" >1.131298</td>
#       <td id="T_2c4c7_row12_col2" class="data row12 col2" >0.929579</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_2c4c7_row13_col0" class="data row13 col0" >0.891190</td>
#       <td id="T_2c4c7_row13_col1" class="data row13 col1" >1.333553</td>
#       <td id="T_2c4c7_row13_col2" class="data row13 col2" >1.073474</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_2c4c7_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_2c4c7_row14_col0" class="data row14 col0" >1.547537</td>
#       <td id="T_2c4c7_row14_col1" class="data row14 col1" >2.439604</td>
#       <td id="T_2c4c7_row14_col2" class="data row14 col2" >1.976793</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_2c4c7_row15_col0" class="data row15 col0" >1.954514</td>
#       <td id="T_2c4c7_row15_col1" class="data row15 col1" >2.815737</td>
#       <td id="T_2c4c7_row15_col2" class="data row15 col2" >2.321682</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row16" class="row_heading level1 row16" >GBT</th>
#       <td id="T_2c4c7_row16_col0" class="data row16 col0" >1.991581</td>
#       <td id="T_2c4c7_row16_col1" class="data row16 col1" >2.862186</td>
#       <td id="T_2c4c7_row16_col2" class="data row16 col2" >2.376550</td>
#     </tr>
#     <tr>
#       <th id="T_2c4c7_level1_row17" class="row_heading level1 row17" >PSBPM-FD</th>
# ...
# #T_7477e_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_7477e_row1_col1, #T_7477e_row3_col1, #T_7477e_row4_col1, #T_7477e_row5_col1 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_7477e_row2_col1, #T_7477e_row7_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_7477e_row6_col1 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_7477e_row8_col1, #T_7477e_row9_col1, #T_7477e_row10_col1, #T_7477e_row11_col1, #T_7477e_row12_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_7477e_row13_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_7477e_row14_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_7477e_row15_col1, #T_7477e_row17_col1, #T_7477e_row18_col1, #T_7477e_row19_col1 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_7477e_row16_col1 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_7477e_row20_col1 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_7477e_row21_col1 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_7477e_row22_col1, #T_7477e_row25_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_7477e_row23_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_7477e_row24_col1, #T_7477e_row26_col1 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_7477e_row27_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7477e">
#   <caption>M=7 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7477e_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_7477e_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_7477e_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7477e_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_7477e_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_7477e_row0_col0" class="data row0 col0" >0.440439</td>
#       <td id="T_7477e_row0_col1" class="data row0 col1" >0.634055</td>
#       <td id="T_7477e_row0_col2" class="data row0 col2" >0.537557</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_7477e_row1_col0" class="data row1 col0" >0.593291</td>
#       <td id="T_7477e_row1_col1" class="data row1 col1" >0.829748</td>
#       <td id="T_7477e_row1_col2" class="data row1 col2" >0.700603</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_7477e_row2_col0" class="data row2 col0" >0.613409</td>
#       <td id="T_7477e_row2_col1" class="data row2 col1" >0.854961</td>
#       <td id="T_7477e_row2_col2" class="data row2 col2" >0.727819</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_7477e_row3_col0" class="data row3 col0" >0.593777</td>
#       <td id="T_7477e_row3_col1" class="data row3 col1" >0.829137</td>
#       <td id="T_7477e_row3_col2" class="data row3 col2" >0.700436</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_7477e_row4_col0" class="data row4 col0" >0.595609</td>
#       <td id="T_7477e_row4_col1" class="data row4 col1" >0.828886</td>
#       <td id="T_7477e_row4_col2" class="data row4 col2" >0.701485</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_7477e_row5_col0" class="data row5 col0" >0.593450</td>
#       <td id="T_7477e_row5_col1" class="data row5 col1" >0.829369</td>
#       <td id="T_7477e_row5_col2" class="data row5 col2" >0.700457</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_7477e_row6_col0" class="data row6 col0" >0.714608</td>
#       <td id="T_7477e_row6_col1" class="data row6 col1" >1.006710</td>
#       <td id="T_7477e_row6_col2" class="data row6 col2" >0.847658</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_7477e_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_7477e_row7_col0" class="data row7 col0" >0.571469</td>
#       <td id="T_7477e_row7_col1" class="data row7 col1" >0.861747</td>
#       <td id="T_7477e_row7_col2" class="data row7 col2" >0.713109</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_7477e_row8_col0" class="data row8 col0" >0.770722</td>
#       <td id="T_7477e_row8_col1" class="data row8 col1" >1.131760</td>
#       <td id="T_7477e_row8_col2" class="data row8 col2" >0.929681</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_7477e_row9_col0" class="data row9 col0" >0.794717</td>
#       <td id="T_7477e_row9_col1" class="data row9 col1" >1.162707</td>
#       <td id="T_7477e_row9_col2" class="data row9 col2" >0.960838</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_7477e_row10_col0" class="data row10 col0" >0.771253</td>
#       <td id="T_7477e_row10_col1" class="data row10 col1" >1.131296</td>
#       <td id="T_7477e_row10_col2" class="data row10 col2" >0.929570</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_7477e_row11_col0" class="data row11 col0" >0.772695</td>
#       <td id="T_7477e_row11_col1" class="data row11 col1" >1.132959</td>
#       <td id="T_7477e_row11_col2" class="data row11 col2" >0.930899</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_7477e_row12_col0" class="data row12 col0" >0.770794</td>
#       <td id="T_7477e_row12_col1" class="data row12 col1" >1.131298</td>
#       <td id="T_7477e_row12_col2" class="data row12 col2" >0.929579</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_7477e_row13_col0" class="data row13 col0" >0.906071</td>
#       <td id="T_7477e_row13_col1" class="data row13 col1" >1.362880</td>
#       <td id="T_7477e_row13_col2" class="data row13 col2" >1.100351</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_7477e_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_7477e_row14_col0" class="data row14 col0" >1.557094</td>
#       <td id="T_7477e_row14_col1" class="data row14 col1" >2.384470</td>
#       <td id="T_7477e_row14_col2" class="data row14 col2" >1.931890</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_7477e_row15_col0" class="data row15 col0" >1.954514</td>
#       <td id="T_7477e_row15_col1" class="data row15 col1" >2.815737</td>
#       <td id="T_7477e_row15_col2" class="data row15 col2" >2.321682</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row16" class="row_heading level1 row16" >GBT</th>
#       <td id="T_7477e_row16_col0" class="data row16 col0" >2.012916</td>
#       <td id="T_7477e_row16_col1" class="data row16 col1" >2.889683</td>
#       <td id="T_7477e_row16_col2" class="data row16 col2" >2.382636</td>
#     </tr>
#     <tr>
#       <th id="T_7477e_level1_row17" class="row_heading level1 row17" >PSBPM-FD</th>
#       <td id="T_7477e_row17_col0" class="data row17 col0" >1.956603</td>
#       <td id="T_7477e_row17_col1" cl
# <style type="text/css">
# #T_cb638_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_cb638_row1_col1, #T_cb638_row3_col1, #T_cb638_row4_col1, #T_cb638_row5_col1, #T_cb638_row7_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_cb638_row2_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_cb638_row6_col1 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_cb638_row8_col1, #T_cb638_row10_col1, #T_cb638_row11_col1, #T_cb638_row12_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_cb638_row9_col1 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_cb638_row13_col1 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_cb638_row14_col1 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_cb638_row15_col1, #T_cb638_row17_col1, #T_cb638_row18_col1, #T_cb638_row19_col1 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_cb638_row16_col1 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_cb638_row20_col1 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_cb638_row21_col1 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_cb638_row22_col1, #T_cb638_row24_col1, #T_cb638_row25_col1, #T_cb638_row26_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_cb638_row23_col1 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_cb638_row27_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cb638">
#   <caption>M=8 · Bloque A en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb638_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_cb638_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_cb638_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb638_level0_row0" class="row_heading level0 row0" rowspan="7">1. MAE  (L^1)</th>
#       <th id="T_cb638_level1_row0" class="row_heading level1 row0" >(truncamiento FPCA)</th>
#       <td id="T_cb638_row0_col0" class="data row0 col0" >0.419471</td>
#       <td id="T_cb638_row0_col1" class="data row0 col1" >0.608619</td>
#       <td id="T_cb638_row0_col2" class="data row0 col2" >0.513731</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row1" class="row_heading level1 row1" >FAR</th>
#       <td id="T_cb638_row1_col0" class="data row1 col0" >0.593291</td>
#       <td id="T_cb638_row1_col1" class="data row1 col1" >0.829748</td>
#       <td id="T_cb638_row1_col2" class="data row1 col2" >0.700603</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row2" class="row_heading level1 row2" >GBT</th>
#       <td id="T_cb638_row2_col0" class="data row2 col0" >0.617871</td>
#       <td id="T_cb638_row2_col1" class="data row2 col1" >0.858735</td>
#       <td id="T_cb638_row2_col2" class="data row2 col2" >0.729923</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row3" class="row_heading level1 row3" >PSBPM-FD</th>
#       <td id="T_cb638_row3_col0" class="data row3 col0" >0.593756</td>
#       <td id="T_cb638_row3_col1" class="data row3 col1" >0.829149</td>
#       <td id="T_cb638_row3_col2" class="data row3 col2" >0.700395</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row4" class="row_heading level1 row4" >RF</th>
#       <td id="T_cb638_row4_col0" class="data row4 col0" >0.593321</td>
#       <td id="T_cb638_row4_col1" class="data row4 col1" >0.828499</td>
#       <td id="T_cb638_row4_col2" class="data row4 col2" >0.701366</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row5" class="row_heading level1 row5" >media</th>
#       <td id="T_cb638_row5_col0" class="data row5 col0" >0.593450</td>
#       <td id="T_cb638_row5_col1" class="data row5 col1" >0.829369</td>
#       <td id="T_cb638_row5_col2" class="data row5 col2" >0.700457</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row6" class="row_heading level1 row6" >persistencia</th>
#       <td id="T_cb638_row6_col0" class="data row6 col0" >0.721336</td>
#       <td id="T_cb638_row6_col1" class="data row6 col1" >1.021812</td>
#       <td id="T_cb638_row6_col2" class="data row6 col2" >0.861315</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level0_row7" class="row_heading level0 row7" rowspan="7">2. RMSE (L^2)</th>
#       <th id="T_cb638_level1_row7" class="row_heading level1 row7" >(truncamiento FPCA)</th>
#       <td id="T_cb638_row7_col0" class="data row7 col0" >0.549809</td>
#       <td id="T_cb638_row7_col1" class="data row7 col1" >0.830887</td>
#       <td id="T_cb638_row7_col2" class="data row7 col2" >0.685138</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row8" class="row_heading level1 row8" >FAR</th>
#       <td id="T_cb638_row8_col0" class="data row8 col0" >0.770722</td>
#       <td id="T_cb638_row8_col1" class="data row8 col1" >1.131760</td>
#       <td id="T_cb638_row8_col2" class="data row8 col2" >0.929681</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row9" class="row_heading level1 row9" >GBT</th>
#       <td id="T_cb638_row9_col0" class="data row9 col0" >0.799725</td>
#       <td id="T_cb638_row9_col1" class="data row9 col1" >1.166077</td>
#       <td id="T_cb638_row9_col2" class="data row9 col2" >0.962926</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row10" class="row_heading level1 row10" >PSBPM-FD</th>
#       <td id="T_cb638_row10_col0" class="data row10 col0" >0.771202</td>
#       <td id="T_cb638_row10_col1" class="data row10 col1" >1.131247</td>
#       <td id="T_cb638_row10_col2" class="data row10 col2" >0.929519</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row11" class="row_heading level1 row11" >RF</th>
#       <td id="T_cb638_row11_col0" class="data row11 col0" >0.770403</td>
#       <td id="T_cb638_row11_col1" class="data row11 col1" >1.134333</td>
#       <td id="T_cb638_row11_col2" class="data row11 col2" >0.930634</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row12" class="row_heading level1 row12" >media</th>
#       <td id="T_cb638_row12_col0" class="data row12 col0" >0.770794</td>
#       <td id="T_cb638_row12_col1" class="data row12 col1" >1.131298</td>
#       <td id="T_cb638_row12_col2" class="data row12 col2" >0.929579</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row13" class="row_heading level1 row13" >persistencia</th>
#       <td id="T_cb638_row13_col0" class="data row13 col0" >0.914693</td>
#       <td id="T_cb638_row13_col1" class="data row13 col1" >1.371541</td>
#       <td id="T_cb638_row13_col2" class="data row13 col2" >1.117523</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level0_row14" class="row_heading level0 row14" rowspan="7">3. E_max promedio por curva</th>
#       <th id="T_cb638_level1_row14" class="row_heading level1 row14" >(truncamiento FPCA)</th>
#       <td id="T_cb638_row14_col0" class="data row14 col0" >1.551269</td>
#       <td id="T_cb638_row14_col1" class="data row14 col1" >2.338143</td>
#       <td id="T_cb638_row14_col2" class="data row14 col2" >1.901538</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row15" class="row_heading level1 row15" >FAR</th>
#       <td id="T_cb638_row15_col0" class="data row15 col0" >1.954514</td>
#       <td id="T_cb638_row15_col1" class="data row15 col1" >2.815737</td>
#       <td id="T_cb638_row15_col2" class="data row15 col2" >2.321682</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row16" class="row_heading level1 row16" >GBT</th>
#       <td id="T_cb638_row16_col0" class="data row16 col0" >2.026033</td>
#       <td id="T_cb638_row16_col1" class="data row16 col1" >2.860291</td>
#       <td id="T_cb638_row16_col2" class="data row16 col2" >2.380556</td>
#     </tr>
#     <tr>
#       <th id="T_cb638_level1_row17" class="row_heading level1 row17" >PSBPM-FD</th>
#       <td id="T_cb638_row17_col0" class="data row17 col0" >1.956298</td>
#       <td id="T_cb638_row17_col1" cl

# %%
# Bloque B: min / max / promedio por banda y metrica.
resB = []
for M in EST:
    e = EST[M]
    vb = e["ventana_B"]
    limpio = vb[~vb["cruza_T0"]]
    for etiqueta, col in METRICAS_B:
        g = limpio.groupby(["banda", "bloque"])[col].agg(["min", "max", "mean"])
        for (banda, bloque), r in g.iterrows():
            resB.append({"M": M, "metrica": etiqueta, "columna": col,
                         "banda": banda, "bloque": bloque,
                         "minimo": float(r["min"]), "maximo": float(r["max"]),
                         "promedio": float(r["mean"])})
resumen_B = pd.DataFrame(resB)
resumen_B.to_csv(PATH_BARRIDO / "99_resumen_bloqueB_min_max_prom.csv", index=False)

for M in EST:
    sub = (resumen_B[(resumen_B.M == M) & (resumen_B.bloque == "test")]
           .set_index(["metrica", "banda"])[["minimo", "maximo", "promedio"]])
    display(sub.style.format("{:.4f}")
            .set_caption(f"M={M} · Bloque B en el TEST · mínimo / máximo / "
                         f"promedio sobre las ventanas (w={W_COMP}) · "
                         f"nivel nominal {NIVEL_IC:.0%}"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_fa976">
#   <caption>M=1 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa976_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_fa976_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_fa976_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa976_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_fa976_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_fa976_row0_col0" class="data row0 col0" >3.5016</td>
#       <td id="T_fa976_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_fa976_row0_col2" class="data row0 col2" >3.5016</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_fa976_row1_col0" class="data row1 col0" >3.5017</td>
#       <td id="T_fa976_row1_col1" class="data row1 col1" >3.5017</td>
#       <td id="T_fa976_row1_col2" class="data row1 col2" >3.5017</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_fa976_row2_col0" class="data row2 col0" >0.8594</td>
#       <td id="T_fa976_row2_col1" class="data row2 col1" >0.8896</td>
#       <td id="T_fa976_row2_col2" class="data row2 col2" >0.8769</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_fa976_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_fa976_row3_col0" class="data row3 col0" >0.9013</td>
#       <td id="T_fa976_row3_col1" class="data row3 col1" >0.9693</td>
#       <td id="T_fa976_row3_col2" class="data row3 col2" >0.9373</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_fa976_row4_col0" class="data row4 col0" >0.9009</td>
#       <td id="T_fa976_row4_col1" class="data row4 col1" >0.9698</td>
#       <td id="T_fa976_row4_col2" class="data row4 col2" >0.9374</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_fa976_row5_col0" class="data row5 col0" >0.3458</td>
#       <td id="T_fa976_row5_col1" class="data row5 col1" >0.4493</td>
#       <td id="T_fa976_row5_col2" class="data row5 col2" >0.3984</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_fa976_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_fa976_row6_col0" class="data row6 col0" >0.1000</td>
#       <td id="T_fa976_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_fa976_row6_col2" class="data row6 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_fa976_row7_col0" class="data row7 col0" >0.1000</td>
#       <td id="T_fa976_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_fa976_row7_col2" class="data row7 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_fa976_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_fa976_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_fa976_row8_col2" class="data row8 col2" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_fa976_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_fa976_row9_col0" class="data row9 col0" >3.9530</td>
#       <td id="T_fa976_row9_col1" class="data row9 col1" >6.9781</td>
#       <td id="T_fa976_row9_col2" class="data row9 col2" >4.9323</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_fa976_row10_col0" class="data row10 col0" >3.9531</td>
#       <td id="T_fa976_row10_col1" class="data row10 col1" >6.9753</td>
#       <td id="T_fa976_row10_col2" class="data row10 col2" >4.9326</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_fa976_row11_col0" class="data row11 col0" >12.3038</td>
#       <td id="T_fa976_row11_col1" class="data row11 col1" >20.3720</td>
#       <td id="T_fa976_row11_col2" class="data row11 col2" >15.9723</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_fa976_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_fa976_row12_col0" class="data row12 col0" >14.4686</td>
#       <td id="T_fa976_row12_col1" class="data row12 col1" >44.8651</td>
#       <td id="T_fa976_row12_col2" class="data row12 col2" >27.1192</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_fa976_row13_col0" class="data row13 col0" >14.4556</td>
#       <td id="T_fa976_row13_col1" class="data row13 col1" >44.8873</td>
#       <td id="T_fa976_row13_col2" class="data row13 col2" >27.1299</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_fa976_row14_col0" class="data row14 col0" >66.5420</td>
#       <td id="T_fa976_row14_col1" class="data row14 col1" >99.8534</td>
#       <td id="T_fa976_row14_col2" class="data row14 col2" >79.9319</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_fa976_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_fa976_row15_col0" class="data row15 col0" >55.9471</td>
#       <td id="T_fa976_row15_col1" class="data row15 col1" >272.7597</td>
#       <td id="T_fa976_row15_col2" class="data row15 col2" >140.3202</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_fa976_row16_col0" class="data row16 col0" >55.7963</td>
#       <td id="T_fa976_row16_col1" class="data row16 col1" >272.7164</td>
#       <td id="T_fa976_row16_col2" class="data row16 col2" >140.3722</td>
#     </tr>
#     <tr>
#       <th id="T_fa976_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_fa976_row17_col0" class="data row17 col0" >113.2371</td>
#       <td id="T_fa976_row17_col1" class="data row17 col1" >356.7841</td>
#       <td id="T_fa976_row17_col2" class="data row17 col2" >195.0440</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d04b5">
#   <caption>M=2 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d04b5_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_d04b5_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_d04b5_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d04b5_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_d04b5_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_d04b5_row0_col0" class="data row0 col0" >3.5016</td>
#       <td id="T_d04b5_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_d04b5_row0_col2" class="data row0 col2" >3.5016</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d04b5_row1_col0" class="data row1 col0" >3.5017</td>
#       <td id="T_d04b5_row1_col1" class="data row1 col1" >3.5017</td>
#       <td id="T_d04b5_row1_col2" class="data row1 col2" >3.5017</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d04b5_row2_col0" class="data row2 col0" >1.2225</td>
#       <td id="T_d04b5_row2_col1" class="data row2 col1" >1.2482</td>
#       <td id="T_d04b5_row2_col2" class="data row2 col2" >1.2332</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_d04b5_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_d04b5_row3_col0" class="data row3 col0" >0.9013</td>
#       <td id="T_d04b5_row3_col1" class="data row3 col1" >0.9693</td>
#       <td id="T_d04b5_row3_col2" class="data row3 col2" >0.9373</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d04b5_row4_col0" class="data row4 col0" >0.9009</td>
#       <td id="T_d04b5_row4_col1" class="data row4 col1" >0.9698</td>
#       <td id="T_d04b5_row4_col2" class="data row4 col2" >0.9375</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d04b5_row5_col0" class="data row5 col0" >0.4578</td>
#       <td id="T_d04b5_row5_col1" class="data row5 col1" >0.5711</td>
#       <td id="T_d04b5_row5_col2" class="data row5 col2" >0.5167</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_d04b5_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_d04b5_row6_col0" class="data row6 col0" >0.1000</td>
#       <td id="T_d04b5_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_d04b5_row6_col2" class="data row6 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d04b5_row7_col0" class="data row7 col0" >0.1000</td>
#       <td id="T_d04b5_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_d04b5_row7_col2" class="data row7 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d04b5_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_d04b5_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_d04b5_row8_col2" class="data row8 col2" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_d04b5_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_d04b5_row9_col0" class="data row9 col0" >3.9530</td>
#       <td id="T_d04b5_row9_col1" class="data row9 col1" >6.9781</td>
#       <td id="T_d04b5_row9_col2" class="data row9 col2" >4.9323</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d04b5_row10_col0" class="data row10 col0" >3.9524</td>
#       <td id="T_d04b5_row10_col1" class="data row10 col1" >6.9767</td>
#       <td id="T_d04b5_row10_col2" class="data row10 col2" >4.9326</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d04b5_row11_col0" class="data row11 col0" >9.8944</td>
#       <td id="T_d04b5_row11_col1" class="data row11 col1" >16.9982</td>
#       <td id="T_d04b5_row11_col2" class="data row11 col2" >13.0617</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_d04b5_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_d04b5_row12_col0" class="data row12 col0" >14.4686</td>
#       <td id="T_d04b5_row12_col1" class="data row12 col1" >44.8651</td>
#       <td id="T_d04b5_row12_col2" class="data row12 col2" >27.1192</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d04b5_row13_col0" class="data row13 col0" >14.4509</td>
#       <td id="T_d04b5_row13_col1" class="data row13 col1" >44.8741</td>
#       <td id="T_d04b5_row13_col2" class="data row13 col2" >27.1292</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d04b5_row14_col0" class="data row14 col0" >61.8626</td>
#       <td id="T_d04b5_row14_col1" class="data row14 col1" >92.7489</td>
#       <td id="T_d04b5_row14_col2" class="data row14 col2" >74.8224</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_d04b5_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_d04b5_row15_col0" class="data row15 col0" >55.9471</td>
#       <td id="T_d04b5_row15_col1" class="data row15 col1" >272.7597</td>
#       <td id="T_d04b5_row15_col2" class="data row15 col2" >140.3202</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_d04b5_row16_col0" class="data row16 col0" >55.7984</td>
#       <td id="T_d04b5_row16_col1" class="data row16 col1" >272.7172</td>
#       <td id="T_d04b5_row16_col2" class="data row16 col2" >140.3595</td>
#     </tr>
#     <tr>
#       <th id="T_d04b5_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_d04b5_row17_col0" class="data row17 col0" >113.1462</td>
#       <td id="T_d04b5_row17_col1" class="data row17 col1" >356.6614</td>
#       <td id="T_d04b5_row17_col2" class="data row17 col2" >191.8229</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_13485">
#   <caption>M=3 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13485_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_13485_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_13485_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13485_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_13485_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_13485_row0_col0" class="data row0 col0" >3.5016</td>
#       <td id="T_13485_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_13485_row0_col2" class="data row0 col2" >3.5016</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_13485_row1_col0" class="data row1 col0" >3.5014</td>
#       <td id="T_13485_row1_col1" class="data row1 col1" >3.5014</td>
#       <td id="T_13485_row1_col2" class="data row1 col2" >3.5014</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_13485_row2_col0" class="data row2 col0" >1.5642</td>
#       <td id="T_13485_row2_col1" class="data row2 col1" >1.5959</td>
#       <td id="T_13485_row2_col2" class="data row2 col2" >1.5811</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_13485_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_13485_row3_col0" class="data row3 col0" >0.9013</td>
#       <td id="T_13485_row3_col1" class="data row3 col1" >0.9693</td>
#       <td id="T_13485_row3_col2" class="data row3 col2" >0.9373</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_13485_row4_col0" class="data row4 col0" >0.9013</td>
#       <td id="T_13485_row4_col1" class="data row4 col1" >0.9698</td>
#       <td id="T_13485_row4_col2" class="data row4 col2" >0.9375</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_13485_row5_col0" class="data row5 col0" >0.5578</td>
#       <td id="T_13485_row5_col1" class="data row5 col1" >0.7000</td>
#       <td id="T_13485_row5_col2" class="data row5 col2" >0.6351</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_13485_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_13485_row6_col0" class="data row6 col0" >0.1000</td>
#       <td id="T_13485_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_13485_row6_col2" class="data row6 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_13485_row7_col0" class="data row7 col0" >0.1000</td>
#       <td id="T_13485_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_13485_row7_col2" class="data row7 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_13485_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_13485_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_13485_row8_col2" class="data row8 col2" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_13485_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_13485_row9_col0" class="data row9 col0" >3.9530</td>
#       <td id="T_13485_row9_col1" class="data row9 col1" >6.9781</td>
#       <td id="T_13485_row9_col2" class="data row9 col2" >4.9323</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_13485_row10_col0" class="data row10 col0" >3.9518</td>
#       <td id="T_13485_row10_col1" class="data row10 col1" >6.9764</td>
#       <td id="T_13485_row10_col2" class="data row10 col2" >4.9322</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_13485_row11_col0" class="data row11 col0" >7.3238</td>
#       <td id="T_13485_row11_col1" class="data row11 col1" >13.6851</td>
#       <td id="T_13485_row11_col2" class="data row11 col2" >10.1627</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_13485_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_13485_row12_col0" class="data row12 col0" >14.4686</td>
#       <td id="T_13485_row12_col1" class="data row12 col1" >44.8651</td>
#       <td id="T_13485_row12_col2" class="data row12 col2" >27.1192</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_13485_row13_col0" class="data row13 col0" >14.4459</td>
#       <td id="T_13485_row13_col1" class="data row13 col1" >44.8655</td>
#       <td id="T_13485_row13_col2" class="data row13 col2" >27.1247</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_13485_row14_col0" class="data row14 col0" >56.3644</td>
#       <td id="T_13485_row14_col1" class="data row14 col1" >86.8879</td>
#       <td id="T_13485_row14_col2" class="data row14 col2" >68.8990</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_13485_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_13485_row15_col0" class="data row15 col0" >55.9471</td>
#       <td id="T_13485_row15_col1" class="data row15 col1" >272.7597</td>
#       <td id="T_13485_row15_col2" class="data row15 col2" >140.3202</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_13485_row16_col0" class="data row16 col0" >55.6785</td>
#       <td id="T_13485_row16_col1" class="data row16 col1" >272.6557</td>
#       <td id="T_13485_row16_col2" class="data row16 col2" >140.3382</td>
#     </tr>
#     <tr>
#       <th id="T_13485_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_13485_row17_col0" class="data row17 col0" >100.7767</td>
#       <td id="T_13485_row17_col1" class="data row17 col1" >350.5504</td>
#       <td id="T_13485_row17_col2" class="data row17 col2" >184.5165</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_52d9e">
#   <caption>M=4 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52d9e_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_52d9e_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_52d9e_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52d9e_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_52d9e_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_52d9e_row0_col0" class="data row0 col0" >3.5016</td>
#       <td id="T_52d9e_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_52d9e_row0_col2" class="data row0 col2" >3.5016</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_52d9e_row1_col0" class="data row1 col0" >3.5014</td>
#       <td id="T_52d9e_row1_col1" class="data row1 col1" >3.5014</td>
#       <td id="T_52d9e_row1_col2" class="data row1 col2" >3.5014</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_52d9e_row2_col0" class="data row2 col0" >1.8041</td>
#       <td id="T_52d9e_row2_col1" class="data row2 col1" >1.8318</td>
#       <td id="T_52d9e_row2_col2" class="data row2 col2" >1.8209</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_52d9e_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_52d9e_row3_col0" class="data row3 col0" >0.9013</td>
#       <td id="T_52d9e_row3_col1" class="data row3 col1" >0.9693</td>
#       <td id="T_52d9e_row3_col2" class="data row3 col2" >0.9373</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_52d9e_row4_col0" class="data row4 col0" >0.9013</td>
#       <td id="T_52d9e_row4_col1" class="data row4 col1" >0.9698</td>
#       <td id="T_52d9e_row4_col2" class="data row4 col2" >0.9374</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_52d9e_row5_col0" class="data row5 col0" >0.6258</td>
#       <td id="T_52d9e_row5_col1" class="data row5 col1" >0.7711</td>
#       <td id="T_52d9e_row5_col2" class="data row5 col2" >0.6987</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_52d9e_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_52d9e_row6_col0" class="data row6 col0" >0.1000</td>
#       <td id="T_52d9e_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_52d9e_row6_col2" class="data row6 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_52d9e_row7_col0" class="data row7 col0" >0.1000</td>
#       <td id="T_52d9e_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_52d9e_row7_col2" class="data row7 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_52d9e_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_52d9e_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_52d9e_row8_col2" class="data row8 col2" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_52d9e_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_52d9e_row9_col0" class="data row9 col0" >3.9530</td>
#       <td id="T_52d9e_row9_col1" class="data row9 col1" >6.9781</td>
#       <td id="T_52d9e_row9_col2" class="data row9 col2" >4.9323</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_52d9e_row10_col0" class="data row10 col0" >3.9520</td>
#       <td id="T_52d9e_row10_col1" class="data row10 col1" >6.9774</td>
#       <td id="T_52d9e_row10_col2" class="data row10 col2" >4.9324</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_52d9e_row11_col0" class="data row11 col0" >6.0290</td>
#       <td id="T_52d9e_row11_col1" class="data row11 col1" >12.0117</td>
#       <td id="T_52d9e_row11_col2" class="data row11 col2" >8.8271</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_52d9e_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_52d9e_row12_col0" class="data row12 col0" >14.4686</td>
#       <td id="T_52d9e_row12_col1" class="data row12 col1" >44.8651</td>
#       <td id="T_52d9e_row12_col2" class="data row12 col2" >27.1192</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_52d9e_row13_col0" class="data row13 col0" >14.4500</td>
#       <td id="T_52d9e_row13_col1" class="data row13 col1" >44.8718</td>
#       <td id="T_52d9e_row13_col2" class="data row13 col2" >27.1265</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_52d9e_row14_col0" class="data row14 col0" >51.3958</td>
#       <td id="T_52d9e_row14_col1" class="data row14 col1" >85.3190</td>
#       <td id="T_52d9e_row14_col2" class="data row14 col2" >65.8571</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_52d9e_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_52d9e_row15_col0" class="data row15 col0" >55.9471</td>
#       <td id="T_52d9e_row15_col1" class="data row15 col1" >272.7597</td>
#       <td id="T_52d9e_row15_col2" class="data row15 col2" >140.3202</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_52d9e_row16_col0" class="data row16 col0" >55.7125</td>
#       <td id="T_52d9e_row16_col1" class="data row16 col1" >272.6567</td>
#       <td id="T_52d9e_row16_col2" class="data row16 col2" >140.3239</td>
#     </tr>
#     <tr>
#       <th id="T_52d9e_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_52d9e_row17_col0" class="data row17 col0" >100.0658</td>
#       <td id="T_52d9e_row17_col1" class="data row17 col1" >350.4157</td>
#       <td id="T_52d9e_row17_col2" class="data row17 col2" >178.9115</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_4d588">
#   <caption>M=5 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d588_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_4d588_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_4d588_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d588_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_4d588_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_4d588_row0_col0" class="data row0 col0" >3.5016</td>
#       <td id="T_4d588_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_4d588_row0_col2" class="data row0 col2" >3.5016</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_4d588_row1_col0" class="data row1 col0" >3.5012</td>
#       <td id="T_4d588_row1_col1" class="data row1 col1" >3.5012</td>
#       <td id="T_4d588_row1_col2" class="data row1 col2" >3.5012</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_4d588_row2_col0" class="data row2 col0" >2.0181</td>
#       <td id="T_4d588_row2_col1" class="data row2 col1" >2.0434</td>
#       <td id="T_4d588_row2_col2" class="data row2 col2" >2.0307</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_4d588_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_4d588_row3_col0" class="data row3 col0" >0.9013</td>
#       <td id="T_4d588_row3_col1" class="data row3 col1" >0.9693</td>
#       <td id="T_4d588_row3_col2" class="data row3 col2" >0.9373</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_4d588_row4_col0" class="data row4 col0" >0.9018</td>
#       <td id="T_4d588_row4_col1" class="data row4 col1" >0.9693</td>
#       <td id="T_4d588_row4_col2" class="data row4 col2" >0.9375</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_4d588_row5_col0" class="data row5 col0" >0.6791</td>
#       <td id="T_4d588_row5_col1" class="data row5 col1" >0.8182</td>
#       <td id="T_4d588_row5_col2" class="data row5 col2" >0.7518</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_4d588_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_4d588_row6_col0" class="data row6 col0" >0.1000</td>
#       <td id="T_4d588_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_4d588_row6_col2" class="data row6 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_4d588_row7_col0" class="data row7 col0" >0.1000</td>
#       <td id="T_4d588_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_4d588_row7_col2" class="data row7 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_4d588_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_4d588_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_4d588_row8_col2" class="data row8 col2" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_4d588_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_4d588_row9_col0" class="data row9 col0" >3.9530</td>
#       <td id="T_4d588_row9_col1" class="data row9 col1" >6.9781</td>
#       <td id="T_4d588_row9_col2" class="data row9 col2" >4.9323</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_4d588_row10_col0" class="data row10 col0" >3.9515</td>
#       <td id="T_4d588_row10_col1" class="data row10 col1" >6.9769</td>
#       <td id="T_4d588_row10_col2" class="data row10 col2" >4.9321</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_4d588_row11_col0" class="data row11 col0" >5.2866</td>
#       <td id="T_4d588_row11_col1" class="data row11 col1" >10.7202</td>
#       <td id="T_4d588_row11_col2" class="data row11 col2" >7.7304</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_4d588_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_4d588_row12_col0" class="data row12 col0" >14.4686</td>
#       <td id="T_4d588_row12_col1" class="data row12 col1" >44.8651</td>
#       <td id="T_4d588_row12_col2" class="data row12 col2" >27.1192</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_4d588_row13_col0" class="data row13 col0" >14.4669</td>
#       <td id="T_4d588_row13_col1" class="data row13 col1" >44.9001</td>
#       <td id="T_4d588_row13_col2" class="data row13 col2" >27.1284</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_4d588_row14_col0" class="data row14 col0" >44.5898</td>
#       <td id="T_4d588_row14_col1" class="data row14 col1" >79.3823</td>
#       <td id="T_4d588_row14_col2" class="data row14 col2" >60.1035</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_4d588_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_4d588_row15_col0" class="data row15 col0" >55.9471</td>
#       <td id="T_4d588_row15_col1" class="data row15 col1" >272.7597</td>
#       <td id="T_4d588_row15_col2" class="data row15 col2" >140.3202</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_4d588_row16_col0" class="data row16 col0" >55.6905</td>
#       <td id="T_4d588_row16_col1" class="data row16 col1" >272.6895</td>
#       <td id="T_4d588_row16_col2" class="data row16 col2" >140.2857</td>
#     </tr>
#     <tr>
#       <th id="T_4d588_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_4d588_row17_col0" class="data row17 col0" >96.6637</td>
#       <td id="T_4d588_row17_col1" class="data row17 col1" >347.8759</td>
#       <td id="T_4d588_row17_col2" class="data row17 col2" >174.0018</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7624b">
#   <caption>M=6 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7624b_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_7624b_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_7624b_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7624b_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_7624b_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_7624b_row0_col0" class="data row0 col0" >3.5016</td>
#       <td id="T_7624b_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_7624b_row0_col2" class="data row0 col2" >3.5016</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_7624b_row1_col0" class="data row1 col0" >3.5009</td>
#       <td id="T_7624b_row1_col1" class="data row1 col1" >3.5009</td>
#       <td id="T_7624b_row1_col2" class="data row1 col2" >3.5009</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_7624b_row2_col0" class="data row2 col0" >2.1899</td>
#       <td id="T_7624b_row2_col1" class="data row2 col1" >2.2142</td>
#       <td id="T_7624b_row2_col2" class="data row2 col2" >2.2012</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_7624b_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_7624b_row3_col0" class="data row3 col0" >0.9013</td>
#       <td id="T_7624b_row3_col1" class="data row3 col1" >0.9693</td>
#       <td id="T_7624b_row3_col2" class="data row3 col2" >0.9373</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_7624b_row4_col0" class="data row4 col0" >0.9018</td>
#       <td id="T_7624b_row4_col1" class="data row4 col1" >0.9698</td>
#       <td id="T_7624b_row4_col2" class="data row4 col2" >0.9376</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_7624b_row5_col0" class="data row5 col0" >0.7178</td>
#       <td id="T_7624b_row5_col1" class="data row5 col1" >0.8453</td>
#       <td id="T_7624b_row5_col2" class="data row5 col2" >0.7859</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_7624b_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_7624b_row6_col0" class="data row6 col0" >0.1000</td>
#       <td id="T_7624b_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_7624b_row6_col2" class="data row6 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_7624b_row7_col0" class="data row7 col0" >0.1000</td>
#       <td id="T_7624b_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_7624b_row7_col2" class="data row7 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_7624b_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_7624b_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_7624b_row8_col2" class="data row8 col2" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_7624b_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_7624b_row9_col0" class="data row9 col0" >3.9530</td>
#       <td id="T_7624b_row9_col1" class="data row9 col1" >6.9781</td>
#       <td id="T_7624b_row9_col2" class="data row9 col2" >4.9323</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_7624b_row10_col0" class="data row10 col0" >3.9518</td>
#       <td id="T_7624b_row10_col1" class="data row10 col1" >6.9764</td>
#       <td id="T_7624b_row10_col2" class="data row10 col2" >4.9327</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_7624b_row11_col0" class="data row11 col0" >4.8929</td>
#       <td id="T_7624b_row11_col1" class="data row11 col1" >10.0666</td>
#       <td id="T_7624b_row11_col2" class="data row11 col2" >7.1209</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_7624b_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_7624b_row12_col0" class="data row12 col0" >14.4686</td>
#       <td id="T_7624b_row12_col1" class="data row12 col1" >44.8651</td>
#       <td id="T_7624b_row12_col2" class="data row12 col2" >27.1192</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_7624b_row13_col0" class="data row13 col0" >14.4361</td>
#       <td id="T_7624b_row13_col1" class="data row13 col1" >44.9750</td>
#       <td id="T_7624b_row13_col2" class="data row13 col2" >27.1408</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_7624b_row14_col0" class="data row14 col0" >42.4868</td>
#       <td id="T_7624b_row14_col1" class="data row14 col1" >77.3898</td>
#       <td id="T_7624b_row14_col2" class="data row14 col2" >57.6805</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_7624b_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_7624b_row15_col0" class="data row15 col0" >55.9471</td>
#       <td id="T_7624b_row15_col1" class="data row15 col1" >272.7597</td>
#       <td id="T_7624b_row15_col2" class="data row15 col2" >140.3202</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_7624b_row16_col0" class="data row16 col0" >55.8028</td>
#       <td id="T_7624b_row16_col1" class="data row16 col1" >272.6842</td>
#       <td id="T_7624b_row16_col2" class="data row16 col2" >140.2942</td>
#     </tr>
#     <tr>
#       <th id="T_7624b_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_7624b_row17_col0" class="data row17 col0" >93.7290</td>
#       <td id="T_7624b_row17_col1" class="data row17 col1" >347.7539</td>
#       <td id="T_7624b_row17_col2" class="data row17 col2" >172.1640</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_1a7aa">
#   <caption>M=7 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a7aa_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_1a7aa_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_1a7aa_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a7aa_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_1a7aa_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_1a7aa_row0_col0" class="data row0 col0" >3.5016</td>
#       <td id="T_1a7aa_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_1a7aa_row0_col2" class="data row0 col2" >3.5016</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_1a7aa_row1_col0" class="data row1 col0" >3.5007</td>
#       <td id="T_1a7aa_row1_col1" class="data row1 col1" >3.5007</td>
#       <td id="T_1a7aa_row1_col2" class="data row1 col2" >3.5007</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_1a7aa_row2_col0" class="data row2 col0" >2.3383</td>
#       <td id="T_1a7aa_row2_col1" class="data row2 col1" >2.3612</td>
#       <td id="T_1a7aa_row2_col2" class="data row2 col2" >2.3484</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_1a7aa_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_1a7aa_row3_col0" class="data row3 col0" >0.9013</td>
#       <td id="T_1a7aa_row3_col1" class="data row3 col1" >0.9693</td>
#       <td id="T_1a7aa_row3_col2" class="data row3 col2" >0.9373</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_1a7aa_row4_col0" class="data row4 col0" >0.9013</td>
#       <td id="T_1a7aa_row4_col1" class="data row4 col1" >0.9698</td>
#       <td id="T_1a7aa_row4_col2" class="data row4 col2" >0.9375</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_1a7aa_row5_col0" class="data row5 col0" >0.7462</td>
#       <td id="T_1a7aa_row5_col1" class="data row5 col1" >0.8649</td>
#       <td id="T_1a7aa_row5_col2" class="data row5 col2" >0.8096</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_1a7aa_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_1a7aa_row6_col0" class="data row6 col0" >0.1000</td>
#       <td id="T_1a7aa_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_1a7aa_row6_col2" class="data row6 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_1a7aa_row7_col0" class="data row7 col0" >0.1000</td>
#       <td id="T_1a7aa_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_1a7aa_row7_col2" class="data row7 col2" >0.2940</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_1a7aa_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_1a7aa_row8_col1" class="data row8 col1" >0.0333</td>
#       <td id="T_1a7aa_row8_col2" class="data row8 col2" >0.0037</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_1a7aa_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_1a7aa_row9_col0" class="data row9 col0" >3.9530</td>
#       <td id="T_1a7aa_row9_col1" class="data row9 col1" >6.9781</td>
#       <td id="T_1a7aa_row9_col2" class="data row9 col2" >4.9323</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_1a7aa_row10_col0" class="data row10 col0" >3.9523</td>
#       <td id="T_1a7aa_row10_col1" class="data row10 col1" >6.9766</td>
#       <td id="T_1a7aa_row10_col2" class="data row10 col2" >4.9327</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_1a7aa_row11_col0" class="data row11 col0" >4.7528</td>
#       <td id="T_1a7aa_row11_col1" class="data row11 col1" >9.4960</td>
#       <td id="T_1a7aa_row11_col2" class="data row11 col2" >6.6927</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_1a7aa_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_1a7aa_row12_col0" class="data row12 col0" >14.4686</td>
#       <td id="T_1a7aa_row12_col1" class="data row12 col1" >44.8651</td>
#       <td id="T_1a7aa_row12_col2" class="data row12 col2" >27.1192</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_1a7aa_row13_col0" class="data row13 col0" >14.4397</td>
#       <td id="T_1a7aa_row13_col1" class="data row13 col1" >44.9600</td>
#       <td id="T_1a7aa_row13_col2" class="data row13 col2" >27.1325</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_1a7aa_row14_col0" class="data row14 col0" >40.8061</td>
#       <td id="T_1a7aa_row14_col1" class="data row14 col1" >75.5591</td>
#       <td id="T_1a7aa_row14_col2" class="data row14 col2" >55.7968</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_1a7aa_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_1a7aa_row15_col0" class="data row15 col0" >55.9471</td>
#       <td id="T_1a7aa_row15_col1" class="data row15 col1" >272.7597</td>
#       <td id="T_1a7aa_row15_col2" class="data row15 col2" >140.3202</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_1a7aa_row16_col0" class="data row16 col0" >55.7028</td>
#       <td id="T_1a7aa_row16_col1" class="data row16 col1" >272.6754</td>
#       <td id="T_1a7aa_row16_col2" class="data row16 col2" >140.3479</td>
#     </tr>
#     <tr>
#       <th id="T_1a7aa_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_1a7aa_row17_col0" class="data row17 col0" >89.3786</td>
#       <td id="T_1a7aa_row17_col1" class="data row17 col1" >347.5460</td>
#       <td id="T_1a7aa_row17_col2" class="data row17 col2" >170.8326</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_45628">
#   <caption>M=8 · Bloque B en el TEST · mínimo / máximo / promedio sobre las ventanas (w=30) · nivel nominal 95%</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45628_level0_col0" class="col_heading level0 col0" >minimo</th>
#       <th id="T_45628_level0_col1" class="col_heading level0 col1" >maximo</th>
#       <th id="T_45628_level0_col2" class="col_heading level0 col2" >promedio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrica</th>
#       <th class="index_name level1" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45628_level0_row0" class="row_heading level0 row0" rowspan="3">5. MPIW</th>
#       <th id="T_45628_level1_row0" class="row_heading level1 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_45628_row0_col0" class="data row0 col0" >3.5016</td>
#       <td id="T_45628_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_45628_row0_col2" class="data row0 col2" >3.5016</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row1" class="row_heading level1 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_45628_row1_col0" class="data row1 col0" >3.5006</td>
#       <td id="T_45628_row1_col1" class="data row1 col1" >3.5006</td>
#       <td id="T_45628_row1_col2" class="data row1 col2" >3.5006</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row2" class="row_heading level1 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_45628_row2_col0" class="data row2 col0" >2.4735</td>
#       <td id="T_45628_row2_col1" class="data row2 col1" >2.4993</td>
#       <td id="T_45628_row2_col2" class="data row2 col2" >2.4849</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level0_row3" class="row_heading level0 row3" rowspan="3">6. PICP puntual</th>
#       <th id="T_45628_level1_row3" class="row_heading level1 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_45628_row3_col0" class="data row3 col0" >0.9013</td>
#       <td id="T_45628_row3_col1" class="data row3 col1" >0.9693</td>
#       <td id="T_45628_row3_col2" class="data row3 col2" >0.9373</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row4" class="row_heading level1 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_45628_row4_col0" class="data row4 col0" >0.9013</td>
#       <td id="T_45628_row4_col1" class="data row4 col1" >0.9698</td>
#       <td id="T_45628_row4_col2" class="data row4 col2" >0.9375</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row5" class="row_heading level1 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_45628_row5_col0" class="data row5 col0" >0.7676</td>
#       <td id="T_45628_row5_col1" class="data row5 col1" >0.8796</td>
#       <td id="T_45628_row5_col2" class="data row5 col2" >0.8306</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level0_row6" class="row_heading level0 row6" rowspan="3">7. PICPB curva completa</th>
#       <th id="T_45628_level1_row6" class="row_heading level1 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_45628_row6_col0" class="data row6 col0" >0.1000</td>
#       <td id="T_45628_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_45628_row6_col2" class="data row6 col2" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row7" class="row_heading level1 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_45628_row7_col0" class="data row7 col0" >0.1000</td>
#       <td id="T_45628_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_45628_row7_col2" class="data row7 col2" >0.2940</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row8" class="row_heading level1 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_45628_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_45628_row8_col1" class="data row8 col1" >0.0333</td>
#       <td id="T_45628_row8_col2" class="data row8 col2" >0.0111</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level0_row9" class="row_heading level0 row9" rowspan="3">8. Winkler</th>
#       <th id="T_45628_level1_row9" class="row_heading level1 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_45628_row9_col0" class="data row9 col0" >3.9530</td>
#       <td id="T_45628_row9_col1" class="data row9 col1" >6.9781</td>
#       <td id="T_45628_row9_col2" class="data row9 col2" >4.9323</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row10" class="row_heading level1 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_45628_row10_col0" class="data row10 col0" >3.9522</td>
#       <td id="T_45628_row10_col1" class="data row10 col1" >6.9768</td>
#       <td id="T_45628_row10_col2" class="data row10 col2" >4.9325</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row11" class="row_heading level1 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_45628_row11_col0" class="data row11 col0" >4.5121</td>
#       <td id="T_45628_row11_col1" class="data row11 col1" >9.0647</td>
#       <td id="T_45628_row11_col2" class="data row11 col2" >6.3618</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level0_row12" class="row_heading level0 row12" rowspan="3">9. Winkler max promedio</th>
#       <th id="T_45628_level1_row12" class="row_heading level1 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_45628_row12_col0" class="data row12 col0" >14.4686</td>
#       <td id="T_45628_row12_col1" class="data row12 col1" >44.8651</td>
#       <td id="T_45628_row12_col2" class="data row12 col2" >27.1192</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row13" class="row_heading level1 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_45628_row13_col0" class="data row13 col0" >14.4410</td>
#       <td id="T_45628_row13_col1" class="data row13 col1" >44.9567</td>
#       <td id="T_45628_row13_col2" class="data row13 col2" >27.1279</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row14" class="row_heading level1 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_45628_row14_col0" class="data row14 col0" >39.0850</td>
#       <td id="T_45628_row14_col1" class="data row14 col1" >72.5480</td>
#       <td id="T_45628_row14_col2" class="data row14 col2" >53.9280</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level0_row15" class="row_heading level0 row15" rowspan="3">10. Winkler max peor ventana</th>
#       <th id="T_45628_level1_row15" class="row_heading level1 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_45628_row15_col0" class="data row15 col0" >55.9471</td>
#       <td id="T_45628_row15_col1" class="data row15 col1" >272.7597</td>
#       <td id="T_45628_row15_col2" class="data row15 col2" >140.3202</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row16" class="row_heading level1 row16" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_45628_row16_col0" class="data row16 col0" >55.7071</td>
#       <td id="T_45628_row16_col1" class="data row16 col1" >272.6699</td>
#       <td id="T_45628_row16_col2" class="data row16 col2" >140.3465</td>
#     </tr>
#     <tr>
#       <th id="T_45628_level1_row17" class="row_heading level1 row17" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_45628_row17_col0" class="data row17 col0" >89.5655</td>
#       <td id="T_45628_row17_col1" class="data row17 col1" >347.1668</td>
#       <td id="T_45628_row17_col2" class="data row17 col2" >168.4177</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 9. Intervalos de credibilidad: FAR contra PSBPM-FD, curva a curva
#
# Los promedios de §7 y §8 dicen *cuánto*, no *dónde*. Aquí se eligen los
# $N$ orígenes de prueba **mejor** y **peor** predichos según
# `METRICA_SEL_IC` ([CONFIG]) y se dibujan las dos bandas superpuestas sobre la
# misma curva verdadera.
#
# Es donde se ve la diferencia cualitativa que las cifras agregadas promedian: el
# IC del FAR tiene **ancho que no depende del origen** —su $\Sigma_\varepsilon$
# es la misma para todo $t$, de modo que sólo hereda la forma de $\tau$— mientras
# que la banda del PSBPM-FD sale de los cuantiles de una predictiva que sí cambia
# con el estado rezagado. En un escenario homogéneo como éste esa flexibilidad no
# tiene nada que explotar y el contraste debería ser pequeño; en los escenarios
# 2–4 es donde tendría que verse.

# %%
# Seleccion de los origenes extremos por METRICA_SEL_IC, sobre el TEST.
from model_psbp_fd.fit import normas_error_por_origen

_CLAVE_NORMA = {"mae_f": "l1", "rmse_f": "l2", "linf_medio": "linf"}
assert METRICA_SEL_IC in _CLAVE_NORMA, (
    f"METRICA_SEL_IC={METRICA_SEL_IC!r} no es una del Bloque A: "
    f"{list(_CLAVE_NORMA)}")

EXTREMOS = {}
for M in EST:
    e = EST[M]
    if e["X_pred_psbp"] is None:
        print(f"[M={M}] sin PSBPM-FD: se omite §9.")
        continue
    nm = normas_error_por_origen(X_obj_ev, e["X_pred_psbp"], grilla,
                                 pesos_tau=PESOS_TAU, verificar=False)
    serie = nm[_CLAVE_NORMA[METRICA_SEL_IC]]          # (n_orig,)
    idx_test = np.where(~es_train)[0]
    orden = idx_test[np.argsort(serie[idx_test])]
    EXTREMOS[M] = {"mejores": orden[:N_EXTREMOS],
                   "peores":  orden[-N_EXTREMOS:][::-1],
                   "serie":   serie}
    print(f"[M={M}] por {METRICA_SEL_IC} (PSBPM-FD, test):")
    print(f"    mejores t = {[int(t_orig[i]) for i in orden[:N_EXTREMOS]]}")
    print(f"    peores  t = {[int(t_orig[i]) for i in orden[-N_EXTREMOS:][::-1]]}")
# Out:
# [M=1] por rmse_f (PSBPM-FD, test):
#     mejores t = [913, 917, 854, 837, 995]
#     peores  t = [896, 886, 895, 740, 765]
# [M=2] por rmse_f (PSBPM-FD, test):
#     mejores t = [913, 917, 854, 837, 995]
#     peores  t = [896, 886, 895, 740, 765]
# [M=3] por rmse_f (PSBPM-FD, test):
#     mejores t = [913, 917, 854, 837, 995]
#     peores  t = [896, 886, 895, 740, 765]
# [M=4] por rmse_f (PSBPM-FD, test):
#     mejores t = [913, 917, 854, 837, 995]
#     peores  t = [896, 886, 895, 740, 765]
# [M=5] por rmse_f (PSBPM-FD, test):
#     mejores t = [913, 917, 854, 837, 995]
#     peores  t = [896, 886, 895, 740, 765]
# [M=6] por rmse_f (PSBPM-FD, test):
#     mejores t = [913, 917, 854, 837, 995]
#     peores  t = [896, 886, 895, 740, 765]
# [M=7] por rmse_f (PSBPM-FD, test):
#     mejores t = [913, 917, 854, 837, 995]
#     peores  t = [896, 886, 895, 740, 765]
# [M=8] por rmse_f (PSBPM-FD, test):
#     mejores t = [913, 917, 854, 837, 995]
#     peores  t = [896, 886, 895, 740, 765]

# %%
# Las dos bandas superpuestas sobre la misma curva. `plot_extractos_curvas`
# dibuja UNA banda, de modo que este contraste se arma aqui: es una vista
# especifica de esta seccion y no una primitiva reutilizable.
def _banda_por_prefijo(bandas_M, prefijo):
    for nombre in bandas_M:
        if nombre.startswith(prefijo):
            return nombre, bandas_M[nombre]
    return None, None


for M in EXTREMOS:
    e = EST[M]
    n1, b1 = _banda_por_prefijo(BANDAS[M], BANDA_A_CONTRASTAR[0])
    n2, b2 = _banda_por_prefijo(BANDAS[M], BANDA_A_CONTRASTAR[1])
    if b1 is None or b2 is None:
        print(f"[M={M}] no estan las dos bandas de BANDA_A_CONTRASTAR; se omite.")
        continue
    (li1, ls1), Xp1 = b1
    (li2, ls2), Xp2 = b2

    for etiqueta_grupo, indices in (("mejores", EXTREMOS[M]["mejores"]),
                                    ("peores",  EXTREMOS[M]["peores"])):
        fig, axes = plt.subplots(1, len(indices),
                                 figsize=(3.1 * len(indices), 3.2),
                                 sharey=True, squeeze=False)
        for ax, i in zip(axes[0], indices):
            ax.fill_between(grilla, li1[i], ls1[i], color="#1f6f8b", alpha=0.20,
                            lw=0, label=n1)
            ax.fill_between(grilla, li2[i], ls2[i], color="#c0392b", alpha=0.20,
                            lw=0, label=n2)
            ax.plot(grilla, Xp1[i], color="#1f6f8b", lw=1.3, ls="--")
            ax.plot(grilla, Xp2[i], color="#c0392b", lw=1.3)
            ax.plot(grilla, X_obj_ev[i], color="k", lw=1.6)
            cob1 = float(np.mean((X_obj_ev[i] >= li1[i]) & (X_obj_ev[i] <= ls1[i])))
            cob2 = float(np.mean((X_obj_ev[i] >= li2[i]) & (X_obj_ev[i] <= ls2[i])))
            ax.set_title(f"t={int(t_orig[i])}\ncob {cob1:.2f} / {cob2:.2f}",
                         fontsize=9)
            ax.tick_params(labelsize=7)
            ax.set_xlabel(r"$\tau$", fontsize=8)
        axes[0][0].set_ylabel(r"$X_t(\tau)$", fontsize=9)
        manijas = [
            plt.Line2D([], [], color="k", lw=1.6, label="curva verdadera"),
            plt.Line2D([], [], color="#1f6f8b", lw=1.3, ls="--", label=n1),
            plt.Line2D([], [], color="#c0392b", lw=1.3, label=n2),
        ]
        fig.legend(handles=manijas, loc="lower center", ncol=3, fontsize=8,
                   frameon=False, bbox_to_anchor=(0.5, -0.10))
        fig.suptitle(f"M={M} · {N_EXTREMOS} orígenes {etiqueta_grupo} por "
                     f"{METRICA_SEL_IC} (test) · cobertura puntual en el título",
                     fontsize=11)
        fig.tight_layout()
        fig.savefig(e["paths"]["out_report"]
                    / f"{PREFIJO + 9}_ic_contraste_{etiqueta_grupo}.png",
                    dpi=150, bbox_inches="tight")
        plt.show()

# %%
# Ancho y cobertura por origen, de cada banda, en los mismos 2N origenes.
filas_ic = []
for M in EXTREMOS:
    e = EST[M]
    for etiqueta_grupo, indices in (("mejores", EXTREMOS[M]["mejores"]),
                                    ("peores",  EXTREMOS[M]["peores"])):
        for i in indices:
            for nombre, ((li, ls), _Xp) in BANDAS[M].items():
                dentro = (X_obj_ev[i] >= li[i]) & (X_obj_ev[i] <= ls[i])
                filas_ic.append({
                    "M": M, "grupo": etiqueta_grupo, "t": int(t_orig[i]),
                    "banda": nombre,
                    f"{METRICA_SEL_IC}_PSBPM": float(EXTREMOS[M]["serie"][i]),
                    "mpiw": float(np.mean(ls[i] - li[i])),
                    "picp_puntual": float(dentro.mean()),
                    "I_t_simultaneo": float(bool(dentro.all())),
                })

ic_df = pd.DataFrame(filas_ic)
for M in EXTREMOS:
    sub = ic_df[ic_df.M == M].set_index(["grupo", "t", "banda"])
    sub.drop(columns=["M"]).to_csv(
        EST[M]["paths"]["out_report"] / f"{PREFIJO + 9}_ic_contraste_origenes.csv")
    display(sub.drop(columns=["M"]).style
            .format({f"{METRICA_SEL_IC}_PSBPM": "{:.4f}", "mpiw": "{:.4f}",
                     "picp_puntual": "{:.3f}", "I_t_simultaneo": "{:.0f}"})
            .set_caption(f"M={M} · ancho y cobertura por origen · "
                         f"I_t_simultaneo = 1 si la banda contiene la curva "
                         "ENTERA"))

print("Lectura: si el MPIW del FAR es practicamente el mismo en los origenes")
print("mejores y en los peores, es porque su ancho NO depende del origen -su")
print("Sigma_eps es la misma para todo t-. Que el del PSBPM-FD SI cambie entre")
print("grupos es la flexibilidad que el escenario 1 no le deja aprovechar.")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8f4a2">
#   <caption>M=1 · ancho y cobertura por origen · I_t_simultaneo = 1 si la banda contiene la curva ENTERA</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f4a2_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_8f4a2_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_8f4a2_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_8f4a2_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f4a2_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_8f4a2_level1_row0" class="row_heading level1 row0" rowspan="3">913</th>
#       <th id="T_8f4a2_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_8f4a2_row0_col0" class="data row0 col0" >0.3363</td>
#       <td id="T_8f4a2_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_8f4a2_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_8f4a2_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_8f4a2_row1_col0" class="data row1 col0" >0.3363</td>
#       <td id="T_8f4a2_row1_col1" class="data row1 col1" >3.5017</td>
#       <td id="T_8f4a2_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_8f4a2_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_8f4a2_row2_col0" class="data row2 col0" >0.3363</td>
#       <td id="T_8f4a2_row2_col1" class="data row2 col1" >0.8822</td>
#       <td id="T_8f4a2_row2_col2" class="data row2 col2" >0.720</td>
#       <td id="T_8f4a2_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level1_row3" class="row_heading level1 row3" rowspan="3">917</th>
#       <th id="T_8f4a2_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_8f4a2_row3_col0" class="data row3 col0" >0.3880</td>
#       <td id="T_8f4a2_row3_col1" class="data row3 col1" >3.5016</td>
#       <td id="T_8f4a2_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_8f4a2_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_8f4a2_row4_col0" class="data row4 col0" >0.3880</td>
#       <td id="T_8f4a2_row4_col1" class="data row4 col1" >3.5017</td>
#       <td id="T_8f4a2_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_8f4a2_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_8f4a2_row5_col0" class="data row5 col0" >0.3880</td>
#       <td id="T_8f4a2_row5_col1" class="data row5 col1" >0.8907</td>
#       <td id="T_8f4a2_row5_col2" class="data row5 col2" >0.693</td>
#       <td id="T_8f4a2_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level1_row6" class="row_heading level1 row6" rowspan="3">854</th>
#       <th id="T_8f4a2_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_8f4a2_row6_col0" class="data row6 col0" >0.4234</td>
#       <td id="T_8f4a2_row6_col1" class="data row6 col1" >3.5016</td>
#       <td id="T_8f4a2_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_8f4a2_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_8f4a2_row7_col0" class="data row7 col0" >0.4234</td>
#       <td id="T_8f4a2_row7_col1" class="data row7 col1" >3.5017</td>
#       <td id="T_8f4a2_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_8f4a2_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_8f4a2_row8_col0" class="data row8 col0" >0.4234</td>
#       <td id="T_8f4a2_row8_col1" class="data row8 col1" >0.9273</td>
#       <td id="T_8f4a2_row8_col2" class="data row8 col2" >0.640</td>
#       <td id="T_8f4a2_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level1_row9" class="row_heading level1 row9" rowspan="3">837</th>
#       <th id="T_8f4a2_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_8f4a2_row9_col0" class="data row9 col0" >0.4330</td>
#       <td id="T_8f4a2_row9_col1" class="data row9 col1" >3.5016</td>
#       <td id="T_8f4a2_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_8f4a2_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_8f4a2_row10_col0" class="data row10 col0" >0.4330</td>
#       <td id="T_8f4a2_row10_col1" class="data row10 col1" >3.5017</td>
#       <td id="T_8f4a2_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_8f4a2_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_8f4a2_row11_col0" class="data row11 col0" >0.4330</td>
#       <td id="T_8f4a2_row11_col1" class="data row11 col1" >0.8385</td>
#       <td id="T_8f4a2_row11_col2" class="data row11 col2" >0.640</td>
#       <td id="T_8f4a2_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level1_row12" class="row_heading level1 row12" rowspan="3">995</th>
#       <th id="T_8f4a2_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_8f4a2_row12_col0" class="data row12 col0" >0.4348</td>
#       <td id="T_8f4a2_row12_col1" class="data row12 col1" >3.5016</td>
#       <td id="T_8f4a2_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_8f4a2_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_8f4a2_row13_col0" class="data row13 col0" >0.4348</td>
#       <td id="T_8f4a2_row13_col1" class="data row13 col1" >3.5017</td>
#       <td id="T_8f4a2_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_8f4a2_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_8f4a2_row14_col0" class="data row14 col0" >0.4348</td>
#       <td id="T_8f4a2_row14_col1" class="data row14 col1" >0.9619</td>
#       <td id="T_8f4a2_row14_col2" class="data row14 col2" >0.707</td>
#       <td id="T_8f4a2_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a2_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_8f4a2_level1_row15" class="row_heading level1 row15" rowspan="3">896</th>
#       <th id="T_8f4a2_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_8f4a2_row15_col0" class="data row15 col0" >2.5577</td>
#       <td id="T_8f4a2_row15_col1" class="data row15 col1" >3.5016</td>
#       <td id="T_8f4a2_row15_col2" class="data row15 col2" >0.560</td>
# <style type="text/css">
# </style>
# <table id="T_7bfc2">
#   <caption>M=2 · ancho y cobertura por origen · I_t_simultaneo = 1 si la banda contiene la curva ENTERA</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bfc2_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_7bfc2_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_7bfc2_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_7bfc2_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bfc2_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_7bfc2_level1_row0" class="row_heading level1 row0" rowspan="3">913</th>
#       <th id="T_7bfc2_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_7bfc2_row0_col0" class="data row0 col0" >0.3364</td>
#       <td id="T_7bfc2_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_7bfc2_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_7bfc2_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_7bfc2_row1_col0" class="data row1 col0" >0.3364</td>
#       <td id="T_7bfc2_row1_col1" class="data row1 col1" >3.5017</td>
#       <td id="T_7bfc2_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_7bfc2_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_7bfc2_row2_col0" class="data row2 col0" >0.3364</td>
#       <td id="T_7bfc2_row2_col1" class="data row2 col1" >1.2725</td>
#       <td id="T_7bfc2_row2_col2" class="data row2 col2" >0.813</td>
#       <td id="T_7bfc2_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level1_row3" class="row_heading level1 row3" rowspan="3">917</th>
#       <th id="T_7bfc2_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_7bfc2_row3_col0" class="data row3 col0" >0.3880</td>
#       <td id="T_7bfc2_row3_col1" class="data row3 col1" >3.5016</td>
#       <td id="T_7bfc2_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_7bfc2_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_7bfc2_row4_col0" class="data row4 col0" >0.3880</td>
#       <td id="T_7bfc2_row4_col1" class="data row4 col1" >3.5017</td>
#       <td id="T_7bfc2_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_7bfc2_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_7bfc2_row5_col0" class="data row5 col0" >0.3880</td>
#       <td id="T_7bfc2_row5_col1" class="data row5 col1" >1.2583</td>
#       <td id="T_7bfc2_row5_col2" class="data row5 col2" >0.760</td>
#       <td id="T_7bfc2_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level1_row6" class="row_heading level1 row6" rowspan="3">854</th>
#       <th id="T_7bfc2_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_7bfc2_row6_col0" class="data row6 col0" >0.4234</td>
#       <td id="T_7bfc2_row6_col1" class="data row6 col1" >3.5016</td>
#       <td id="T_7bfc2_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_7bfc2_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_7bfc2_row7_col0" class="data row7 col0" >0.4234</td>
#       <td id="T_7bfc2_row7_col1" class="data row7 col1" >3.5017</td>
#       <td id="T_7bfc2_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_7bfc2_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_7bfc2_row8_col0" class="data row8 col0" >0.4234</td>
#       <td id="T_7bfc2_row8_col1" class="data row8 col1" >1.2468</td>
#       <td id="T_7bfc2_row8_col2" class="data row8 col2" >0.813</td>
#       <td id="T_7bfc2_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level1_row9" class="row_heading level1 row9" rowspan="3">837</th>
#       <th id="T_7bfc2_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_7bfc2_row9_col0" class="data row9 col0" >0.4333</td>
#       <td id="T_7bfc2_row9_col1" class="data row9 col1" >3.5016</td>
#       <td id="T_7bfc2_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_7bfc2_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_7bfc2_row10_col0" class="data row10 col0" >0.4333</td>
#       <td id="T_7bfc2_row10_col1" class="data row10 col1" >3.5017</td>
#       <td id="T_7bfc2_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_7bfc2_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_7bfc2_row11_col0" class="data row11 col0" >0.4333</td>
#       <td id="T_7bfc2_row11_col1" class="data row11 col1" >1.1845</td>
#       <td id="T_7bfc2_row11_col2" class="data row11 col2" >0.773</td>
#       <td id="T_7bfc2_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level1_row12" class="row_heading level1 row12" rowspan="3">995</th>
#       <th id="T_7bfc2_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_7bfc2_row12_col0" class="data row12 col0" >0.4346</td>
#       <td id="T_7bfc2_row12_col1" class="data row12 col1" >3.5016</td>
#       <td id="T_7bfc2_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_7bfc2_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_7bfc2_row13_col0" class="data row13 col0" >0.4346</td>
#       <td id="T_7bfc2_row13_col1" class="data row13 col1" >3.5017</td>
#       <td id="T_7bfc2_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_7bfc2_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_7bfc2_row14_col0" class="data row14 col0" >0.4346</td>
#       <td id="T_7bfc2_row14_col1" class="data row14 col1" >1.2739</td>
#       <td id="T_7bfc2_row14_col2" class="data row14 col2" >0.813</td>
#       <td id="T_7bfc2_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7bfc2_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_7bfc2_level1_row15" class="row_heading level1 row15" rowspan="3">896</th>
#       <th id="T_7bfc2_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_7bfc2_row15_col0" class="data row15 col0" >2.5582</td>
#       <td id="T_7bfc2_row15_col1" class="data row15 col1" >3.5016</td>
#       <td id="T_7bfc2_row15_col2" class="data row15 col2" >0.560</td>
# <style type="text/css">
# </style>
# <table id="T_e6c68">
#   <caption>M=3 · ancho y cobertura por origen · I_t_simultaneo = 1 si la banda contiene la curva ENTERA</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6c68_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_e6c68_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_e6c68_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_e6c68_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6c68_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_e6c68_level1_row0" class="row_heading level1 row0" rowspan="3">913</th>
#       <th id="T_e6c68_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_e6c68_row0_col0" class="data row0 col0" >0.3364</td>
#       <td id="T_e6c68_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_e6c68_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_e6c68_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_e6c68_row1_col0" class="data row1 col0" >0.3364</td>
#       <td id="T_e6c68_row1_col1" class="data row1 col1" >3.5014</td>
#       <td id="T_e6c68_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_e6c68_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_e6c68_row2_col0" class="data row2 col0" >0.3364</td>
#       <td id="T_e6c68_row2_col1" class="data row2 col1" >1.6076</td>
#       <td id="T_e6c68_row2_col2" class="data row2 col2" >0.920</td>
#       <td id="T_e6c68_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level1_row3" class="row_heading level1 row3" rowspan="3">917</th>
#       <th id="T_e6c68_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_e6c68_row3_col0" class="data row3 col0" >0.3874</td>
#       <td id="T_e6c68_row3_col1" class="data row3 col1" >3.5016</td>
#       <td id="T_e6c68_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_e6c68_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_e6c68_row4_col0" class="data row4 col0" >0.3874</td>
#       <td id="T_e6c68_row4_col1" class="data row4 col1" >3.5014</td>
#       <td id="T_e6c68_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_e6c68_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_e6c68_row5_col0" class="data row5 col0" >0.3874</td>
#       <td id="T_e6c68_row5_col1" class="data row5 col1" >1.5871</td>
#       <td id="T_e6c68_row5_col2" class="data row5 col2" >0.907</td>
#       <td id="T_e6c68_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level1_row6" class="row_heading level1 row6" rowspan="3">854</th>
#       <th id="T_e6c68_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_e6c68_row6_col0" class="data row6 col0" >0.4235</td>
#       <td id="T_e6c68_row6_col1" class="data row6 col1" >3.5016</td>
#       <td id="T_e6c68_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_e6c68_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_e6c68_row7_col0" class="data row7 col0" >0.4235</td>
#       <td id="T_e6c68_row7_col1" class="data row7 col1" >3.5014</td>
#       <td id="T_e6c68_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_e6c68_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_e6c68_row8_col0" class="data row8 col0" >0.4235</td>
#       <td id="T_e6c68_row8_col1" class="data row8 col1" >1.6237</td>
#       <td id="T_e6c68_row8_col2" class="data row8 col2" >0.920</td>
#       <td id="T_e6c68_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level1_row9" class="row_heading level1 row9" rowspan="3">837</th>
#       <th id="T_e6c68_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_e6c68_row9_col0" class="data row9 col0" >0.4338</td>
#       <td id="T_e6c68_row9_col1" class="data row9 col1" >3.5016</td>
#       <td id="T_e6c68_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_e6c68_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_e6c68_row10_col0" class="data row10 col0" >0.4338</td>
#       <td id="T_e6c68_row10_col1" class="data row10 col1" >3.5014</td>
#       <td id="T_e6c68_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_e6c68_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_e6c68_row11_col0" class="data row11 col0" >0.4338</td>
#       <td id="T_e6c68_row11_col1" class="data row11 col1" >1.5345</td>
#       <td id="T_e6c68_row11_col2" class="data row11 col2" >0.933</td>
#       <td id="T_e6c68_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level1_row12" class="row_heading level1 row12" rowspan="3">995</th>
#       <th id="T_e6c68_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_e6c68_row12_col0" class="data row12 col0" >0.4342</td>
#       <td id="T_e6c68_row12_col1" class="data row12 col1" >3.5016</td>
#       <td id="T_e6c68_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_e6c68_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_e6c68_row13_col0" class="data row13 col0" >0.4342</td>
#       <td id="T_e6c68_row13_col1" class="data row13 col1" >3.5014</td>
#       <td id="T_e6c68_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_e6c68_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_e6c68_row14_col0" class="data row14 col0" >0.4342</td>
#       <td id="T_e6c68_row14_col1" class="data row14 col1" >1.5936</td>
#       <td id="T_e6c68_row14_col2" class="data row14 col2" >0.920</td>
#       <td id="T_e6c68_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e6c68_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_e6c68_level1_row15" class="row_heading level1 row15" rowspan="3">896</th>
#       <th id="T_e6c68_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_e6c68_row15_col0" class="data row15 col0" >2.5579</td>
#       <td id="T_e6c68_row15_col1" class="data row15 col1" >3.5016</td>
#       <td id="T_e6c68_row15_col2" class="data row15 col2" >0.560</td>
# <style type="text/css">
# </style>
# <table id="T_efcb3">
#   <caption>M=4 · ancho y cobertura por origen · I_t_simultaneo = 1 si la banda contiene la curva ENTERA</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efcb3_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_efcb3_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_efcb3_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_efcb3_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efcb3_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_efcb3_level1_row0" class="row_heading level1 row0" rowspan="3">913</th>
#       <th id="T_efcb3_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_efcb3_row0_col0" class="data row0 col0" >0.3358</td>
#       <td id="T_efcb3_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_efcb3_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_efcb3_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_efcb3_row1_col0" class="data row1 col0" >0.3358</td>
#       <td id="T_efcb3_row1_col1" class="data row1 col1" >3.5014</td>
#       <td id="T_efcb3_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_efcb3_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_efcb3_row2_col0" class="data row2 col0" >0.3358</td>
#       <td id="T_efcb3_row2_col1" class="data row2 col1" >1.8575</td>
#       <td id="T_efcb3_row2_col2" class="data row2 col2" >0.987</td>
#       <td id="T_efcb3_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level1_row3" class="row_heading level1 row3" rowspan="3">917</th>
#       <th id="T_efcb3_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_efcb3_row3_col0" class="data row3 col0" >0.3878</td>
#       <td id="T_efcb3_row3_col1" class="data row3 col1" >3.5016</td>
#       <td id="T_efcb3_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_efcb3_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_efcb3_row4_col0" class="data row4 col0" >0.3878</td>
#       <td id="T_efcb3_row4_col1" class="data row4 col1" >3.5014</td>
#       <td id="T_efcb3_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_efcb3_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_efcb3_row5_col0" class="data row5 col0" >0.3878</td>
#       <td id="T_efcb3_row5_col1" class="data row5 col1" >1.8118</td>
#       <td id="T_efcb3_row5_col2" class="data row5 col2" >0.947</td>
#       <td id="T_efcb3_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level1_row6" class="row_heading level1 row6" rowspan="3">854</th>
#       <th id="T_efcb3_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_efcb3_row6_col0" class="data row6 col0" >0.4236</td>
#       <td id="T_efcb3_row6_col1" class="data row6 col1" >3.5016</td>
#       <td id="T_efcb3_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_efcb3_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_efcb3_row7_col0" class="data row7 col0" >0.4236</td>
#       <td id="T_efcb3_row7_col1" class="data row7 col1" >3.5014</td>
#       <td id="T_efcb3_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_efcb3_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_efcb3_row8_col0" class="data row8 col0" >0.4236</td>
#       <td id="T_efcb3_row8_col1" class="data row8 col1" >1.8596</td>
#       <td id="T_efcb3_row8_col2" class="data row8 col2" >0.960</td>
#       <td id="T_efcb3_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level1_row9" class="row_heading level1 row9" rowspan="3">837</th>
#       <th id="T_efcb3_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_efcb3_row9_col0" class="data row9 col0" >0.4335</td>
#       <td id="T_efcb3_row9_col1" class="data row9 col1" >3.5016</td>
#       <td id="T_efcb3_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_efcb3_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_efcb3_row10_col0" class="data row10 col0" >0.4335</td>
#       <td id="T_efcb3_row10_col1" class="data row10 col1" >3.5014</td>
#       <td id="T_efcb3_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_efcb3_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_efcb3_row11_col0" class="data row11 col0" >0.4335</td>
#       <td id="T_efcb3_row11_col1" class="data row11 col1" >1.7964</td>
#       <td id="T_efcb3_row11_col2" class="data row11 col2" >0.947</td>
#       <td id="T_efcb3_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level1_row12" class="row_heading level1 row12" rowspan="3">995</th>
#       <th id="T_efcb3_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_efcb3_row12_col0" class="data row12 col0" >0.4344</td>
#       <td id="T_efcb3_row12_col1" class="data row12 col1" >3.5016</td>
#       <td id="T_efcb3_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_efcb3_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_efcb3_row13_col0" class="data row13 col0" >0.4344</td>
#       <td id="T_efcb3_row13_col1" class="data row13 col1" >3.5014</td>
#       <td id="T_efcb3_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_efcb3_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_efcb3_row14_col0" class="data row14 col0" >0.4344</td>
#       <td id="T_efcb3_row14_col1" class="data row14 col1" >1.8519</td>
#       <td id="T_efcb3_row14_col2" class="data row14 col2" >0.933</td>
#       <td id="T_efcb3_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_efcb3_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_efcb3_level1_row15" class="row_heading level1 row15" rowspan="3">896</th>
#       <th id="T_efcb3_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_efcb3_row15_col0" class="data row15 col0" >2.5588</td>
#       <td id="T_efcb3_row15_col1" class="data row15 col1" >3.5016</td>
#       <td id="T_efcb3_row15_col2" class="data row15 col2" >0.560</td>
# <style type="text/css">
# </style>
# <table id="T_694dc">
#   <caption>M=5 · ancho y cobertura por origen · I_t_simultaneo = 1 si la banda contiene la curva ENTERA</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_694dc_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_694dc_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_694dc_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_694dc_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_694dc_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_694dc_level1_row0" class="row_heading level1 row0" rowspan="3">913</th>
#       <th id="T_694dc_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_694dc_row0_col0" class="data row0 col0" >0.3356</td>
#       <td id="T_694dc_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_694dc_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_694dc_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_694dc_row1_col0" class="data row1 col0" >0.3356</td>
#       <td id="T_694dc_row1_col1" class="data row1 col1" >3.5012</td>
#       <td id="T_694dc_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_694dc_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_694dc_row2_col0" class="data row2 col0" >0.3356</td>
#       <td id="T_694dc_row2_col1" class="data row2 col1" >2.0779</td>
#       <td id="T_694dc_row2_col2" class="data row2 col2" >0.987</td>
#       <td id="T_694dc_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level1_row3" class="row_heading level1 row3" rowspan="3">917</th>
#       <th id="T_694dc_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_694dc_row3_col0" class="data row3 col0" >0.3878</td>
#       <td id="T_694dc_row3_col1" class="data row3 col1" >3.5016</td>
#       <td id="T_694dc_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_694dc_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_694dc_row4_col0" class="data row4 col0" >0.3878</td>
#       <td id="T_694dc_row4_col1" class="data row4 col1" >3.5012</td>
#       <td id="T_694dc_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_694dc_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_694dc_row5_col0" class="data row5 col0" >0.3878</td>
#       <td id="T_694dc_row5_col1" class="data row5 col1" >2.0037</td>
#       <td id="T_694dc_row5_col2" class="data row5 col2" >0.987</td>
#       <td id="T_694dc_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level1_row6" class="row_heading level1 row6" rowspan="3">854</th>
#       <th id="T_694dc_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_694dc_row6_col0" class="data row6 col0" >0.4236</td>
#       <td id="T_694dc_row6_col1" class="data row6 col1" >3.5016</td>
#       <td id="T_694dc_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_694dc_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_694dc_row7_col0" class="data row7 col0" >0.4236</td>
#       <td id="T_694dc_row7_col1" class="data row7 col1" >3.5012</td>
#       <td id="T_694dc_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_694dc_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_694dc_row8_col0" class="data row8 col0" >0.4236</td>
#       <td id="T_694dc_row8_col1" class="data row8 col1" >2.0520</td>
#       <td id="T_694dc_row8_col2" class="data row8 col2" >0.973</td>
#       <td id="T_694dc_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level1_row9" class="row_heading level1 row9" rowspan="3">837</th>
#       <th id="T_694dc_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_694dc_row9_col0" class="data row9 col0" >0.4335</td>
#       <td id="T_694dc_row9_col1" class="data row9 col1" >3.5016</td>
#       <td id="T_694dc_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_694dc_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_694dc_row10_col0" class="data row10 col0" >0.4335</td>
#       <td id="T_694dc_row10_col1" class="data row10 col1" >3.5012</td>
#       <td id="T_694dc_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_694dc_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_694dc_row11_col0" class="data row11 col0" >0.4335</td>
#       <td id="T_694dc_row11_col1" class="data row11 col1" >2.0284</td>
#       <td id="T_694dc_row11_col2" class="data row11 col2" >0.947</td>
#       <td id="T_694dc_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level1_row12" class="row_heading level1 row12" rowspan="3">995</th>
#       <th id="T_694dc_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_694dc_row12_col0" class="data row12 col0" >0.4348</td>
#       <td id="T_694dc_row12_col1" class="data row12 col1" >3.5016</td>
#       <td id="T_694dc_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_694dc_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_694dc_row13_col0" class="data row13 col0" >0.4348</td>
#       <td id="T_694dc_row13_col1" class="data row13 col1" >3.5012</td>
#       <td id="T_694dc_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_694dc_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_694dc_row14_col0" class="data row14 col0" >0.4348</td>
#       <td id="T_694dc_row14_col1" class="data row14 col1" >2.0538</td>
#       <td id="T_694dc_row14_col2" class="data row14 col2" >0.987</td>
#       <td id="T_694dc_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_694dc_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_694dc_level1_row15" class="row_heading level1 row15" rowspan="3">896</th>
#       <th id="T_694dc_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_694dc_row15_col0" class="data row15 col0" >2.5583</td>
#       <td id="T_694dc_row15_col1" class="data row15 col1" >3.5016</td>
#       <td id="T_694dc_row15_col2" class="data row15 col2" >0.560</td>
# <style type="text/css">
# </style>
# <table id="T_f0a12">
#   <caption>M=6 · ancho y cobertura por origen · I_t_simultaneo = 1 si la banda contiene la curva ENTERA</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0a12_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_f0a12_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_f0a12_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_f0a12_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0a12_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_f0a12_level1_row0" class="row_heading level1 row0" rowspan="3">913</th>
#       <th id="T_f0a12_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_f0a12_row0_col0" class="data row0 col0" >0.3357</td>
#       <td id="T_f0a12_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_f0a12_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_f0a12_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_f0a12_row1_col0" class="data row1 col0" >0.3357</td>
#       <td id="T_f0a12_row1_col1" class="data row1 col1" >3.5009</td>
#       <td id="T_f0a12_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_f0a12_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_f0a12_row2_col0" class="data row2 col0" >0.3357</td>
#       <td id="T_f0a12_row2_col1" class="data row2 col1" >2.2398</td>
#       <td id="T_f0a12_row2_col2" class="data row2 col2" >0.987</td>
#       <td id="T_f0a12_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level1_row3" class="row_heading level1 row3" rowspan="3">917</th>
#       <th id="T_f0a12_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_f0a12_row3_col0" class="data row3 col0" >0.3879</td>
#       <td id="T_f0a12_row3_col1" class="data row3 col1" >3.5016</td>
#       <td id="T_f0a12_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_f0a12_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_f0a12_row4_col0" class="data row4 col0" >0.3879</td>
#       <td id="T_f0a12_row4_col1" class="data row4 col1" >3.5009</td>
#       <td id="T_f0a12_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_f0a12_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_f0a12_row5_col0" class="data row5 col0" >0.3879</td>
#       <td id="T_f0a12_row5_col1" class="data row5 col1" >2.1744</td>
#       <td id="T_f0a12_row5_col2" class="data row5 col2" >0.987</td>
#       <td id="T_f0a12_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level1_row6" class="row_heading level1 row6" rowspan="3">854</th>
#       <th id="T_f0a12_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_f0a12_row6_col0" class="data row6 col0" >0.4259</td>
#       <td id="T_f0a12_row6_col1" class="data row6 col1" >3.5016</td>
#       <td id="T_f0a12_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_f0a12_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_f0a12_row7_col0" class="data row7 col0" >0.4259</td>
#       <td id="T_f0a12_row7_col1" class="data row7 col1" >3.5009</td>
#       <td id="T_f0a12_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_f0a12_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_f0a12_row8_col0" class="data row8 col0" >0.4259</td>
#       <td id="T_f0a12_row8_col1" class="data row8 col1" >2.2070</td>
#       <td id="T_f0a12_row8_col2" class="data row8 col2" >0.973</td>
#       <td id="T_f0a12_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level1_row9" class="row_heading level1 row9" rowspan="3">837</th>
#       <th id="T_f0a12_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_f0a12_row9_col0" class="data row9 col0" >0.4329</td>
#       <td id="T_f0a12_row9_col1" class="data row9 col1" >3.5016</td>
#       <td id="T_f0a12_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_f0a12_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_f0a12_row10_col0" class="data row10 col0" >0.4329</td>
#       <td id="T_f0a12_row10_col1" class="data row10 col1" >3.5009</td>
#       <td id="T_f0a12_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_f0a12_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_f0a12_row11_col0" class="data row11 col0" >0.4329</td>
#       <td id="T_f0a12_row11_col1" class="data row11 col1" >2.1927</td>
#       <td id="T_f0a12_row11_col2" class="data row11 col2" >0.947</td>
#       <td id="T_f0a12_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level1_row12" class="row_heading level1 row12" rowspan="3">995</th>
#       <th id="T_f0a12_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_f0a12_row12_col0" class="data row12 col0" >0.4352</td>
#       <td id="T_f0a12_row12_col1" class="data row12 col1" >3.5016</td>
#       <td id="T_f0a12_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_f0a12_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_f0a12_row13_col0" class="data row13 col0" >0.4352</td>
#       <td id="T_f0a12_row13_col1" class="data row13 col1" >3.5009</td>
#       <td id="T_f0a12_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_f0a12_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_f0a12_row14_col0" class="data row14 col0" >0.4352</td>
#       <td id="T_f0a12_row14_col1" class="data row14 col1" >2.2260</td>
#       <td id="T_f0a12_row14_col2" class="data row14 col2" >0.987</td>
#       <td id="T_f0a12_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f0a12_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_f0a12_level1_row15" class="row_heading level1 row15" rowspan="3">896</th>
#       <th id="T_f0a12_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_f0a12_row15_col0" class="data row15 col0" >2.5586</td>
#       <td id="T_f0a12_row15_col1" class="data row15 col1" >3.5016</td>
#       <td id="T_f0a12_row15_col2" class="data row15 col2" >0.560</td>
# ...
#       <th id="T_a4400_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_a4400_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_a4400_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_a4400_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4400_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_a4400_level1_row0" class="row_heading level1 row0" rowspan="3">913</th>
#       <th id="T_a4400_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_a4400_row0_col0" class="data row0 col0" >0.3353</td>
#       <td id="T_a4400_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_a4400_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_a4400_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a4400_row1_col0" class="data row1 col0" >0.3353</td>
#       <td id="T_a4400_row1_col1" class="data row1 col1" >3.5007</td>
#       <td id="T_a4400_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_a4400_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a4400_row2_col0" class="data row2 col0" >0.3353</td>
#       <td id="T_a4400_row2_col1" class="data row2 col1" >2.3965</td>
#       <td id="T_a4400_row2_col2" class="data row2 col2" >0.987</td>
#       <td id="T_a4400_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level1_row3" class="row_heading level1 row3" rowspan="3">917</th>
#       <th id="T_a4400_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_a4400_row3_col0" class="data row3 col0" >0.3888</td>
#       <td id="T_a4400_row3_col1" class="data row3 col1" >3.5016</td>
#       <td id="T_a4400_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_a4400_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a4400_row4_col0" class="data row4 col0" >0.3888</td>
#       <td id="T_a4400_row4_col1" class="data row4 col1" >3.5007</td>
#       <td id="T_a4400_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_a4400_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a4400_row5_col0" class="data row5 col0" >0.3888</td>
#       <td id="T_a4400_row5_col1" class="data row5 col1" >2.3037</td>
#       <td id="T_a4400_row5_col2" class="data row5 col2" >0.987</td>
#       <td id="T_a4400_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level1_row6" class="row_heading level1 row6" rowspan="3">854</th>
#       <th id="T_a4400_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_a4400_row6_col0" class="data row6 col0" >0.4267</td>
#       <td id="T_a4400_row6_col1" class="data row6 col1" >3.5016</td>
#       <td id="T_a4400_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_a4400_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a4400_row7_col0" class="data row7 col0" >0.4267</td>
#       <td id="T_a4400_row7_col1" class="data row7 col1" >3.5007</td>
#       <td id="T_a4400_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_a4400_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a4400_row8_col0" class="data row8 col0" >0.4267</td>
#       <td id="T_a4400_row8_col1" class="data row8 col1" >2.3382</td>
#       <td id="T_a4400_row8_col2" class="data row8 col2" >0.973</td>
#       <td id="T_a4400_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level1_row9" class="row_heading level1 row9" rowspan="3">837</th>
#       <th id="T_a4400_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_a4400_row9_col0" class="data row9 col0" >0.4323</td>
#       <td id="T_a4400_row9_col1" class="data row9 col1" >3.5016</td>
#       <td id="T_a4400_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_a4400_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a4400_row10_col0" class="data row10 col0" >0.4323</td>
#       <td id="T_a4400_row10_col1" class="data row10 col1" >3.5007</td>
#       <td id="T_a4400_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_a4400_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a4400_row11_col0" class="data row11 col0" >0.4323</td>
#       <td id="T_a4400_row11_col1" class="data row11 col1" >2.3223</td>
#       <td id="T_a4400_row11_col2" class="data row11 col2" >0.947</td>
#       <td id="T_a4400_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level1_row12" class="row_heading level1 row12" rowspan="3">995</th>
#       <th id="T_a4400_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_a4400_row12_col0" class="data row12 col0" >0.4339</td>
#       <td id="T_a4400_row12_col1" class="data row12 col1" >3.5016</td>
#       <td id="T_a4400_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_a4400_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_a4400_row13_col0" class="data row13 col0" >0.4339</td>
#       <td id="T_a4400_row13_col1" class="data row13 col1" >3.5007</td>
#       <td id="T_a4400_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_a4400_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_a4400_row14_col0" class="data row14 col0" >0.4339</td>
#       <td id="T_a4400_row14_col1" class="data row14 col1" >2.3863</td>
#       <td id="T_a4400_row14_col2" class="data row14 col2" >0.987</td>
#       <td id="T_a4400_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a4400_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_a4400_level1_row15" class="row_heading level1 row15" rowspan="3">896</th>
#       <th id="T_a4400_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_a4400_row15_col0" class="data row15 col0" >2.5591</td>
#       <td id="T_a4400_row15_col1" class="data row15 col1" >3.5016</td>
#       <td id="T_a4400_row15_col2" class="data row15 col2" >0.560</td>
# <style type="text/css">
# </style>
# <table id="T_f854f">
#   <caption>M=8 · ancho y cobertura por origen · I_t_simultaneo = 1 si la banda contiene la curva ENTERA</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f854f_level0_col0" class="col_heading level0 col0" >rmse_f_PSBPM</th>
#       <th id="T_f854f_level0_col1" class="col_heading level0 col1" >mpiw</th>
#       <th id="T_f854f_level0_col2" class="col_heading level0 col2" >picp_puntual</th>
#       <th id="T_f854f_level0_col3" class="col_heading level0 col3" >I_t_simultaneo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grupo</th>
#       <th class="index_name level1" >t</th>
#       <th class="index_name level2" >banda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f854f_level0_row0" class="row_heading level0 row0" rowspan="15">mejores</th>
#       <th id="T_f854f_level1_row0" class="row_heading level1 row0" rowspan="3">913</th>
#       <th id="T_f854f_level2_row0" class="row_heading level2 row0" >FAR (IC del modelo AR)</th>
#       <td id="T_f854f_row0_col0" class="data row0 col0" >0.3355</td>
#       <td id="T_f854f_row0_col1" class="data row0 col1" >3.5016</td>
#       <td id="T_f854f_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_f854f_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level2_row1" class="row_heading level2 row1" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_f854f_row1_col0" class="data row1 col0" >0.3355</td>
#       <td id="T_f854f_row1_col1" class="data row1 col1" >3.5006</td>
#       <td id="T_f854f_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_f854f_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level2_row2" class="row_heading level2 row2" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_f854f_row2_col0" class="data row2 col0" >0.3355</td>
#       <td id="T_f854f_row2_col1" class="data row2 col1" >2.5311</td>
#       <td id="T_f854f_row2_col2" class="data row2 col2" >0.987</td>
#       <td id="T_f854f_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level1_row3" class="row_heading level1 row3" rowspan="3">917</th>
#       <th id="T_f854f_level2_row3" class="row_heading level2 row3" >FAR (IC del modelo AR)</th>
#       <td id="T_f854f_row3_col0" class="data row3 col0" >0.3889</td>
#       <td id="T_f854f_row3_col1" class="data row3 col1" >3.5016</td>
#       <td id="T_f854f_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_f854f_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level2_row4" class="row_heading level2 row4" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_f854f_row4_col0" class="data row4 col0" >0.3889</td>
#       <td id="T_f854f_row4_col1" class="data row4 col1" >3.5006</td>
#       <td id="T_f854f_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_f854f_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level2_row5" class="row_heading level2 row5" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_f854f_row5_col0" class="data row5 col0" >0.3889</td>
#       <td id="T_f854f_row5_col1" class="data row5 col1" >2.4184</td>
#       <td id="T_f854f_row5_col2" class="data row5 col2" >1.000</td>
#       <td id="T_f854f_row5_col3" class="data row5 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level1_row6" class="row_heading level1 row6" rowspan="3">854</th>
#       <th id="T_f854f_level2_row6" class="row_heading level2 row6" >FAR (IC del modelo AR)</th>
#       <td id="T_f854f_row6_col0" class="data row6 col0" >0.4273</td>
#       <td id="T_f854f_row6_col1" class="data row6 col1" >3.5016</td>
#       <td id="T_f854f_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_f854f_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level2_row7" class="row_heading level2 row7" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_f854f_row7_col0" class="data row7 col0" >0.4273</td>
#       <td id="T_f854f_row7_col1" class="data row7 col1" >3.5006</td>
#       <td id="T_f854f_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_f854f_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level2_row8" class="row_heading level2 row8" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_f854f_row8_col0" class="data row8 col0" >0.4273</td>
#       <td id="T_f854f_row8_col1" class="data row8 col1" >2.4856</td>
#       <td id="T_f854f_row8_col2" class="data row8 col2" >0.973</td>
#       <td id="T_f854f_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level1_row9" class="row_heading level1 row9" rowspan="3">837</th>
#       <th id="T_f854f_level2_row9" class="row_heading level2 row9" >FAR (IC del modelo AR)</th>
#       <td id="T_f854f_row9_col0" class="data row9 col0" >0.4323</td>
#       <td id="T_f854f_row9_col1" class="data row9 col1" >3.5016</td>
#       <td id="T_f854f_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_f854f_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level2_row10" class="row_heading level2 row10" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_f854f_row10_col0" class="data row10 col0" >0.4323</td>
#       <td id="T_f854f_row10_col1" class="data row10 col1" >3.5006</td>
#       <td id="T_f854f_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_f854f_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level2_row11" class="row_heading level2 row11" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_f854f_row11_col0" class="data row11 col0" >0.4323</td>
#       <td id="T_f854f_row11_col1" class="data row11 col1" >2.4562</td>
#       <td id="T_f854f_row11_col2" class="data row11 col2" >0.960</td>
#       <td id="T_f854f_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level1_row12" class="row_heading level1 row12" rowspan="3">995</th>
#       <th id="T_f854f_level2_row12" class="row_heading level2 row12" >FAR (IC del modelo AR)</th>
#       <td id="T_f854f_row12_col0" class="data row12 col0" >0.4336</td>
#       <td id="T_f854f_row12_col1" class="data row12 col1" >3.5016</td>
#       <td id="T_f854f_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_f854f_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level2_row13" class="row_heading level2 row13" >PSBPM-FD (IC gaussiano, mismo mecanismo)</th>
#       <td id="T_f854f_row13_col0" class="data row13 col0" >0.4336</td>
#       <td id="T_f854f_row13_col1" class="data row13 col1" >3.5006</td>
#       <td id="T_f854f_row13_col2" class="data row13 col2" >1.000</td>
#       <td id="T_f854f_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level2_row14" class="row_heading level2 row14" >PSBPM-FD (predictiva bayesiana)</th>
#       <td id="T_f854f_row14_col0" class="data row14 col0" >0.4336</td>
#       <td id="T_f854f_row14_col1" class="data row14 col1" >2.5331</td>
#       <td id="T_f854f_row14_col2" class="data row14 col2" >0.987</td>
#       <td id="T_f854f_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f854f_level0_row15" class="row_heading level0 row15" rowspan="15">peores</th>
#       <th id="T_f854f_level1_row15" class="row_heading level1 row15" rowspan="3">896</th>
#       <th id="T_f854f_level2_row15" class="row_heading level2 row15" >FAR (IC del modelo AR)</th>
#       <td id="T_f854f_row15_col0" class="data row15 col0" >2.5597</td>
#       <td id="T_f854f_row15_col1" class="data row15 col1" >3.5016</td>
#       <td id="T_f854f_row15_col2" class="data row15 col2" >0.560</td>
# Lectura: si el MPIW del FAR es practicamente el mismo en los origenes
# mejores y en los peores, es porque su ancho NO depende del origen -su
# Sigma_eps es la misma para todo t-. Que el del PSBPM-FD SI cambie entre
# grupos es la flexibilidad que el escenario 1 no le deja aprovechar.
